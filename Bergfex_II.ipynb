# %% [markdown]
# <html>
# <h1> Bergfex webscraping
# </h1>
# <body>We gather information about outdoor sport itineraries from <a href='https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page=1'> Bergfex.com </a> in the region of Bern.<br />
#     - The website displays 20 tours per page, with infos such as length, type of sport, rating, etc... <br />
#     - Most informations are provided by users.<br />
# <br />
# We then clean the data, and do a bunch of simple analysis.
# </body>
# </html>

# %% [markdown]
# <html>
# <h2> Part 1: Data scraping and cleaning
# </h2>
#
# </html>

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# initializing the future colums of our dataframe with empty lists

title = []  # Title of the tour
difficulty = []  # difficulty (easy, medium, hard)
sport = []  # Sport type (hiking, sledging, snowshoe...)
length = []  # length in km
time = []  # tour time in hours:minutes
climb = []  # positive elevation climb in m
minmax = []  # minimum and maximum altitude of the tour in m
technique = []  # technique difficulty ratings (out of 6)
fitness = []  # fitness difficulty ratings (out of 6)
total_title = [] # will help extracting the ID of the tour

# all ratings are stored together so we will need this along the way:
rating = []  # list to store technique and fitness rating info

# %%
# looping over the 10 first pages of Bergfex
# each separate tour on the page is framed by a div tag with 'touren-details'

page_number = 20  # number of pages we want to scap through

for p in range(1, (page_number+1)):
    base_link = 'https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page='
    link = base_link+str(p)  # going over p pages with numbers appended to the base link
    page = requests.get(link, timeout=5)
    print("scraped page", p)
    soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
    tours = soup.findAll('div', {'class': 'touren-detail'})  # checks for the separate tours on the page

# For each page, we loop over each tour and fill our lists with info     
    for i in range(0,len(tours)):
        tour_1 = tours[i] # tour iterating over the 20 tours of the page

        tour_title = tour_1.findAll('a' ) # this gets the title out
        title.append([info.get_text().strip() for info in tour_title])
        total_title.append(tour_title) # this gets the full tourtitle information
        
        tour_diff = tour_1.findAll('span', {'class': 'tour-difficulty'}) #tour level difficulty
        difficulty.append([info.get_text().strip() for info in tour_diff])

        tour_type = tour_1.findAll('span', {'class': 'tour-type'}) # putting type into sports (should all be hiking)
        sport.append([info.get_text().strip() for info in tour_type])

        tour_stats = tour_1.findAll('div', {'class': 'tour-stats'}) # stats has 4 info binned together
        stat_text = [info.get_text().strip() for info in tour_stats]
        length.append(stat_text[0])
        time.append(stat_text[1])
        climb.append(stat_text[2])
        minmax.append(stat_text[3])
        
        tour_rating = tour_1.find_all("div", {'class': 'tour-rating'}) # getting the rating data 
        rating.append([info for info in tour_rating])   # it's a class name so we can't get_text.
# Out:
# scraped page 1
# scraped page 2
# scraped page 3
# scraped page 4
# scraped page 5
# scraped page 6
# scraped page 7
# scraped page 8
# scraped page 9
# scraped page 10
# scraped page 11
# scraped page 12
# scraped page 13
# scraped page 14
# scraped page 15
# scraped page 16
# scraped page 17
# scraped page 18
# scraped page 19
# scraped page 20

# %%
print("number of tours collected:", len(title))
# Out:
# number of tours collected: 400

# %%
### Get the titles and IDs into a list and then a DF
links_title = []

for i in total_title:
    i = str(i)
    i = i.strip('[]')
    print(i)
    links_title.append(i)

id_df3 = pd.DataFrame(links_title)
#df_test
# Out:
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/310007,trailsummit-chrinnenhorn-t3/" title="Trailsummit Chrinnenhorn T3">Trailsummit Chrinnenhorn T3</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49274,aus-dem-diemtigtal-zum-seebergsee/" title="Aus dem Diemtigtal zum Seebergsee">Aus dem Diemtigtal zum Seebergsee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131936,panoramaweg-hasliberg/" title="Panoramaweg Hasliberg">Panoramaweg Hasliberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131157,lauterbrunnen--muerren/" title="Lauterbrunnen - Mürren">Lauterbrunnen - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/81701,von-der-saane-zum-denkmal-der-schlacht-von-laupen/" title="Von der Saane zum Denkmal der Schlacht von Laupen">Von der Saane zum Denkmal der Schlacht von Laupen</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133916,habkern--waldegg--beatenberg/" title="Habkern - Waldegg - Beatenberg">Habkern - Waldegg - Beatenberg</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/289429,winterwanderweg-justistal/" title="Winterwanderweg Justistal">Winterwanderweg Justistal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/224321,von-kirchberg-ueber-den-loberg-nach-burgdorf/" title="Von Kirchberg über den Loberg nach Burgdorf">Von Kirchberg über den Loberg nach Burgdorf</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/314647,wengen--wengernalp--kleine-scheidegg/" title="Wengen - Wengernalp - Kleine Scheidegg">Wengen - Wengernalp - Kleine Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/850700,gfw-48--botchenalp/" title="GFW 48 - Botchenalp">GFW 48 - Botchenalp</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/131673,tour-de-lhongrin/" title="Tour de l'Hongrin">Tour de l'Hongrin</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/393640,wen-dw--muerren--schilthorn--rotstockhuette--muerren/" title="WEN-DW - Mürren - Schilthorn - Rotstockhütte - Mürren">WEN-DW - Mürren - Schilthorn - Rotstockhütte - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/161251,rund-um-den-bielersee-2-tage/" title="Rund um den Bielersee (2 Tage)">Rund um den Bielersee (2 Tage)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50319,wandern-und-planschen-an-sense-und-saane/" title="Wandern und planschen an Sense und Saane">Wandern und planschen an Sense und Saane</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114203,die-vielfalt-des-oberaargaus-erwandern/" title="Die Vielfalt des Oberaargaus erwandern">Die Vielfalt des Oberaargaus erwandern</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/172138,heftig-schoenes-saxeten/" title="Heftig schönes Saxeten">Heftig schönes Saxeten</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/285370,rundtour-interlaken--weissenau--unterseen/" title="Rundtour Interlaken – Weissenau – Unterseen">Rundtour Interlaken – Weissenau – Unterseen</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156783,drei-seen-weg-mont-raimeux--perrefitte/" title="Drei-Seen-Weg: Mont Raimeux - Perrefitte">Drei-Seen-Weg: Mont Raimeux - Perrefitte</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/95872,hinterburgseeli-trail-axalp/" title="Hinterburgseeli Trail (Axalp)">Hinterburgseeli Trail (Axalp)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58074,natur-pur-am-geltenschuss/" title="Natur pur am Geltenschuss">Natur pur am Geltenschuss</a>
# <a class="h2" href="/sommer/bern-region/touren/skitour/853410,zweisimmen--chumigalm-2125-muem/" title="Zweisimmen – Chumigalm (2125 M.ü.M)">Zweisimmen – Chumigalm (2125 M.ü.M)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131699,rinderberg--hornberg--horneggli/" title="Rinderberg - Hornberg - Horneggli">Rinderberg - Hornberg - Horneggli</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131165,berghaus-maenndlenen--burglauenen/" title="Berghaus Männdlenen - Burglauenen">Berghaus Männdlenen - Burglauenen</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/172139,moraenensee-route/" title="Moränensee Route">Moränensee Route</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49177,auf-altem-passweg-zur-grossen-scheidegg/" title="Auf altem Passweg zur Grossen Scheidegg">Auf altem Passweg zur Grossen Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/75399,sentier-des-monts--mont-soleil/" title="Sentier des Monts - Mont Soleil">Sentier des Monts - Mont Soleil</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/280191,von-heiligenschwendi-auf-die-blueme/" title="Von Heiligenschwendi auf die Blueme">Von Heiligenschwendi auf die Blueme</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/131679,gstaad--lauenensee--gstaad/" title="Gstaad - Lauenensee - Gstaad">Gstaad - Lauenensee - Gstaad</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/101689,wanderung-zur-idyllischen-otti-muehle-oberwil/" title="Wanderung zur idyllischen Otti Mühle Oberwil">Wanderung zur idyllischen Otti Mühle Oberwil</a>
# <a class="h2" href="/sommer/bern-region/touren/klettersteig/260807,klettersteig-chaeligang/" title="Klettersteig Chäligang">Klettersteig Chäligang</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508320,in-der-schlucht-von-court-die-ruhe-geniessen/" title="In der Schlucht von Court die Ruhe geniessen">In der Schlucht von Court die Ruhe geniessen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49564,natur-pur-am-stadtrand/" title="Natur pur am Stadtrand">Natur pur am Stadtrand</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/900863,bergpanorama-und-sonne-pur/" title="Bergpanorama und Sonne pur">Bergpanorama und Sonne pur</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/315060,lauterbrunnen--wengen/" title="Lauterbrunnen - Wengen">Lauterbrunnen - Wengen</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/270692,jaunpass-trail/" title="Jaunpass Trail">Jaunpass Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508311,auf-den-spuren-der-juragewaesserkorrektion/" title="Auf den Spuren der Juragewässerkorrektion">Auf den Spuren der Juragewässerkorrektion</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/383162,wen-dw--lauterbrunnen--preech--wengen/" title="WEN-DW - Lauterbrunnen - Preech - Wengen">WEN-DW - Lauterbrunnen - Preech - Wengen</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131979,gibel/" title="Gibel">Gibel</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133937,zum-steinwild-am-augstmatthorn/" title="Zum Steinwild am Augstmatthorn">Zum Steinwild am Augstmatthorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/63190,route-emmenmatt--trubschachen/" title="Route Emmenmatt – Trubschachen">Route Emmenmatt – Trubschachen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/315539,first--bachalpsee--hiendertellti--grosse-scheidegg/" title="First - Bachalpsee - Hiendertellti - Grosse Scheidegg">First - Bachalpsee - Hiendertellti - Grosse Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/131766,tour-de-la-reine-sud/" title="Tour de la reine sud">Tour de la reine sud</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/264877,von-weissenburg-zur-haengebruecke-leiternweide/" title="Von Weissenburg zur Hängebrücke Leiternweide">Von Weissenburg zur Hängebrücke Leiternweide</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/316229,gipfelwanderung-zum-rauflihorn/" title="Gipfelwanderung zum Rauflihorn">Gipfelwanderung zum Rauflihorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49283,blumenparadies-an-der-montagne-de-droit/" title="Blumenparadies an der Montagne de Droit">Blumenparadies an der Montagne de Droit</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162941,grueenenbergpass--aus-dem-waldland-ins-gebiet-der-hochmoore/" title="Grüenenbergpass – aus dem Waldland ins Gebiet der Hochmoore">Grüenenbergpass – aus dem Waldland ins Gebiet der Hochmoore</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131953,schrybershoernli/" title="Schrybershörnli">Schrybershörnli</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/658360,viaberna--etappe-16/" title="ViaBerna - Etappe 16">ViaBerna - Etappe 16</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709671,schwarzgraetli/" title="Schwarzgrätli">Schwarzgrätli</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/109938,wandern-in-der-heimat-des-vogellisis-von-adelboden/" title="Wandern in der Heimat des Vogellisis von Adelboden">Wandern in der Heimat des Vogellisis von Adelboden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/562755,wen-hdw--wengen--lauterbrunnen--staubbachwasserfall/" title="WEN-HDW - Wengen - Lauterbrunnen - Staubbachwasserfall.">WEN-HDW - Wengen - Lauterbrunnen - Staubbachwasserfall.</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133924,gruenenbergpass/" title="Grünenbergpass">Grünenbergpass</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/262276,grimselpass-innertkirchen--gletsch/" title="Grimselpass: Innertkirchen - Gletsch">Grimselpass: Innertkirchen - Gletsch</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/101688,signau--eggiwil-ueche-oder-ache--so-wie-das-emmental-eben-ist/" title="Signau - Eggiwil „ueche“ oder „ache“ – so wie das Emmental eben ist">Signau - Eggiwil „ueche“ oder „ache“ – so wie das Emmental eben ist</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/59952,ueber-lichte-alpweiden-zum-vertraeumten-arnesee/" title="Über lichte Alpweiden zum verträumten Arnesee">Über lichte Alpweiden zum verträumten Arnesee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/232759,von-burgdorf-nach-solothurn/" title="Von Burgdorf nach Solothurn">Von Burgdorf nach Solothurn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508307,im-naherholungsgebiet-von-unterseen-und-interlaken/" title="Im Naherholungsgebiet von Unterseen und Interlaken">Im Naherholungsgebiet von Unterseen und Interlaken</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49120,ueber-die-sonnigen-hoehen-blasenflue-und-moosegg/" title="Über die sonnigen Höhen Blasenflue und Moosegg">Über die sonnigen Höhen Blasenflue und Moosegg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/486923,von-der-lueg-nach-affoltern-ie/" title="Von der Lueg nach Affoltern i.E.">Von der Lueg nach Affoltern i.E.</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49314,ueber-sanfte-hoehen-zur-150-gipfel-sicht/" title="Über sanfte Höhen zur 150-Gipfel-Sicht!">Über sanfte Höhen zur 150-Gipfel-Sicht!</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50213,rellerli--zum-beliebten-ausflugsberg/" title="Rellerli - Zum beliebten Ausflugsberg">Rellerli - Zum beliebten Ausflugsberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162704,vom-klosterdorf-rueeggisberg-ins-guerbetal/" title="Vom Klosterdorf Rüeggisberg ins Gürbetal">Vom Klosterdorf Rüeggisberg ins Gürbetal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/309487,von-adelboden-zur-lohnerhuette/" title="Von Adelboden zur Lohnerhütte">Von Adelboden zur Lohnerhütte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51621,durch-eine-eindrueckliche-klus/" title="Durch eine eindrückliche Klus">Durch eine eindrückliche Klus</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/294666,wanderweg-zum-fondue-huettli-chessler/" title="Wanderweg zum Fondue Hüttli Chessler">Wanderweg zum Fondue Hüttli Chessler</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/522405,first--waldspitz--bort-nr-51/" title="First – Waldspitz – Bort (Nr. 51)">First – Waldspitz – Bort (Nr. 51)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131820,eiger-trail/" title="Eiger Trail">Eiger Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/59079,winterwanderweg-hoerelirundweg-adelboden/" title="Winterwanderweg Hörelirundweg (Adelboden)">Winterwanderweg Hörelirundweg (Adelboden)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/175676,vom-grimselpass-auf-das-sidelhorn/" title="Vom Grimselpass auf das Sidelhorn">Vom Grimselpass auf das Sidelhorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49181,zu-james-bonds-piz-gloria/" title="Zu James Bonds Piz Gloria">Zu James Bonds Piz Gloria</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/532165,sparenmoos--site-alp--sparenmoos/" title="Sparenmoos - Site Alp - Sparenmoos">Sparenmoos - Site Alp - Sparenmoos</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49332,sonnige-hoehe--sagenumwobene-schlucht/" title="Sonnige Höhe – sagenumwobene Schlucht">Sonnige Höhe – sagenumwobene Schlucht</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/525056,swiss-trail-tour-lenk-strecke-freitag-2020/" title="Swiss Trail Tour Lenk, Strecke Freitag, 2020">Swiss Trail Tour Lenk, Strecke Freitag, 2020</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50431,auf-dem-jurahoehenweg/" title="Auf dem Jurahöhenweg">Auf dem Jurahöhenweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/553952,wen-dw--stechelberg--schmadrihuette--stechelberg/" title="WEN-DW - Stechelberg - Schmadrihütte - Stechelberg">WEN-DW - Stechelberg - Schmadrihütte - Stechelberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/149720,jungfrautrek/" title="Jungfrautrek">Jungfrautrek</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/536612,der-winter-geheimtipp-trail-zum-faulhorn-w5/" title="Der Winter Geheimtipp Trail zum Faulhorn W5">Der Winter Geheimtipp Trail zum Faulhorn W5</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/147745,flueeweg-burgdorf/" title="Flüeweg Burgdorf">Flüeweg Burgdorf</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/455701,rund-um-den-stauweiher-spiez/" title="Rund um den Stauweiher Spiez">Rund um den Stauweiher Spiez</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/131614,blumenweg-horneggli-rundwanderung/" title="Blumenweg Horneggli (Rundwanderung)">Blumenweg Horneggli (Rundwanderung)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49198,auf-dem-terrassenweg-von-muensingen-nach-thun/" title="Auf dem Terrassenweg von Münsingen nach Thun">Auf dem Terrassenweg von Münsingen nach Thun</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162745,montagne-du-droit--erlebnis-sonnenenergieberg/" title="Montagne du Droit - Erlebnis Sonnen(energie)berg">Montagne du Droit - Erlebnis Sonnen(energie)berg</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/311562,gantrisch-fribourg-weg-rueeggisberg--schwarzenburg/" title="Gantrisch-Fribourg-Weg: Rüeggisberg - Schwarzenburg">Gantrisch-Fribourg-Weg: Rüeggisberg - Schwarzenburg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/157952,vom-urbachtal-zur-gaulihuette/" title="Vom Urbachtal zur Gaulihütte">Vom Urbachtal zur Gaulihütte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/54824,bergeinsamkeit-am-obersteinberg/" title="Bergeinsamkeit am Obersteinberg">Bergeinsamkeit am Obersteinberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162927,auf-dem-grenzpfad-napfbergland/" title="Auf dem Grenzpfad Napfbergland">Auf dem Grenzpfad Napfbergland</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/552524,spiezer-kraftort-wanderung-auf-den-hondrichhuegel/" title="Spiezer Kraftort-Wanderung auf den Hondrichhügel">Spiezer Kraftort-Wanderung auf den Hondrichhügel</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/315064,zweiluetschinen--lauterbrunnen/" title="Zweilütschinen - Lauterbrunnen">Zweilütschinen - Lauterbrunnen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131612,gstaad--oberbort--turbach--tuerli--lauenen/" title="Gstaad - Oberbort - Turbach - Türli - Lauenen">Gstaad - Oberbort - Turbach - Türli - Lauenen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49258,auf-dem-aare-uferweg-durch-die-elfenau/" title="Auf dem Aare-Uferweg durch die Elfenau">Auf dem Aare-Uferweg durch die Elfenau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49220,hoehenweg-mit-ausserordentlicher-hochalpen-sicht/" title="Höhenweg mit ausserordentlicher Hochalpen-Sicht">Höhenweg mit ausserordentlicher Hochalpen-Sicht</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/294660,gstaad-wasserngrat-turnels-gstaad-nr-25/" title="Gstaad-Wasserngrat-Turnels-Gstaad (Nr. 25)">Gstaad-Wasserngrat-Turnels-Gstaad (Nr. 25)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114202,schuepberg--vorgarten-der-agglomeration/" title="Schüpberg - Vorgarten der Agglomeration">Schüpberg - Vorgarten der Agglomeration</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/744917,blausee/" title="Blausee">Blausee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/70037,ueber-die-buetschelegg/" title="Über die Bütschelegg">Über die Bütschelegg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50187,auf-der-sonnenterrasse-beatenberg/" title="Auf der Sonnenterrasse Beatenberg">Auf der Sonnenterrasse Beatenberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/870928,via-alpina--etappe-14-kandersteg--adelboden/" title="Via Alpina - Etappe 14 Kandersteg - Adelboden">Via Alpina - Etappe 14 Kandersteg - Adelboden</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/97940,winterwanderweg-chrindi--oberbaergli--chrindi-stockhorn/" title="Winterwanderweg Chrindi - Oberbärgli - Chrindi (Stockhorn)">Winterwanderweg Chrindi - Oberbärgli - Chrindi (Stockhorn)</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309993,trailsummit-schreckhornhuette-t4/" title="Trailsummit Schreckhornhütte  T4">Trailsummit Schreckhornhütte  T4</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49186,hoehenwanderung-ueber-den-churzenberg/" title="Höhenwanderung über den Churzenberg">Höhenwanderung über den Churzenberg</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/297108,windegg--chrutmettli--axalp/" title="Windegg - Chrutmettli - Axalp">Windegg - Chrutmettli - Axalp</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/875937,schlittelweg-aeschiried-mit-grandioser-aussicht-hoch-ueber-dem-thunersee/" title="Schlittelweg Aeschiried mit grandioser Aussicht hoch über dem Thunersee">Schlittelweg Aeschiried mit grandioser Aussicht hoch über dem Thunersee</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/59115,winterwanderweg-beatenberg-waldegg--habkern/" title="Winterwanderweg Beatenberg/Waldegg - Habkern">Winterwanderweg Beatenberg/Waldegg - Habkern</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129224,von-der-engstligenalp-zur-iffigenalp/" title="Von der Engstligenalp zur Iffigenalp">Von der Engstligenalp zur Iffigenalp</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/63669,route-bort--grindelwald/" title="Route Bort – Grindelwald">Route Bort – Grindelwald</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131816,panorama-trail/" title="Panorama Trail">Panorama Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131979,gibel/" title="Gibel">Gibel</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709661,alpschelenhubel/" title="Alpschelenhubel">Alpschelenhubel</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/131913,lauberhorn-loop--kleine-scheidegg-nr-4/" title="Lauberhorn Loop - Kleine Scheidegg (Nr. 4)">Lauberhorn Loop - Kleine Scheidegg (Nr. 4)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/526846,von-belp-ueber-den-belpberg-nach-kirchdorf/" title="Von Belp über den Belpberg nach Kirchdorf">Von Belp über den Belpberg nach Kirchdorf</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49192,wo-die-wehrli-knaben-ihr-abendlied-sangen/" title="Wo die Wehrli-Knaben ihr Abendlied sangen">Wo die Wehrli-Knaben ihr Abendlied sangen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508326,auf-dem-blumenweg-zum-bachsee/" title="Auf dem Blumenweg zum Bachsee">Auf dem Blumenweg zum Bachsee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709662,biberg/" title="Biberg">Biberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/864928,gfw-54--baerzelistagswanderung-2022/" title="GFW 54 - Bärzelistagswanderung 2022">GFW 54 - Bärzelistagswanderung 2022</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/160861,familien-schneeschuhtour-auf-sunnbueel/" title="Familien-Schneeschuhtour auf Sunnbüel">Familien-Schneeschuhtour auf Sunnbüel</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50144,den-firnfeldern-entgegen/" title="Den Firnfeldern entgegen">Den Firnfeldern entgegen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50395,aus-dem-anker-dorf-ins-aare-staedtchen/" title="Aus dem «Anker-Dorf» ins Aare-Städtchen">Aus dem «Anker-Dorf» ins Aare-Städtchen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/617761,sieben-hengste/" title="Sieben Hengste">Sieben Hengste</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/131935,sherlock-holmes-weg/" title="Sherlock Holmes Weg">Sherlock Holmes Weg</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/129268,von-nods-auf-den-chasseral/" title="Von Nods auf den Chasseral">Von Nods auf den Chasseral</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/133944,schnitzlerweg/" title="Schnitzlerweg">Schnitzlerweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51618,ueber-graitery-und-oberdoerferberg/" title="Über Graitery und Oberdörferberg">Über Graitery und Oberdörferberg</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/522405,first--waldspitz--bort-nr-51/" title="First – Waldspitz – Bort (Nr. 51)">First – Waldspitz – Bort (Nr. 51)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131804,chaenelegg-trail/" title="Chänelegg Trail">Chänelegg Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50388,von-alp-zu-alp-hoch-ueber-dem-hasliberg/" title="Von Alp zu Alp, hoch über dem Hasliberg">Von Alp zu Alp, hoch über dem Hasliberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133938,alp-botchen--kulturlandschaftspreis-2014/" title="Alp Botchen - Kulturlandschaftspreis 2014">Alp Botchen - Kulturlandschaftspreis 2014</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133913,brienzersee-loop/" title="Brienzersee Loop">Brienzersee Loop</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114238,treichelschmiede-in-oberbalm/" title="Treichelschmiede in Oberbalm">Treichelschmiede in Oberbalm</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/361145,wen-dw--eigertrail--eigergletschertrail/" title="WEN-DW - Eigertrail - Eigergletschertrail">WEN-DW - Eigertrail - Eigergletschertrail</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/53598,murmeli-trail/" title="Murmeli Trail">Murmeli Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48766,zur-tuefelsburdi-auf-dem-jolimont/" title="Zur Tüfelsburdi auf dem Jolimont">Zur Tüfelsburdi auf dem Jolimont</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/97591,schlittelweg-maennlichen--hollenstein-grindelwald/" title="Schlittelweg Männlichen - Hollenstein (Grindelwald)">Schlittelweg Männlichen - Hollenstein (Grindelwald)</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309494,schwendibiel-runde-nr-12/" title="Schwendibiel Runde Nr. 12">Schwendibiel Runde Nr. 12</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/398534,von-kandersteg-ueber-die-gemmi-nach-leukerbad/" title="Von Kandersteg über die Gemmi nach Leukerbad">Von Kandersteg über die Gemmi nach Leukerbad</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/288423,grosse-scheidegg--schwarzwaldalp/" title="Grosse Scheidegg - Schwarzwaldalp">Grosse Scheidegg - Schwarzwaldalp</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/286179,schlittelspass-leiterli--stoss/" title="Schlittelspass Leiterli – Stoss">Schlittelspass Leiterli – Stoss</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/471934,von-olten-nach-grenchen/" title="Von Olten nach Grenchen">Von Olten nach Grenchen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162902,von-sparenmoos-ueber-den-rellerligrat/" title="Von Sparenmoos über den Rellerligrat">Von Sparenmoos über den Rellerligrat</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131951,axalphorn/" title="Axalphorn">Axalphorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709666,heuberg-oeschinensee/" title="Heuberg Oeschinensee">Heuberg Oeschinensee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/161251,rund-um-den-bielersee-2-tage/" title="Rund um den Bielersee (2 Tage)">Rund um den Bielersee (2 Tage)</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/172178,panoramabike-tour--habkern-bis-thun/" title="Panoramabike Tour - Habkern bis Thun">Panoramabike Tour - Habkern bis Thun</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/314647,wengen--wengernalp--kleine-scheidegg/" title="Wengen - Wengernalp - Kleine Scheidegg">Wengen - Wengernalp - Kleine Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49176,wilder-uebergang-vom-gadmertal-ins-haslital/" title="Wilder Übergang vom Gadmertal ins Haslital">Wilder Übergang vom Gadmertal ins Haslital</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/717235,zweisimmen--oey-diemtigen--zwischenflueh--seebergsee--meieberg--zweisimmen/" title="Zweisimmen - Oey Diemtigen - Zwischenflüh - Seebergsee - Meieberg - Zweisimmen">Zweisimmen - Oey Diemtigen - Zwischenflüh - Seebergsee - Meieberg - Zweisimmen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50212,alpwanderung-hoch-ueber-dem-arnesee/" title="Alpwanderung hoch über dem Arnesee">Alpwanderung hoch über dem Arnesee</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/682833,pure-natur/" title="Pure Natur">Pure Natur</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49225,wo-die-eislawinen-von-der-jungfrau-niederdonnern/" title="Wo die Eislawinen von der Jungfrau niederdonnern">Wo die Eislawinen von der Jungfrau niederdonnern</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51087,schaeumendes-wildwasser-im-kiental/" title="Schäumendes Wildwasser im Kiental">Schäumendes Wildwasser im Kiental</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508334,ins-urtuemliche-gasteretal/" title="Ins urtümliche Gasteretal">Ins urtümliche Gasteretal</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/172141,boedeli-route/" title="Bödeli Route">Bödeli Route</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/256470,ueber-die-wilde-seite-auf-die-planplatten/" title="Über die wilde Seite auf die Planplatten">Über die wilde Seite auf die Planplatten</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/744927,loetschberg-panoramaweg/" title="Lötschberg-Panoramaweg">Lötschberg-Panoramaweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/232759,von-burgdorf-nach-solothurn/" title="Von Burgdorf nach Solothurn">Von Burgdorf nach Solothurn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129327,vom-lauenensee-zur-geltenhuette/" title="Vom Lauenensee zur Geltenhütte">Vom Lauenensee zur Geltenhütte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/616579,von-saanen-via-rellerligrat-und-hundsruegg-nach-jaunpass/" title="Von Saanen via Rellerligrat und Hundsrügg nach Jaunpass">Von Saanen via Rellerligrat und Hundsrügg nach Jaunpass</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/131681,truetlisberg-bike-nr-891-gstaad--lauenen--truetlisberg--turbach--gstaad/" title="Trütlisberg Bike Nr. 891: Gstaad - Lauenen - Trütlisberg - Turbach - Gstaad">Trütlisberg Bike Nr. 891: Gstaad - Lauenen - Trütlisberg - Turbach - Gstaad</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508311,auf-den-spuren-der-juragewaesserkorrektion/" title="Auf den Spuren der Juragewässerkorrektion">Auf den Spuren der Juragewässerkorrektion</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/59115,winterwanderweg-beatenberg-waldegg--habkern/" title="Winterwanderweg Beatenberg/Waldegg - Habkern">Winterwanderweg Beatenberg/Waldegg - Habkern</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/158678,kemmeriboden-trail/" title="Kemmeriboden-Trail">Kemmeriboden-Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50972,grandiose-aussicht-ueber-dem-aaretal/" title="Grandiose Aussicht über dem Aaretal">Grandiose Aussicht über dem Aaretal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49173,faszination-grimselgebiet/" title="Faszination Grimselgebiet">Faszination Grimselgebiet</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49313,auf-der-alten-poststrasse-vom-langete-tal-ins-lueg-gebiet/" title="Auf der alten Poststrasse vom Langete-Tal ins Lueg-Gebiet">Auf der alten Poststrasse vom Langete-Tal ins Lueg-Gebiet</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51087,schaeumendes-wildwasser-im-kiental/" title="Schäumendes Wildwasser im Kiental">Schäumendes Wildwasser im Kiental</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508317,viel-erleben--kurz-wandern/" title="Viel erleben – kurz wandern">Viel erleben – kurz wandern</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/49027,winteridylle-auf-dem-tschaette-rundweg/" title="Winteridylle auf dem Tschätte-Rundweg">Winteridylle auf dem Tschätte-Rundweg</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/296921,von-first-auf-das-faulhorn/" title="Von First auf das Faulhorn">Von First auf das Faulhorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51170,im-faermeltal--mit-der-natur-auf-du-und-du/" title="Im Färmeltal – mit der Natur «auf du und du»">Im Färmeltal – mit der Natur «auf du und du»</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/67826,ins-naturschutzgebiet-gelten-iffigen/" title="Ins Naturschutzgebiet Gelten–Iffigen">Ins Naturschutzgebiet Gelten–Iffigen</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/311562,gantrisch-fribourg-weg-rueeggisberg--schwarzenburg/" title="Gantrisch-Fribourg-Weg: Rüeggisberg - Schwarzenburg">Gantrisch-Fribourg-Weg: Rüeggisberg - Schwarzenburg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51090,rund-um-bern--auf-den-chutzeturm/" title="Rund um Bern - auf den Chutzeturm">Rund um Bern - auf den Chutzeturm</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/744974,hohtuerli-2778-m/" title="Hohtürli 2778 m">Hohtürli 2778 m</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/749188,gruetschalp--winteregg--muerren-1h30/" title="Grütschalp - Winteregg - Mürren (1h30)">Grütschalp - Winteregg - Mürren (1h30)</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/301337,panorama-bergwanderung-grimmiwasser/" title="Panorama-Bergwanderung Grimmiwasser">Panorama-Bergwanderung Grimmiwasser</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51010,ueber-die-scheidegg-ins-simmental/" title="Über die Scheidegg ins Simmental">Über die Scheidegg ins Simmental</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/182392,rundtour-mettlenalp--staechelegg--napf/" title="Rundtour Mettlenalp – Stächelegg – Napf">Rundtour Mettlenalp – Stächelegg – Napf</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/272876,saanersloch-run/" title="Saanersloch Run">Saanersloch Run</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114206,zuoberst-im-langetetal/" title="Zuoberst im Langetetal">Zuoberst im Langetetal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/101685,wandern-dort-wo-das-vreneli-ab-em-guggisberg-gelebt-hat/" title="Wandern dort, wo das -Vreneli ab em Guggisberg- gelebt hat">Wandern dort, wo das -Vreneli ab em Guggisberg- gelebt hat</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162696,wo-die-heimiswiler-ihren-sonntagsspaziergang-unternehmen/" title="Wo die Heimiswiler ihren Sonntagsspaziergang unternehmen">Wo die Heimiswiler ihren Sonntagsspaziergang unternehmen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51012,durch-das-schwarzenburgerland/" title="Durch das Schwarzenburgerland">Durch das Schwarzenburgerland</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/526912,alpiglen-brandegg-eiger-run-nr-64a--direkt/" title="Alpiglen-Brandegg «Eiger Run» (Nr. 64a - Direkt)">Alpiglen-Brandegg «Eiger Run» (Nr. 64a - Direkt)</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/288417,alpiglen-brandegg-eiger-run-nr-64/" title="Alpiglen-Brandegg «Eiger Run» (Nr. 64)">Alpiglen-Brandegg «Eiger Run» (Nr. 64)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/744918,hoeh/" title="Höh">Höh</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49185,wo-emmental-und-berner-oberland-sich-treffen/" title="Wo Emmental und Berner Oberland sich treffen">Wo Emmental und Berner Oberland sich treffen</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/53488,alpenbockweg-oey/" title="Alpenbockweg Oey">Alpenbockweg Oey</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/301337,panorama-bergwanderung-grimmiwasser/" title="Panorama-Bergwanderung Grimmiwasser">Panorama-Bergwanderung Grimmiwasser</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133083,adelboden--cholerenschlucht--retour/" title="Adelboden - Cholerenschlucht - retour">Adelboden - Cholerenschlucht - retour</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48799,moosegg-inbegriff-von-aussicht-und-gastlichkeit/" title="Moosegg: Inbegriff von Aussicht und Gastlichkeit">Moosegg: Inbegriff von Aussicht und Gastlichkeit</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129253,von-frutigen-zur-haengebruecke-hostalde/" title="Von Frutigen zur Hängebrücke Hostalde">Von Frutigen zur Hängebrücke Hostalde</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50425,an-stolzen-bauernsitzen-vorueber-durch-den-suedlichen-oberaargau/" title="An stolzen Bauernsitzen vorüber durch den südlichen Oberaargau">An stolzen Bauernsitzen vorüber durch den südlichen Oberaargau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49174,hoehenwanderung-zur-engstlenalp/" title="Höhenwanderung zur Engstlenalp">Höhenwanderung zur Engstlenalp</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51295,weite-alpen--herrliche-aussicht/" title="Weite Alpen – herrliche Aussicht">Weite Alpen – herrliche Aussicht</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/183373,von-corgemont-zur-schokoladefabrik-nach-courtelary/" title="Von Corgémont zur Schokoladefabrik nach Courtelary">Von Corgémont zur Schokoladefabrik nach Courtelary</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/72257,rund-ums-cheibehorn-am-stockhorn/" title="Rund ums Cheibehorn am Stockhorn">Rund ums Cheibehorn am Stockhorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51170,im-faermeltal--mit-der-natur-auf-du-und-du/" title="Im Färmeltal – mit der Natur «auf du und du»">Im Färmeltal – mit der Natur «auf du und du»</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49039,vom-wasserschloss-ins-auen-idyll/" title="Vom Wasserschloss ins Auen-Idyll">Vom Wasserschloss ins Auen-Idyll</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/60580,gantrisch-panoramaweg/" title="Gantrisch panorama trail">Gantrisch panorama trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/455708,alpiner-baenkli-rundweg/" title="Alpiner Bänkli-Rundweg">Alpiner Bänkli-Rundweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/358901,rundwanderung-von-wengen-zum-leithorn/" title="Rundwanderung von Wengen zum Leithorn">Rundwanderung von Wengen zum Leithorn</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156763,berner-oberlaender-weg-merligen--thun-variante-b/" title="Berner-Oberländer-Weg: Merligen - Thun (Variante B)">Berner-Oberländer-Weg: Merligen - Thun (Variante B)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/49974,ramslauenen-trail--kiental/" title="Ramslauenen Trail - Kiental">Ramslauenen Trail - Kiental</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/358899,fahrt-zur-gruetschalp-wanderung-nach-muerren-ueber-den-mountain-view-trail/" title="Fahrt zur Grütschalp, Wanderung nach Mürren über den Mountain View Trail">Fahrt zur Grütschalp, Wanderung nach Mürren über den Mountain View Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/563594,wen-hdw--holenstein--oepfelchueechliweg--brandegg/" title="WEN-HDW - Holenstein - Öpfelchüechliweg - Brandegg">WEN-HDW - Holenstein - Öpfelchüechliweg - Brandegg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/289899,von-der-gruetschalp-nach-muerren/" title="Von der Grütschalp nach Mürren">Von der Grütschalp nach Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49286,zum-aussichtsreichen-berg-ohne-namen/" title="Zum aussichtsreichen «Berg ohne Namen»">Zum aussichtsreichen «Berg ohne Namen»</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508353,ueber-den-belpberg/" title="Über den Belpberg">Über den Belpberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131835,gibelweg/" title="Gibelweg">Gibelweg</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/290497,dorfrunde--nr1/" title="Dorfrunde - Nr1">Dorfrunde - Nr1</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/84519,auf-den-bantiger-der-stadtnahe-aussichtsberg/" title="Auf den Bantiger, der Stadtnahe Aussichtsberg">Auf den Bantiger, der Stadtnahe Aussichtsberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/304129,durch-den-bremgartenwald-nach-bern-bethlehem/" title="Durch den Bremgartenwald nach Bern-Bethlehem">Durch den Bremgartenwald nach Bern-Bethlehem</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/156906,berner-oberland-weg-bruenigpass--amsoldingen/" title="Berner Oberland Weg: Brünigpass - Amsoldingen">Berner Oberland Weg: Brünigpass - Amsoldingen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/300855,aussichtsreiche-wanderung-aufs-baederhorn/" title="Aussichtsreiche Wanderung aufs Bäderhorn">Aussichtsreiche Wanderung aufs Bäderhorn</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/131673,tour-de-lhongrin/" title="Tour de l'Hongrin">Tour de l'Hongrin</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/348119,schoenried--rellerli--grossi-vorschess--bergmatte--schoenried/" title="Schönried – Rellerli – Grossi Vorschess – Bergmatte - Schönried">Schönried – Rellerli – Grossi Vorschess – Bergmatte - Schönried</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133094,gsuerweg/" title="Gsürweg">Gsürweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/573706,die-3-stein-wanderung-im-oberaargau/" title="Die 3-Stein-Wanderung im Oberaargau">Die 3-Stein-Wanderung im Oberaargau</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/131770,koenigsrunde-nord/" title="Königsrunde Nord">Königsrunde Nord</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/62318,vom-ruedihus-zur-doldenhornhuette-sac/" title="Vom Ruedihus zur Doldenhornhütte SAC">Vom Ruedihus zur Doldenhornhütte SAC</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51010,ueber-die-scheidegg-ins-simmental/" title="Über die Scheidegg ins Simmental">Über die Scheidegg ins Simmental</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48766,zur-tuefelsburdi-auf-dem-jolimont/" title="Zur Tüfelsburdi auf dem Jolimont">Zur Tüfelsburdi auf dem Jolimont</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133924,gruenenbergpass/" title="Grünenbergpass">Grünenbergpass</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162918,grenz-und-gratwanderung-im-herzen-der-schweiz/" title="Grenz- und Gratwanderung im Herzen der Schweiz">Grenz- und Gratwanderung im Herzen der Schweiz</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709670,oeschinenalp--under--oberbaergli/" title="Oeschinenalp / Under-&amp; Oberbärgli">Oeschinenalp / Under-&amp; Oberbärgli</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/267538,von-boltigen-auf-die-mittagfluh/" title="Von Boltigen auf die Mittagfluh">Von Boltigen auf die Mittagfluh</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/67766,route-worb--walkringen/" title="Route Worb – Walkringen">Route Worb – Walkringen</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/93346,sulwald-trail--isenfluh/" title="Sulwald Trail - Isenfluh">Sulwald Trail - Isenfluh</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162914,wandern-im-angesicht-von-eiger-moench-und-jungfrau/" title="Wandern im Angesicht von Eiger, Mönch und Jungfrau">Wandern im Angesicht von Eiger, Mönch und Jungfrau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/267553,von-den-simmenfaellen-zu-den-siebenbrunnen/" title="Von den Simmenfällen zu den Siebenbrunnen">Von den Simmenfällen zu den Siebenbrunnen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49192,wo-die-wehrli-knaben-ihr-abendlied-sangen/" title="Wo die Wehrli-Knaben ihr Abendlied sangen">Wo die Wehrli-Knaben ihr Abendlied sangen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49121,auf-dem-alten-maeritweg-in-die-kornkammer-des-bernbiets/" title="Auf dem alten Märitweg in die Kornkammer des Bernbiets">Auf dem alten Märitweg in die Kornkammer des Bernbiets</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/573676,wen-dw--marmottenwandeling-met-grindelwaldbus/" title="WEN-DW - Marmottenwandeling met GrindelwaldBus">WEN-DW - Marmottenwandeling met GrindelwaldBus</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/749188,gruetschalp--winteregg--muerren-1h30/" title="Grütschalp - Winteregg - Mürren (1h30)">Grütschalp - Winteregg - Mürren (1h30)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162912,hoehenwanderung-im-angesicht-des-wetterhorns/" title="Höhenwanderung im Angesicht des Wetterhorns">Höhenwanderung im Angesicht des Wetterhorns</a>
# <a class="h2" href="/sommer/bern-region/touren/hochtour/14760,hockenhorntour-ab-kandersteg/" title="Hockenhorn Hike (from Kandersteg)">Hockenhorn Hike (from Kandersteg)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50184,auf-dem-panorama-hoehenweg-stockhorn-gantrisch/" title="Auf dem Panorama-Höhenweg Stockhorn–Gantrisch">Auf dem Panorama-Höhenweg Stockhorn–Gantrisch</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/744974,hohtuerli-2778-m/" title="Hohtürli 2778 m">Hohtürli 2778 m</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/131899,bachalpsee-loop-trail-grindelwald-nr-1/" title="Bachalpsee Loop Trail Grindelwald (Nr. 1)">Bachalpsee Loop Trail Grindelwald (Nr. 1)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50181,ueber-den-gurbsgrat/" title="Über den Gurbsgrat">Über den Gurbsgrat</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/129248,grimmimutz-erlebnisweg/" title="Grimmimutz-Erlebnisweg">Grimmimutz-Erlebnisweg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/292891,albert-schweitzer-weg/" title="Albert Schweitzer Weg">Albert Schweitzer Weg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/289465,thunthunthun/" title="ThunThunThun">ThunThunThun</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/75407,childrens-adventure-trail--muerren/" title="Children's Adventure Trail - Mürren">Children's Adventure Trail - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51044,seeblick-am-sonnenhang/" title="Seeblick am Sonnenhang">Seeblick am Sonnenhang</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/123943,eiger-trail-via-the-gletscherschlucht-to-grindelwald/" title="Eiger trail via the Gletscherschlucht to Grindelwald">Eiger trail via the Gletscherschlucht to Grindelwald</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58603,bergwanderung-ueber-den-hochstollen/" title="Bergwanderung über den Hochstollen">Bergwanderung über den Hochstollen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/70001,im-banne-von-eiger-moench-und-jungfrau/" title="Im Banne von Eiger, Mönch und Jungfrau">Im Banne von Eiger, Mönch und Jungfrau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/244083,obwaldner-hoehenweg-etappe-4/" title="Obwaldner Höhenweg: Etappe 4">Obwaldner Höhenweg: Etappe 4</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709662,biberg/" title="Biberg">Biberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/455701,rund-um-den-stauweiher-spiez/" title="Rund um den Stauweiher Spiez">Rund um den Stauweiher Spiez</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131151,wilderswil--zweiluetschinen/" title="Wilderswil - Zweilütschinen">Wilderswil - Zweilütschinen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49229,vom-aarelauf-ins-dorf-der-drei-bundesraete/" title="Vom Aarelauf ins Dorf der drei Bundesräte">Vom Aarelauf ins Dorf der drei Bundesräte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50180,chrine--sanfter-uebergang-zwischen-den-beiden-wispile/" title="Chrine – sanfter Übergang zwischen den beiden Wispile">Chrine – sanfter Übergang zwischen den beiden Wispile</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/54086,chastalet-rundweg/" title="Chastalet Rundweg">Chastalet Rundweg</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156818,luzerner-weg-huttwil--burgdorf/" title="Luzerner Weg: Huttwil - Burgdorf">Luzerner Weg: Huttwil - Burgdorf</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/831318,rellerli-loop/" title="Rellerli Loop">Rellerli Loop</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/100450,engstlenalp-ursprung-des-gentalwassers/" title="Engstlenalp, Ursprung des Gentalwassers">Engstlenalp, Ursprung des Gentalwassers</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/132567,winterwanderweg-wiriehorn/" title="Winterwanderweg Wiriehorn">Winterwanderweg Wiriehorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49030,wo-die-zahmen-wildbaeche-entspringen/" title="Wo die zahmen Wildbäche entspringen">Wo die zahmen Wildbäche entspringen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49191,ueber-alpweiden-am-fuss-des-hohgant/" title="Über Alpweiden am Fuss des Hohgant">Über Alpweiden am Fuss des Hohgant</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/159652,emmental-wie-aus-dem-bilderbuch/" title="Emmental, wie aus dem Bilderbuch">Emmental, wie aus dem Bilderbuch</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58074,natur-pur-am-geltenschuss/" title="Natur pur am Geltenschuss">Natur pur am Geltenschuss</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/691502,lenk--iffigenalp--lenk/" title="Lenk - Iffigenalp - Lenk">Lenk - Iffigenalp - Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131707,eggli--vorderes-eggli--eggli/" title="Eggli - Vorderes Eggli - Eggli">Eggli - Vorderes Eggli - Eggli</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/509378,vom-limpachtal-an-die-alte-aare/" title="Vom Limpachtal an die Alte Aare">Vom Limpachtal an die Alte Aare</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/310002,uphilltrail-kleine-scheidegg-u3/" title="Uphilltrail Kleine Scheidegg U3">Uphilltrail Kleine Scheidegg U3</a>
# ...
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49224,das-viertausender-erlebnis-fuer-jedermann/" title="Das Viertausender-Erlebnis für jedermann">Das Viertausender-Erlebnis für jedermann</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/304176,sigriswiler-rothorn/" title="Sigriswiler Rothorn">Sigriswiler Rothorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/327996,rundtour-von-burgdorf-ueber-die-rothoehe/" title="Rundtour von Burgdorf über die Rothöhe">Rundtour von Burgdorf über die Rothöhe</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131883,first--bachalpsee--faulhorn--bussalp/" title="First - Bachalpsee - Faulhorn - Bussalp">First - Bachalpsee - Faulhorn - Bussalp</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/205225,re-vital-und-sinnespfad-luetzelflueh/" title="Re-Vital und Sinnespfad Lützelflüh">Re-Vital und Sinnespfad Lützelflüh</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/358900,panoramaweg-kleine-scheidegg/" title="Panoramaweg Kleine Scheidegg">Panoramaweg Kleine Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/klettersteig/114242,taelli-klettersteig--gadmen/" title="Tälli Klettersteig - Gadmen">Tälli Klettersteig - Gadmen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/145451,von-der-schynige-platte-auf-das-faulhorn/" title="Von der Schynige Platte auf das Faulhorn">Von der Schynige Platte auf das Faulhorn</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309938,uphilltrail-maennlichen-u2/" title="Uphilltrail Männlichen U2">Uphilltrail Männlichen U2</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133091,panoramawanderung-hoernliweg-adelboden/" title="Panoramawanderung: Hörnliweg Adelboden">Panoramawanderung: Hörnliweg Adelboden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/183373,von-corgemont-zur-schokoladefabrik-nach-courtelary/" title="Von Corgémont zur Schokoladefabrik nach Courtelary">Von Corgémont zur Schokoladefabrik nach Courtelary</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/405259,von-interlaken-ueber-den-rugen-nach-wilderswil/" title="Von Interlaken über den Rugen nach Wilderswil">Von Interlaken über den Rugen nach Wilderswil</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/163886,von-wimmis-auf-den-niesen/" title="Von Wimmis auf den Niesen">Von Wimmis auf den Niesen</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/158678,kemmeriboden-trail/" title="Kemmeriboden-Trail">Kemmeriboden-Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/275964,von-schloss-thun-zum-schloss-oberhofen/" title="Von Schloss Thun zum Schloss Oberhofen">Von Schloss Thun zum Schloss Oberhofen</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/131465,waldspitz--bort--waldlehrpfad/" title="Waldspitz - Bort | Waldlehrpfad">Waldspitz - Bort | Waldlehrpfad</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/70001,im-banne-von-eiger-moench-und-jungfrau/" title="Im Banne von Eiger, Mönch und Jungfrau">Im Banne von Eiger, Mönch und Jungfrau</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/278642,elsighorn-trail/" title="Elsighorn Trail">Elsighorn Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/718574,loetschenpasshuette/" title="Lötschenpasshütte">Lötschenpasshütte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133941,baettenalp--kulturlandschaftspreis-2007/" title="Bättenalp -  Kulturlandschaftspreis 2007">Bättenalp -  Kulturlandschaftspreis 2007</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/66078,vogelweg-oey/" title="Vogelweg Oey">Vogelweg Oey</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156751,berner-oberlaender-weg-merligen--amsoldingen-original/" title="Berner-Oberländer-Weg: Merligen - Amsoldingen (Original)">Berner-Oberländer-Weg: Merligen - Amsoldingen (Original)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/57280,der-kander-entlang-ins-tal-der-simme/" title="Der Kander entlang ins Tal der Simme">Der Kander entlang ins Tal der Simme</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/132107,via-jacobi-schwarzenburg--fribourg/" title="Via Jacobi: Schwarzenburg - Fribourg">Via Jacobi: Schwarzenburg - Fribourg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48801,viel-emmental-in-kurzer-zeit/" title="Viel Emmental in kurzer Zeit">Viel Emmental in kurzer Zeit</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/522405,first--waldspitz--bort-nr-51/" title="First – Waldspitz – Bort (Nr. 51)">First – Waldspitz – Bort (Nr. 51)</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309970,trailsummit-reeti-t1/" title="Trailsummit Reeti T1">Trailsummit Reeti T1</a>
# <a class="h2" href="/sommer/bern-region/touren/klettersteig/92578,schwarzhorn-klettersteig--grindelwald/" title="Schwarzhorn Klettersteig - Grindelwald">Schwarzhorn Klettersteig - Grindelwald</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50182,berggenuss-rund-um-das-seehore/" title="Berggenuss rund um das Seehore">Berggenuss rund um das Seehore</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/58522,schnitzlerweg-axalp/" title="Schnitzlerweg Axalp">Schnitzlerweg Axalp</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/70016,iffigfall-trail--lenk/" title="Iffigfall Trail - Lenk">Iffigfall Trail - Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48807,panoramawanderung-ins-saanenland/" title="Panoramawanderung ins Saanenland">Panoramawanderung ins Saanenland</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/553952,wen-dw--stechelberg--schmadrihuette--stechelberg/" title="WEN-DW - Stechelberg - Schmadrihütte - Stechelberg">WEN-DW - Stechelberg - Schmadrihütte - Stechelberg</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/525056,swiss-trail-tour-lenk-strecke-freitag-2020/" title="Swiss Trail Tour Lenk, Strecke Freitag, 2020">Swiss Trail Tour Lenk, Strecke Freitag, 2020</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131784,muerren--schilthorn-loop-11h/" title="Mürren - Schilthorn Loop (11h)">Mürren - Schilthorn Loop (11h)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162904,gratwanderung-zwischen-saanenland-und-simmental/" title="Gratwanderung zwischen Saanenland und Simmental">Gratwanderung zwischen Saanenland und Simmental</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49113,das-tal-der-kraeftigen-maedchen/" title="Das Tal der kräftigen Mädchen">Das Tal der kräftigen Mädchen</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/183278,eiger-ultra-trail-e51/" title="Eiger Ultra Trail E51">Eiger Ultra Trail E51</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/278513,vom-mont-soleil-zum-mont-crosin/" title="Vom Mont Soleil zum Mont Crosin">Vom Mont Soleil zum Mont Crosin</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/658329,durchs-jahr-wandern--tuerkenbund-ob-grindelwald/" title="Durchs Jahr wandern - Türkenbund ob Grindelwald">Durchs Jahr wandern - Türkenbund ob Grindelwald</a>
# <a class="h2" href="/sommer/bern-region/touren/nordic-walking/114497,fit-mit-genuss/" title="Fit mit Genuss">Fit mit Genuss</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/69173,saemis-saeumerpfad--innertkirchen/" title="Sämis Säumerpfad - Innertkirchen">Sämis Säumerpfad - Innertkirchen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/744919,kanderfaelle/" title="Kanderfälle">Kanderfälle</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/593358,jungfrau-eiger-walk-eigergletscher--kleine-scheidegg/" title="«Jungfrau Eiger Walk» Eigergletscher - Kleine Scheidegg">«Jungfrau Eiger Walk» Eigergletscher - Kleine Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/96773,saxeten-trail/" title="Saxeten Trail">Saxeten Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133923,rundtour-sichle/" title="Rundtour Sichle">Rundtour Sichle</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/97600,schlittelweg-betelberg--poeschenried-lenk/" title="Schlittelweg Betelberg - Pöschenried (Lenk)">Schlittelweg Betelberg - Pöschenried (Lenk)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/53227,vom-seeruecken-zum-jaeissberg/" title="Vom Seerücken zum Jäissberg">Vom Seerücken zum Jäissberg</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/823098,wispile--lauenen-trail/" title="Wispile – Lauenen Trail">Wispile – Lauenen Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/260904,von-einigen-nach-thun/" title="Von Einigen nach Thun">Von Einigen nach Thun</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129364,von-grindelwald-auf-den-wildgaerst/" title="Von Grindelwald auf den Wildgärst">Von Grindelwald auf den Wildgärst</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/532165,sparenmoos--site-alp--sparenmoos/" title="Sparenmoos - Site Alp - Sparenmoos">Sparenmoos - Site Alp - Sparenmoos</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/62315,zur-lobhornhuette-sac-ein-aussichtsbalkon-ersten-ranges/" title="Zur Lobhornhütte SAC- ein Aussichtsbalkon ersten Ranges">Zur Lobhornhütte SAC- ein Aussichtsbalkon ersten Ranges</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131919,taelliweg-engstlenalp--taelli/" title="Tälliweg (Engstlenalp - Tälli)">Tälliweg (Engstlenalp - Tälli)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/911372,wispile--lauenen-trail/" title="Wispile - Lauenen Trail">Wispile - Lauenen Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/454773,bergtour-gross-siedelhorn--uelistock/" title="Bergtour Gross Siedelhorn - Uelistock">Bergtour Gross Siedelhorn - Uelistock</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/182387,zu-den-osterglocken-bei-les-pres-dorvin/" title="Zu den Osterglocken bei Les Prés-d'Orvin">Zu den Osterglocken bei Les Prés-d'Orvin</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133086,bikeroute-nr-5-sillerebuehl-troneggrat/" title="Bikeroute Nr. 5 Sillerebühl-Troneggrat">Bikeroute Nr. 5 Sillerebühl-Troneggrat</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/96773,saxeten-trail/" title="Saxeten Trail">Saxeten Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/281199,unterseener-uferweg/" title="Unterseener Uferweg">Unterseener Uferweg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/75407,childrens-adventure-trail--muerren/" title="Children's Adventure Trail - Mürren">Children's Adventure Trail - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/525058,swiss-trail-tour-lenk-strecke-samstag-2020/" title="Swiss Trail Tour Lenk, Strecke Samstag, 2020">Swiss Trail Tour Lenk, Strecke Samstag, 2020</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49229,vom-aarelauf-ins-dorf-der-drei-bundesraete/" title="Vom Aarelauf ins Dorf der drei Bundesräte">Vom Aarelauf ins Dorf der drei Bundesräte</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/289903,schwingerweg-springenboden/" title="Schwingerweg Springenboden">Schwingerweg Springenboden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/315061,interlaken-ost--harder-kulm/" title="Interlaken Ost - Harder Kulm">Interlaken Ost - Harder Kulm</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51047,blumenparadies-im-faermeltal/" title="Blumenparadies im Färmeltal">Blumenparadies im Färmeltal</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/315071,winterwanderweg-springenboden/" title="Winterwanderweg Springenboden">Winterwanderweg Springenboden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114220,zum-aussichtsturm-auf-dem-moron/" title="Zum Aussichtsturm auf dem Moron">Zum Aussichtsturm auf dem Moron</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/733526,chasseral--der-abgeschiedene-huegelzug-hoch-ueber-dem-seeland/" title="Chasseral - der abgeschiedene Hügelzug hoch über dem Seeland">Chasseral - der abgeschiedene Hügelzug hoch über dem Seeland</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49311,ueber-den-mont-sujet/" title="Über den Mont Sujet">Über den Mont Sujet</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162916,der-klassiker-im-jungfraugebiet/" title="Der Klassiker im Jungfraugebiet">Der Klassiker im Jungfraugebiet</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51047,blumenparadies-im-faermeltal/" title="Blumenparadies im Färmeltal">Blumenparadies im Färmeltal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/84519,auf-den-bantiger-der-stadtnahe-aussichtsberg/" title="Auf den Bantiger, der Stadtnahe Aussichtsberg">Auf den Bantiger, der Stadtnahe Aussichtsberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50391,im-banne-der-blueemlisalp-hohtuerli/" title="Im Banne der Blüemlisalp (Hohtürli)">Im Banne der Blüemlisalp (Hohtürli)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/110806,trubschachen--schangnau/" title="Trubschachen – Schangnau">Trubschachen – Schangnau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508350,das-guggershorn--ein-klassisches-ausflugsziel/" title="Das Guggershorn – ein klassisches Ausflugsziel">Das Guggershorn – ein klassisches Ausflugsziel</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131467,grindelwald--abbachfall--bussalp/" title="Grindelwald - Abbachfall - Bussalp">Grindelwald - Abbachfall - Bussalp</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/309530,kambly-entdeckerpfad-in-trubschachen/" title="Kambly Entdeckerpfad in Trubschachen">Kambly Entdeckerpfad in Trubschachen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/298918,vom-gurten-nach-kehrsatz/" title="Vom Gurten nach Kehrsatz">Vom Gurten nach Kehrsatz</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/49218,winterwanderweg-hoeh-tour-kandersteg/" title="Winterwanderweg Höh-Tour (Kandersteg)">Winterwanderweg Höh-Tour (Kandersteg)</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/131810,lieselotteweg-maennlichen--holenstein/" title="«Lieselotteweg» Männlichen - Holenstein">«Lieselotteweg» Männlichen - Holenstein</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49192,wo-die-wehrli-knaben-ihr-abendlied-sangen/" title="Wo die Wehrli-Knaben ihr Abendlied sangen">Wo die Wehrli-Knaben ihr Abendlied sangen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133083,adelboden--cholerenschlucht--retour/" title="Adelboden - Cholerenschlucht - retour">Adelboden - Cholerenschlucht - retour</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/297007,planetenweg-ringgenberg/" title="Planetenweg Ringgenberg">Planetenweg Ringgenberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/151862,von-der-elsigenalp-auf-das-elsighorn/" title="Von der Elsigenalp auf das Elsighorn">Von der Elsigenalp auf das Elsighorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/101889,in-der-auenlandschaft-der-aare-bei-muensingen/" title="In der Auenlandschaft der Aare bei Münsingen">In der Auenlandschaft der Aare bei Münsingen</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/131604,saanen--saanenmoeser--oeschseite--zweisimmen/" title="Saanen - Saanenmöser - Oeschseite - Zweisimmen">Saanen - Saanenmöser - Oeschseite - Zweisimmen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131173,schynige-platte--oberberghorn--schynige-platte/" title="Schynige Platte - Oberberghorn - Schynige Platte">Schynige Platte - Oberberghorn - Schynige Platte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/84396,meiringen--wo-kunst-und-geschichte-sich-erwandern-lassen/" title="Meiringen - Wo Kunst und Geschichte sich erwandern lassen">Meiringen - Wo Kunst und Geschichte sich erwandern lassen</a>

# %%
### Strip out the ID --> in column ix 5 as 'str'
id_df2 = id_df3[0].str.split(' ',expand = True)
id_df1 = id_df2[2].str.split(',',expand = True)
id_df = id_df1[0].str.split('/',expand = True)
id_df[5][0]

## ---> id_df is holding the IDs
# Out:
# '310007'

# %%
# Dealing with the ratings for fitness and technique
# we need to extract Rating data which is "embedded" as a class name in the bs4.BeautifulSoup
rating[0]
# Out:
# [<div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-5"></div></div>
#  </div>,
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-5"></div></div>
#  </div>]

# %%
# converting into string
tour_rating_str = str(rating)

# taking out unnecessary info - each second rating is Technique or Fitness, starting with technique
rating_all_short = tour_rating_str.replace('<div class="tour-rating">\n<div class="tour-rating-label">Technique</div>\n<div class="rating-circles rating-max6"><div class="','').replace('<div class="tour-rating">\n<div class="tour-rating-label">Fitness</div>\n<div class="rating-circles rating-max6"><div class="','').replace('"></div></div>\n</div>',"")
rating_even_shorter = rating_all_short.replace('[','').replace(']','')


## splitting into lists
rating_list = rating_even_shorter.split(", ")

# %%
# filling the lists technique = [] and fitness = []  we defined in the beginning

for i in range(0,(len(rating_list))):
    if i == 0:
        technique.append(rating_list[i]) # first item goes into technique
    elif i % 2 == 0:
        technique.append(rating_list[i]) # then every second item as well
    else:
        fitness.append(rating_list[i]) # the other items go into fitness

# %%
# Forming a dataframe from our lists as columns:

hikes_df = pd.DataFrame(
    {'title': title,
     'difficulty': difficulty,
     'sport': sport,
     'length': length,
     'time': time,
     'climb': climb,
     'minmax': minmax,
     'technique': technique,
     'fitness': fitness
    })

# %%
#  First draft dataframe: brackets, units, minmax to separate
hikes_df
# Out:
#                                                  title   difficulty  \
# 0                        [Trailsummit Chrinnenhorn T3]  [difficult]
# 1                  [Aus dem Diemtigtal zum Seebergsee]     [medium]
# 2                              [Panoramaweg Hasliberg]     [medium]
# 3                             [Lauterbrunnen - Mürren]     [medium]
# 4    [Von der Saane zum Denkmal der Schlacht von La...           []
# ..                                                 ...          ...
# 395             [Von der Elsigenalp auf das Elsighorn]     [medium]
# 396     [In der Auenlandschaft der Aare bei Münsingen]           []
# 397   [Saanen - Saanenmöser - Oeschseite - Zweisimmen]     [medium]
# 398  [Schynige Platte - Oberberghorn - Schynige Pla...       [easy]
# 399  [Meiringen - Wo Kunst und Geschichte sich erwa...     [medium]
#
#               sport   length    time    climb          minmax technique  \
# 0    [Trailrunning]  10.06km  02:49h  1,755hm  1,039 - 2,740m  rating-5
# 1          [Hiking]  18.63km  06:30h  1,023hm  1,081 - 1,929m  rating-3
# 2          [Hiking]    8.6km  03:00h    355hm    979 - 1,263m  rating-2
# 3          [Hiking]   5.11km  02:30h    846hm    798 - 1,644m  rating-2
# 4          [Hiking]  14.11km  03:40h    212hm      482 - 649m   rating-
# ..              ...      ...     ...      ...             ...       ...
# 395        [Hiking]  10.55km  04:30h    833hm  1,777 - 2,333m  rating-2
# 396        [Hiking]  11.89km  02:50h     97hm      515 - 565m   rating-
# 397       [Cycling]  17.36km  01:30h    270hm    941 - 1,280m  rating-3
# 398        [Hiking]   3.06km  01:15h    179hm  1,940 - 2,066m  rating-2
# 399        [Hiking]   6.39km  02:40h    460hm      595 - 997m  rating-3
#
#       fitness
# 0    rating-5
# 1    rating-4
# 2    rating-3
# 3    rating-3
# 4    rating-0
# ..        ...
# 395  rating-3
# 396  rating-0
# 397  rating-2
# 398  rating-2
# 399  rating-3
#
# [400 rows x 9 columns]

# %% [markdown]
# <html>
# <h2> Part 2: Data cleaning
# </h2>
# <body></body>
# </html>

# %%
# Converting the text columns to strings for easier handling later

hikes_df[['title', 'difficulty', 'sport']] = hikes_df[['title', 'difficulty', 'sport']].astype('str')

# %%
# Removing the brackets

hikes_df['title'] = hikes_df['title'].str.strip('[]')
hikes_df['difficulty'] = hikes_df['difficulty'].str.strip('[]')
hikes_df['sport'] = hikes_df['sport'].str.strip('[]')

# %%
# For some reason '' appear now, removing those as well

hikes_df['title'] = pd.Series(hikes_df['title']).str.replace("'", '')
hikes_df['difficulty'] = pd.Series(hikes_df['difficulty']).str.replace("'", '')
hikes_df['sport'] = pd.Series(hikes_df['sport']).str.replace("'", '')

# %%
# The "string-cleaned" dataframe
hikes_df
# Out:
#                                                  title difficulty  \
# 0                          Trailsummit Chrinnenhorn T3  difficult
# 1                    Aus dem Diemtigtal zum Seebergsee     medium
# 2                                Panoramaweg Hasliberg     medium
# 3                               Lauterbrunnen - Mürren     medium
# 4    Von der Saane zum Denkmal der Schlacht von Laupen
# ..                                                 ...        ...
# 395               Von der Elsigenalp auf das Elsighorn     medium
# 396       In der Auenlandschaft der Aare bei Münsingen
# 397     Saanen - Saanenmöser - Oeschseite - Zweisimmen     medium
# 398   Schynige Platte - Oberberghorn - Schynige Platte       easy
# 399  Meiringen - Wo Kunst und Geschichte sich erwan...     medium
#
#             sport   length    time    climb          minmax technique  \
# 0    Trailrunning  10.06km  02:49h  1,755hm  1,039 - 2,740m  rating-5
# 1          Hiking  18.63km  06:30h  1,023hm  1,081 - 1,929m  rating-3
# 2          Hiking    8.6km  03:00h    355hm    979 - 1,263m  rating-2
# 3          Hiking   5.11km  02:30h    846hm    798 - 1,644m  rating-2
# 4          Hiking  14.11km  03:40h    212hm      482 - 649m   rating-
# ..            ...      ...     ...      ...             ...       ...
# 395        Hiking  10.55km  04:30h    833hm  1,777 - 2,333m  rating-2
# 396        Hiking  11.89km  02:50h     97hm      515 - 565m   rating-
# 397       Cycling  17.36km  01:30h    270hm    941 - 1,280m  rating-3
# 398        Hiking   3.06km  01:15h    179hm  1,940 - 2,066m  rating-2
# 399        Hiking   6.39km  02:40h    460hm      595 - 997m  rating-3
#
#       fitness
# 0    rating-5
# 1    rating-4
# 2    rating-3
# 3    rating-3
# 4    rating-0
# ..        ...
# 395  rating-3
# 396  rating-0
# 397  rating-2
# 398  rating-2
# 399  rating-3
#
# [400 rows x 9 columns]

# %%
# getting rid of the units (they're always the same anyway)

hikes_df['length'] = pd.Series(hikes_df['length']).str.replace("km", '')
hikes_df['time'] = pd.Series(hikes_df['time']).str.replace("h", '')
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace("hm", '')
hikes_df['minmax'] = pd.Series(hikes_df['minmax']).str.replace("m", '')

# %%
# making 2 columns out of the last one, and removing the old minmax column

hikes_df[['min','max']] = hikes_df['minmax'].str.split("-",expand=True)
hikes_df = hikes_df.drop(columns=['minmax'])

# moving the ratings back to the end
hikes_df = hikes_df[['title', 'difficulty', 'sport', 'length', 'time', 'climb', 'min', 'max', 'technique', 'fitness']]

# %%
# The clean dataframe in string format

hikes_df
# Out:
#                                                  title difficulty  \
# 0                          Trailsummit Chrinnenhorn T3  difficult
# 1                    Aus dem Diemtigtal zum Seebergsee     medium
# 2                                Panoramaweg Hasliberg     medium
# 3                               Lauterbrunnen - Mürren     medium
# 4    Von der Saane zum Denkmal der Schlacht von Laupen
# ..                                                 ...        ...
# 395               Von der Elsigenalp auf das Elsighorn     medium
# 396       In der Auenlandschaft der Aare bei Münsingen
# 397     Saanen - Saanenmöser - Oeschseite - Zweisimmen     medium
# 398   Schynige Platte - Oberberghorn - Schynige Platte       easy
# 399  Meiringen - Wo Kunst und Geschichte sich erwan...     medium
#
#             sport length   time  climb     min     max technique   fitness
# 0    Trailrunning  10.06  02:49  1,755  1,039    2,740  rating-5  rating-5
# 1          Hiking  18.63  06:30  1,023  1,081    1,929  rating-3  rating-4
# 2          Hiking    8.6  03:00    355    979    1,263  rating-2  rating-3
# 3          Hiking   5.11  02:30    846    798    1,644  rating-2  rating-3
# 4          Hiking  14.11  03:40    212    482      649   rating-  rating-0
# ..            ...    ...    ...    ...     ...     ...       ...       ...
# 395        Hiking  10.55  04:30    833  1,777    2,333  rating-2  rating-3
# 396        Hiking  11.89  02:50     97    515      565   rating-  rating-0
# 397       Cycling  17.36  01:30    270    941    1,280  rating-3  rating-2
# 398        Hiking   3.06  01:15    179  1,940    2,066  rating-2  rating-2
# 399        Hiking   6.39  02:40    460    595      997  rating-3  rating-3
#
# [400 rows x 10 columns]

# %%
# converting to number data types:

# length
hikes_df['length'] = (hikes_df['length']).astype(float)

# Climb
# to handle the conversions we replace missing values by 0. Maybe nan would work too, but didn't find out how yet
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace(",", '') # replace thousand separator
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace("-", '0') # replaces - by 0
hikes_df['climb'] = (hikes_df['climb']).astype(int)

# %%
#min and max
hikes_df['min'] = pd.Series(hikes_df['min']).str.replace(",", '') # replace thousand separator
hikes_df['min'] = (hikes_df['min']).astype(int)
hikes_df['max'] = pd.Series(hikes_df['max']).str.replace(",", '') # replace thousand separator
hikes_df['max'] = (hikes_df['max']).astype(int)

# %%
# converting times to time objects

# pandas datetime doesn't handle times over 24 hours so we have to give him an alternative
try:
    hikes_df['time'] = pd.to_datetime(hikes_df['time'], format='%H:%M').dt.time #duration 
except ValueError:
    pass
# I want to get rid of seconds but it's bed time

# %%
## rating technique
hikes_df['technique'] = pd.Series(hikes_df['technique']).str.replace("rating-", '')
hikes_df['technique'] = pd.to_numeric(hikes_df['technique'], errors='coerce')
hikes_df['technique'] = pd.Series(hikes_df['technique']).replace(np.nan, 0, regex = True)
hikes_df['technique'] = pd.Series(hikes_df['technique']).astype('int')

# rating fitness
hikes_df['fitness'] = pd.Series(hikes_df['fitness']).str.replace("rating-", '')
hikes_df['fitness'] = pd.to_numeric(hikes_df['fitness'], errors='coerce')
hikes_df['fitness'] = pd.Series(hikes_df['fitness']).replace(np.nan, 0, regex = True)
hikes_df['fitness'] = hikes_df['fitness'].astype('int')

# %%
# Finally the clean dataframe 

hikes_df
# Out:
#                                                  title difficulty  \
# 0                          Trailsummit Chrinnenhorn T3  difficult
# 1                    Aus dem Diemtigtal zum Seebergsee     medium
# 2                                Panoramaweg Hasliberg     medium
# 3                               Lauterbrunnen - Mürren     medium
# 4    Von der Saane zum Denkmal der Schlacht von Laupen
# ..                                                 ...        ...
# 395               Von der Elsigenalp auf das Elsighorn     medium
# 396       In der Auenlandschaft der Aare bei Münsingen
# 397     Saanen - Saanenmöser - Oeschseite - Zweisimmen     medium
# 398   Schynige Platte - Oberberghorn - Schynige Platte       easy
# 399  Meiringen - Wo Kunst und Geschichte sich erwan...     medium
#
#             sport  length   time  climb   min   max  technique  fitness
# 0    Trailrunning   10.06  02:49   1755  1039  2740          5        5
# 1          Hiking   18.63  06:30   1023  1081  1929          3        4
# 2          Hiking    8.60  03:00    355   979  1263          2        3
# 3          Hiking    5.11  02:30    846   798  1644          2        3
# 4          Hiking   14.11  03:40    212   482   649          0        0
# ..            ...     ...    ...    ...   ...   ...        ...      ...
# 395        Hiking   10.55  04:30    833  1777  2333          2        3
# 396        Hiking   11.89  02:50     97   515   565          0        0
# 397       Cycling   17.36  01:30    270   941  1280          3        2
# 398        Hiking    3.06  01:15    179  1940  2066          2        2
# 399        Hiking    6.39  02:40    460   595   997          3        3
#
# [400 rows x 10 columns]

# %%
# the dataframe info sum up yay we managed!
hikes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       400 non-null    object
#  1   difficulty  400 non-null    object
#  2   sport       400 non-null    object
#  3   length      400 non-null    float64
#  4   time        400 non-null    object
#  5   climb       400 non-null    int64
#  6   min         400 non-null    int64
#  7   max         400 non-null    int64
#  8   technique   400 non-null    int64
#  9   fitness     400 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 31.4+ KB

# %% [markdown]
# #### <html>
# <h2> Part 3: Downloading GeoData for the hikes
# </h2>
# <body>to create the for loop for all the 400 hikes</body>
# </html>

# %%
### Imports
import requests
import re
from pykml import parser
from lxml import etree
from lxml import objectify

# %% [markdown]
# #### <html>
# <h3> Download the KML file
#     </h3>
# <body>We do this by parsing the url, and then converting into the the kml link that is used on the website.
#
# - https://www.bergfex.com/downloads/gps/?type=&id=271548&fileType=kml
# - Get file name from the url
#     </body>
# </html>

# %%
kml_link = ""
url = "https://www.bergfex.com/downloads/gps/"
url3= "https://www.bergfex.com/downloads/gps/?type=&amp;id=271548&amp;fileType=kml"
if url3.find('/'):
    print(url3.rsplit('/', 1)[1])
    kml_link = (url3.rsplit('/', 1)[1])
    new_s = kml_link.replace('=&amp;', '=&')
    print(new_s)

conc_kml_link = (url + new_s)
print(conc_kml_link )
# Out:
# ?type=&amp;id=271548&amp;fileType=kml
# ?type=&id=271548&amp;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=271548&amp;fileType=kml

# %% [markdown]
# #### <html>
# <h3>Write the data to a klm file locally
#     </h3>
# <body>
# - TO DO:
# - This will be the file that we need to write our data from, and then add it to a data frame
#     </body>
#     </html>

# %%
r = requests.get(conc_kml_link, allow_redirects=True)
write_link = ( new_s + ".klm")
write_link
open(write_link, 'wb').write(r.content)
# Out:
# 14653

# %% [markdown]
# #### <html>
# <h3>Create loop to download all entries
#     </h3>
#     <body> DONE </body>

# %%
## get list of all IDs
final_id = id_df.iloc[:,5]
final_id
# Out:
# 0      310007
# 1       49274
# 2      131936
# 3      131157
# 4       81701
#         ...
# 395    151862
# 396    101889
# 397    131604
# 398    131173
# 399     84396
# Name: 5, Length: 400, dtype: object

# %%
test_loop = final_id.iloc[0:3]
test_loop
# Out:
# 0    310007
# 1     49274
# 2    131936
# Name: 5, dtype: object

# %%
## For loop to create: i) all kml files (400 items) --> take 'final_id', ii) for testing --> take 'test_loop'
## Saves the files in same directory as the notebook

for sport_id in test_loop: 
    url_id = f"https://www.bergfex.com/downloads/gps/?type=&amp;id='{sport_id}&amp;fileType=kml"
    print(url_id)
    r = requests.get(url_id, allow_redirects=True)
    write_link = (sport_id + ".klm")
    open(write_link, 'wb').write(r.content)

write_link
# Out:
# https://www.bergfex.com/downloads/gps/?type=&amp;id='310007&amp;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&amp;id='49274&amp;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&amp;id='131936&amp;fileType=kml
# '131936.klm'

# %% [markdown]
# #### <html>
# <h3> Read out the first postion of each file and add to DF
#     </h3>
#
# <body> Still to do </body>

# %% [markdown]
# #### <html>
# <h2> Part 4: Get snow data
# </h2>
# <body>DONE</body>
# </html>

# %%
### all the imports

import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
### initializing the future colums of our dataframe with empty lists

snowlevel = []  # height in cm
location = []  # town and elevation of town

## no looping over several pages necessary

## only scrape first page
link = 'http://www.meteocentrale.ch/de/wetter/hitlisten/schneehoehen.html'
page = requests.get(link, timeout=10)
print(page.status_code)
soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
hitlist = soup.findAll('table', {'class': 'hitlist'})  #bs4.element.ResultSet
# Out:
# 200

# %%
## get location
location_item = hitlist[0].findAll('a')
location.append([info.get_text().strip() for info in location_item])
loc = location[0]
#len(loc)
#loc

## get snowlevel
snowlevel_item = hitlist[0].findAll('td', {'class': 'value'}) #
snowlevel.append([info.get_text().strip() for info in snowlevel_item])
#len(snowlevel)
snow = snowlevel[0]
#len(snow)
#snow


## combine into DF
heights_df = pd.DataFrame({'location': loc,'snowlevel': snow})
heights_df
# Out:
#                    location snowlevel
# 0     Weissfluhjoch, 2690 m     58 cm
# 1         Corvatsch, 3315 m     45 cm
# 2            Säntis, 2490 m     20 cm
# 3          Glattalp, 1858 m     15 cm
# 4         Schwägalp, 1350 m      4 cm
# ..                      ...       ...
# 74          Zermatt, 1638 m      0 cm
# 75        Zollikofen, 553 m      0 cm
# 76  Zürich-Affoltern, 443 m      0 cm
# 77  Zürich-Flughafen, 432 m      0 cm
# 78             Zuoz, 1664 m      0 cm
#
# [79 rows x 2 columns]

# %%
### data manipulation: 

##remove cm, convert to 'int'
heights_df['snowlevel_in_cm']=pd.Series(heights_df['snowlevel']).str.replace(" cm", '')
heights_df['snowlevel_in_cm']=pd.Series(heights_df['snowlevel_in_cm']).astype(int)
#type(heights_df['snowlevel_in_cm'][0])
#heights_df

## split location into 'village' and 'elevation of village' and merge with previous DF
split_loc = pd.Series(heights_df['location']).str.split(',',n=2,expand = True)
merged_df = pd.merge(heights_df, split_loc, left_index=True, right_index=True)
#merged_df

## drop unused columns, rename final columns, remove unit, sort columns
intermediate_df1 = merged_df.iloc[:,[2,3,4]]
intermediate_df1.columns = ['snowlevel_in_cm', 'location', 'height_in_m']
intermediate_df1['height_in_m']=pd.Series(intermediate_df1['height_in_m']).str.replace(" m", '')
intermediate_df2 = pd.DataFrame(intermediate_df1, columns = ['location', 'height_in_m', 'snowlevel_in_cm'])
# Out:
# <ipython-input-45-b1b349985263>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intermediate_df1['height_in_m']=pd.Series(intermediate_df1['height_in_m']).str.replace(" m", '')

# %%
### final dataframe

intermediate_df2
# Out:
#             location height_in_m  snowlevel_in_cm
# 0      Weissfluhjoch        2690               58
# 1          Corvatsch        3315               45
# 2             Säntis        2490               20
# 3           Glattalp        1858               15
# 4          Schwägalp        1350                4
# ..               ...         ...              ...
# 74           Zermatt        1638                0
# 75        Zollikofen         553                0
# 76  Zürich-Affoltern         443                0
# 77  Zürich-Flughafen         432                0
# 78              Zuoz        1664                0
#
# [79 rows x 3 columns]

# %%
### Export into csv

#intermediate_df2.to_csv(r'/Users/sd/Documents/0-Coding/sarah-dutschke/04-Visualization/Challenge/snow_level.csv', index = False)

# %% [markdown]
# #### <html>
# <h2> Part 5: Data analysis
# </h2>
# <body>(just to check the dataframe actually works)</body>
# </html>

# %%
# Number of entries by types of sports
hikes_df['sport'].value_counts().plot(kind='bar')

# %%
# Creating a df for "Number of entries by sport type" + average tour length

sporttype = hikes_df.groupby('sport') \
       .agg({'sport':'count', 'length':'mean'}) \
       .rename(columns={'sport':'count','length':'average_length'}) \
       .reset_index()
sporttype

# %%
# Difficulty

hikes_df['difficulty'].unique()

# %%
hikes_df['difficulty'].value_counts().plot(kind='bar')

# %%
# mean length for difficulty:

hikes_df.groupby('difficulty').mean()

# %%
#df.reset_index().plot.scatter(x = 'index', y = 'value')
tour_len = sorted(pd.Series(hikes_df["length"]))
tour_climb = sorted(pd.Series(hikes_df["climb"]))
plt.plot(tour_len, tour_climb)
plt.ylabel('climb (m)')
plt.xlabel("length (km)")
plt.title('All activities')

# %%
## Creating a df for deeper analysis for Hiking
# Filter for hiking
hiking = hikes_df[hikes_df.sport == "Hiking"]

# calculating the count by Fitness level and the average length 
fitness_length = hiking.groupby('fitness') \
       .agg({'fitness':'count', 'length':'mean'}) \
       .rename(columns={'fitness':'count','length':'average_length'}) \
       .reset_index()

# calculating weighted and normalized length
fitness_length['weighted_ave_length'] = fitness_length["count"] * fitness_length["average_length"]
fitness_length["normalized_weighted_length"] = (fitness_length["weighted_ave_length"] - fitness_length["weighted_ave_length"].min()) \
                                                / (fitness_length["weighted_ave_length"].max() - fitness_length["weighted_ave_length"].min()) * 10
fitness_length

# %%
## Plotting Length vs. Fitness rating
#--> Conclusion: the routes with no fitness rating seems quite long. Investigate further

plt.plot(fitness_length["fitness"], fitness_length["average_length"])
plt.ylabel('average_length')
plt.xlabel("rating_fitness")
plt.title('Hiking: Average Length by Fitness Level Rating')

plt.show()

# %%
# quality checking data / or realizing we don't understand the columns?

hikes_df["residual"]= hikes_df["climb"] - (hikes_df["max"] - hikes_df["min"])
hikes_df["residual"].plot.density()

# %% [markdown]
# #### <html>
# <h2> Part 6: Dashboard
# </h2>
# <body>(pretty much a lot to do stil :-))</body>
# </html>
