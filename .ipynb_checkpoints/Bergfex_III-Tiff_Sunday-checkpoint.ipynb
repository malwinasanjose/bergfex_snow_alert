# %% [markdown]
# <html>
# <h1> Bergfex webscraping
# </h1>
# <body>We gather information about outdoor sport itineraries from <a href='https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page=1'> Bergfex.com </a> in the region of Bern.<br />
#     - The website displays 20 tours per page, with infos such as length, type of sport, rating, etc... <br />
#     - Most informations are provided by users.<br />
# <br />
# We then clean the data, and do a bunch of simple analysis.
# </body>
# </html>

# %% [markdown]
# <html>
# <h2> Part 1: Data scraping and cleaning
# </h2>
#
# </html>

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# initializing the future colums of our dataframe with empty lists

title = []  # Title of the tour
difficulty = []  # difficulty (easy, medium, hard)
sport = []  # Sport type (hiking, sledging, snowshoe...)
length = []  # length in km
time = []  # tour time in hours:minutes
climb = []  # positive elevation climb in m
minmax = []  # minimum and maximum altitude of the tour in m
technique = []  # technique difficulty ratings (out of 6)
fitness = []  # fitness difficulty ratings (out of 6)
total_title = [] # will help extracting the ID of the tour

# all ratings are stored together so we will need this along the way:
rating = []  # list to store technique and fitness rating info

# %%
# looping over the 10 first pages of Bergfex
# each separate tour on the page is framed by a div tag with 'touren-details'

page_number = 20  # number of pages we want to scap through

for p in range(1, (page_number+1)):
    base_link = 'https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page='
    link = base_link+str(p)  # going over p pages with numbers appended to the base link
    page = requests.get(link, timeout=5)
    print("scraped page", p)
    soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
    tours = soup.findAll('div', {'class': 'touren-detail'})  # checks for the separate tours on the page

# For each page, we loop over each tour and fill our lists with info     
    for i in range(0,len(tours)):
        tour_1 = tours[i] # tour iterating over the 20 tours of the page

        tour_title = tour_1.findAll('a' ) # this gets the title out
        title.append([info.get_text().strip() for info in tour_title])
        total_title.append(tour_title) # this gets the full tourtitle information
        
        tour_diff = tour_1.findAll('span', {'class': 'tour-difficulty'}) #tour level difficulty
        difficulty.append([info.get_text().strip() for info in tour_diff])

        tour_type = tour_1.findAll('span', {'class': 'tour-type'}) # putting type into sports (should all be hiking)
        sport.append([info.get_text().strip() for info in tour_type])

        tour_stats = tour_1.findAll('div', {'class': 'tour-stats'}) # stats has 4 info binned together
        stat_text = [info.get_text().strip() for info in tour_stats]
        length.append(stat_text[0])
        time.append(stat_text[1])
        climb.append(stat_text[2])
        minmax.append(stat_text[3])
        
        tour_rating = tour_1.find_all("div", {'class': 'tour-rating'}) # getting the rating data 
        rating.append([info for info in tour_rating])   # it's a class name so we can't get_text.
# Out:
# scraped page 1
# scraped page 2
# scraped page 3
# scraped page 4
# scraped page 5
# scraped page 6
# scraped page 7
# scraped page 8
# scraped page 9
# scraped page 10
# scraped page 11
# scraped page 12
# scraped page 13
# scraped page 14
# scraped page 15
# scraped page 16
# scraped page 17
# scraped page 18
# scraped page 19
# scraped page 20

# %%
print("number of tours collected:", len(title))
# Out:
# number of tours collected: 400

# %%
### Get the titles and IDs into a list and then a DF
links_title = []

for i in total_title:
    i = str(i)
    i = i.strip('[]')
    print(i)
    links_title.append(i)

id_df3 = pd.DataFrame(links_title)
# Out:
# <a class="h2" href="/sommer/bern-region/touren/wanderung/560728,burgenweg-in-wilderswil/" title="Burgenweg in Wilderswil">Burgenweg in Wilderswil</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/133933,chueematte-trail/" title="Chüematte Trail">Chüematte Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309476,dem-wetterhorn-entgegen-nr-2/" title="Dem Wetterhorn entgegen Nr. 2">Dem Wetterhorn entgegen Nr. 2</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/278777,vom-rinderberg-ueber-den-truettlisbergpass-nach-lenk/" title="Vom Rinderberg über den Trüttlisbergpass nach Lenk">Vom Rinderberg über den Trüttlisbergpass nach Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131734,lauenen--chrinepass--wispile/" title="Lauenen - Chrinepass - Wispile">Lauenen - Chrinepass - Wispile</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/733526,chasseral--der-abgeschiedene-huegelzug-hoch-ueber-dem-seeland/" title="Chasseral - der abgeschiedene Hügelzug hoch über dem Seeland">Chasseral - der abgeschiedene Hügelzug hoch über dem Seeland</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/707126,lauterbrunnen--stechelberg--so/" title="Lauterbrunnen   -  Stechelberg / So">Lauterbrunnen   -  Stechelberg / So</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/522366,der-klassiker-city-run-bussalp--weidli-nr-57/" title="Der Klassiker: «City Run» Bussalp – Weidli (Nr. 57)">Der Klassiker: «City Run» Bussalp – Weidli (Nr. 57)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/289433,panoramawanderung-von-muelenen-auf-den-niesen/" title="Panoramawanderung von Mülenen auf den Niesen">Panoramawanderung von Mülenen auf den Niesen</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/97618,schlittelweg-niederhorn--vorsass-beatenberg/" title="Schlittelweg Niederhorn - Vorsass  (Beatenberg)">Schlittelweg Niederhorn - Vorsass  (Beatenberg)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/158678,kemmeriboden-trail/" title="Kemmeriboden-Trail">Kemmeriboden-Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162712,hoehenweg-entlebuch-emmental--etappe-5-grosshorben--schangnau/" title="Höhenweg Entlebuch Emmental - Etappe 5: Grosshorben – Schangnau">Höhenweg Entlebuch Emmental - Etappe 5: Grosshorben – Schangnau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/503335,rundtour-oeschinensee--heuberg/" title="Rundtour Oeschinensee – Heuberg">Rundtour Oeschinensee – Heuberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/718571,mutthornhuette/" title="Mutthornhütte">Mutthornhütte</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/286179,schlittelspass-leiterli--stoss/" title="Schlittelspass Leiterli – Stoss">Schlittelspass Leiterli – Stoss</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133942,panoramaweg-aeschi--meielisalp--leissigen/" title="Panoramaweg Aeschi – Meielisalp – Leissigen">Panoramaweg Aeschi – Meielisalp – Leissigen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49461,es-isch-e-laenge-waeg-ufs-guggershoernli/" title="«Es isch e länge Wäg ufs Guggershörnli...»">«Es isch e länge Wäg ufs Guggershörnli...»</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/307031,lauberhorn-trail/" title="Lauberhorn Trail">Lauberhorn Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/156906,berner-oberland-weg-bruenigpass--amsoldingen/" title="Berner Oberland Weg: Brünigpass - Amsoldingen">Berner Oberland Weg: Brünigpass - Amsoldingen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/281199,unterseener-uferweg/" title="Unterseener Uferweg">Unterseener Uferweg</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/129286,von-schwanden-nach-goldiwil/" title="Von Schwanden nach Goldiwil">Von Schwanden nach Goldiwil</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/389013,loetschberger-nordrampe/" title="Lötschberger Nordrampe">Lötschberger Nordrampe</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/131657,saanen--gstaad--feutersoey--gsteig/" title="Saanen - Gstaad - Feutersoey - Gsteig">Saanen - Gstaad - Feutersoey - Gsteig</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/535344,waldspitz-loop-nr-3/" title="Waldspitz Loop (Nr. 3)">Waldspitz Loop (Nr. 3)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/51678,wiriehorn-trail--diemtigtal/" title="Wiriehorn Trail - Diemtigtal">Wiriehorn Trail - Diemtigtal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131169,interlaken--goldswil--baumgartisegg--harder-kulm/" title="Interlaken - Goldswil - Baumgartisegg - Harder Kulm">Interlaken - Goldswil - Baumgartisegg - Harder Kulm</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131814,axalphorn--meiringen/" title="Axalphorn - Meiringen">Axalphorn - Meiringen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/178573,vom-grimselpass-auf-das-sidelhorn/" title="Vom Grimselpass auf das Sidelhorn">Vom Grimselpass auf das Sidelhorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131973,glecksteinhuette/" title="Glecksteinhütte">Glecksteinhütte</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/185343,gstaad--wispile--lauenensee-nr-24/" title="Gstaad - Wispile - Lauenensee (Nr. 24)">Gstaad - Wispile - Lauenensee (Nr. 24)</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309493,abendrunde-nr-4/" title="Abendrunde Nr. 4">Abendrunde Nr. 4</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/164755,rundweg-engstligenalp/" title="Rundweg Engstligenalp">Rundweg Engstligenalp</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131804,chaenelegg-trail/" title="Chänelegg Trail">Chänelegg Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/98136,zu-onkel-thom-in-die-schnitzelscheune/" title="Zu Onkel Thom in die Schnitzelscheune">Zu Onkel Thom in die Schnitzelscheune</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/831318,rellerli-loop/" title="Rellerli Loop">Rellerli Loop</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/348116,saanenmoeser--schoenried--gstaad/" title="Saanenmöser – Schönried – Gstaad">Saanenmöser – Schönried – Gstaad</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/92457,auf-den-gurten-den-berner-hausberg/" title="Auf den Gurten, den Berner Hausberg">Auf den Gurten, den Berner Hausberg</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133924,gruenenbergpass/" title="Grünenbergpass">Grünenbergpass</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/524943,easy-maennlichen--holenstein-nr-61/" title="Easy Männlichen - Holenstein (Nr. 61)">Easy Männlichen - Holenstein (Nr. 61)</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156754,berner-oberlaender-weg-brienz--interlaken-variante-b/" title="Berner-Oberländer-Weg: Brienz - Interlaken (Variante B)">Berner-Oberländer-Weg: Brienz - Interlaken (Variante B)</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/49028,winter-talwanderweg-lenk--simmefaelle/" title="Winter-Talwanderweg Lenk - Simmefälle">Winter-Talwanderweg Lenk - Simmefälle</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/707177,schoenried-ermitage-gruben-runde/" title="Schönried Ermitage Gruben Runde">Schönried Ermitage Gruben Runde</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/616599,von-schwanden-sigriswil-via-winterberg-heiligenschwendi-nach-goldiwil-thun/" title="Von Schwanden (Sigriswil) via Winterberg (Heiligenschwendi) nach Goldiwil (Thun)">Von Schwanden (Sigriswil) via Winterberg (Heiligenschwendi) nach Goldiwil (Thun)</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/101612,schleifenroute-ch--jungfrau-region--schlittelroute-rodeln/" title="Schleifenroute CH / Jungfrau-Region / Schlittelroute (Rodeln)">Schleifenroute CH / Jungfrau-Region / Schlittelroute (Rodeln)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/52069,panorama-trail--grindelwald/" title="Panorama Trail - Grindelwald">Panorama Trail - Grindelwald</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/295431,diemtigtaler-hausweg-hinteres-tal/" title="Diemtigtaler Hausweg «Hinteres Tal»">Diemtigtaler Hausweg «Hinteres Tal»</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/131627,audioguide-saanen/" title="Audioguide Saanen">Audioguide Saanen</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/505584,globi-bergweg-engstligenalp/" title="Globi-Bergweg Engstligenalp">Globi-Bergweg Engstligenalp</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/110805,trachselwald/" title="Trachselwald">Trachselwald</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/522368,nachtschlittel-highlight-auf-der-bussalp-nr-57/" title="Nachtschlittel-Highlight auf der Bussalp (Nr. 57)">Nachtschlittel-Highlight auf der Bussalp (Nr. 57)</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/700241,veloweg-lenk--zweisimmen/" title="Veloweg Lenk - Zweisimmen">Veloweg Lenk - Zweisimmen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/109937,sommerwanderung-am-brienzersee/" title="Sommerwanderung am Brienzersee">Sommerwanderung am Brienzersee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48797,durch-die-wilde-aareschlucht/" title="Durch die wilde Aareschlucht">Durch die wilde Aareschlucht</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58126,auf-aussichtsreichem-hoehenweg/" title="Auf aussichtsreichem Höhenweg">Auf aussichtsreichem Höhenweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51623,das-emmental-von-der-moosegg-aus-gesehen/" title="Das Emmental von der Moosegg aus gesehen">Das Emmental von der Moosegg aus gesehen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131784,muerren--schilthorn-loop-11h/" title="Mürren - Schilthorn Loop (11h)">Mürren - Schilthorn Loop (11h)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/586724,der-steinige-weg-ueber-die-sefinafurgga/" title="Der steinige Weg über die Sefinafurgga">Der steinige Weg über die Sefinafurgga</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/900863,bergpanorama-und-sonne-pur/" title="Bergpanorama und Sonne pur">Bergpanorama und Sonne pur</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133088,panoramaweg-elsigenalp--adelboden/" title="Panoramaweg Elsigenalp - Adelboden">Panoramaweg Elsigenalp - Adelboden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/658324,durchs-jahr-wandern--krokusse-am-raemisgummen/" title="Durchs Jahr wandern - Krokusse am Rämisgummen">Durchs Jahr wandern - Krokusse am Rämisgummen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/358910,auf-dem-eiger-trail-nach-grindelwald/" title="Auf dem Eiger Trail nach Grindelwald">Auf dem Eiger Trail nach Grindelwald</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/358900,panoramaweg-kleine-scheidegg/" title="Panoramaweg Kleine Scheidegg">Panoramaweg Kleine Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/78168,baenkli-rundweg-aeschi-bei-spiez/" title="Bänkli-Rundweg Aeschi bei Spiez">Bänkli-Rundweg Aeschi bei Spiez</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/560726,dorfrundgang-in-gsteigwiler/" title="Dorfrundgang in Gsteigwiler">Dorfrundgang in Gsteigwiler</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/337168,horneggli--hornberg--rinderberg/" title="Horneggli - Hornberg - Rinderberg">Horneggli - Hornberg - Rinderberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50926,frei-wie-ein-vogel-ueber-der-lenk/" title="Frei wie ein Vogel über der Lenk">Frei wie ein Vogel über der Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/593367,grindelwald--bort/" title="Grindelwald - Bort">Grindelwald - Bort</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/831318,rellerli-loop/" title="Rellerli Loop">Rellerli Loop</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/658323,durchs-jahr-wandern--aprilglocken-im-berner-jura/" title="Durchs Jahr wandern - Aprilglocken im Berner Jura">Durchs Jahr wandern - Aprilglocken im Berner Jura</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129252,von-moutier-zum-lac-vert/" title="Von Moutier zum Lac Vert">Von Moutier zum Lac Vert</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/199823,course-de-la-solidarite/" title="Course de la solidarité">Course de la solidarité</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/365568,auf-dem-strandweg-von-interlaken-ost-nach-boenigen/" title="Auf dem Strandweg von Interlaken Ost nach Bönigen">Auf dem Strandweg von Interlaken Ost nach Bönigen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709667,ueschenegrat-wyssi-flue/" title="Üschenegrat-Wyssi Flue">Üschenegrat-Wyssi Flue</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/383171,tour-de-gruyere/" title="Tour de Gruyère">Tour de Gruyère</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48800,im-land-der-eggen-und-chraechen/" title="Im Land der Eggen und Chrächen">Im Land der Eggen und Chrächen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58126,auf-aussichtsreichem-hoehenweg/" title="Auf aussichtsreichem Höhenweg">Auf aussichtsreichem Höhenweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50182,berggenuss-rund-um-das-seehore/" title="Berggenuss rund um das Seehore">Berggenuss rund um das Seehore</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/301385,gurten-rundweg/" title="Gurten-Rundweg">Gurten-Rundweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129369,von-lauterbrunnen-nach-stechelberg/" title="Von Lauterbrunnen nach Stechelberg">Von Lauterbrunnen nach Stechelberg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/573726,unterwegs-auf-dem-sagenweg-im-bipper-jura/" title="Unterwegs auf dem Sagenweg im Bipper-Jura">Unterwegs auf dem Sagenweg im Bipper-Jura</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/358909,wanderung-von-muerren-zur-gruetschalp/" title="Wanderung von Mürren zur Grütschalp">Wanderung von Mürren zur Grütschalp</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309995,grosse-panoramarunde-nr-34/" title="Grosse Panoramarunde Nr. 34">Grosse Panoramarunde Nr. 34</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/83702,wanderung-weissenburg--oberwil/" title="Wanderung Weissenburg – Oberwil">Wanderung Weissenburg – Oberwil</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/482336,swiss-trail-tour-lenk-strecke-ultra-sonntag-2019/" title="Swiss Trail Tour Lenk, Strecke Ultra, Sonntag 2019">Swiss Trail Tour Lenk, Strecke Ultra, Sonntag 2019</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49260,durch-den-forst-ins-wehrhafte-laupen/" title="Durch den Forst ins wehrhafte Laupen">Durch den Forst ins wehrhafte Laupen</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/131949,muggestutz-1-zwergenweg-maegisalp-bidmi/" title="Muggestutz 1, Zwergenweg Mägisalp-Bidmi">Muggestutz 1, Zwergenweg Mägisalp-Bidmi</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/881291,diemtigtaler-niederhorn/" title="Diemtigtaler Niederhorn">Diemtigtaler Niederhorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48832,vom-jaunpass-nach-boltigen--blumen-kraeuter-und-alpkaese/" title="Vom Jaunpass nach Boltigen - Blumen, Kräuter und Alpkäse">Vom Jaunpass nach Boltigen - Blumen, Kräuter und Alpkäse</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51085,auf-den-berg-der-berge/" title="Auf den Berg der Berge">Auf den Berg der Berge</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/891220,gfw-15--rund-ume-frienisberger/" title="GFW 15 - Rund ume Frienisberger">GFW 15 - Rund ume Frienisberger</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/707177,schoenried-ermitage-gruben-runde/" title="Schönried Ermitage Gruben Runde">Schönried Ermitage Gruben Runde</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508340,ueber-den-boezingenberg-zur-taubenlochschlucht/" title="Über den Bözingenberg zur Taubenlochschlucht">Über den Bözingenberg zur Taubenlochschlucht</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/172154,panoramatrail-faltschen/" title="Panoramatrail Faltschen">Panoramatrail Faltschen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/271548,vom-maennlichen-zur-kleinen-scheidegg/" title="Vom Männlichen zur Kleinen Scheidegg">Vom Männlichen zur Kleinen Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/509373,hochparterre-mit-alpensicht/" title="Hochparterre mit Alpensicht">Hochparterre mit Alpensicht</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/289429,winterwanderweg-justistal/" title="Winterwanderweg Justistal">Winterwanderweg Justistal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/718574,loetschenpasshuette/" title="Lötschenpasshütte">Lötschenpasshütte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/62314,karrenfelder-und-tuempel/" title="Karrenfelder und Tümpel">Karrenfelder und Tümpel</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/132567,winterwanderweg-wiriehorn/" title="Winterwanderweg Wiriehorn">Winterwanderweg Wiriehorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709664,gaellihorn/" title="Gällihorn">Gällihorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162965,lauschiger-uferweg-am-brienzersee/" title="Lauschiger Uferweg am Brienzersee">Lauschiger Uferweg am Brienzersee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/232759,von-burgdorf-nach-solothurn/" title="Von Burgdorf nach Solothurn">Von Burgdorf nach Solothurn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58273,die-aussicht-lohnt-den-aufstieg/" title="Die Aussicht lohnt den Aufstieg">Die Aussicht lohnt den Aufstieg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/70039,zum-vreneli-ab-em-guggisbaerg/" title="«Zum Vreneli ab em Guggisbärg»">«Zum Vreneli ab em Guggisbärg»</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/277605,kandersteg-to-leukerbad-via-gemmipass/" title="Kandersteg to Leukerbad (via Gemmipass)">Kandersteg to Leukerbad (via Gemmipass)</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/49166,eiskristall-zauber-an-felswaenden/" title="Eiskristall-Zauber an Felswänden">Eiskristall-Zauber an Felswänden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/157952,vom-urbachtal-zur-gaulihuette/" title="Vom Urbachtal zur Gaulihütte">Vom Urbachtal zur Gaulihütte</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/374712,grosse-scheidegg/" title="Grosse Scheidegg">Grosse Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/303358,von-aeschi-nach-aeschiried/" title="Von Aeschi nach Aeschiried">Von Aeschi nach Aeschiried</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/348103,gstaad--lauenensee--gstaad-singletrail-version/" title="Gstaad - Lauenensee - Gstaad (Singletrail Version)">Gstaad - Lauenensee - Gstaad (Singletrail Version)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/174595,wandern-am-wasser--gelmersee/" title="Wandern am Wasser - Gelmersee">Wandern am Wasser - Gelmersee</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/131893,maennlichen--kleine-scheidegg-nr-63/" title="Männlichen - Kleine Scheidegg (Nr. 63)">Männlichen - Kleine Scheidegg (Nr. 63)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/577444,grindelwald--abbachfall--bussalp/" title="Grindelwald - Abbachfall - Bussalp">Grindelwald - Abbachfall - Bussalp</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49113,das-tal-der-kraeftigen-maedchen/" title="Das Tal der kräftigen Mädchen">Das Tal der kräftigen Mädchen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48828,auf-dem-hoehenwegen-zum-badesee/" title="Auf dem Höhenwegen zum Badesee">Auf dem Höhenwegen zum Badesee</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/524950,die-winter-genuss-runde-an-der-sonnseite-w1/" title="Die Winter Genuss Runde an der Sonnseite W1">Die Winter Genuss Runde an der Sonnseite W1</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51012,durch-das-schwarzenburgerland/" title="Durch das Schwarzenburgerland">Durch das Schwarzenburgerland</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/132575,vogelweg--vom-rotmilan-zur-wasseramsel/" title="Vogelweg - vom Rotmilan zur Wasseramsel">Vogelweg - vom Rotmilan zur Wasseramsel</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50182,berggenuss-rund-um-das-seehore/" title="Berggenuss rund um das Seehore">Berggenuss rund um das Seehore</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/691505,lenk--metsch--metschmaad--buehlberg--lenk/" title="Lenk - Metsch - Metschmaad - Bühlberg - Lenk">Lenk - Metsch - Metschmaad - Bühlberg - Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49177,auf-altem-passweg-zur-grossen-scheidegg/" title="Auf altem Passweg zur Grossen Scheidegg">Auf altem Passweg zur Grossen Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/269686,von-burgdorf-nach-hasle-rueegsau/" title="Von Burgdorf nach Hasle-Rüegsau">Von Burgdorf nach Hasle-Rüegsau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/84396,meiringen--wo-kunst-und-geschichte-sich-erwandern-lassen/" title="Meiringen - Wo Kunst und Geschichte sich erwandern lassen">Meiringen - Wo Kunst und Geschichte sich erwandern lassen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48827,uferweg-idylle-am-brienzersee/" title="Uferweg-Idylle am Brienzersee">Uferweg-Idylle am Brienzersee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/917867,rund-um-bern--rund-um-den-huernberg/" title="Rund um Bern - rund um den Hürnberg">Rund um Bern - rund um den Hürnberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131977,bergsee--gletscherweg-first--grosse-scheidegg/" title="«Bergsee- &amp; Gletscherweg» First - Grosse Scheidegg">«Bergsee- &amp; Gletscherweg» First - Grosse Scheidegg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/53598,murmeli-trail/" title="Murmeli Trail">Murmeli Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49331,twannbachschlucht/" title="Twannbachschlucht">Twannbachschlucht</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131981,schynige-platte--maenndlenen--faulhorn--first/" title="Schynige Platte - Männdlenen - Faulhorn - First">Schynige Platte - Männdlenen - Faulhorn - First</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309952,seen-tour-am-fuss-des-wildgaerst-nr-35/" title="Seen-Tour am Fuss des Wildgärst Nr. 35">Seen-Tour am Fuss des Wildgärst Nr. 35</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129252,von-moutier-zum-lac-vert/" title="Von Moutier zum Lac Vert">Von Moutier zum Lac Vert</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/59027,mit-dem-schlitten-zur-aussichtskanzel-des-haslitals/" title="Mit dem Schlitten zur Aussichtskanzel des Haslitals">Mit dem Schlitten zur Aussichtskanzel des Haslitals</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48961,zu-alpenluft-und-schwefelduft/" title="Zu Alpenluft und Schwefelduft">Zu Alpenluft und Schwefelduft</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/70014,chaenelegg-trail--muerren/" title="Chänelegg Trail - Mürren">Chänelegg Trail - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49286,zum-aussichtsreichen-berg-ohne-namen/" title="Zum aussichtsreichen «Berg ohne Namen»">Zum aussichtsreichen «Berg ohne Namen»</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508338,in-die-heimat-von-karl-grunder/" title="In die Heimat von Karl Grunder">In die Heimat von Karl Grunder</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/744974,hohtuerli-2778-m/" title="Hohtürli 2778 m">Hohtürli 2778 m</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709672,giesene-sattelhore/" title="Giesene-Sattelhore">Giesene-Sattelhore</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/97591,schlittelweg-maennlichen--hollenstein-grindelwald/" title="Schlittelweg Männlichen - Hollenstein (Grindelwald)">Schlittelweg Männlichen - Hollenstein (Grindelwald)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49120,ueber-die-sonnigen-hoehen-blasenflue-und-moosegg/" title="Über die sonnigen Höhen Blasenflue und Moosegg">Über die sonnigen Höhen Blasenflue und Moosegg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/113853,ein-hoehenweg-der-seinesgleichen-sucht/" title="Ein Höhenweg, der seinesgleichen sucht!">Ein Höhenweg, der seinesgleichen sucht!</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/123933,lauterbrunnen-to-wengen/" title="Lauterbrunnen to Wengen">Lauterbrunnen to Wengen</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/49244,arktische-insel-im-berner-oberland/" title="Arktische Insel im Berner Oberland">Arktische Insel im Berner Oberland</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49220,hoehenweg-mit-ausserordentlicher-hochalpen-sicht/" title="Höhenweg mit ausserordentlicher Hochalpen-Sicht">Höhenweg mit ausserordentlicher Hochalpen-Sicht</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/95872,hinterburgseeli-trail-axalp/" title="Hinterburgseeli Trail (Axalp)">Hinterburgseeli Trail (Axalp)</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309955,trailsummit-rotstock-t5/" title="Trailsummit Rotstock T5">Trailsummit Rotstock T5</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51009,aussichtsreiche-huegel-und-stille-waelder/" title="Aussichtsreiche Hügel und stille Wälder">Aussichtsreiche Hügel und stille Wälder</a>
# <a class="h2" href="/sommer/bern-region/touren/hochtour/14760,hockenhorntour-ab-kandersteg/" title="Hockenhorn Hike (from Kandersteg)">Hockenhorn Hike (from Kandersteg)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58275,sanfter-uebergang-ins-diemtigtal/" title="Sanfter Übergang ins Diemtigtal">Sanfter Übergang ins Diemtigtal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131629,via-alpina-gstaad--letivaz/" title="Via Alpina: Gstaad - L'Etivaz">Via Alpina: Gstaad - L'Etivaz</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58274,baedergeschichte-und-alpkultur-auf-der-via-casea-im-simmental/" title="Bädergeschichte und Alpkultur auf der Via Casea im Simmental">Bädergeschichte und Alpkultur auf der Via Casea im Simmental</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/131679,gstaad--lauenensee--gstaad/" title="Gstaad - Lauenensee - Gstaad">Gstaad - Lauenensee - Gstaad</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/63186,route-gurnigel--wattenwil/" title="Route Gurnigel – Wattenwil">Route Gurnigel – Wattenwil</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49231,ins-herz-des-fraubrunnenamtes/" title="Ins Herz des Fraubrunnenamtes">Ins Herz des Fraubrunnenamtes</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50214,zu-einem-der-schoensten-amtssitze-im-kanton-bern/" title="Zu einem der schönsten Amtssitze im Kanton Bern">Zu einem der schönsten Amtssitze im Kanton Bern</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/100447,zum-seebergsee-100-natur--0-hartbelag/" title="Zum Seebergsee: 100% Natur – 0% Hartbelag">Zum Seebergsee: 100% Natur – 0% Hartbelag</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/164755,rundweg-engstligenalp/" title="Rundweg Engstligenalp">Rundweg Engstligenalp</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/288421,allmendhubel--muerren-bob-run/" title="Allmendhubel - Mürren (Bob Run)">Allmendhubel - Mürren (Bob Run)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50425,an-stolzen-bauernsitzen-vorueber-durch-den-suedlichen-oberaargau/" title="An stolzen Bauernsitzen vorüber durch den südlichen Oberaargau">An stolzen Bauernsitzen vorüber durch den südlichen Oberaargau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/327996,rundtour-von-burgdorf-ueber-die-rothoehe/" title="Rundtour von Burgdorf über die Rothöhe">Rundtour von Burgdorf über die Rothöhe</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/131766,tour-de-la-reine-sud/" title="Tour de la reine sud">Tour de la reine sud</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/471054,aare-route-etappe-5-von-biel-nach-solothurn/" title="Aare-Route, Etappe 5: Von Biel nach Solothurn">Aare-Route, Etappe 5: Von Biel nach Solothurn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/55103,auf-sonnigem-hoehenweg/" title="Auf sonnigem Höhenweg">Auf sonnigem Höhenweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/100448,im-innereriz-abseits-der-grossen-touristenstroeme/" title="Im Innereriz, abseits der grossen Touristenströme">Im Innereriz, abseits der grossen Touristenströme</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/224315,walk-to-lenk/" title="Walk to Lenk">Walk to Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508330,durch-das-wachseldornmoos/" title="Durch das Wachseldornmoos">Durch das Wachseldornmoos</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114256,zur-hohwacht-im-emmental/" title="Zur Hohwacht im Emmental">Zur Hohwacht im Emmental</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/95783,winter-rundwanderung-aeschi-bei-spiez/" title="Winter-Rundwanderung Aeschi bei Spiez">Winter-Rundwanderung Aeschi bei Spiez</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51620,zum-aussichts-turm-auf-dem-moron/" title="Zum Aussichts-Turm auf dem Moron">Zum Aussichts-Turm auf dem Moron</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131460,wengen--leiterhorn--spaetenalp--burglauenen/" title="Wengen - Leiterhorn - Spätenalp - Burglauenen">Wengen - Leiterhorn - Spätenalp - Burglauenen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162934,auf-verschlungenen-wegen-zum-niesenbaenkli/" title="Auf verschlungenen Wegen zum Niesenbänkli">Auf verschlungenen Wegen zum Niesenbänkli</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/691484,lenk-iffigfall-langermatte-rezliberg-simmenfaelle-lenk/" title="Lenk-Iffigfall-Langermatte-Rezliberg-Simmenfälle-Lenk">Lenk-Iffigfall-Langermatte-Rezliberg-Simmenfälle-Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49293,viel-aussicht-in-den-buchsi-und-wynigenbergen/" title="Viel Aussicht in den Buchsi- und Wynigenbergen">Viel Aussicht in den Buchsi- und Wynigenbergen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50398,passwanderung-ins-gruene-eriz/" title="Passwanderung ins grüne Eriz">Passwanderung ins grüne Eriz</a>
# <a class="h2" href="/sommer/bern-region/touren/klettersteig/156126,klettersteig-tierbergli/" title="Klettersteig Tierbergli">Klettersteig Tierbergli</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/97616,schlittelweg-oeschinensee--kandersteg/" title="Schlittelweg Oeschinensee - Kandersteg">Schlittelweg Oeschinensee - Kandersteg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/109938,wandern-in-der-heimat-des-vogellisis-von-adelboden/" title="Wandern in der Heimat des Vogellisis von Adelboden">Wandern in der Heimat des Vogellisis von Adelboden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49281,wo-ehemals-berndeutsch-gesprochen-wurde/" title="Wo ehemals Berndeutsch gesprochen wurde">Wo ehemals Berndeutsch gesprochen wurde</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156754,berner-oberlaender-weg-brienz--interlaken-variante-b/" title="Berner-Oberländer-Weg: Brienz - Interlaken (Variante B)">Berner-Oberländer-Weg: Brienz - Interlaken (Variante B)</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/837028,trailrunning-rund-um-adelboden/" title="Trailrunning Rund um Adelboden">Trailrunning Rund um Adelboden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58074,natur-pur-am-geltenschuss/" title="Natur pur am Geltenschuss">Natur pur am Geltenschuss</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/700234,st-stephan--duerrewald--eggmatte--st-stephan/" title="St. Stephan - Dürrewald - Eggmatte - St. Stephan">St. Stephan - Dürrewald - Eggmatte - St. Stephan</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58275,sanfter-uebergang-ins-diemtigtal/" title="Sanfter Übergang ins Diemtigtal">Sanfter Übergang ins Diemtigtal</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48965,durch-die-auenlandschaft-an-der-alten-aare/" title="Durch die Auenlandschaft an der Alten Aare">Durch die Auenlandschaft an der Alten Aare</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/315038,schneeschuhtrail-grimmialp/" title="Schneeschuhtrail Grimmialp">Schneeschuhtrail Grimmialp</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156818,luzerner-weg-huttwil--burgdorf/" title="Luzerner Weg: Huttwil - Burgdorf">Luzerner Weg: Huttwil - Burgdorf</a>
# <a class="h2" href="/sommer/bern-region/touren/skitour/911345,lauenen--tossenstand-1917-muem/" title="Lauenen - Tossenstand (1917 M.ü.M)">Lauenen - Tossenstand (1917 M.ü.M)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/161541,eiger-trail-von-holenstein-nach-brandegg/" title="Eiger-Trail von Holenstein nach Brandegg">Eiger-Trail von Holenstein nach Brandegg</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/310000,uphilltrail-pfingstegg-u4/" title="Uphilltrail Pfingstegg U4">Uphilltrail Pfingstegg U4</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131939,stechelberg--sefinental--rotstockhuette--muerren/" title="Stechelberg - Sefinental - Rotstockhütte - Mürren">Stechelberg - Sefinental - Rotstockhütte - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/698706,kandersteg--hoeh-biketour/" title="Kandersteg - Höh Biketour">Kandersteg - Höh Biketour</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/97609,schlittelweg-sparenmoos--zweisimmen/" title="Schlittelweg Sparenmoos - Zweisimmen">Schlittelweg Sparenmoos - Zweisimmen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/315060,lauterbrunnen--wengen/" title="Lauterbrunnen - Wengen">Lauterbrunnen - Wengen</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/70018,jaunpass-trail--boltigen/" title="Jaunpass Trail - Boltigen">Jaunpass Trail - Boltigen</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133924,gruenenbergpass/" title="Grünenbergpass">Grünenbergpass</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/83713,wanderung-axalp--axalp/" title="Wanderung Axalp – Axalp">Wanderung Axalp – Axalp</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/149251,durch-einstiges-schwemmgebiet-beim-haeftli/" title="Durch einstiges Schwemmgebiet beim Häftli">Durch einstiges Schwemmgebiet beim Häftli</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508309,liebliche-landschaft-am-thunersee/" title="Liebliche Landschaft am Thunersee">Liebliche Landschaft am Thunersee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/744921,arvenseeli/" title="Arvenseeli">Arvenseeli</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/95944,alpwaeg-trail--grindelwald/" title="Alpwäg Trail - Grindelwald">Alpwäg Trail - Grindelwald</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/60249,engelberg--lungern/" title="Engelberg - Lungern">Engelberg - Lungern</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114192,naturerlebnisse-an-der-lenk/" title="Naturerlebnisse an der Lenk">Naturerlebnisse an der Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49286,zum-aussichtsreichen-berg-ohne-namen/" title="Zum aussichtsreichen «Berg ohne Namen»">Zum aussichtsreichen «Berg ohne Namen»</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/894203,talstation-betelberg--seefluh--staldengaessli--talst-betelberg/" title="Talstation Betelberg - Seefluh - Staldengässli - Talst. Betelberg">Talstation Betelberg - Seefluh - Staldengässli - Talst. Betelberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162908,schynige-platte-rundweg--top-sicht-auf-das-dreigestirn/" title="Schynige-Platte-Rundweg - Top Sicht auf das Dreigestirn">Schynige-Platte-Rundweg - Top Sicht auf das Dreigestirn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131887,eiger-trail-eigergletscher--alpiglen/" title="«Eiger Trail» Eigergletscher - Alpiglen">«Eiger Trail» Eigergletscher - Alpiglen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49038,bern-ost-vom-schlosspark-zur-alpensicht/" title="Bern-Ost: Vom Schlosspark zur Alpensicht">Bern-Ost: Vom Schlosspark zur Alpensicht</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/524950,die-winter-genuss-runde-an-der-sonnseite-w1/" title="Die Winter Genuss Runde an der Sonnseite W1">Die Winter Genuss Runde an der Sonnseite W1</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/275647,geissewaeg--die-wasen-genusstour-vorderarniwaeg/" title="Geissewäg – die Wasen-Genusstour (Vorderarniwäg)">Geissewäg – die Wasen-Genusstour (Vorderarniwäg)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49175,schatt-und-sonnseits-der-gadmerflue/" title="Schatt- und sonnseits der Gadmerflue">Schatt- und sonnseits der Gadmerflue</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/870923,alpine-bike-1--kiental-frutigen--adelboden--lenk/" title="Alpine Bike 1 -  Kiental- Frutigen - Adelboden - Lenk">Alpine Bike 1 -  Kiental- Frutigen - Adelboden - Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/58650,auf-dem-zulg-talweg/" title="Auf dem Zulg-Talweg">Auf dem Zulg-Talweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/563549,rundtour-von-riedtwil-zum-mutzbachfall/" title="Rundtour von Riedtwil zum Mutzbachfall">Rundtour von Riedtwil zum Mutzbachfall</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/67763,kemmeriboden--bumbach-trail-in-schangnau/" title="Kemmeriboden - Bumbach Trail in Schangnau">Kemmeriboden - Bumbach Trail in Schangnau</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/374711,grimselpass/" title="Grimselpass">Grimselpass</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/75399,sentier-des-monts--mont-soleil/" title="Sentier des Monts - Mont Soleil">Sentier des Monts - Mont Soleil</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/288418,easy-maennlichen--holenstein-nr-61/" title="Easy Männlichen - Holenstein (Nr. 61)">Easy Männlichen - Holenstein (Nr. 61)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/174602,wandern-am-wasser--gaebelbach/" title="Wandern am Wasser - Gäbelbach">Wandern am Wasser - Gäbelbach</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156816,luzerner-weg-bern--rueeggisberg/" title="Luzerner Weg: Bern - Rüeggisberg">Luzerner Weg: Bern - Rüeggisberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162941,grueenenbergpass--aus-dem-waldland-ins-gebiet-der-hochmoore/" title="Grüenenbergpass – aus dem Waldland ins Gebiet der Hochmoore">Grüenenbergpass – aus dem Waldland ins Gebiet der Hochmoore</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/70021,griesalp-trail--kiental/" title="Griesalp Trail - Kiental">Griesalp Trail - Kiental</a>
# <a class="h2" href="/sommer/bern-region/touren/trailrunning/309951,trailsummit-schwarzhorn-t2/" title="Trailsummit Schwarzhorn T2">Trailsummit Schwarzhorn T2</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114220,zum-aussichtsturm-auf-dem-moron/" title="Zum Aussichtsturm auf dem Moron">Zum Aussichtsturm auf dem Moron</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/175702,vom-grimselpass-ueber-das-sidelhorn-zum-oberaargletscher/" title="Vom Grimselpass über das Sidelhorn zum Oberaargletscher">Vom Grimselpass über das Sidelhorn zum Oberaargletscher</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/59027,mit-dem-schlitten-zur-aussichtskanzel-des-haslitals/" title="Mit dem Schlitten zur Aussichtskanzel des Haslitals">Mit dem Schlitten zur Aussichtskanzel des Haslitals</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508321,ueber-zehn-bruecken/" title="Über zehn Brücken">Über zehn Brücken</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/75407,childrens-adventure-trail--muerren/" title="Children's Adventure Trail - Mürren">Children's Adventure Trail - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/49060,durchs-jahr-wandern--panorama-winterwanderweg-wispile-fondue-tour/" title="Durchs Jahr Wandern - Panorama-Winterwanderweg Wispile (Fondue-Tour)">Durchs Jahr Wandern - Panorama-Winterwanderweg Wispile (Fondue-Tour)</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/131752,schoenried--gruben--gstaad/" title="Schönried - Gruben - Gstaad">Schönried - Gruben - Gstaad</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/65320,luchs-trail--lenk/" title="Luchs Trail - Lenk">Luchs Trail - Lenk</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51218,mittelalterliche-staetten-am-aare-uferweg/" title="Mittelalterliche Stätten am Aare-Uferweg">Mittelalterliche Stätten am Aare-Uferweg</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/707150,zweisimmen--mannried--grubenwald--seebergsee--zweisimmen/" title="Zweisimmen - Mannried - Grubenwald - Seebergsee - Zweisimmen">Zweisimmen - Mannried - Grubenwald - Seebergsee - Zweisimmen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49289,eine-barocke-klosterkirche-am-wanderweg/" title="Eine barocke Klosterkirche am Wanderweg">Eine barocke Klosterkirche am Wanderweg</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/97580,schlittelweg-maegisalp--bidmi-hasliberg/" title="Schlittelweg Mägisalp - Bidmi (Hasliberg)">Schlittelweg Mägisalp - Bidmi (Hasliberg)</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/286179,schlittelspass-leiterli--stoss/" title="Schlittelspass Leiterli – Stoss">Schlittelspass Leiterli – Stoss</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/166512,ueber-die-buetschelegg-zur-klosterruine/" title="Über die Bütschelegg zur Klosterruine">Über die Bütschelegg zur Klosterruine</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/289450,bussalp--rasthysi--bort-nr-56/" title="Bussalp - Rasthysi - Bort (Nr. 56)">Bussalp - Rasthysi - Bort (Nr. 56)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50349,licht-und-ruhe-auf-der-waetterlatte/" title="Licht und Ruhe auf der Wätterlatte">Licht und Ruhe auf der Wätterlatte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49176,wilder-uebergang-vom-gadmertal-ins-haslital/" title="Wilder Übergang vom Gadmertal ins Haslital">Wilder Übergang vom Gadmertal ins Haslital</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51663,durch-die-freiberge-auf-den-mont-soleil/" title="Durch die Freiberge auf den Mont Soleil">Durch die Freiberge auf den Mont Soleil</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48955,den-lenker-bergriesen-nahe/" title="Den Lenker Bergriesen nahe">Den Lenker Bergriesen nahe</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/97600,schlittelweg-betelberg--poeschenried-lenk/" title="Schlittelweg Betelberg - Pöschenried (Lenk)">Schlittelweg Betelberg - Pöschenried (Lenk)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/532162,muehlebach-trail/" title="Mühlebach Trail">Mühlebach Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/93370,engstligenalp-trail--adelboden/" title="Engstligenalp Trail - Adelboden">Engstligenalp Trail - Adelboden</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/875918,engstligenalp--chindbettipass--daubensee--gemmipass/" title="Engstligenalp – Chindbettipass – Daubensee – Gemmipass">Engstligenalp – Chindbettipass – Daubensee – Gemmipass</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/586724,der-steinige-weg-ueber-die-sefinafurgga/" title="Der steinige Weg über die Sefinafurgga">Der steinige Weg über die Sefinafurgga</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49311,ueber-den-mont-sujet/" title="Über den Mont Sujet">Über den Mont Sujet</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49854,durch-felder-und-waelder-am-bucheggberg/" title="Durch Felder und Wälder am Bucheggberg">Durch Felder und Wälder am Bucheggberg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/78168,baenkli-rundweg-aeschi-bei-spiez/" title="Bänkli-Rundweg Aeschi bei Spiez">Bänkli-Rundweg Aeschi bei Spiez</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49794,von-schloss-zu-schloss-ueber-ulmiz-und-lisiberg/" title="Von Schloss zu Schloss über Ulmiz- und Lisiberg">Von Schloss zu Schloss über Ulmiz- und Lisiberg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/563594,wen-hdw--holenstein--oepfelchueechliweg--brandegg/" title="WEN-HDW - Holenstein - Öpfelchüechliweg - Brandegg">WEN-HDW - Holenstein - Öpfelchüechliweg - Brandegg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/58844,simmentaler-hausweg-terrassenweg/" title="Simmentaler Hausweg (Terrassenweg)">Simmentaler Hausweg (Terrassenweg)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50426,col-du-pillon--schluessel-zum-diablerets-gebiet/" title="Col du Pillon - Schlüssel zum Diablerets-Gebiet">Col du Pillon - Schlüssel zum Diablerets-Gebiet</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/295442,diemtigtaler-hausweg-vorderes-tal/" title="Diemtigtaler Hausweg «Vorderes Tal»">Diemtigtaler Hausweg «Vorderes Tal»</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162906,auf-dem-panoramaweg-elsigenalp--frutigen/" title="Auf dem Panoramaweg Elsigenalp - Frutigen">Auf dem Panoramaweg Elsigenalp - Frutigen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49256,aus-der-stadt-der-stolzen-bruecken-zur-wiege-der-schweizer-post/" title="Aus der Stadt der stolzen Brücken zur Wiege der Schweizer Post">Aus der Stadt der stolzen Brücken zur Wiege der Schweizer Post</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/76615,beatusweg--beatenberg/" title="Beatusweg - Beatenberg">Beatusweg - Beatenberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/110614,arnihaaggen--brienzer-rothorn/" title="Arnihaaggen – Brienzer Rothorn">Arnihaaggen – Brienzer Rothorn</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/159628,von-schangnau-auf-den-raemisgummenhoger/" title="Von Schangnau auf den Rämisgummenhoger">Von Schangnau auf den Rämisgummenhoger</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/76670,durch-die-wilde-landschaft/" title="Durch die wilde Landschaft">Durch die wilde Landschaft</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/131857,sulwald-trail/" title="Sulwald Trail">Sulwald Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508317,viel-erleben--kurz-wandern/" title="Viel erleben – kurz wandern">Viel erleben – kurz wandern</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/133944,schnitzlerweg/" title="Schnitzlerweg">Schnitzlerweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129342,von-habkern-ueber-den-gruenenbergpass-ins-eriz/" title="Von Habkern über den Grünenbergpass ins Eriz">Von Habkern über den Grünenbergpass ins Eriz</a>
# ...
# <a class="h2" href="/sommer/bern-region/touren/wanderung/83713,wanderung-axalp--axalp/" title="Wanderung Axalp – Axalp">Wanderung Axalp – Axalp</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/361145,wen-dw--eigertrail--eigergletschertrail/" title="WEN-DW - Eigertrail - Eigergletschertrail">WEN-DW - Eigertrail - Eigergletschertrail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/133941,baettenalp--kulturlandschaftspreis-2007/" title="Bättenalp -  Kulturlandschaftspreis 2007">Bättenalp -  Kulturlandschaftspreis 2007</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/717235,zweisimmen--oey-diemtigen--zwischenflueh--seebergsee--meieberg--zweisimmen/" title="Zweisimmen - Oey Diemtigen - Zwischenflüh - Seebergsee - Meieberg - Zweisimmen">Zweisimmen - Oey Diemtigen - Zwischenflüh - Seebergsee - Meieberg - Zweisimmen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162934,auf-verschlungenen-wegen-zum-niesenbaenkli/" title="Auf verschlungenen Wegen zum Niesenbänkli">Auf verschlungenen Wegen zum Niesenbänkli</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/524943,easy-maennlichen--holenstein-nr-61/" title="Easy Männlichen - Holenstein (Nr. 61)">Easy Männlichen - Holenstein (Nr. 61)</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/51343,hoehenwanderung-von-der-bussalp-zum-bort/" title="Höhenwanderung von der Bussalp zum Bort">Höhenwanderung von der Bussalp zum Bort</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48828,auf-dem-hoehenwegen-zum-badesee/" title="Auf dem Höhenwegen zum Badesee">Auf dem Höhenwegen zum Badesee</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/315043,schneeschuhtrail-wiriehorn/" title="Schneeschuhtrail Wiriehorn">Schneeschuhtrail Wiriehorn</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/159047,vom-meniggrund-ueber-meniggrat-und-stand/" title="Vom Meniggrund über Meniggrat und Stand">Vom Meniggrund über Meniggrat und Stand</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/315062,maennlichen--kleine-scheidegg--panoramaweg/" title="Männlichen - Kleine Scheidegg | Panoramaweg">Männlichen - Kleine Scheidegg | Panoramaweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51573,zum-wunderbaren-seebergsee/" title="Zum wunderbaren Seebergsee">Zum wunderbaren Seebergsee</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/131897,alpine-bike-etappe-11-meiringen--grindelwald/" title="Alpine Bike, Etappe 11: Meiringen - Grindelwald">Alpine Bike, Etappe 11: Meiringen - Grindelwald</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/641941,wen-wiw--muerren/" title="WEN-WIW - Mürren">WEN-WIW - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/174780,wandern-am-wasser--aare/" title="Wandern am Wasser - Aare">Wandern am Wasser - Aare</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/509595,gfw-14--durch-die-aareauen/" title="GFW 14 - Durch die Aareauen">GFW 14 - Durch die Aareauen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/509619,gfw-27--taubenlochschlucht/" title="GFW 27 - Taubenlochschlucht">GFW 27 - Taubenlochschlucht</a>
# <a class="h2" href="/sommer/bern-region/touren/radfahren/131855,lauterbrunnen--trachsellauenen/" title="Lauterbrunnen - Trachsellauenen">Lauterbrunnen - Trachsellauenen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709672,giesene-sattelhore/" title="Giesene-Sattelhore">Giesene-Sattelhore</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/131770,koenigsrunde-nord/" title="Königsrunde Nord">Königsrunde Nord</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131611,wispile--chrine--gsteig/" title="Wispile - Chrine - Gsteig">Wispile - Chrine - Gsteig</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129224,von-der-engstligenalp-zur-iffigenalp/" title="Von der Engstligenalp zur Iffigenalp">Von der Engstligenalp zur Iffigenalp</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156784,drei-seen-weg-perrefitte--bellelay/" title="Drei-Seen-Weg: Perrefitte - Bellelay">Drei-Seen-Weg: Perrefitte - Bellelay</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/315064,zweiluetschinen--lauterbrunnen/" title="Zweilütschinen - Lauterbrunnen">Zweilütschinen - Lauterbrunnen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/276224,zum-saengeliweiher/" title="Zum Sängeliweiher">Zum Sängeliweiher</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/294666,wanderweg-zum-fondue-huettli-chessler/" title="Wanderweg zum Fondue Hüttli Chessler">Wanderweg zum Fondue Hüttli Chessler</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/718573,laemmerenhuette/" title="Lämmerenhütte">Lämmerenhütte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49183,zur-weiten-alpensicht/" title="Zur weiten Alpensicht">Zur weiten Alpensicht</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/709667,ueschenegrat-wyssi-flue/" title="Üschenegrat-Wyssi Flue">Üschenegrat-Wyssi Flue</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162700,der-gurten--warum-in-die-ferne-schweifen/" title="Der Gurten - Warum in die Ferne schweifen…">Der Gurten - Warum in die Ferne schweifen…</a>
# <a class="h2" href="/sommer/bern-region/touren/pilgerweg/156763,berner-oberlaender-weg-merligen--thun-variante-b/" title="Berner-Oberländer-Weg: Merligen - Thun (Variante B)">Berner-Oberländer-Weg: Merligen - Thun (Variante B)</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/53111,stock-trail--kandersteg/" title="Stock Trail - Kandersteg">Stock Trail - Kandersteg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/65312,weltcuptrail-chuenisbaergli/" title="Weltcuptrail Chuenisbärgli">Weltcuptrail Chuenisbärgli</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49223,auf-dem-eigertrail-eigernordwand-hautnah/" title="Auf dem Eigertrail: Eigernordwand hautnah">Auf dem Eigertrail: Eigernordwand hautnah</a>
# <a class="h2" href="/sommer/bern-region/touren/rodeln/272895,hornberg-run/" title="Hornberg Run">Hornberg Run</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/131891,first--bachalpsee--faulhorn--bussalp-nr-50/" title="First - Bachalpsee - Faulhorn - Bussalp (Nr. 50)">First - Bachalpsee - Faulhorn - Bussalp (Nr. 50)</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/526953,kleine-scheidegg--wengen-nr-66/" title="Kleine Scheidegg - Wengen (Nr. 66)">Kleine Scheidegg - Wengen (Nr. 66)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508314,stadt--land--mitenand/" title="Stadt – Land – mitenand">Stadt – Land – mitenand</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50432,auf-den-spuren-der-taeufer-zum-chasseral/" title="Auf den Spuren der Täufer zum Chasseral">Auf den Spuren der Täufer zum Chasseral</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/795214,griesalp--bundalp--griesalp/" title="Griesalp - Bundalp - Griesalp">Griesalp - Bundalp - Griesalp</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/113481,stockhorn-2190-m/" title="Stockhorn, 2190 m">Stockhorn, 2190 m</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/133914,tour-ins-imposante-tal-der-wasserfaelle/" title="Tour ins imposante Tal der Wasserfälle">Tour ins imposante Tal der Wasserfälle</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48962,im-bann-der-blueemlisalp-oeschinenrundweg/" title="Im Bann der Blüemlisalp (Oeschinenrundweg)">Im Bann der Blüemlisalp (Oeschinenrundweg)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/348119,schoenried--rellerli--grossi-vorschess--bergmatte--schoenried/" title="Schönried – Rellerli – Grossi Vorschess – Bergmatte - Schönried">Schönried – Rellerli – Grossi Vorschess – Bergmatte - Schönried</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/101588,ueber-den-chapf--emmental-pur/" title="Über den Chapf - Emmental pur">Über den Chapf - Emmental pur</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51392,ueber-stille-jura-weiden-zu-einem-vertraeumten-waldsee/" title="Über stille Jura-Weiden zu einem verträumten Waldsee">Über stille Jura-Weiden zu einem verträumten Waldsee</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51621,durch-eine-eindrueckliche-klus/" title="Durch eine eindrückliche Klus">Durch eine eindrückliche Klus</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/315064,zweiluetschinen--lauterbrunnen/" title="Zweilütschinen - Lauterbrunnen">Zweilütschinen - Lauterbrunnen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/129226,von-der-griesalp-ueber-das-hohtuerli-nach-kandersteg/" title="Von der Griesalp über das Hohtürli nach Kandersteg">Von der Griesalp über das Hohtürli nach Kandersteg</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/49974,ramslauenen-trail--kiental/" title="Ramslauenen Trail - Kiental">Ramslauenen Trail - Kiental</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/304811,beobachtungsweg-laegerstutz-winterroescht-faerrich-laegerstutz/" title="Beobachtungsweg Lägerstutz-Winterröscht-Färrich-Lägerstutz">Beobachtungsweg Lägerstutz-Winterröscht-Färrich-Lägerstutz</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48801,viel-emmental-in-kurzer-zeit/" title="Viel Emmental in kurzer Zeit">Viel Emmental in kurzer Zeit</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/58844,simmentaler-hausweg-terrassenweg/" title="Simmentaler Hausweg (Terrassenweg)">Simmentaler Hausweg (Terrassenweg)</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/99639,probsteberg--einsames-grenzgebiet-bern-solothurn/" title="Probsteberg - einsames Grenzgebiet Bern/Solothurn">Probsteberg - einsames Grenzgebiet Bern/Solothurn</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/131752,schoenried--gruben--gstaad/" title="Schönried - Gruben - Gstaad">Schönried - Gruben - Gstaad</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/84519,auf-den-bantiger-der-stadtnahe-aussichtsberg/" title="Auf den Bantiger, der Stadtnahe Aussichtsberg">Auf den Bantiger, der Stadtnahe Aussichtsberg</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/131679,gstaad--lauenensee--gstaad/" title="Gstaad - Lauenensee - Gstaad">Gstaad - Lauenensee - Gstaad</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/144065,auf-und-um-das-cheibenhorn-im-simmental/" title="Auf und um das Cheibenhorn im Simmental">Auf und um das Cheibenhorn im Simmental</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/610944,durchs-jahr-wandern--maerzgloeckchen-bei-wimmis/" title="Durchs Jahr wandern - Märzglöckchen bei Wimmis">Durchs Jahr wandern - Märzglöckchen bei Wimmis</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/161268,vom-zentrum-paul-klee-zu-den-steinbruechen-ostermundigen/" title="Vom Zentrum Paul Klee zu den Steinbrüchen Ostermundigen">Vom Zentrum Paul Klee zu den Steinbrüchen Ostermundigen</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/131760,tour-de-gruyere/" title="Tour de Gruyère">Tour de Gruyère</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49315,hoehenwanderung-auf-dem-jakobsweg/" title="Höhenwanderung auf dem Jakobsweg">Höhenwanderung auf dem Jakobsweg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/486923,von-der-lueg-nach-affoltern-ie/" title="Von der Lueg nach Affoltern i.E.">Von der Lueg nach Affoltern i.E.</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131161,harder-kulm-rundweg/" title="Harder Kulm Rundweg">Harder Kulm Rundweg</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/97084,winterwanderweg-gstaad--bissen--turbach/" title="Winterwanderweg Gstaad - Bissen - Turbach">Winterwanderweg Gstaad - Bissen - Turbach</a>
# <a class="h2" href="/sommer/bern-region/touren/laufen/501843,rund-um-boenigen/" title="Rund um Bönigen">Rund um Bönigen</a>
# <a class="h2" href="/sommer/bern-region/touren/rennrad/131766,tour-de-la-reine-sud/" title="Tour de la reine sud">Tour de la reine sud</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/280191,von-heiligenschwendi-auf-die-blueme/" title="Von Heiligenschwendi auf die Blueme">Von Heiligenschwendi auf die Blueme</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/131683,burgenweg-zweisimmen-rundwanderung/" title="Burgenweg Zweisimmen (Rundwanderung)">Burgenweg Zweisimmen (Rundwanderung)</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/59028,auf-dem-panoramaweg-ueber-den-hasliberg/" title="Auf dem Panoramaweg über den Hasliberg">Auf dem Panoramaweg über den Hasliberg</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/296988,geopfad-wiriehorn/" title="Geopfad Wiriehorn">Geopfad Wiriehorn</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50425,an-stolzen-bauernsitzen-vorueber-durch-den-suedlichen-oberaargau/" title="An stolzen Bauernsitzen vorüber durch den südlichen Oberaargau">An stolzen Bauernsitzen vorüber durch den südlichen Oberaargau</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51090,rund-um-bern--auf-den-chutzeturm/" title="Rund um Bern - auf den Chutzeturm">Rund um Bern - auf den Chutzeturm</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/225655,walk-to-letivaz/" title="Walk to L'Etivaz">Walk to L'Etivaz</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/131829,engelhornhuette/" title="Engelhornhütte">Engelhornhütte</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114495,mit-blick-auf-das-ewige-eis/" title="Mit Blick auf das ewige Eis">Mit Blick auf das ewige Eis</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/59115,winterwanderweg-beatenberg-waldegg--habkern/" title="Winterwanderweg Beatenberg/Waldegg - Habkern">Winterwanderweg Beatenberg/Waldegg - Habkern</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/306710,first--bachalpsee--first/" title="First - Bachalpsee - First">First - Bachalpsee - First</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/162699,stadtnahe-aussicht-vom-laengenberg/" title="Stadtnahe Aussicht vom Längenberg">Stadtnahe Aussicht vom Längenberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/337168,horneggli--hornberg--rinderberg/" title="Horneggli - Hornberg - Rinderberg">Horneggli - Hornberg - Rinderberg</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/49286,zum-aussichtsreichen-berg-ohne-namen/" title="Zum aussichtsreichen «Berg ohne Namen»">Zum aussichtsreichen «Berg ohne Namen»</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51617,sanfte-hoehen--gastliche-haeuser/" title="Sanfte Höhen – gastliche Häuser">Sanfte Höhen – gastliche Häuser</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50255,vom-teuffenthal-ins-eriz--idyllische-wanderung-durch-die-huegelwelt/" title="Vom Teuffenthal ins Eriz – idyllische Wanderung durch die Hügelwelt">Vom Teuffenthal ins Eriz – idyllische Wanderung durch die Hügelwelt</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/81772,wanderung-bueren-a-a--altreu-faehre/" title="Wanderung Büren a. A. – Altreu-Fähre">Wanderung Büren a. A. – Altreu-Fähre</a>
# <a class="h2" href="/sommer/bern-region/touren/themenweg/75407,childrens-adventure-trail--muerren/" title="Children's Adventure Trail - Mürren">Children's Adventure Trail - Mürren</a>
# <a class="h2" href="/sommer/bern-region/touren/winterwandern/157787,panoramaweg-hasliberg/" title="Panoramaweg Hasliberg">Panoramaweg Hasliberg</a>
# <a class="h2" href="/sommer/bern-region/touren/schneeschuh/52070,eriz-trail--eriz/" title="Eriz Trail - Eriz">Eriz Trail - Eriz</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/509595,gfw-14--durch-die-aareauen/" title="GFW 14 - Durch die Aareauen">GFW 14 - Durch die Aareauen</a>

# %%
### Strip out the ID --> in column ix 5 as 'str'
id_df2 = id_df3[0].str.split(' ',expand = True)
id_df1 = id_df2[2].str.split(',',expand = True)
id_df = id_df1[0].str.split('/',expand = True)
id_df[5][0]

## ---> id_df is holding the IDs
# Out:
# '560728'

# %%
# Dealing with the ratings for fitness and technique
# we need to extract Rating data which is "embedded" as a class name in the bs4.BeautifulSoup
rating[0]
# Out:
# [<div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>,
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>]

# %%
# converting into string
tour_rating_str = str(rating)

# taking out unnecessary info - each second rating is Technique or Fitness, starting with technique
rating_all_short = tour_rating_str.replace('<div class="tour-rating">\n<div class="tour-rating-label">Technique</div>\n<div class="rating-circles rating-max6"><div class="','').replace('<div class="tour-rating">\n<div class="tour-rating-label">Fitness</div>\n<div class="rating-circles rating-max6"><div class="','').replace('"></div></div>\n</div>',"")
rating_even_shorter = rating_all_short.replace('[','').replace(']','')


## splitting into lists
rating_list = rating_even_shorter.split(", ")

# %%
# filling the lists technique = [] and fitness = []  we defined in the beginning

for i in range(0,(len(rating_list))):
    if i == 0:
        technique.append(rating_list[i]) # first item goes into technique
    elif i % 2 == 0:
        technique.append(rating_list[i]) # then every second item as well
    else:
        fitness.append(rating_list[i]) # the other items go into fitness

# %%
# Forming a dataframe from our lists as columns:

hikes_df = pd.DataFrame(
    {'title': title,
     'difficulty': difficulty,
     'sport': sport,
     'length': length,
     'time': time,
     'climb': climb,
     'minmax': minmax,
     'technique': technique,
     'fitness': fitness
    })

# %%
#  First draft dataframe: brackets, units, minmax to separate
hikes_df
# Out:
#                                                  title   difficulty  \
# 0                            [Burgenweg in Wilderswil]       [easy]
# 1                                    [Chüematte Trail]     [medium]
# 2                      [Dem Wetterhorn entgegen Nr. 2]       [easy]
# 3    [Vom Rinderberg über den Trüttlisbergpass nach...     [medium]
# 4                     [Lauenen - Chrinepass - Wispile]  [difficult]
# ..                                                 ...          ...
# 395             [Wanderung Büren a. A. – Altreu-Fähre]       [easy]
# 396              [Children's Adventure Trail - Mürren]       [easy]
# 397                            [Panoramaweg Hasliberg]       [easy]
# 398                                [Eriz Trail - Eriz]     [medium]
# 399                      [GFW 14 - Durch die Aareauen]           []
#
#                 sport   length    time  climb          minmax technique  \
# 0            [Hiking]   5.08km  01:45h  136hm      580 - 684m  rating-1
# 1          [Snowshoe]  10.45km  05:00h  560hm  1,201 - 1,815m   rating-
# 2      [Trailrunning]   9.54km  01:52h  428hm    986 - 1,350m  rating-2
# 3            [Hiking]  17.83km  05:45h  536hm  1,689 - 2,079m  rating-3
# 4          [Snowshoe]   7.56km  04:00h  717hm  1,235 - 1,938m  rating-5
# ..                ...      ...     ...    ...             ...       ...
# 395          [Hiking]  10.07km  02:25h      -      422 - 445m  rating-1
# 396  [Thematic route]   2.48km  01:50h   10hm  1,638 - 1,909m  rating-2
# 397   [Winter hiking]   8.15km  03:00h  332hm    981 - 1,217m  rating-1
# 398        [Snowshoe]   6.39km  03:20h  440hm  1,023 - 1,468m  rating-2
# 399          [Hiking]  11.27km  02:50h   50hm      505 - 565m   rating-
#
#       fitness
# 0    rating-2
# 1    rating-4
# 2    rating-2
# 3    rating-4
# 4    rating-5
# ..        ...
# 395  rating-2
# 396  rating-2
# 397  rating-2
# 398  rating-3
# 399  rating-0
#
# [400 rows x 9 columns]

# %% [markdown]
# <html>
# <h2> Part 2: Data cleaning
# </h2>
# <body></body>
# </html>

# %%
# Converting the text columns to strings for easier handling later

hikes_df[['title', 'difficulty', 'sport']] = hikes_df[['title', 'difficulty', 'sport']].astype('str')

# %%
# Removing the brackets

hikes_df['title'] = hikes_df['title'].str.strip('[]')
hikes_df['difficulty'] = hikes_df['difficulty'].str.strip('[]')
hikes_df['sport'] = hikes_df['sport'].str.strip('[]')

# %%
# For some reason '' appear now, removing those as well

hikes_df['title'] = pd.Series(hikes_df['title']).str.replace("'", '')
hikes_df['difficulty'] = pd.Series(hikes_df['difficulty']).str.replace("'", '')
hikes_df['sport'] = pd.Series(hikes_df['sport']).str.replace("'", '')

# %%
# The "string-cleaned" dataframe
hikes_df
# Out:
#                                                  title difficulty  \
# 0                              Burgenweg in Wilderswil       easy
# 1                                      Chüematte Trail     medium
# 2                        Dem Wetterhorn entgegen Nr. 2       easy
# 3    Vom Rinderberg über den Trüttlisbergpass nach ...     medium
# 4                       Lauenen - Chrinepass - Wispile  difficult
# ..                                                 ...        ...
# 395               Wanderung Büren a. A. – Altreu-Fähre       easy
# 396               "Childrens Adventure Trail - Mürren"       easy
# 397                              Panoramaweg Hasliberg       easy
# 398                                  Eriz Trail - Eriz     medium
# 399                        GFW 14 - Durch die Aareauen
#
#               sport   length    time  climb          minmax technique  \
# 0            Hiking   5.08km  01:45h  136hm      580 - 684m  rating-1
# 1          Snowshoe  10.45km  05:00h  560hm  1,201 - 1,815m   rating-
# 2      Trailrunning   9.54km  01:52h  428hm    986 - 1,350m  rating-2
# 3            Hiking  17.83km  05:45h  536hm  1,689 - 2,079m  rating-3
# 4          Snowshoe   7.56km  04:00h  717hm  1,235 - 1,938m  rating-5
# ..              ...      ...     ...    ...             ...       ...
# 395          Hiking  10.07km  02:25h      -      422 - 445m  rating-1
# 396  Thematic route   2.48km  01:50h   10hm  1,638 - 1,909m  rating-2
# 397   Winter hiking   8.15km  03:00h  332hm    981 - 1,217m  rating-1
# 398        Snowshoe   6.39km  03:20h  440hm  1,023 - 1,468m  rating-2
# 399          Hiking  11.27km  02:50h   50hm      505 - 565m   rating-
#
#       fitness
# 0    rating-2
# 1    rating-4
# 2    rating-2
# 3    rating-4
# 4    rating-5
# ..        ...
# 395  rating-2
# 396  rating-2
# 397  rating-2
# 398  rating-3
# 399  rating-0
#
# [400 rows x 9 columns]

# %%
# getting rid of the units (they're always the same anyway)

hikes_df['length'] = pd.Series(hikes_df['length']).str.replace("km", '')
hikes_df['time'] = pd.Series(hikes_df['time']).str.replace("h", '')
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace("hm", '')
hikes_df['minmax'] = pd.Series(hikes_df['minmax']).str.replace("m", '')

# %%
# making 2 columns out of the last one, and removing the old minmax column

hikes_df[['min','max']] = hikes_df['minmax'].str.split("-",expand=True)
hikes_df = hikes_df.drop(columns=['minmax'])

# moving the ratings back to the end
hikes_df = hikes_df[['title', 'difficulty', 'sport', 'length', 'time', 'climb', 'min', 'max', 'technique', 'fitness']]

# %%
# The clean dataframe in string format

hikes_df
# Out:
#                                                  title difficulty  \
# 0                              Burgenweg in Wilderswil       easy
# 1                                      Chüematte Trail     medium
# 2                        Dem Wetterhorn entgegen Nr. 2       easy
# 3    Vom Rinderberg über den Trüttlisbergpass nach ...     medium
# 4                       Lauenen - Chrinepass - Wispile  difficult
# ..                                                 ...        ...
# 395               Wanderung Büren a. A. – Altreu-Fähre       easy
# 396               "Childrens Adventure Trail - Mürren"       easy
# 397                              Panoramaweg Hasliberg       easy
# 398                                  Eriz Trail - Eriz     medium
# 399                        GFW 14 - Durch die Aareauen
#
#               sport length   time climb     min     max technique   fitness
# 0            Hiking   5.08  01:45   136    580      684  rating-1  rating-2
# 1          Snowshoe  10.45  05:00   560  1,201    1,815   rating-  rating-4
# 2      Trailrunning   9.54  01:52   428    986    1,350  rating-2  rating-2
# 3            Hiking  17.83  05:45   536  1,689    2,079  rating-3  rating-4
# 4          Snowshoe   7.56  04:00   717  1,235    1,938  rating-5  rating-5
# ..              ...    ...    ...   ...     ...     ...       ...       ...
# 395          Hiking  10.07  02:25     -    422      445  rating-1  rating-2
# 396  Thematic route   2.48  01:50    10  1,638    1,909  rating-2  rating-2
# 397   Winter hiking   8.15  03:00   332    981    1,217  rating-1  rating-2
# 398        Snowshoe   6.39  03:20   440  1,023    1,468  rating-2  rating-3
# 399          Hiking  11.27  02:50    50    505      565   rating-  rating-0
#
# [400 rows x 10 columns]

# %%
# converting to number data types:

# length
hikes_df['length'] = (hikes_df['length']).astype(float)

# Climb
# to handle the conversions we replace missing values by 0. Maybe nan would work too, but didn't find out how yet
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace(",", '') # replace thousand separator
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace("-", '0') # replaces - by 0
hikes_df['climb'] = (hikes_df['climb']).astype(int)

# %%
#min and max
hikes_df['min'] = pd.Series(hikes_df['min']).str.replace(",", '') # replace thousand separator
hikes_df['min'] = (hikes_df['min']).astype(int)
hikes_df['max'] = pd.Series(hikes_df['max']).str.replace(",", '') # replace thousand separator
hikes_df['max'] = (hikes_df['max']).astype(int)

# %%
# dropping activities that are longer than 24 hrs
#### Watchout - only run once!!??

filt = hikes_df[(hikes_df['time'] > '24:00')]
filt

index_todrop = hikes_df.index[hikes_df['time'] > '24:00'].tolist()

hikes_df = hikes_df.drop(index_todrop)
#len(hikes_df)
hikes_df
# Out:
#                                                  title difficulty  \
# 0                              Burgenweg in Wilderswil       easy
# 1                                      Chüematte Trail     medium
# 2                        Dem Wetterhorn entgegen Nr. 2       easy
# 3    Vom Rinderberg über den Trüttlisbergpass nach ...     medium
# 4                       Lauenen - Chrinepass - Wispile  difficult
# ..                                                 ...        ...
# 395               Wanderung Büren a. A. – Altreu-Fähre       easy
# 396               "Childrens Adventure Trail - Mürren"       easy
# 397                              Panoramaweg Hasliberg       easy
# 398                                  Eriz Trail - Eriz     medium
# 399                        GFW 14 - Durch die Aareauen
#
#               sport  length   time  climb   min   max technique   fitness
# 0            Hiking    5.08  01:45    136   580   684  rating-1  rating-2
# 1          Snowshoe   10.45  05:00    560  1201  1815   rating-  rating-4
# 2      Trailrunning    9.54  01:52    428   986  1350  rating-2  rating-2
# 3            Hiking   17.83  05:45    536  1689  2079  rating-3  rating-4
# 4          Snowshoe    7.56  04:00    717  1235  1938  rating-5  rating-5
# ..              ...     ...    ...    ...   ...   ...       ...       ...
# 395          Hiking   10.07  02:25      0   422   445  rating-1  rating-2
# 396  Thematic route    2.48  01:50     10  1638  1909  rating-2  rating-2
# 397   Winter hiking    8.15  03:00    332   981  1217  rating-1  rating-2
# 398        Snowshoe    6.39  03:20    440  1023  1468  rating-2  rating-3
# 399          Hiking   11.27  02:50     50   505   565   rating-  rating-0
#
# [400 rows x 10 columns]

# %%
# converting times to time objects

# pandas datetime doesn't handle times over 24 hours so we have to give him an alternative
try:
    hikes_df['time'] = pd.to_datetime(hikes_df['time'], format='%H:%M').dt.time
except ValueError:
    pass
# I want to get rid of seconds but it's bed time

# %%
type(hikes_df['technique'][0])
# Out:
# str

# %%
## rating technique
hikes_df['technique'] = pd.Series(hikes_df['technique']).str.replace("rating-", '')
hikes_df['technique'] = pd.to_numeric(hikes_df['technique'], errors='coerce')
hikes_df['technique'] = pd.Series(hikes_df['technique']).replace(np.nan, 0, regex = True)
hikes_df['technique'] = pd.Series(hikes_df['technique']).astype('int')

# rating fitness
hikes_df['fitness'] = pd.Series(hikes_df['fitness']).str.replace("rating-", '')
hikes_df['fitness'] = pd.to_numeric(hikes_df['fitness'], errors='coerce')
hikes_df['fitness'] = pd.Series(hikes_df['fitness']).replace(np.nan, 0, regex = True)
hikes_df['fitness'] = hikes_df['fitness'].astype('int')

# %%
# Finally the clean dataframe 

hikes_df
# Out:
#                                                  title difficulty  \
# 0                              Burgenweg in Wilderswil       easy
# 1                                      Chüematte Trail     medium
# 2                        Dem Wetterhorn entgegen Nr. 2       easy
# 3    Vom Rinderberg über den Trüttlisbergpass nach ...     medium
# 4                       Lauenen - Chrinepass - Wispile  difficult
# ..                                                 ...        ...
# 395               Wanderung Büren a. A. – Altreu-Fähre       easy
# 396               "Childrens Adventure Trail - Mürren"       easy
# 397                              Panoramaweg Hasliberg       easy
# 398                                  Eriz Trail - Eriz     medium
# 399                        GFW 14 - Durch die Aareauen
#
#               sport  length      time  climb   min   max  technique  fitness
# 0            Hiking    5.08  01:45:00    136   580   684          1        2
# 1          Snowshoe   10.45  05:00:00    560  1201  1815          0        4
# 2      Trailrunning    9.54  01:52:00    428   986  1350          2        2
# 3            Hiking   17.83  05:45:00    536  1689  2079          3        4
# 4          Snowshoe    7.56  04:00:00    717  1235  1938          5        5
# ..              ...     ...       ...    ...   ...   ...        ...      ...
# 395          Hiking   10.07  02:25:00      0   422   445          1        2
# 396  Thematic route    2.48  01:50:00     10  1638  1909          2        2
# 397   Winter hiking    8.15  03:00:00    332   981  1217          1        2
# 398        Snowshoe    6.39  03:20:00    440  1023  1468          2        3
# 399          Hiking   11.27  02:50:00     50   505   565          0        0
#
# [400 rows x 10 columns]

# %%
# the dataframe info sum up yay we managed!
hikes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       400 non-null    object
#  1   difficulty  400 non-null    object
#  2   sport       400 non-null    object
#  3   length      400 non-null    float64
#  4   time        400 non-null    object
#  5   climb       400 non-null    int64
#  6   min         400 non-null    int64
#  7   max         400 non-null    int64
#  8   technique   400 non-null    int64
#  9   fitness     400 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 54.4+ KB

# %% [markdown]
# #### <html>
# <h2> Part 3: Downloading GeoData for the hikes
# </h2>
# <body>to create the for loop for all the 400 hikes</body>
# </html>

# %%
### Imports
import requests
import re
from pykml import parser
from lxml import etree
from lxml import objectify

# %% [markdown]
# #### <html>
# <h3> Download the KML file
#     </h3>
# <body>We do this by parsing the url, and then converting into the the kml link that is used on the website.
#
# - https://www.bergfex.com/downloads/gps/?type=&id=271548&fileType=kml
# - Get file name from the url
#     </body>
# </html>

# %%
kml_link = ""
url = "https://www.bergfex.com/downloads/gps/"
url3= "https://www.bergfex.com/downloads/gps/?type=&amp;id=271548&amp;fileType=kml"
if url3.find('/'):
    print(url3.rsplit('/', 1)[1])
    kml_link = (url3.rsplit('/', 1)[1])
    new_s = kml_link.replace('=&amp;', '=&')
    print(new_s)

conc_kml_link = (url + new_s)
print(conc_kml_link )
# Out:
# ?type=&amp;id=271548&amp;fileType=kml
# ?type=&id=271548&amp;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=271548&amp;fileType=kml

# %% [markdown]
# #### <html>
# <h3>Write the data to a klm file locally
#     </h3>
# <body>
# - TO DO:
# - This will be the file that we need to write our data from, and then add it to a data frame
#     </body>
#     </html>

# %%
r = requests.get(conc_kml_link, allow_redirects=True)
write_link = ( new_s + ".kml")
write_link
open(write_link, 'wb').write(r.content)
# Out:
# 14653

# %% [markdown]
# #### <html>
# <h3>Create loop to download all entries
#     </h3>
#     <body> DONE </body>

# %%
## get list of all IDs
final_id = id_df.iloc[:,5]
final_id
# Out:
# 0      560728
# 1      133933
# 2      309476
# 3      278777
# 4      131734
#         ...
# 395     81772
# 396     75407
# 397    157787
# 398     52070
# 399    509595
# Name: 5, Length: 400, dtype: object

# %%
test_loop = final_id.iloc[0:3]
test_loop
# Out:
# 0    560728
# 1    133933
# 2    309476
# Name: 5, dtype: object

# %% [markdown]
# # Loop through hikes and save gpx files to folder
# This loop uses the hike id's to navigate to each of the hike's pages. It then downloads the kml file to the folder "gpx_files" and saves it as a filename "Unique hike id.gpx"

# %%
## For loop to create: i) all kml files (400 items) --> take 'final_id', ii) for testing --> take 'test_loop'
## Saves the files in same directory as the notebook

for sport_id in test_loop: 
    url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={sport_id};fileType=kml"
    print(url_id)
    r = requests.get(url_id, allow_redirects=True)
    write_link = (sport_id + ".gpx")
    # Replace kml files with your directory path
    with open('gpx_files/'+ write_link, 'wb') as f:
        f.write(r.content)
# Out:
# https://www.bergfex.com/downloads/gps/?type=&amp;id='560728&amp;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&amp;id='133933&amp;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&amp;id='309476&amp;fileType=kml
# '309476.klm'

# %% [markdown]
# ## Correcting the url path x
#
# https://www.bergfex.com/downloads/gps/?type=&amp;id=271548&amp;amp;fileType=kml    # Truth
# Loop through each file and scrape out the gpx coords, then save it to a list

# %%
# This works!!!
hikingtrail_name_list = []
lat_list = []
lon_list = []
hiking_trail = []
path = "gpx_files/*.gpx"
for fname in glob.glob(path):
    soup = BeautifulSoup(open(fname,'r'), 'lxml')
    parser = etree.XMLParser(recover=True, remove_blank_text=True)
#    file_name="kml_files/131687.kml"
    root = etree.parse(fname, parser)
    names = root.xpath('//kml:name', namespaces={'kml': "http://www.topografix.com/GPX/1/1"})

    for name in names:
        trail_name = name.text
        lat = trkpt['lat']
        lon = trkpt['lat']
        # append to list 
        hiking_trail.append([name.text, trkpt['lat'], trkpt['lon']] )
#       hiking_trail.append(trkpt['lat'])
#       hiking_trail.append(trkpt['lon'])

print(hiking_trail)                                                                             # Have type=&amp;id=123
# Out:
# https://www.bergfex.com/downloads/gps/?type=&id=560728;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133933;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=309476;fileType=kml

# %% [markdown]
# #### <html>
# <h3> Read out the first postion of each file and add to DF
#     </h3>
#
# <body> Still to do </body>

# %%
kml_link = ""
url = "https://www.bergfex.com/downloads/gps/"
url3= "https://www.bergfex.com/downloads/gps/?type=&amp;id=271548&amp;fileType=kml"
if url3.find('/'):
    print(url3.rsplit('/', 1)[1])
    kml_link = (url3.rsplit('/', 1)[1])
    new_s = kml_link.replace('=&amp;', '=&')
    print(new_s)

conc_kml_link = (url + new_s)
print(conc_kml_link )
# Out:
# ?type=&amp;id=271548&amp;fileType=kml
# ?type=&id=271548&amp;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=271548&amp;fileType=kml

# %% [markdown]
# #### <html>
# <h2> Part 4: Get snow data
# </h2>
# <body>DONE</body>
# </html>

# %%
### all the imports

import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
### initializing the future colums of our dataframe with empty lists

snowlevel = []  # height in cm
location = []  # town and elevation of town

## no looping over several pages necessary

## only scrape first page
link = 'http://www.meteocentrale.ch/de/wetter/hitlisten/schneehoehen.html'
page = requests.get(link, timeout=10)
print(page.status_code)
soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
hitlist = soup.findAll('table', {'class': 'hitlist'})  #bs4.element.ResultSet
# Out:
# 200

# %%
## get location
location_item = hitlist[0].findAll('a')
location.append([info.get_text().strip() for info in location_item])
loc = location[0]
#len(loc)
#loc

## get snowlevel
snowlevel_item = hitlist[0].findAll('td', {'class': 'value'}) #
snowlevel.append([info.get_text().strip() for info in snowlevel_item])
#len(snowlevel)
snow = snowlevel[0]
#len(snow)
#snow


## combine into DF
heights_df = pd.DataFrame({'location': loc,'snowlevel': snow})
heights_df
# Out:
#                         location snowlevel
# 0          Weissfluhjoch, 2690 m     58 cm
# 1              Corvatsch, 3315 m     45 cm
# 2             Gornergrat, 3130 m     41 cm
# 3                 Säntis, 2490 m     20 cm
# 4               Glattalp, 1858 m     15 cm
# ..                           ...       ...
# 76             Zollikofen, 553 m      0 cm
# 77       Zürich-Affoltern, 443 m      0 cm
# 78       Zürich-Flughafen, 432 m      0 cm
# 79  Zürich-Fluntern (SMA), 556 m      0 cm
# 80                  Zuoz, 1664 m      0 cm
#
# [81 rows x 2 columns]

# %%
### data manipulation: 

##remove cm, convert to 'int'
heights_df['snowlevel_in_cm']=pd.Series(heights_df['snowlevel']).str.replace(" cm", '')
heights_df['snowlevel_in_cm']=pd.Series(heights_df['snowlevel_in_cm']).astype(int)
#type(heights_df['snowlevel_in_cm'][0])
#heights_df

## split location into 'village' and 'elevation of village' and merge with previous DF
split_loc = pd.Series(heights_df['location']).str.split(',',n=2,expand = True)
merged_df = pd.merge(heights_df, split_loc, left_index=True, right_index=True)
#merged_df

## drop unused columns, rename final columns, remove unit, sort columns
intermediate_df1 = merged_df.iloc[:,[2,3,4]]
intermediate_df1.columns = ['snowlevel_in_cm', 'location', 'height_in_m']
intermediate_df1['height_in_m']=pd.Series(intermediate_df1['height_in_m']).str.replace(" m", '')
intermediate_df2 = pd.DataFrame(intermediate_df1, columns = ['location', 'height_in_m', 'snowlevel_in_cm'])
# Out:
# <ipython-input-36-b1b349985263>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intermediate_df1['height_in_m']=pd.Series(intermediate_df1['height_in_m']).str.replace(" m", '')

# %%
### final dataframe

intermediate_df2
# Out:
#                  location height_in_m  snowlevel_in_cm
# 0           Weissfluhjoch        2690               58
# 1               Corvatsch        3315               45
# 2              Gornergrat        3130               41
# 3                  Säntis        2490               20
# 4                Glattalp        1858               15
# ..                    ...         ...              ...
# 76             Zollikofen         553                0
# 77       Zürich-Affoltern         443                0
# 78       Zürich-Flughafen         432                0
# 79  Zürich-Fluntern (SMA)         556                0
# 80                   Zuoz        1664                0
#
# [81 rows x 3 columns]

# %%
### Export into csv

#intermediate_df2.to_csv(r'/Users/sd/Documents/0-Coding/sarah-dutschke/04-Visualization/Challenge/snow_level.csv', index = False)

# %% [markdown]
# #### <html>
# <h2> Part 5: Data analysis
# </h2>
# <body>(just to check the dataframe actually works)</body>
# </html>

# %%
# Number of entries by types of sports
hikes_df['sport'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Creating a df for "Number of entries by sport type" + average tour length

sporttype = hikes_df.groupby('sport') \
       .agg({'sport':'count', 'length':'mean'}) \
       .rename(columns={'sport':'count','length':'average_length'}) \
       .reset_index()
sporttype
# Out:
#              sport  count  average_length
# 0          Cycling     11       34.673636
# 1        High tour      1       18.370000
# 2           Hiking    236       10.577373
# 3     Mountainbike     15       28.227333
# 4       Pilgrimage      6       19.896667
# 5           Racing      7       84.734286
# 6          Running      1        9.860000
# 7         Ski tour      1        3.390000
# 8           Sledge     15        5.045333
# 9         Snowshoe     31        6.238710
# 10  Thematic route     28        7.190357
# 11    Trailrunning     15       20.547333
# 12     Via ferrata      1        9.500000
# 13   Winter hiking     32        6.414688

# %%
# Difficulty

hikes_df['difficulty'].unique()
# Out:
# array(['easy', 'medium', 'difficult', ''], dtype=object)

# %%
hikes_df['difficulty'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# mean length for difficulty:

hikes_df.groupby('difficulty').mean()
# Out:
#                length        climb          min          max  technique  \
# difficulty
#             12.423333   358.523810   911.904762  1507.809524   0.000000
# difficult   26.269054  1260.527027   989.310811  2027.283784   3.175676
# easy         7.121511   176.705036  1001.417266  1229.769784   1.503597
# medium      11.107952   483.668675  1081.102410  1605.993976   2.427711
#
#              fitness
# difficulty
#             0.000000
# difficult   5.189189
# easy        1.805755
# medium      3.283133

# %%
#df.reset_index().plot.scatter(x = 'index', y = 'value')
tour_len = sorted(pd.Series(hikes_df["length"]))
tour_climb = sorted(pd.Series(hikes_df["climb"]))
plt.plot(tour_len, tour_climb)
plt.ylabel('climb (m)')
plt.xlabel("length (km)")
plt.title('All activities')
# Out:
# Text(0.5, 1.0, 'All activities')

# %%
## Creating a df for deeper analysis for Hiking
# Filter for hiking
hiking = hikes_df[hikes_df.sport == "Hiking"]

# calculating the count by Fitness level and the average length 
fitness_length = hiking.groupby('fitness') \
       .agg({'fitness':'count', 'length':'mean'}) \
       .rename(columns={'fitness':'count','length':'average_length'}) \
       .reset_index()

# calculating weighted and normalized length
fitness_length['weighted_ave_length'] = fitness_length["count"] * fitness_length["average_length"]
fitness_length["normalized_weighted_length"] = (fitness_length["weighted_ave_length"] - fitness_length["weighted_ave_length"].min()) \
                                                / (fitness_length["weighted_ave_length"].max() - fitness_length["weighted_ave_length"].min()) * 10
fitness_length
# Out:
#    fitness  count  average_length  weighted_ave_length  \
# 0        0     16        9.951250               159.22
# 1        1     19        5.073684                96.40
# 2        2     71        7.661831               543.99
# 3        3     46       10.376304               477.31
# 4        4     44       13.635455               599.96
# 5        5     31       14.566774               451.57
# 6        6      9       18.645556               167.81
#
#    normalized_weighted_length
# 0                    1.247518
# 1                    0.000000
# 2                    8.888514
# 3                    7.564342
# 4                   10.000000
# 5                    7.053181
# 6                    1.418103

# %%
## Plotting Length vs. Fitness rating
#--> Conclusion: the routes with no fitness rating seems quite long. Investigate further

plt.plot(fitness_length["fitness"], fitness_length["average_length"])
plt.ylabel('average_length')
plt.xlabel("rating_fitness")
plt.title('Hiking: Average Length by Fitness Level Rating')

plt.show()

# %%
# quality checking data / or realizing we don't understand the columns?

hikes_df["residual"]= hikes_df["climb"] - (hikes_df["max"] - hikes_df["min"])
hikes_df["residual"].plot.density()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-0a0a542f7de7> in <module>
#       2
#       3 hikes_df["residual"]= hikes_df["climb"] - (hikes_df["max"] - hikes_df["min"])
# ----> 4 hikes_df["residual"].plot.density()
#
# ~/opt/anaconda3/envs/DS_toolkit/lib/python3.8/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1396             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1397         """
# -> 1398         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1399
#    1400     density = kde
#
# ~/opt/anaconda3/envs/DS_toolkit/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/envs/DS_toolkit/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/envs/DS_toolkit/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# ~/opt/anaconda3/envs/DS_toolkit/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py in _make_plot(self)
#      81                 kwds["weights"] = weights[:, i]
#      82
# ---> 83             artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#      84             self._add_legend_handle(artists[0], label, index=i)
#      85
#
# ~/opt/anaconda3/envs/DS_toolkit/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py in _plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     149         **kwds,
#     150     ):
# --> 151         from scipy.stats import gaussian_kde
#     152
#     153         y = remove_na_arraylike(y)
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# #### <html>
# <h2> Part 6: Dashboard
# </h2>
# <body>(pretty much a lot to do stil :-))</body>
# </html>

# %%
### import Dashboard libraries

# bokeh
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, CDSView, HoverTool, Range1d,GroupFilter
from bokeh.io import output_notebook
from bokeh.palettes import Dark2_8, magma
from bokeh.models import Legend, LegendItem
import itertools

# Panel as well
import panel as pn

pn.extension()
output_notebook()

# %%
## Prepare the x/y axis for elevation graph

## x_axis made out of time duration
x = []
for n in hikes_df['time']:
    x.append(n)
xs = [[0,n] for n in x]

## y_axis made out of min and max altitude
y1 = []
y2 = []
for min_, max_ in zip(hikes_df['min'], hikes_df['max']):
    y1.append(min_)
    y2.append(max_)
ys = [[min_, max_] for min_, max_ in zip(hikes_df['min'], hikes_df['max'])]

#ys
#len(ys)
#xs
len(xs)

# %%
## Add to DataFrame

hikes_df['ys'] = ys
hikes_df['xs'] = xs
#type(hikes_df['time'][0])

# %%
### Preparing the plots

## Create a ColumnDataSource
main_cds = ColumnDataSource(hikes_df)

## Create the views for each difficulty level
easy_view = CDSView(source = main_cds, filters=[GroupFilter(column_name='difficulty', group = 'easy')])
medium_view = CDSView(source = main_cds,filters=[GroupFilter(column_name='difficulty', group = 'medium')])
difficult_view = CDSView(source = main_cds,filters=[GroupFilter(column_name='difficulty',group = 'difficult')])

## Create and configure the figure
easy_fig = figure(x_range=[0,hikes_df['time'].max()], 
                  y_range=(hikes_df['min'].min()-100,hikes_df['max'].max()+100), 
                plot_width= 400, plot_height=300,
                 x_axis_label = "Length in hrs",
                 y_axis_label = 'Altitude: from start to highest point',
                 toolbar_location = None)

#line_color = magma(201)

## Fill the figures
easy_fig.multi_line('xs', 'ys', color = 'firebrick', alpha = 0.5, line_width=1, source = main_cds, view = easy_view)

## Remaining aestetics
#easy_fig.legend.location = 'below'

show(easy_fig)

# %%
type(hikes_df['length'][0])
