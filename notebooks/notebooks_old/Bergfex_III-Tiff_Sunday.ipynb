# %% [markdown]
# <html>
# <h1> Bergfex webscraping
# </h1>
# <body>We gather information about outdoor sport itineraries from <a href='https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page=1'> Bergfex.com </a> in the region of Bern.<br />
#     - The website displays 20 tours per page, with infos such as length, type of sport, rating, etc... <br />
#     - Most informations are provided by users.<br />
# <br />
# We then clean the data, and do a bunch of simple analysis.
# </body>
# </html>

# %% [markdown]
# <html>
# <h2> Part 1: Data scraping and cleaning
# </h2>
#
# </html>

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# initializing the future colums of our dataframe with empty lists

title = []  # Title of the tour
difficulty = []  # difficulty (easy, medium, hard)
sport = []  # Sport type (hiking, sledging, snowshoe...)
length = []  # length in km
time = []  # tour time in hours:minutes
climb = []  # positive elevation climb in m
minmax = []  # minimum and maximum altitude of the tour in m
technique = []  # technique difficulty ratings (out of 6)
fitness = []  # fitness difficulty ratings (out of 6)
total_title = [] # will help extracting the ID of the tour

# all ratings are stored together so we will need this along the way:
rating = []  # list to store technique and fitness rating info

# %%
# looping over the 10 first pages of Bergfex
# each separate tour on the page is framed by a div tag with 'touren-details'

page_number = 20  # number of pages we want to scap through

for p in range(1, (page_number+1)):
    base_link = 'https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page='
    link = base_link+str(p)  # going over p pages with numbers appended to the base link
    page = requests.get(link, timeout=8)
    print("scraped page", p)
    soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
    tours = soup.findAll('div', {'class': 'touren-detail'})  # checks for the separate tours on the page

# For each page, we loop over each tour and fill our lists with info     
    for i in range(0,len(tours)):
        tour_1 = tours[i] # tour iterating over the 20 tours of the page

        tour_title = tour_1.findAll('a' ) # this gets the title out
        title.append([info.get_text().strip() for info in tour_title])
        total_title.append(tour_title) # this gets the full tourtitle information
        
        tour_diff = tour_1.findAll('span', {'class': 'tour-difficulty'}) #tour level difficulty
        difficulty.append([info.get_text().strip() for info in tour_diff])

        tour_type = tour_1.findAll('span', {'class': 'tour-type'}) # putting type into sports (should all be hiking)
        sport.append([info.get_text().strip() for info in tour_type])

        tour_stats = tour_1.findAll('div', {'class': 'tour-stats'}) # stats has 4 info binned together
        stat_text = [info.get_text().strip() for info in tour_stats]
        length.append(stat_text[0])
        time.append(stat_text[1])
        climb.append(stat_text[2])
        minmax.append(stat_text[3])
        
        tour_rating = tour_1.find_all("div", {'class': 'tour-rating'}) # getting the rating data 
        rating.append([info for info in tour_rating])   # it's a class name so we can't get_text.
# Out:
# scraped page 1
# scraped page 2
# scraped page 3
# scraped page 4
# scraped page 5
# scraped page 6
# scraped page 7
# scraped page 8
# scraped page 9
# scraped page 10
# scraped page 11
# scraped page 12
# scraped page 13
# scraped page 14
# scraped page 15
# scraped page 16
# scraped page 17
# scraped page 18
# scraped page 19
# scraped page 20

# %%
print("number of tours collected:", len(title))
# Out:
# number of tours collected: 400

# %%
### Get the titles and IDs into a list and then a DF
links_title = []

for i in total_title:
    i = str(i)
    i = i.strip('[]')
    print(i)
    links_title.append(i)

id_df3 = pd.DataFrame(links_title)
# Out:
# <a class="h2" href="/sommer/bern-region/touren/rennrad/172138,heftig-schoenes-saxeten/" title="Heftig schönes Saxeten">Heftig schönes Saxeten</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung
a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/823098,wispile--lauenen-trail/" title="Wispile – Lauenen Trail">Wispile – Lauenen Trail</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/276223,rund-um-den-moossee/" title="Rund um den Moossee">Rund um den Moossee</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/850762,st-stephan-loop/" title="St. Stephan Loop">St. Stephan Loop</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/508338,in-die-heimat-von-karl-grunder/" title="In die Heimat von Karl Grunder">In die Heimat von Karl Grunder</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/51623,das-emmental-von-der-moosegg-aus-gesehen/" title="Das Emmental von der Moosegg aus gesehen">Das Emmental von der Moosegg aus gesehen</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/50397,zum-ursprung-der-emme/" title="Zum Ursprung der Emme">Zum Ursprung der Emme</a>
# <a class="h2" href="/sommer/bern-region/touren/mountainbike/60329,chasseral--die-koenigin-des-juras/" title="Chasseral - The Queen of the Jura">Chasseral - The Queen of the Jura</a>
# <a class="h2" href="/sommer/bern-region/touren/wanderung/48766,zur-tuefelsburdi-auf-dem-jolimont/" title="Zur Tüfelsburdi auf dem Jolimont">Zur Tüfelsburdi auf dem Jolimont</a>

# %%
### Strip out the ID --> in column ix 5 as 'str'
id_df2 = id_df3[0].str.split(' ',expand = True)
id_df1 = id_df2[2].str.split(',',expand = True)
id_df = id_df1[0].str.split('/',expand = True)
id_df[5][0]

## ---> id_df is holding the IDs
# Out:
# '172138'

# %%
# Dealing with the ratings for fitness and technique
# we need to extract Rating data which is "embedded" as a class name in the bs4.BeautifulSoup
rating[0]
# Out:
# [<div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>,
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-5"></div></div>
#  </div>]

# %%
# converting into string
tour_rating_str = str(rating)

# taking out unnecessary info - each second rating is Technique or Fitness, starting with technique
rating_all_short = tour_rating_str.replace('<div class="tour-rating">\n<div class="tour-rating-label">Technique</div>\n<div class="rating-circles rating-max6"><div class="','').replace('<div class="tour-rating">\n<div class="tour-rating-label">Fitness</div>\n<div class="rating-circles rating-max6"><div class="','').replace('"></div></div>\n</div>',"")
rating_even_shorter = rating_all_short.replace('[','').replace(']','')


## splitting into lists
rating_list = rating_even_shorter.split(", ")

# %%
# filling the lists technique = [] and fitness = []  we defined in the beginning

for i in range(0,(len(rating_list))):
    if i == 0:
        technique.append(rating_list[i]) # first item goes into technique
    elif i % 2 == 0:
        technique.append(rating_list[i]) # then every second item as well
    else:
        fitness.append(rating_list[i]) # the other items go into fitness

# %%
# Forming a dataframe from our lists as columns:

hikes_df = pd.DataFrame(
    {'title': title,
     'difficulty': difficulty,
     'sport': sport,
     'length': length,
     'time': time,
     'climb': climb,
     'minmax': minmax,
     'technique': technique,
     'fitness': fitness
    })

# %%
#  First draft dataframe: brackets, units, minmax to separate
hikes_df
# Out:
#                                            title   difficulty           sport  \
# 0                       [Heftig schönes Saxeten]  [difficult]        [Racing]
# 1                    [Vis-à-vis der Engelhörner]  [difficult]        [Hiking]
# 2    [Bikeroute Nr. 11 Adelboden - Tschentenalp]     [medium]  [Mountainbike]
# 3                                  [Wispile Run]     [medium]        [Sledge]
# 4          [Allmenalp Klettersteig - Kandersteg]  [difficult]   [Via ferrata]
# ..                                           ...          ...             ...
# 395             [In die Heimat von Karl Grunder]       [easy]        [Hiking]
# 396   [Das Emmental von der Moosegg aus gesehen]     [medium]        [Hiking]
# 397                      [Zum Ursprung der Emme]     [medium]        [Hiking]
# 398          [Chasseral - The Queen of the Jura]     [medium]  [Mountainbike]
# 399           [Zur Tüfelsburdi auf dem Jolimont]       [easy]        [Hiking]
#
#       length    time    climb          minmax technique   fitness
# 0    26.64km  02:10h    890hm    566 - 1,457m  rating-4  rating-5
# 1    16.79km  05:40h    670hm    589 - 1,874m  rating-4  rating-5
# 2    16.89km  01:30h    829hm  1,263 - 1,940m  rating-4  rating-3
# 3     8.16km  02:00h      9hm  1,188 - 1,917m  rating-4  rating-4
# 4     1.42km  03:30h    533hm  1,187 - 1,720m   rating-  rating-3
# ..       ...     ...      ...             ...       ...       ...
# 395  10.02km  03:10h    470hm      603 - 972m  rating-2  rating-2
# 396  14.08km  04:20h    700hm    597 - 1,009m  rating-2  rating-4
# 397  14.26km  04:50h    800hm    984 - 1,715m  rating-3  rating-3
# 398  37.88km  05:20h  1,167hm    436 - 1,602m  rating-4  rating-4
# 399   6.98km  02:00h    220hm      428 - 603m  rating-2  rating-2
#
# [400 rows x 9 columns]

# %% [markdown]
# <html>
# <h2> Part 2: Data cleaning
# </h2>
# <body></body>
# </html>

# %%
# Converting the text columns to strings for easier handling later

hikes_df[['title', 'difficulty', 'sport']] = hikes_df[['title', 'difficulty', 'sport']].astype('str')

# %%
# Removing the brackets

hikes_df['title'] = hikes_df['title'].str.strip('[]')
hikes_df['difficulty'] = hikes_df['difficulty'].str.strip('[]')
hikes_df['sport'] = hikes_df['sport'].str.strip('[]')

# %%
# For some reason '' appear now, removing those as well

hikes_df['title'] = pd.Series(hikes_df['title']).str.replace("'", '')
hikes_df['difficulty'] = pd.Series(hikes_df['difficulty']).str.replace("'", '')
hikes_df['sport'] = pd.Series(hikes_df['sport']).str.replace("'", '')

# %%
# The "string-cleaned" dataframe
hikes_df
# Out:
#                                          title difficulty         sport  \
# 0                       Heftig schönes Saxeten  difficult        Racing
# 1                    Vis-à-vis der Engelhörner  difficult        Hiking
# 2    Bikeroute Nr. 11 Adelboden - Tschentenalp     medium  Mountainbike
# 3                                  Wispile Run     medium        Sledge
# 4          Allmenalp Klettersteig - Kandersteg  difficult   Via ferrata
# ..                                         ...        ...           ...
# 395             In die Heimat von Karl Grunder       easy        Hiking
# 396   Das Emmental von der Moosegg aus gesehen     medium        Hiking
# 397                      Zum Ursprung der Emme     medium        Hiking
# 398          Chasseral - The Queen of the Jura     medium  Mountainbike
# 399           Zur Tüfelsburdi auf dem Jolimont       easy        Hiking
#
#       length    time    climb          minmax technique   fitness
# 0    26.64km  02:10h    890hm    566 - 1,457m  rating-4  rating-5
# 1    16.79km  05:40h    670hm    589 - 1,874m  rating-4  rating-5
# 2    16.89km  01:30h    829hm  1,263 - 1,940m  rating-4  rating-3
# 3     8.16km  02:00h      9hm  1,188 - 1,917m  rating-4  rating-4
# 4     1.42km  03:30h    533hm  1,187 - 1,720m   rating-  rating-3
# ..       ...     ...      ...             ...       ...       ...
# 395  10.02km  03:10h    470hm      603 - 972m  rating-2  rating-2
# 396  14.08km  04:20h    700hm    597 - 1,009m  rating-2  rating-4
# 397  14.26km  04:50h    800hm    984 - 1,715m  rating-3  rating-3
# 398  37.88km  05:20h  1,167hm    436 - 1,602m  rating-4  rating-4
# 399   6.98km  02:00h    220hm      428 - 603m  rating-2  rating-2
#
# [400 rows x 9 columns]

# %%
# getting rid of the units (they're always the same anyway)

hikes_df['length'] = pd.Series(hikes_df['length']).str.replace("km", '')
hikes_df['time'] = pd.Series(hikes_df['time']).str.replace("h", '')
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace("hm", '')
hikes_df['minmax'] = pd.Series(hikes_df['minmax']).str.replace("m", '')

# %%
# making 2 columns out of the last one, and removing the old minmax column

hikes_df[['min','max']] = hikes_df['minmax'].str.split("-",expand=True)
hikes_df = hikes_df.drop(columns=['minmax'])

# moving the ratings back to the end
hikes_df = hikes_df[['title', 'difficulty', 'sport', 'length', 'time', 'climb', 'min', 'max', 'technique', 'fitness']]

# %%
# The clean dataframe in string format

hikes_df
# Out:
#                                          title difficulty         sport  \
# 0                       Heftig schönes Saxeten  difficult        Racing
# 1                    Vis-à-vis der Engelhörner  difficult        Hiking
# 2    Bikeroute Nr. 11 Adelboden - Tschentenalp     medium  Mountainbike
# 3                                  Wispile Run     medium        Sledge
# 4          Allmenalp Klettersteig - Kandersteg  difficult   Via ferrata
# ..                                         ...        ...           ...
# 395             In die Heimat von Karl Grunder       easy        Hiking
# 396   Das Emmental von der Moosegg aus gesehen     medium        Hiking
# 397                      Zum Ursprung der Emme     medium        Hiking
# 398          Chasseral - The Queen of the Jura     medium  Mountainbike
# 399           Zur Tüfelsburdi auf dem Jolimont       easy        Hiking
#
#     length   time  climb     min     max technique   fitness
# 0    26.64  02:10    890    566    1,457  rating-4  rating-5
# 1    16.79  05:40    670    589    1,874  rating-4  rating-5
# 2    16.89  01:30    829  1,263    1,940  rating-4  rating-3
# 3     8.16  02:00      9  1,188    1,917  rating-4  rating-4
# 4     1.42  03:30    533  1,187    1,720   rating-  rating-3
# ..     ...    ...    ...     ...     ...       ...       ...
# 395  10.02  03:10    470    603      972  rating-2  rating-2
# 396  14.08  04:20    700    597    1,009  rating-2  rating-4
# 397  14.26  04:50    800    984    1,715  rating-3  rating-3
# 398  37.88  05:20  1,167    436    1,602  rating-4  rating-4
# 399   6.98  02:00    220    428      603  rating-2  rating-2
#
# [400 rows x 10 columns]

# %%
# converting to number data types:

# length
hikes_df['length'] = (hikes_df['length']).astype(float)

# Climb
# to handle the conversions we replace missing values by 0. Maybe nan would work too, but didn't find out how yet
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace(",", '') # replace thousand separator
hikes_df['climb'] = pd.Series(hikes_df['climb']).str.replace("-", '0') # replaces - by 0
hikes_df['climb'] = (hikes_df['climb']).astype(int)

# %%
#min and max
hikes_df['min'] = pd.Series(hikes_df['min']).str.replace(",", '') # replace thousand separator
hikes_df['min'] = (hikes_df['min']).astype(int)
hikes_df['max'] = pd.Series(hikes_df['max']).str.replace(",", '') # replace thousand separator
hikes_df['max'] = (hikes_df['max']).astype(int)

# %%
# dropping activities that are longer than 24 hrs
#### Watchout - only run once!!??

filt = hikes_df[(hikes_df['time'] > '24:00')]
filt

index_todrop = hikes_df.index[hikes_df['time'] > '24:00'].tolist()

hikes_df = hikes_df.drop(index_todrop)
#len(hikes_df)
hikes_df
# Out:
#                                          title difficulty         sport  \
# 0                       Heftig schönes Saxeten  difficult        Racing
# 1                    Vis-à-vis der Engelhörner  difficult        Hiking
# 2    Bikeroute Nr. 11 Adelboden - Tschentenalp     medium  Mountainbike
# 3                                  Wispile Run     medium        Sledge
# 4          Allmenalp Klettersteig - Kandersteg  difficult   Via ferrata
# ..                                         ...        ...           ...
# 395             In die Heimat von Karl Grunder       easy        Hiking
# 396   Das Emmental von der Moosegg aus gesehen     medium        Hiking
# 397                      Zum Ursprung der Emme     medium        Hiking
# 398          Chasseral - The Queen of the Jura     medium  Mountainbike
# 399           Zur Tüfelsburdi auf dem Jolimont       easy        Hiking
#
#      length   time  climb   min   max technique   fitness
# 0     26.64  02:10    890   566  1457  rating-4  rating-5
# 1     16.79  05:40    670   589  1874  rating-4  rating-5
# 2     16.89  01:30    829  1263  1940  rating-4  rating-3
# 3      8.16  02:00      9  1188  1917  rating-4  rating-4
# 4      1.42  03:30    533  1187  1720   rating-  rating-3
# ..      ...    ...    ...   ...   ...       ...       ...
# 395   10.02  03:10    470   603   972  rating-2  rating-2
# 396   14.08  04:20    700   597  1009  rating-2  rating-4
# 397   14.26  04:50    800   984  1715  rating-3  rating-3
# 398   37.88  05:20   1167   436  1602  rating-4  rating-4
# 399    6.98  02:00    220   428   603  rating-2  rating-2
#
# [399 rows x 10 columns]

# %%
# converting times to time objects

# pandas datetime doesn't handle times over 24 hours so we have to give him an alternative
try:
    hikes_df['time'] = pd.to_datetime(hikes_df['time'], format='%H:%M').dt.time
except ValueError:
    pass
# I want to get rid of seconds but it's bed time

# %%
type(hikes_df['technique'][0])
# Out:
# str

# %%
## rating technique
hikes_df['technique'] = pd.Series(hikes_df['technique']).str.replace("rating-", '')
hikes_df['technique'] = pd.to_numeric(hikes_df['technique'], errors='coerce')
hikes_df['technique'] = pd.Series(hikes_df['technique']).replace(np.nan, 0, regex = True)
hikes_df['technique'] = pd.Series(hikes_df['technique']).astype('int')

# rating fitness
hikes_df['fitness'] = pd.Series(hikes_df['fitness']).str.replace("rating-", '')
hikes_df['fitness'] = pd.to_numeric(hikes_df['fitness'], errors='coerce')
hikes_df['fitness'] = pd.Series(hikes_df['fitness']).replace(np.nan, 0, regex = True)
hikes_df['fitness'] = hikes_df['fitness'].astype('int')

# %%
# Finally the clean dataframe 

hikes_df
# Out:
#                                          title difficulty         sport  \
# 0                       Heftig schönes Saxeten  difficult        Racing
# 1                    Vis-à-vis der Engelhörner  difficult        Hiking
# 2    Bikeroute Nr. 11 Adelboden - Tschentenalp     medium  Mountainbike
# 3                                  Wispile Run     medium        Sledge
# 4          Allmenalp Klettersteig - Kandersteg  difficult   Via ferrata
# ..                                         ...        ...           ...
# 395             In die Heimat von Karl Grunder       easy        Hiking
# 396   Das Emmental von der Moosegg aus gesehen     medium        Hiking
# 397                      Zum Ursprung der Emme     medium        Hiking
# 398          Chasseral - The Queen of the Jura     medium  Mountainbike
# 399           Zur Tüfelsburdi auf dem Jolimont       easy        Hiking
#
#      length      time  climb   min   max  technique  fitness
# 0     26.64  02:10:00    890   566  1457          4        5
# 1     16.79  05:40:00    670   589  1874          4        5
# 2     16.89  01:30:00    829  1263  1940          4        3
# 3      8.16  02:00:00      9  1188  1917          4        4
# 4      1.42  03:30:00    533  1187  1720          0        3
# ..      ...       ...    ...   ...   ...        ...      ...
# 395   10.02  03:10:00    470   603   972          2        2
# 396   14.08  04:20:00    700   597  1009          2        4
# 397   14.26  04:50:00    800   984  1715          3        3
# 398   37.88  05:20:00   1167   436  1602          4        4
# 399    6.98  02:00:00    220   428   603          2        2
#
# [399 rows x 10 columns]

# %%
# the dataframe info sum up yay we managed!
hikes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 399 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       399 non-null    object
#  1   difficulty  399 non-null    object
#  2   sport       399 non-null    object
#  3   length      399 non-null    float64
#  4   time        399 non-null    object
#  5   climb       399 non-null    int64
#  6   min         399 non-null    int64
#  7   max         399 non-null    int64
#  8   technique   399 non-null    int64
#  9   fitness     399 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 54.3+ KB

# %% [markdown]
# #### <html>
# <h2> Part 3: Downloading GeoData for the hikes
# </h2>
# <body>to create the for loop for all the 400 hikes</body>
# </html>

# %%
### Imports
import requests
import re
from pykml import parser
from lxml import etree
from lxml import objectify

# %% [markdown]
# #### <html>
# <h3> Download the KML file
#     </h3>
# <body>We do this by parsing the url, and then converting into the the kml link that is used on the website.
#
# - https://www.bergfex.com/downloads/gps/?type=&id=271548&fileType=kml
# - Get file name from the url
#     </body>
# </html>

# %%
kml_link = ""
url = "https://www.bergfex.com/downloads/gps/"
url3= "https://www.bergfex.com/downloads/gps/?type=&amp;id=271548&amp;fileType=kml"
if url3.find('/'):
    print(url3.rsplit('/', 1)[1])
    kml_link = (url3.rsplit('/', 1)[1])
    new_s = kml_link.replace('=&amp;', '=&')
    print(new_s)

conc_kml_link = (url + new_s)
print(conc_kml_link )
# Out:
# ?type=&amp;id=271548&amp;fileType=kml
# ?type=&id=271548&amp;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=271548&amp;fileType=kml

# %% [markdown]
# #### <html>
# <h3>Write the data to a klm file locally
#     </h3>
# <body>
# - TO DO:
# - This will be the file that we need to write our data from, and then add it to a data frame
#     </body>
#     </html>

# %%
r = requests.get(conc_kml_link, allow_redirects=True)
write_link = ( new_s + ".kml")
write_link
open(write_link, 'wb').write(r.content)
# Out:
# 14653

# %% [markdown]
# #### <html>
# <h3>Create loop to download all entries
#     </h3>
#     <body> DONE </body>

# %%
## get list of all IDs
final_id = id_df.iloc[:,5]
final_id
# Out:
# 0      172138
# 1       69998
# 2      133092
# 3      131645
# 4       76710
#         ...
# 395    508338
# 396     51623
# 397     50397
# 398     60329
# 399     48766
# Name: 5, Length: 400, dtype: object

# %%
test_loop = final_id.iloc[0:3]
test_loop
# Out:
# 0    172138
# 1     69998
# 2    133092
# Name: 5, dtype: object

# %% [markdown]
# # Loop through hikes and save gpx files to folder
# This loop uses the hike id's to navigate to each of the hike's pages. It then downloads the kml file to the folder "gpx_files" and saves it as a filename "Unique hike id.gpx"

# %%
## For loop to create: i) all kml files (400 items) --> take 'final_id', ii) for testing --> take 'test_loop'
## Saves the files in same directory as the notebook

for sport_id in final_id: 
    url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={sport_id};fileType=kml"
    print(url_id)
    r = requests.get(url_id, allow_redirects=True)
    write_link = (sport_id + ".gpx")
    # Replace kml files with your directory path
    with open('gpx_files/'+ write_link, 'wb') as f:
        f.write(r.content)
# Out:
# https://www.bergfex.com/downloads/gps/?type=&id=172138;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=69998;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133092;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131645;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=76710;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49281;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133939;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=522401;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162912;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=383168;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=658326;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133081;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=156751;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=70002;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=108498;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=57281;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=593368;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=277605;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49114;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=63669;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=58009;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131885;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50182;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=368308;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508323;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=526926;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=76019;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=129374;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744974;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51048;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=309511;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=306710;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=289465;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=10196;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=224307;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=14760;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48851;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49285;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50353;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162696;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48828;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162941;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=482339;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49282;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=474086;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=159628;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131949;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51347;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=129361;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=129248;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=58274;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=573726;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744972;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=304131;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=129286;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131161;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=275964;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=70033;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=208213;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48925;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51396;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=812685;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=682833;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50429;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=97600;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=238987;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=97607;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131616;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48802;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48962;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508322;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=211608;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=532165;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131738;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131798;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131766;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=157949;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=655236;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744927;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131780;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=53488;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=908574;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=616543;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51130;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=65312;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=110806;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=156736;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=700234;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50349;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=293157;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=149720;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133918;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=185343;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51619;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508322;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=155540;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=309993;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=63186;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=698704;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51006;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=224276;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48925;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=65312;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=294666;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=733526;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=658326;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=301385;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=95943;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=595654;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131643;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50390;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131673;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49185;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=348126;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48805;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=156754;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49121;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=875909;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=156736;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48766;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51046;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508352;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162913;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50185;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48850;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=526953;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131963;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=70036;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=53637;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=172177;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744976;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162742;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=289465;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=293157;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=314649;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=182387;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=129342;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49176;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=267538;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=691505;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=70036;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=562755;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49277;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=289491;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744919;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=161541;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131608;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50426;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=55103;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=75399;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508322;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162942;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=616579;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=358909;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=83702;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=159615;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50211;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=101685;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=156125;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49986;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=93370;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=159612;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508330;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51188;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=795205;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51008;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=823060;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=156906;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=113853;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=70004;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=276227;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=389018;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=211600;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162036;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131689;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133083;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=309494;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50974;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51043;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=114192;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508309;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49442;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=276266;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=289465;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744927;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=98136;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131926;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=296938;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131883;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131963;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49229;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=503357;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131798;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=70006;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=315063;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=159612;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=183373;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=306681;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=309938;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=524941;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=174600;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49823;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131470;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50428;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=150615;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133934;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=155029;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=161249;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=58128;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49073;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50926;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=812686;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=210483;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133942;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=100447;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48797;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=129374;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=159615;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162927;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51189;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50426;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=911372;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50180;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744918;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49561;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=310006;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=718569;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=834924;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=318768;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162939;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49250;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48965;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=375351;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=823098;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49424;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131182;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=165217;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=224315;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=304129;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=700241;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=70024;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=145451;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133927;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=870922;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=655235;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48964;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162707;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=310007;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=709664;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=101689;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=374713;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162067;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=185343;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=272875;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=110805;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49257;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131667;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133935;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=97598;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51006;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=129240;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=709678;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49028;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=14677;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=276227;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=58009;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=129387;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=709676;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=795213;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49187;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49333;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=150613;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51046;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=161051;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=374712;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=132557;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=151860;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133920;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131823;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=509376;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=599069;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48770;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=529176;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=875903;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=455708;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=67766;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131645;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=156763;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=70006;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=71455;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131463;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49034;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50179;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133924;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=309494;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=358910;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51213;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=58603;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=157783;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=53598;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=309494;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=294660;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744916;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=225655;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=749188;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131703;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=289438;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49275;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131909;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162927;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49332;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51051;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=224254;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=309955;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=455708;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=532165;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51007;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=123943;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=709677;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=114346;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=156784;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=153906;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=455708;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51396;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131916;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=159629;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=532162;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=65953;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=110806;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=908572;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133940;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49247;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=260805;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=718568;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48957;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49177;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=99637;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131679;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=691504;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51049;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=62376;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=875909;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=177101;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=454773;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133922;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=172147;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50397;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=174782;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51621;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=99641;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=153906;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51085;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=67238;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51458;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131770;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=823056;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=709662;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=164755;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=83742;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=161251;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51391;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=552524;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=114220;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=84559;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49255;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=65320;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=288422;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131671;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162702;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49169;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=110614;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=210483;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=458382;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=655236;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508326;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=59028;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=292891;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=123946;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49288;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=63192;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131778;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=162986;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133089;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=58746;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=296921;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49273;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=72257;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=49030;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508315;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133924;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=269686;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=131689;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=823098;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=276223;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=850762;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=508338;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51623;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=50397;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=60329;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48766;fileType=kml

# %% [markdown]
# ## Correcting the url path x
#
# https://www.bergfex.com/downloads/gps/?type=&amp;id=271548&amp;amp;fileType=kml    # Truth
# Loop through each file and scrape out the gpx coords, then save it to a list

# %%
import glob

# This works!!!
hikingtrail_name_list = []
lat_list = []
lon_list = []
hiking_trail = []
path = "gpx_files/*.gpx"
for fname in glob.glob(path):
    soup = BeautifulSoup(open(fname,'r'), 'lxml')
    parser = etree.XMLParser(recover=True, remove_blank_text=True)
#    file_name="kml_files/131687.kml"
    root = etree.parse(fname, parser)
    names = root.xpath('//kml:name', namespaces={'kml': "http://www.topografix.com/GPX/1/1"})

    for name in names:
        trail_name = name.text
        lat = trkpt['lat']
        lon = trkpt['lat']
        # append to list 
        hiking_trail.append([name.text, trkpt['lat'], trkpt['lon']] )
#       hiking_trail.append(trkpt['lat'])
#       hiking_trail.append(trkpt['lon'])

print(hiking_trail)                                                                             # Have type=&amp;id=123
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-39-bf931047f47e> in <module>
#      11 #    file_name="kml_files/131687.kml"
#      12     root = etree.parse(fname, parser)
# ---> 13     names = root.xpath('//kml:name', namespaces={'kml': "http://www.topografix.com/GPX/1/1"})
#      14
#      15     for name in names:
#
# src/lxml/etree.pyx in lxml.etree._ElementTree.xpath()
#
# src/lxml/etree.pyx in lxml.etree._ElementTree._assertHasRoot()
#
# AssertionError: ElementTree not initialized, missing root

# %% [markdown]
# #### <html>
# <h3> Read out the first postion of each file and add to DF
#     </h3>
#
# <body> Still to do </body>

# %%
kml_link = ""
url = "https://www.bergfex.com/downloads/gps/"
url3= "https://www.bergfex.com/downloads/gps/?type=&amp;id=271548&amp;fileType=kml"
if url3.find('/'):
    print(url3.rsplit('/', 1)[1])
    kml_link = (url3.rsplit('/', 1)[1])
    new_s = kml_link.replace('=&amp;', '=&')
    print(new_s)

conc_kml_link = (url + new_s)
print(conc_kml_link )

# %% [markdown]
# #### <html>
# <h2> Part 4: Get snow data
# </h2>
# <body>DONE</body>
# </html>

# %%
### all the imports

import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
### initializing the future colums of our dataframe with empty lists

snowlevel = []  # height in cm
location = []  # town and elevation of town

## no looping over several pages necessary

## only scrape first page
link = 'http://www.meteocentrale.ch/de/wetter/hitlisten/schneehoehen.html'
page = requests.get(link, timeout=10)
print(page.status_code)
soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
hitlist = soup.findAll('table', {'class': 'hitlist'})  #bs4.element.ResultSet

# %%
## get location
location_item = hitlist[0].findAll('a')
location.append([info.get_text().strip() for info in location_item])
loc = location[0]
#len(loc)
#loc

## get snowlevel
snowlevel_item = hitlist[0].findAll('td', {'class': 'value'}) #
snowlevel.append([info.get_text().strip() for info in snowlevel_item])
#len(snowlevel)
snow = snowlevel[0]
#len(snow)
#snow


## combine into DF
heights_df = pd.DataFrame({'location': loc,'snowlevel': snow})
heights_df

# %%
### data manipulation: 

##remove cm, convert to 'int'
heights_df['snowlevel_in_cm']=pd.Series(heights_df['snowlevel']).str.replace(" cm", '')
heights_df['snowlevel_in_cm']=pd.Series(heights_df['snowlevel_in_cm']).astype(int)
#type(heights_df['snowlevel_in_cm'][0])
#heights_df

## split location into 'village' and 'elevation of village' and merge with previous DF
split_loc = pd.Series(heights_df['location']).str.split(',',n=2,expand = True)
merged_df = pd.merge(heights_df, split_loc, left_index=True, right_index=True)
#merged_df

## drop unused columns, rename final columns, remove unit, sort columns
intermediate_df1 = merged_df.iloc[:,[2,3,4]]
intermediate_df1.columns = ['snowlevel_in_cm', 'location', 'height_in_m']
intermediate_df1['height_in_m']=pd.Series(intermediate_df1['height_in_m']).str.replace(" m", '')
intermediate_df2 = pd.DataFrame(intermediate_df1, columns = ['location', 'height_in_m', 'snowlevel_in_cm'])

# %%
### final dataframe

intermediate_df2

# %%
### Export into csv

#intermediate_df2.to_csv(r'/Users/sd/Documents/0-Coding/sarah-dutschke/04-Visualization/Challenge/snow_level.csv', index = False)

# %% [markdown]
# #### <html>
# <h2> Part 5: Data analysis
# </h2>
# <body>(just to check the dataframe actually works)</body>
# </html>

# %%
# Number of entries by types of sports
hikes_df['sport'].value_counts().plot(kind='bar')

# %%
# Creating a df for "Number of entries by sport type" + average tour length

sporttype = hikes_df.groupby('sport') \
       .agg({'sport':'count', 'length':'mean'}) \
       .rename(columns={'sport':'count','length':'average_length'}) \
       .reset_index()
sporttype

# %%
# Difficulty

hikes_df['difficulty'].unique()

# %%
hikes_df['difficulty'].value_counts().plot(kind='bar')

# %%
# mean length for difficulty:

hikes_df.groupby('difficulty').mean()

# %%
#df.reset_index().plot.scatter(x = 'index', y = 'value')
tour_len = sorted(pd.Series(hikes_df["length"]))
tour_climb = sorted(pd.Series(hikes_df["climb"]))
plt.plot(tour_len, tour_climb)
plt.ylabel('climb (m)')
plt.xlabel("length (km)")
plt.title('All activities')

# %%
## Creating a df for deeper analysis for Hiking
# Filter for hiking
hiking = hikes_df[hikes_df.sport == "Hiking"]

# calculating the count by Fitness level and the average length 
fitness_length = hiking.groupby('fitness') \
       .agg({'fitness':'count', 'length':'mean'}) \
       .rename(columns={'fitness':'count','length':'average_length'}) \
       .reset_index()

# calculating weighted and normalized length
fitness_length['weighted_ave_length'] = fitness_length["count"] * fitness_length["average_length"]
fitness_length["normalized_weighted_length"] = (fitness_length["weighted_ave_length"] - fitness_length["weighted_ave_length"].min()) \
                                                / (fitness_length["weighted_ave_length"].max() - fitness_length["weighted_ave_length"].min()) * 10
fitness_length

# %%
## Plotting Length vs. Fitness rating
#--> Conclusion: the routes with no fitness rating seems quite long. Investigate further

plt.plot(fitness_length["fitness"], fitness_length["average_length"])
plt.ylabel('average_length')
plt.xlabel("rating_fitness")
plt.title('Hiking: Average Length by Fitness Level Rating')

plt.show()

# %%
# quality checking data / or realizing we don't understand the columns?

hikes_df["residual"]= hikes_df["climb"] - (hikes_df["max"] - hikes_df["min"])
hikes_df["residual"].plot.density()

# %% [markdown]
# #### <html>
# <h2> Part 6: Dashboard
# </h2>
# <body>(pretty much a lot to do stil :-))</body>
# </html>

# %%
### import Dashboard libraries

# bokeh
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, CDSView, HoverTool, Range1d,GroupFilter
from bokeh.io import output_notebook
from bokeh.palettes import Dark2_8, magma
from bokeh.models import Legend, LegendItem
import itertools

# Panel as well
import panel as pn

pn.extension()
output_notebook()

# %%
## Prepare the x/y axis for elevation graph

## x_axis made out of time duration
x = []
for n in hikes_df['time']:
    x.append(n)
xs = [[0,n] for n in x]

## y_axis made out of min and max altitude
y1 = []
y2 = []
for min_, max_ in zip(hikes_df['min'], hikes_df['max']):
    y1.append(min_)
    y2.append(max_)
ys = [[min_, max_] for min_, max_ in zip(hikes_df['min'], hikes_df['max'])]

#ys
#len(ys)
#xs
len(xs)

# %%
## Add to DataFrame

hikes_df['ys'] = ys
hikes_df['xs'] = xs
#type(hikes_df['time'][0])

# %%
### Preparing the plots

## Create a ColumnDataSource
main_cds = ColumnDataSource(hikes_df)

## Create the views for each difficulty level
easy_view = CDSView(source = main_cds, filters=[GroupFilter(column_name='difficulty', group = 'easy')])
medium_view = CDSView(source = main_cds,filters=[GroupFilter(column_name='difficulty', group = 'medium')])
difficult_view = CDSView(source = main_cds,filters=[GroupFilter(column_name='difficulty',group = 'difficult')])

## Create and configure the figure
easy_fig = figure(x_range=[0,hikes_df['time'].max()], 
                  y_range=(hikes_df['min'].min()-100,hikes_df['max'].max()+100), 
                plot_width= 400, plot_height=300,
                 x_axis_label = "Length in hrs",
                 y_axis_label = 'Altitude: from start to highest point',
                 toolbar_location = None)

#line_color = magma(201)

## Fill the figures
easy_fig.multi_line('xs', 'ys', color = 'firebrick', alpha = 0.5, line_width=1, source = main_cds, view = easy_view)

## Remaining aestetics
#easy_fig.legend.location = 'below'

show(easy_fig)

# %%
type(hikes_df['length'][0])
