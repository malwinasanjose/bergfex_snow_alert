# %% [markdown]
# ### Installations

# %%
#!pip install lxml
#!pip install wget
#!pip install gpxpy

# %% [markdown]
# ### Imports

# %%
# import requests
import re
from bs4 import BeautifulSoup 
import pandas as pd
import lxml

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import requests
#import wget
import glob
import datetime as dt
import time
import seaborn as sns
from matplotlib import rcParams
import matplotlib.pyplot as plt

import time
import gpxpy 
import gpxpy.gpx 
import glob

# %% [markdown]
# # Still to do:
# - Add key words: Webscraping from a static page, Basic Data Cleaning, Basic plots, GPX coordinates, KML coordinates (add both? describe the differences?), spatial data
# - check why 2nd correlation matrix does not include difficulty level
# - simplify gpx code
# - run gpx code for all 257 codes
# - check why datetime code does not always work

# %% [markdown]
# # 1  Data scraping
#
# Prepare to scrape the Bergfex.com website in order to create Pandas dataframes that contain important information about each trail. This code uses BeautifulSoup to parse the html tags into json, which is easier to work with. A for-loop iterates over each html tag and adds the corresponding information into empty lists.

# %% [markdown]
# ### 1.1 Scrape all the information (basic and more complicated)

# %%
title = []  # Title of the tour
difficulty = []  # difficulty (easy, medium, hard)
sport = []  # Sport type (hiking, sledging, snowshoe...)
length = []  # length in km
time_list = []  # tour time in hours:minutes
climb = []  # positive elevation climb in m
minmax = []  # minimum and maximum altitude of the tour in m
technique = []  # technique difficulty ratings (out of 6)
fitness = []  # fitness difficulty ratings (out of 6)
total_title = [] # will help extracting the ID of the tour

# all ratings are stored together so we will need this along the way:
rating = []  # list to store technique and fitness rating info

# %%
# looping over the 10 first pages of Bergfex
# each separate tour on the page is framed by a div tag with 'touren-details'

page_number = 20  # number of pages we want to scap through

for p in range(1, (page_number+1)):
    base_link = 'https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page='
    link = base_link+str(p)  # going over p pages with numbers appended to the base link
    page = requests.get(link, timeout=5)
    print("scraped page", p)
    soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
    tours = soup.findAll('div', {'class': 'touren-detail'})  # checks for the separate tours on the page

# For each page, we loop over each tour and fill our lists with info     
    for i in range(0,len(tours)):
        tour_1 = tours[i] # tour iterating over the 20 tours of the page

        tour_title = tour_1.findAll('a' ) # this gets the title out
        title.append([info.get_text().strip() for info in tour_title])
        total_title.append(tour_title) 
        # this gets the full tour-title information including the ID, will need to be processed further later on
        
        tour_diff = tour_1.findAll('span', {'class': 'tour-difficulty'}) #tour level difficulty
        difficulty.append([info.get_text().strip() for info in tour_diff])

        tour_type = tour_1.findAll('span', {'class': 'tour-type'}) # putting type into sports (should all be hiking)
        sport.append([info.get_text().strip() for info in tour_type])

        tour_stats = tour_1.findAll('div', {'class': 'tour-stats'}) # stats has 4 info binned together
        stat_text = [info.get_text().strip() for info in tour_stats]
        length.append(stat_text[0])
        time_list.append(stat_text[1])
        climb.append(stat_text[2])
        minmax.append(stat_text[3])
        
        tour_rating = tour_1.find_all("div", {'class': 'tour-rating'}) # getting the rating data 
        rating.append([info for info in tour_rating])   # it's a class name so we can't get_text.
# Out:
# scraped page 1
# scraped page 2
# scraped page 3
# scraped page 4
# scraped page 5
# scraped page 6
# scraped page 7
# scraped page 8
# scraped page 9
# scraped page 10
# scraped page 11
# scraped page 12
# scraped page 13
# scraped page 14
# scraped page 15
# scraped page 16
# scraped page 17
# scraped page 18
# scraped page 19
# scraped page 20

# %%
print("number of tours collected:", len(title))
# Out:
# number of tours collected: 400

# %% [markdown]
# ### 1.2 Extracting embedded HTML tags: <a href=""
# Each trail name and ID was used in Bergfex's URL. Using the trail ID in the dataframe will provide a unique ID to use later in the analysis. However, those two data points are embedded deeper in the html code. The below codes shows how to extract the datapoints into a dataframe.

# %%
# Extracting the ID via the URL
links_title = []

for i in total_title:
    i = str(i)
    i = i.strip('[]')
    links_title.append(i)

# %% [markdown]
# In order to make the trail ID usable it needs to be cleaned up and converted into a string

# %%
# Extracting ID
id_df3 = pd.DataFrame(links_title)
id_df2 = id_df3[0].str.split(' ',expand = True)
id_df1 = id_df2[2].str.split(',',expand = True)
id_df = id_df1[0].str.split('/',expand = True)

# %%
# from this format:
pd.options.display.max_colwidth = 100
id_df3.head()
# Out:
#                                                                                                      0
# 0  <a class="h2" href="/sommer/bern-region/touren/trailrunning/482334,swiss-trail-tour-lenk-strecke...
# 1  <a class="h2" href="/sommer/bern-region/touren/wanderung/113481,stockhorn-2190-m/" title="Stockh...
# 2  <a class="h2" href="/sommer/bern-region/touren/wanderung/133083,adelboden--cholerenschlucht--ret...
# 3  <a class="h2" href="/sommer/bern-region/touren/wanderung/870921,via-alpina--etappe-15-adelboden-...
# 4  <a class="h2" href="/sommer/bern-region/touren/rennrad/131766,tour-de-la-reine-sud/" title="Tour...

# %%
# to this format:
id_df.head()
# Out:
#         0       1            2       3             4       5
# 0  href="  sommer  bern-region  touren  trailrunning  482334
# 1  href="  sommer  bern-region  touren     wanderung  113481
# 2  href="  sommer  bern-region  touren     wanderung  133083
# 3  href="  sommer  bern-region  touren     wanderung  870921
# 4  href="  sommer  bern-region  touren       rennrad  131766

# %% [markdown]
# ### 1.3 Extracting embedded HTML tags: <Div class=""
# The HTML tags for the fitness and technique ratings were embedded within Div class tags; they are extracted using a for loop and then stripped of unecessary characeters.
# - Convert the tour rating tag into a string
# - Strip away unecessary characters
# - Split into lists which look like rating_list[Technique, Fitness, Technique, Fitness]
# - Finally, convert into seperate lists for Technique and Fitness

# %%
rating[0] # View the emmbedded DIV tag
# Out:
# [<div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>,
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-5"></div></div>
#  </div>]

# %%
# Replace unwanted information
tour_rating_str = str(rating)
rating_all_short = tour_rating_str.replace(
'<div class="tour-rating">\n<div class="tour-rating-label">Technique</div>\n<div class="rating-circles rating-max6"><div class="',''
).replace(
    '<div class="tour-rating">\n<div class="tour-rating-label">Fitness</div>\n<div class="rating-circles rating-max6"><div class="','').replace('"></div></div>\n</div>',"")
rating_even_shorter = rating_all_short.replace('[','').replace(']','')
rating_list = rating_even_shorter.split(", ")

for i in range(0,(len(rating_list))):
    if i == 0:
        technique.append(rating_list[i]) # add first item in technique
    elif i % 2 == 0:
        technique.append(rating_list[i]) # then every second item as well
    else:
        fitness.append(rating_list[i]) # the other appended to fitness list

# %%
## Let's look at the result

#rating_all_short
#rating_even_shorter
rating_list
# Out:
# ['rating-4',
#  'rating-5',
#  'rating-4',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-6',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-5',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-0',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-',
#  'rating-4',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-4',
#  'rating-2',
#  'rating-3',
#  'rating-',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-5',
#  'rating-4',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-6',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-5',
#  'rating-2',
#  'rating-5',
#  'rating-',
#  'rating-5',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-3',
#  'rating-3',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-5',
#  'rating-6',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-1',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-5',
#  'rating-3',
#  'rating-5',
#  'rating-4',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-4',
#  'rating-5',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-1',
#  'rating-0',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-5',
#  'rating-3',
#  'rating-4',
#  'rating-',
#  'rating-5',
#  'rating-',
#  'rating-5',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-6',
#  'rating-4',
#  'rating-6',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-5',
#  'rating-',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-5',
#  'rating-5',
#  'rating-6',
#  'rating-4',
#  'rating-4',
#  'rating-5',
#  'rating-4',
#  'rating-3',
#  'rating-5',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-3',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-0',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-4',
#  'rating-5',
#  'rating-5',
#  'rating-6',
#  'rating-2',
#  'rating-2',
#  'rating-5',
#  'rating-6',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-',
#  'rating-5',
#  'rating-2',
#  'rating-5',
#  'rating-',
#  'rating-5',
#  'rating-4',
#  'rating-4',
#  'rating-',
#  'rating-0',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-5',
#  'rating-2',
#  'rating-6',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-',
#  'rating-1',
#  'rating-5',
#  'rating-5',
#  'rating-6',
#  'rating-6',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-6',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-6',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-6',
#  'rating-5',
#  'rating-5',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-3',
#  'rating-',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-',
#  'rating-0',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-5',
#  'rating-4',
#  'rating-5',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-5',
#  'rating-4',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-5',
#  'rating-6',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-5',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-2',
#  'rating-4',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-4',
#  'rating-2',
#  'rating-3',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-1',
#  'rating-1',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-5',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-5',
#  'rating-4',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-6',
#  'rating-5',
#  'rating-5',
#  'rating-2',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-5',
#  'rating-4',
#  'rating-4',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-1',
#  'rating-1',
#  'rating-',
#  'rating-1',
#  'rating-4',
#  'rating-4',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-5',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-4',
#  'rating-4',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-6',
#  'rating-',
#  'rating-4',
#  'rating-',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-1',
#  'rating-5',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-1',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-4',
#  'rating-1',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-',
#  'rating-0',
#  'rating-4',
#  'rating-3',
#  'rating-1',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-',
#  'rating-0',
#  'rating-5',
#  'rating-5',
#  'rating-2',
#  'rating-6',
#  'rating-3',
#  'rating-3',
#  'rating-5',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-5',
#  'rating-5',
#  'rating-3',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-1',
#  'rating-1',
#  'rating-5',
#  'rating-4',
#  'rating-',
#  'rating-4',
#  'rating-3',
#  'rating-6',
#  'rating-3',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-5',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-2',
#  'rating-6',
#  'rating-1',
#  'rating-2',
#  'rating-5',
#  'rating-4',
#  'rating-',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-6',
#  'rating-4',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-5',
#  'rating-1',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-3',
#  'rating-1',
#  'rating-1',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-5',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-2',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-5',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-4',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-1',
#  'rating-1',
#  'rating-',
#  'rating-1',
#  'rating-',
#  'rating-5',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-4',
#  'rating-',
#  'rating-2',
#  'rating-4',
#  'rating-6',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-3',
#  'rating-',
#  'rating-5',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-5',
#  'rating-2',
#  'rating-5',
#  'rating-4',
#  'rating-5',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-6',
#  'rating-4',
#  'rating-4',
#  'rating-3',
#  'rating-3',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-',
#  'rating-3',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-5',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-1',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-5',
#  'rating-5',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-5',
#  'rating-5',
#  'rating-5',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-1',
#  'rating-3',
#  'rating-4',
#  'rating-',
#  'rating-3',
#  'rating-1',
#  'rating-1',
#  'rating-4',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-1',
#  'rating-6',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-',
#  'rating-1',
#  'rating-3',
#  'rating-5',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-4',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-4',
#  'rating-3',
#  'rating-4']

# %% [markdown]
# ### 1.4  Create dataframe for extracted elements
#
# This dataframe is not in the final stage yet as there are still extra brackets, the minimum and maximum elevation are still in one column, and units must be stripped away

# %%
activities_df = pd.DataFrame(
    {'title': title,
     'difficulty': difficulty,
     'sport': sport,
     'length': length,
     'time': time_list,
     'climb': climb,
     'minmax': minmax,
     'technique': technique,
     'fitness': fitness
    })
activities_df['ID']= id_df.iloc[:,5].copy() # add the ID columns from an earlier DF

# %%
activities_df
# Out:
#                                                    title   difficulty  \
# 0    [Swiss Trail Tour Lenk, Strecke Tour, Samstag 2019]  [difficult]
# 1                                    [Stockhorn, 2190 m]     [medium]
# 2                [Adelboden - Cholerenschlucht - retour]       [easy]
# 3              [Via Alpina - Etappe 15 Adelboden - Lenk]       [easy]
# 4                                 [Tour de la reine sud]  [difficult]
# ..                                                   ...          ...
# 395                            [Pioneer Trail - stage 1]       [easy]
# 396                         [Durch das Lauterbrunnental]       [easy]
# 397                             [1x Meringue und zurück]     [medium]
# 398                     [Biketour Langenthal Ochlenberg]     [medium]
# 399                     [Rundfahrt südlicher Oberaargau]     [medium]
#
#               sport    length    time    climb          minmax technique  \
# 0    [Trailrunning]   35.79km  07:25h  1,877hm  1,010 - 2,108m  rating-4
# 1          [Hiking]   13.13km  08:00h  1,557hm    680 - 2,189m  rating-4
# 2          [Hiking]    7.72km  01:30h    286hm  1,145 - 1,360m  rating-1
# 3          [Hiking]   13.81km  04:30h    700hm  1,067 - 1,951m  rating-1
# 4          [Racing]  120.31km  07:45h  2,670hm    393 - 1,776m  rating-2
# ..              ...       ...     ...      ...             ...       ...
# 395        [Hiking]    12.6km  04:00h     37hm    741 - 1,540m  rating-2
# 396        [Hiking]      24km  03:09h    223hm      802 - 958m  rating-2
# 397       [Cycling]   65.89km  08:00h    937hm    697 - 1,317m  rating-4
# 398  [Mountainbike]   33.08km  04:05h    791hm      479 - 748m  rating-4
# 399       [Cycling]   35.32km  03:08h    614hm      531 - 746m  rating-3
#
#       fitness      ID
# 0    rating-5  482334
# 1    rating-4  113481
# 2    rating-2  133083
# 3    rating-2  870921
# 4    rating-6  131766
# ..        ...     ...
# 395  rating-2   63183
# 396  rating-3  575440
# 397  rating-4   69538
# 398  rating-4  619586
# 399  rating-4  610972
#
# [400 rows x 10 columns]

# %% [markdown]
# # 2  Data Cleaning
#
# As mentioned above, the dataframe still needs to be cleaned up.

# %% [markdown]
# ### 2.1 Clean Categorical Data
# - Convert columns to strings
# - Remove brackets that are in the first 3 columnns
# - Remove extra whitespace

# %%
# Converting the text columns to strings for easier handling later
activities_df[['title', 'difficulty', 'sport']] = activities_df[['title', 'difficulty', 'sport']].astype('str')

# Removing the brackets
activities_df['title'] = activities_df['title'].str.strip('[]')
activities_df['difficulty'] = activities_df['difficulty'].str.strip('[]')
activities_df['sport'] = activities_df['sport'].str.strip('[]')

# Remove extra whitespace
activities_df['title'] = pd.Series(activities_df['title']).str.replace("'", '')
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("'", '')
activities_df['sport'] = pd.Series(activities_df['sport']).str.replace("'", '')

# Remove units (km, m, h, hm, m)
activities_df['length'] = pd.Series(activities_df['length']).str.replace("km", '')
activities_df['time'] = pd.Series(activities_df['time']).str.replace("h", '')
activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("hm", '')
activities_df['minmax'] = pd.Series(activities_df['minmax']).str.replace("m", '')

# Seperate the minmax altitude into a min column and a max column
activities_df[['min','max']] = activities_df['minmax'].str.split("-",expand=True)
activities_df = activities_df.drop(columns=['minmax'])

# Organize the dataframe columns
activities_df = activities_df[['ID','title', 'difficulty', 'sport', 'length', 
                               'time', 'climb', 'min', 'max', 'technique', 'fitness']]

# %%
activities_df
# Out:
#          ID                                              title difficulty  \
# 0    482334  Swiss Trail Tour Lenk, Strecke Tour, Samstag 2019  difficult
# 1    113481                                  Stockhorn, 2190 m     medium
# 2    133083              Adelboden - Cholerenschlucht - retour       easy
# 3    870921            Via Alpina - Etappe 15 Adelboden - Lenk       easy
# 4    131766                               Tour de la reine sud  difficult
# ..      ...                                                ...        ...
# 395   63183                            Pioneer Trail - stage 1       easy
# 396  575440                         Durch das Lauterbrunnental       easy
# 397   69538                             1x Meringue und zurück     medium
# 398  619586                     Biketour Langenthal Ochlenberg     medium
# 399  610972                     Rundfahrt südlicher Oberaargau     medium
#
#             sport  length   time  climb     min     max technique   fitness
# 0    Trailrunning   35.79  07:25  1,877  1,010    2,108  rating-4  rating-5
# 1          Hiking   13.13  08:00  1,557    680    2,189  rating-4  rating-4
# 2          Hiking    7.72  01:30    286  1,145    1,360  rating-1  rating-2
# 3          Hiking   13.81  04:30    700  1,067    1,951  rating-1  rating-2
# 4          Racing  120.31  07:45  2,670    393    1,776  rating-2  rating-6
# ..            ...     ...    ...    ...     ...     ...       ...       ...
# 395        Hiking    12.6  04:00     37    741    1,540  rating-2  rating-2
# 396        Hiking      24  03:09    223    802      958  rating-2  rating-3
# 397       Cycling   65.89  08:00    937    697    1,317  rating-4  rating-4
# 398  Mountainbike   33.08  04:05    791    479      748  rating-4  rating-4
# 399       Cycling   35.32  03:08    614    531      746  rating-3  rating-4
#
# [400 rows x 11 columns]

# %% [markdown]
# ### 2.2 Clean Numerical Data
#
# In order to normalize numerical data for analysis, we must preform the following steps:
#
# -  Replace missing numerical data with 0
# -  Remove commas
# -  Remove "-"
# -  Remove unnecessary words ("rating-")

# %%
activities_df['length'] = (activities_df['length']).astype(float)

activities_df['climb'] = pd.Series(activities_df['climb']).str.replace(",", '') 
activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("-", '0') 
activities_df['climb'] = (activities_df['climb']).astype(int)

activities_df['min'] = pd.Series(activities_df['min']).str.replace(",", '') 
activities_df['min'] = (activities_df['min']).astype(int)
activities_df['max'] = pd.Series(activities_df['max']).str.replace(",", '') 
activities_df['max'] = (activities_df['max']).astype(int)

activities_df['technique'] = pd.Series(activities_df['technique']).str.replace("rating-", '')
activities_df['technique'] = pd.to_numeric(activities_df['technique'], errors='coerce')
activities_df['technique'] = pd.Series(activities_df['technique']).replace(np.nan, 0, regex = True)
activities_df['technique'] = pd.Series(activities_df['technique']).astype('int')

activities_df['fitness'] = pd.Series(activities_df['fitness']).str.replace("rating-", '')
activities_df['fitness'] = pd.to_numeric(activities_df['fitness'], errors='coerce')
activities_df['fitness'] = pd.Series(activities_df['fitness']).replace(np.nan, 0, regex = True)
activities_df['fitness'] = activities_df['fitness'].astype('int')

# %% [markdown]
# ### 2.3 Clean Time Data
# Some of the hikes can register times >24 hours, and this causes Pandas to throw an error. This is handled by using Try/Except

# %%
activities_df
# Out:
#          ID                                              title difficulty  \
# 0    482334  Swiss Trail Tour Lenk, Strecke Tour, Samstag 2019  difficult
# 1    113481                                  Stockhorn, 2190 m     medium
# 2    133083              Adelboden - Cholerenschlucht - retour       easy
# 3    870921            Via Alpina - Etappe 15 Adelboden - Lenk       easy
# 4    131766                               Tour de la reine sud  difficult
# ..      ...                                                ...        ...
# 395   63183                            Pioneer Trail - stage 1       easy
# 396  575440                         Durch das Lauterbrunnental       easy
# 397   69538                             1x Meringue und zurück     medium
# 398  619586                     Biketour Langenthal Ochlenberg     medium
# 399  610972                     Rundfahrt südlicher Oberaargau     medium
#
#             sport  length   time  climb   min   max  technique  fitness
# 0    Trailrunning   35.79  07:25   1877  1010  2108          4        5
# 1          Hiking   13.13  08:00   1557   680  2189          4        4
# 2          Hiking    7.72  01:30    286  1145  1360          1        2
# 3          Hiking   13.81  04:30    700  1067  1951          1        2
# 4          Racing  120.31  07:45   2670   393  1776          2        6
# ..            ...     ...    ...    ...   ...   ...        ...      ...
# 395        Hiking   12.60  04:00     37   741  1540          2        2
# 396        Hiking   24.00  03:09    223   802   958          2        3
# 397       Cycling   65.89  08:00    937   697  1317          4        4
# 398  Mountainbike   33.08  04:05    791   479   748          4        4
# 399       Cycling   35.32  03:08    614   531   746          3        4
#
# [400 rows x 11 columns]

# %%
# convert times to time objects
try:
    activities_df['time'] = activities_df['time'].dt.strftime('%H:%M')
except ValueError:
    pass
# Out:
# ---------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-19-6fd0448cda6e> in <module>
#       1 # convert times to time objects
#       2 try:
# ----> 3     activities_df['time'] = activities_df['time'].dt.strftime('%H:%M')
#       4 except ValueError:
#       5     pass
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     336             return DatetimeProperties(data, orig)
#     337
# --> 338         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %% [markdown]
# ### 2.4 Final check of DataFrame
# Double check for null values. It looks pretty good!  Now it's time to start analysis.

# %%
activities_df
# Out:
#          ID                                              title difficulty  \
# 0    482334  Swiss Trail Tour Lenk, Strecke Tour, Samstag 2019  difficult
# 1    113481                                  Stockhorn, 2190 m     medium
# 2    133083              Adelboden - Cholerenschlucht - retour       easy
# 3    870921            Via Alpina - Etappe 15 Adelboden - Lenk       easy
# 4    131766                               Tour de la reine sud  difficult
# ..      ...                                                ...        ...
# 395   63183                            Pioneer Trail - stage 1       easy
# 396  575440                         Durch das Lauterbrunnental       easy
# 397   69538                             1x Meringue und zurück     medium
# 398  619586                     Biketour Langenthal Ochlenberg     medium
# 399  610972                     Rundfahrt südlicher Oberaargau     medium
#
#             sport  length   time  climb   min   max  technique  fitness
# 0    Trailrunning   35.79  07:25   1877  1010  2108          4        5
# 1          Hiking   13.13  08:00   1557   680  2189          4        4
# 2          Hiking    7.72  01:30    286  1145  1360          1        2
# 3          Hiking   13.81  04:30    700  1067  1951          1        2
# 4          Racing  120.31  07:45   2670   393  1776          2        6
# ..            ...     ...    ...    ...   ...   ...        ...      ...
# 395        Hiking   12.60  04:00     37   741  1540          2        2
# 396        Hiking   24.00  03:09    223   802   958          2        3
# 397       Cycling   65.89  08:00    937   697  1317          4        4
# 398  Mountainbike   33.08  04:05    791   479   748          4        4
# 399       Cycling   35.32  03:08    614   531   746          3        4
#
# [400 rows x 11 columns]

# %%
activities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          400 non-null    object
#  1   title       400 non-null    object
#  2   difficulty  400 non-null    object
#  3   sport       400 non-null    object
#  4   length      400 non-null    float64
#  5   time        400 non-null    object
#  6   climb       400 non-null    int64
#  7   min         400 non-null    int64
#  8   max         400 non-null    int64
#  9   technique   400 non-null    int64
#  10  fitness     400 non-null    int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 34.5+ KB

# %% [markdown]
# ### 2.5 Write CSV
#
# Now that the data has been cleaned properly, let's save the dataframe to a CSV for future use and hash out the scraping code in 1.1. Otherwise if you rerun the Kernel too often, there is a risk of being blocked by the website.

# %%
activities_df.to_csv("../data/activities.csv", index=False)

# %% [markdown]
# # 3  Initial Data Analysis
#
# Before moving onto combining weather data with hiking trails, lets do some preliminary data analysis to see what we are working with.

# %%
plt.style.use('fivethirtyeight')
rcParams['figure.figsize'] = 10, 8

# %% [markdown]
# ### 3.1 Data Exploration
#
# We will begin the data analysis by data exploration. By creating different data frames and removing activities with little data to improve visualizations we can get a better idea of what types of trails we are working with.
#
# Here we can see that cycling, racing, and long-distance walking are much longer than the other types of trails. Another helpful tool this DataFrame provides is that we can now view the least used trail types in the dataset. These are going to be removed for the next few analysis steps so it's easier to look at the interesting trail statistics.

# %%
# Creating a df for "Number of entries by sport type" + average tour length
sporttype = activities_df.groupby('sport') \
       .agg({'sport':'count', 'length':'mean'}) \
       .rename(columns={'sport':'count','length':'average_length'}) \
       .reset_index() \
       .sort_values(by=['average_length'])
sporttype
# Out:
#                           sport  count  average_length
# 8                Thematic route     42        5.453333
# 6                       Running      5       10.560000
# 7                      Ski tour      1       11.490000
# 1                        Hiking    237       13.186878
# 10                  Via ferrata      3       14.766667
# 4                    Pilgrimage     10       16.905000
# 9                  Trailrunning     16       27.230625
# 3                  Mountainbike     30       27.931000
# 2         Long distance cycling      1       30.590000
# 0                       Cycling     40       35.684750
# 11  long-distance walking trail      1       60.960000
# 5                        Racing     14       85.160000

# %% [markdown]
# ### 3.2 Focus on the most relevant activities
# Remove the activities, which have less than 10 entries.

# %%
analysis = activities_df.groupby("sport").filter(lambda x: len(x) > 10)
analysis.groupby(['sport']).size()
# Out:
# sport
# Cycling            40
# Hiking            237
# Mountainbike       30
# Racing             14
# Thematic route     42
# Trailrunning       16
# dtype: int64

# %% [markdown]
# ### 3.3 Bar Chart Visualization
# Now that the activities with little entries are removed, a barchart of the sport types is much more readable. We can see that the most popular activity on our list of trails is hiking with more than 250 entries.

# %%
ax = analysis['sport'].value_counts().plot(kind='bar')
plt.title('Frequency of Activity types')
plt.xlabel('Type of Activity')
plt.ylabel('Count of Activity');

# %% [markdown]
# How does the picture look like by level of difficulty?

# %%
analysis['difficulty'].value_counts().plot(kind='bar')
plt.title('Number of Activities by Difficulty')
plt.xlabel('Difficulty')
plt.ylabel('Count of Activity');

# %% [markdown]
# ### 3.4 Scatter Plot Visualization
#
# The scatter plot paints an interesting picture of the trail data. First, the cycling trails are both the longest and the ones with most height difference out of the bunch. And second, it looks like all of the hiking trails fall between 2 and 20 km (except for one). Perhaps this is because long distance hiking trails often fall into the "Pilgrimages" category?

# %%
sns.scatterplot(    
    data=analysis,
    x="length", y="climb", hue='sport',
).set_title('Length and Distance By Sport Type');

# %%
# mean length for difficulty:
activities_df.groupby('difficulty').mean()
# Out:
#                length        climb          min          max  technique  \
# difficulty
#             38.038077   594.384615   756.384615  1047.538462   0.000000
# difficult   34.701667  1336.312500   936.572917  1924.760417   3.156250
# easy         7.815328   224.885246  1026.459016  1239.090164   1.377049
# medium      15.018910   712.064103  1082.467949  1670.211538   2.628205
#
#              fitness
# difficulty
#             0.000000
# difficult   5.135417
# easy        1.770492
# medium      3.371795

# %% [markdown]
# Now let's explore the data using only hiking trail data.

# %% [markdown]
# # 4 Analysis: Hiking Trails
#
# The primary interest of this analysis is hiking trail data. The following analysis will compare only hiking trails and drop the rest of the sport types.

# %%
hiking = activities_df[activities_df.sport == "Hiking"]
hiking.shape
# Out:
# (237, 11)

# %% [markdown]
# ### 4.1 Scatter plot: Length and Distance of each Activity By Difficulty

# %%
sns.scatterplot(    
    data=hiking,
    x="length", y="climb", hue='difficulty',
).set_title('Length and Distance By Difficulty');

# %% [markdown]
# Seems we have one "outlier" which is more than 200km long. Let's remove it to get a better view on the majority of the trails.

# %%
sns.scatterplot(    
    data=hiking[hiking.length < 200],
    x="length", y="climb", hue='difficulty',
).set_title('Length and Distance By Difficulty');

# %% [markdown]
# The easier trails seem to be shorter in length and with lower elevation gain. Let's see if there is a correlation.

# %% [markdown]
# ### 4.2 Line Plot: Comparison of average Trail Length vs. Fitness Score

# %% [markdown]
# The following dataframe uses the fitness scores and compares them to the length of each trail. How correlated is the trail length to the fitness score? A new columns is added for average length.

# %%
# calculating the count by Fitness level and the average length 
fitness_length_check = hiking.groupby('fitness') \
       .agg({'fitness':'count', 'length':'mean'}) \
       .rename(columns={'fitness':'count','length':'average_length'}) \
       .reset_index()
fitness_length_check
# Out:
#    fitness  count  average_length
# 0        0     26       36.586154
# 1        1     13        5.229231
# 2        2     50        7.079400
# 3        3     54       10.441852
# 4        4     54       11.667407
# 5        5     34       13.394706
# 6        6      6       17.130000

# %% [markdown]
# The routes with no fitness rating seems quite long. Probably related to the outlier previously identified.
# For further analysis let's remove the trails without any difficulty rating and check if there is a visual clue.

# %%
fitness_length = fitness_length_check[fitness_length_check['fitness'] != 0]
plt.plot(fitness_length["fitness"], fitness_length["average_length"])
plt.ylabel('average_length')
plt.xlabel("rating_fitness")
plt.title('Hiking: Average Length by Fitness Level Rating')
plt.show()

# %% [markdown]
# There seems to be a relationship indeed between fitness score and length of the hike.

# %% [markdown]
# ### 4.3 Boxplots: Difficulty vs. Elevation Gain and Length
#
# The following boxplots show how the trail data is distributed by difficulty catagory compared to both elevation gain and length. It's pretty clear that the relationship between elevation gain and difficulty is more meaningful than the relationship between distance and difficulty. My legs agree!

# %%
ax = sns.boxplot(x="difficulty", y="climb", data=hiking) \
.set_title('Relationship between Trail Difficulty Rating and Elevation Gain')

# %%
ax = sns.boxplot(x="difficulty", y="length",showfliers = False, data=hiking) \
.set_title('Relationship between Trail Difficulty Rating and Distance')

# %% [markdown]
# ### 3.6 Correlation Matrix
# Let's see what the mathematical correlations are between the four parameters: climb, length, fitness score, technique score.

# %%
corr_matrix_df = hiking.drop(columns = ['min','max']).copy()
corr_matrix = corr_matrix_df.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corr_matrix, annot = True, cmap = 'Blues');

# %%
corr_matrix_df_easy = corr_matrix_df[corr_matrix_df['difficulty']== 'easy']
corr_matrix_easy = corr_matrix_df_easy.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corr_matrix_easy, annot = True,cmap = 'Blues');

# %%
corr_matrix_df['difficulty_level'] = corr_matrix_df['difficulty']
corr_matrix_df.loc[corr_matrix_df['difficulty'] == 'easy', ['difficulty_level']] = 1
corr_matrix_df.loc[corr_matrix_df['difficulty'] == 'medium', ['difficulty_level']] = 2
corr_matrix_df.loc[corr_matrix_df['difficulty'] == 'difficult', ['difficulty_level']] = 3
corr_matrix_df.loc[corr_matrix_df['difficulty'] == '', ['difficulty_level']] = 0
corr_matrix_df2 = corr_matrix_df.copy()
corr_matrix_df2
# Out:
#          ID  \
# 1    113481
# 2    133083
# 3    870921
# 5    114210
# 7    616579
# ..      ...
# 389  783969
# 391  895528
# 393  614116
# 395   63183
# 396  575440
#
#                                                                                       title  \
# 1                                                                         Stockhorn, 2190 m
# 2                                                     Adelboden - Cholerenschlucht - retour
# 3                                                   Via Alpina - Etappe 15 Adelboden - Lenk
# 5                                                Über sieben Brücken im Kiesen- und Aaretal
# 7                                   Von Saanen via Rellerligrat und Hundsrügg nach Jaunpass
# ..                                                                                      ...
# 389  Kleine Scheidegg - Eigergletscher - Alpiglen (37 Jungfrau Eiger Walk + 36 Eiger Trail)
# 391                                                              Lauterbrunnen - Schilthorn
# 393                                                                         Rundweg Mülenen
# 395                                                                 Pioneer Trail - stage 1
# 396                                                              Durch das Lauterbrunnental
#
#     difficulty   sport  length   time  climb  technique  fitness  \
# 1       medium  Hiking   13.13  08:00   1557          4        4
# 2         easy  Hiking    7.72  01:30    286          1        2
# 3         easy  Hiking   13.81  04:30    700          1        2
# 5               Hiking    9.31  02:10     57          0        0
# 7       medium  Hiking   17.00  05:45   1300          2        3
# ..         ...     ...     ...    ...    ...        ...      ...
# 389     medium  Hiking    9.93  03:35    340          3        3
# 391     medium  Hiking   15.20  06:00   2190          3        5
# 393       easy  Hiking    8.45  02:02    315          4        4
# 395       easy  Hiking   12.60  04:00     37          2        2
# 396       easy  Hiking   24.00  03:09    223          2        3
#
#     difficulty_level
# 1                  2
# 2                  1
# 3                  1
# 5                  0
# 7                  2
# ..               ...
# 389                2
# 391                2
# 393                1
# 395                1
# 396                1
#
# [237 rows x 10 columns]

# %%
corr_matrix = corr_matrix_df2.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corr_matrix, annot = True,cmap = 'Blues');

# %% [markdown]
# # 5 Download Trail GPS Data
#
# The next part of this notebook deals with parsing HTML tags again, however this time around we will be gathering the GPS data needed to create the snowfall alert. The GPS data for each trail is actually a list of GPS points that comprise the length of the trail, from start to summit. However, we will only be using the first GPS point in our algorithm, which is the trail-head.
#
# The Bergfex website embedds their GPS data into downloadable files, which are meant to be uploaded to a GPS device for navigation purposes. As such, the following code will automatically download each GPS file into a folder. Importantly, a sleep timer is added to replicate how a human may download these files, if the sleep timer is not added, the website will become suspicious and prevent us from downloading more files.
#
# The type of GPS file that is being downloaded is a "GPX" or "GPS Exchange Format" file, which is a special type of XML file that can be used to describe waypoints. For testing purposes, these GPX files were uploaded into Google Earth, and it correctly displayed the location.
#
# - https://www.bergfex.com/downloads/gps/?type=&id=271548&fileType=kml

# %% [markdown]
# ### 5.1 Download Batches of GPX Files
#
# This loop uses the hike id's to navigate to each of the hike's pages. It then downloads the GPS file to the folder "gpx_files" and saves it as a filename "Unique hike id.gpx". To prevent being blocked from the page, we download the dat in small batches for all 400 activities.

# %%
test_id = corr_matrix_df.iloc[20:30,0]

# %%
# create a small subset of data for testing
test_id = corr_matrix_df.iloc[20:30,0]
for hike_id in test_id: 
    url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={hike_id};fileType=kml"
    print(url_id)
    r = requests.get(url_id, allow_redirects=True)
    time.sleep(5) 
    write_link = ('../gpx_files/'+ hike_id + ".gpx")
    # Replace kml files with your filename
    with open(write_link, 'wb') as f:
        f.write(r.content)
# Out:
# https://www.bergfex.com/downloads/gps/?type=&id=315061;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=132107;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=247242;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=114210;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=51169;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=133091;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=744923;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=159602;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=658326;fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=83713;fileType=kml

# %% [markdown]
# ###  5.2 Extract Coordinates from GPX files
#
# Now that the GPX files have been downloaded to a local file, we can loop through them and extract the important information, which is the latitude and the longitude of the trail start.

# %%
list_of_trails_list = []
list_of_files = glob.glob('*gpx')  
for hike_id in test_id: 
    trail_gps_list = []
    gpx = gpxpy.parse(open('../gpx_files/'+hike_id+'.gpx', 'r'))
    trail_gps_list.append(hike_id)
    for track in gpx.tracks: 
        trail_name = track.name
        trail_gps_list.append(trail_name)
        for segment in track.segments: 
            for point in segment.points: 
              lat = point.latitude
              trail_gps_list.append(lat)
              lon = point.longitude
              trail_gps_list.append(lon) 
              break
        list_of_trails_list.append(trail_gps_list)

print(list_of_trails_list)
# Out:
# [['315061', 'Interlaken Ost - Harder Kulm', 46.690472, 7.868505], ['132107', 'Via Jacobi: Schwarzenburg - Fribourg', 46.81908, 7.34291], ['247242', 'Cable car to Wispile. Walk to Lauenensee', 46.439976, 7.2924], ['114210', 'Über sieben Brücken im Kiesen- und Aaretal', 46.819523, 7.575754], ['51169', 'Durch Berns Kornkammer', 47.086246, 7.523001], ['133091', 'Panoramawanderung: Hörnliweg Adelboden', 46.493469, 7.56035], ['744923', 'Bahnhof-Eggeschwand', 46.495193, 7.671376], ['159602', 'Rund um den Thunersee, Merligen-Interlaken West', 46.69656, 7.737741], ['658326', 'Durchs Jahr wandern - Edelweiss am Iffighorn', 46.400131, 7.44155], ['83713', 'Wanderung Axalp – Axalp', 46.71896, 8.03773]]

# %% [markdown]
# ### 5.3  Create a Dataframe and Save as CSV
#
# Lets take a look at our data now that it has been extracted. It looks like everything has is working as intended. Each trail has a unique ID and latitude and longitude. This data can now be saved to a CSV file which will be used for the snow alert in the next notebook.

# %%
trail_coords_df = pd.DataFrame(list_of_trails_list)
# name the columns
trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon']
trail_coords_df.set_index('trail_id')
# Out:
#                                                      name        lat       lon
# trail_id
# 315061                       Interlaken Ost - Harder Kulm  46.690472  7.868505
# 132107               Via Jacobi: Schwarzenburg - Fribourg  46.819080  7.342910
# 247242           Cable car to Wispile. Walk to Lauenensee  46.439976  7.292400
# 114210         Über sieben Brücken im Kiesen- und Aaretal  46.819523  7.575754
# 51169                              Durch Berns Kornkammer  47.086246  7.523001
# 133091             Panoramawanderung: Hörnliweg Adelboden  46.493469  7.560350
# 744923                                Bahnhof-Eggeschwand  46.495193  7.671376
# 159602    Rund um den Thunersee, Merligen-Interlaken West  46.696560  7.737741
# 658326       Durchs Jahr wandern - Edelweiss am Iffighorn  46.400131  7.441550
# 83713                             Wanderung Axalp – Axalp  46.718960  8.037730

# %%
trail_coords_df.to_csv('../data/trail_coords_df.csv', index=False)
read= pd.read_csv('../data/trail_coords_df.csv')
read
# Out:
#    trail_id                                             name        lat  \
# 0    315061                     Interlaken Ost - Harder Kulm  46.690472
# 1    132107             Via Jacobi: Schwarzenburg - Fribourg  46.819080
# 2    247242         Cable car to Wispile. Walk to Lauenensee  46.439976
# 3    114210       Über sieben Brücken im Kiesen- und Aaretal  46.819523
# 4     51169                           Durch Berns Kornkammer  47.086246
# 5    133091           Panoramawanderung: Hörnliweg Adelboden  46.493469
# 6    744923                              Bahnhof-Eggeschwand  46.495193
# 7    159602  Rund um den Thunersee, Merligen-Interlaken West  46.696560
# 8    658326     Durchs Jahr wandern - Edelweiss am Iffighorn  46.400131
# 9     83713                          Wanderung Axalp – Axalp  46.718960
#
#         lon
# 0  7.868505
# 1  7.342910
# 2  7.292400
# 3  7.575754
# 4  7.523001
# 5  7.560350
# 6  7.671376
# 7  7.737741
# 8  7.441550
# 9  8.037730

# %% [markdown]
# # CONTINUE IN NOTEBOOK II
