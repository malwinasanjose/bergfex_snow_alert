# %% [markdown]
# ## Bergfex Webscraping
# <b> Milestone 1</b>
#
# Scraping the Bergfex.com website in order to create Pandas dataframes that contain important information about each trail. This code uses BeautifulSoup to parse the html tags into json, which is easier to work with. A for-loop iterates over each html tag and adds the corresponding information into empty lists. Data is cleaned and an initial data analysis is performed.
# Finally, also the corresponding GPS data is downloaded and scraped.
# The functions created in this notebook allow to easily repeat the steps or perform them for different regions.

# %% [markdown]
# ### Installations

# %%
# unhash and run the below line once
#!pip install lxml
#!pip install wget
#!pip install gpxpy

# %% [markdown]
# ### Imports

# %%
# import requests
import re
from bs4 import BeautifulSoup 
import pandas as pd
import lxml

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math

import requests
#import wget
import glob
import datetime as dt
import time

import seaborn as sns
from matplotlib import rcParams
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import gpxpy 
import gpxpy.gpx 
import glob

# %% [markdown]
# # Still to do:
# - Add key words: Webscraping from a static page, Data Cleaning, plots, GPX coordinates, KML coordinates (add both? describe the differences?), spatial data, tableau, visualization, seaboarn, matplotlib
#
# - DONE: clean up of functions
# - DONE: clean up gpx all df: name, trail_id
# - DONE: check if example ID is in DF for google earth
# - WIP: test final functions
# - WIP: download of final GPX files

# %% [markdown]
# # 1  Data scraping
#
# Prepare to scrape the Bergfex.com website in order to create Pandas dataframes that contain important information about each trail. This code uses BeautifulSoup to parse the html tags into json. A for-loop iterates over each html tag and adds the corresponding information into empty lists.

# %% [markdown]
# ## 1.1 Scrape all the information (basic and more complicated)

# %%
title = []  # Title of the tour
difficulty = []  # difficulty (easy, medium, hard)
sport = []  # Sport type (hiking, sledging, snowshoe...)
length = []  # length in km
time_list = []  # tour time in hours:minutes
climb = []  # positive elevation climb in m
minmax = []  # minimum and maximum altitude of the tour in m
technique = []  # technique difficulty ratings (out of 6)
fitness = []  # fitness difficulty ratings (out of 6)
total_title = [] # will help extracting the ID of the tour

# all ratings are stored together so we will need this along the way:
rating = []  # list to store technique and fitness rating info

# %%
# looping over the x first pages of Bergfex
# each separate tour on the page is framed by a div tag with 'touren-details'

page_number = 2  # number of pages we want to scrape through

for p in range(1, (page_number+1)):
    base_link = 'https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page='
    link = base_link+str(p)  # going over p pages with numbers appended to the base link
    page = requests.get(link, timeout=5)
    print("scraped page", p)
    soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
    tours = soup.findAll('div', {'class': 'touren-detail'})  # checks for the separate tours on the page

# For each page, we loop over each tour and fill our lists with info     
    for i in range(0,len(tours)):
        tour_1 = tours[i] # tour iterating over the 20 tours of the page

        tour_title = tour_1.findAll('a' ) # this gets the title out
        title.append([info.get_text().strip() for info in tour_title])
        total_title.append(tour_title) 
        # this gets the full tour-title information including the ID, will need to be processed further later on
        
        tour_diff = tour_1.findAll('span', {'class': 'tour-difficulty'}) #tour level difficulty
        difficulty.append([info.get_text().strip() for info in tour_diff])

        tour_type = tour_1.findAll('span', {'class': 'tour-type'}) # putting type into sports
        sport.append([info.get_text().strip() for info in tour_type])

        tour_stats = tour_1.findAll('div', {'class': 'tour-stats'}) # stats has 4 info binned together
        stat_text = [info.get_text().strip() for info in tour_stats]
        length.append(stat_text[0])
        time_list.append(stat_text[1])
        climb.append(stat_text[2])
        minmax.append(stat_text[3])
        
        tour_rating = tour_1.find_all("div", {'class': 'tour-rating'}) # getting the rating data 
        rating.append([info for info in tour_rating])   # it's a class name so we can't get_text.
# Out:
# scraped page 1
# scraped page 2

# %%
tours
# Out:
# [<div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/114256,zur-hohwacht-im-emmental/" title="Zur Hohwacht im Emmental">Zur Hohwacht im Emmental</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  11.37<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>03:20</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  423<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  669 - 1,074<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="84f7246e881e3d9ede82b2cecedc5d8a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/d8a/84f7246e881e3d9ede82b2cecedc5d8a.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="e2b4028dc84ce0f7ec1835237deb0be4" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/be4/e2b4028dc84ce0f7ec1835237deb0be4.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="a70d31a153c428e5d5e79f037f0165bf" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/5bf/a70d31a153c428e5d5e79f037f0165bf.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="86c2624025961ef1b67172a72d848107" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/107/86c2624025961ef1b67172a72d848107.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/radfahren/700226,st-stephan--ruewlispass--gstaad--saanenmoeser--st-stephan/" title="St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan">St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Cycling
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  38.14<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>03:50</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  1,055<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  934 - 1,724<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="919452c86a22554672db285b53f98ed2" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ed2/919452c86a22554672db285b53f98ed2.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="8549a8f400887bb87c0a88646176c9c9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/9c9/8549a8f400887bb87c0a88646176c9c9.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="0561cc12a0e6bad5f10cf10b1fd75c00" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c00/0561cc12a0e6bad5f10cf10b1fd75c00.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="4b7084b7d21181e129f7a9c753fcc7b9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7b9/4b7084b7d21181e129f7a9c753fcc7b9.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/themenweg/108674,holz-skulpturenweg--frutigen/" title="Holz-Skulpturenweg - Frutigen">Holz-Skulpturenweg - Frutigen</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Thematic route
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  9.56<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>02:45</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  134<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  779 - 913<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="189e5cfd81f6947c350ad868ffa1dc82" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c82/189e5cfd81f6947c350ad868ffa1dc82.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="99c5d31d8e7d9eeda477d6cf062c5ef3" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ef3/99c5d31d8e7d9eeda477d6cf062c5ef3.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="cb8cf20183df84cdaee3df8a5f3efbe7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/be7/cb8cf20183df84cdaee3df8a5f3efbe7.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="3c8af39949e1117898d99d4473308ad9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ad9/3c8af39949e1117898d99d4473308ad9.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/themenweg/295433,diemtigtaler-hausweg-mittleres-tal/" title="Diemtigtaler Hausweg «Mittleres Tal»">Diemtigtaler Hausweg «Mittleres Tal»</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-1">
#  easy
#  </span>
#  <span class="tour-type">
#  Thematic route
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  10.2<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>03:15</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  434<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  814 - 1,128<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="7ddcf296ce9de48e981ddcafd78c8238" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/238/7ddcf296ce9de48e981ddcafd78c8238.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="95fd65948c1651fc8acfe27477cd2c7d" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c7d/95fd65948c1651fc8acfe27477cd2c7d.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="f48283d2e801d036df90e06e990aaae5" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ae5/f48283d2e801d036df90e06e990aaae5.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="49d996e736eac6736015ed7116034f4a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f4a/49d996e736eac6736015ed7116034f4a.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/radfahren/172139,moraenensee-route/" title="Moränensee Route">Moränensee Route</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-1">
#  easy
#  </span>
#  <span class="tour-type">
#  Cycling
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  25.49<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>01:40</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  197<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  553 - 750<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="9ea606c8c82bbd9f28c9ee6ffac2366e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/66e/9ea606c8c82bbd9f28c9ee6ffac2366e.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="689c2e8bdc609f7f83d981c043c14f65" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f65/689c2e8bdc609f7f83d981c043c14f65.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="7bba0d70a0824d2a80eb6f7e434c5152" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/152/7bba0d70a0824d2a80eb6f7e434c5152.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/99639,probsteberg--einsames-grenzgebiet-bern-solothurn/" title="Probsteberg - einsames Grenzgebiet Bern/Solothurn">Probsteberg - einsames Grenzgebiet Bern/Solothurn</a>
#  <div>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  16.44<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>04:45</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  581<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  640 - 1,149<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="54600219282c1badb675b774fa3418c8" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/8c8/54600219282c1badb675b774fa3418c8.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="3f2f03ffc4b1c201f2c0cd87cadac7a7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7a7/3f2f03ffc4b1c201f2c0cd87cadac7a7.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-0"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/509375,meraengge-cher-im-kemmribodenbad/" title="Merängge-Cher im Kemmribodenbad">Merängge-Cher im Kemmribodenbad</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-1">
#  easy
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  6.97<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>02:10</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  330<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  975 - 1,184<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="7e83b7446943e940e9b6769b2ec64302" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/302/7e83b7446943e940e9b6769b2ec64302.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/348126,lauenen--lauenensee--lauenen/" title="Lauenen – Lauenensee - Lauenen">Lauenen – Lauenensee - Lauenen</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  8.99<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>02:30</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  178<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,236 - 1,409<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="380affffeb5520165793457fc76b664a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/64a/380affffeb5520165793457fc76b664a.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="e715d2d342428159ef959a1872a1d51f" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/51f/e715d2d342428159ef959a1872a1d51f.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="1c76a68ac9a126da97054ec289361daa" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/daa/1c76a68ac9a126da97054ec289361daa.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="2afe47c97f236c5c964fe6ff71abbc34" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c34/2afe47c97f236c5c964fe6ff71abbc34.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="073659e3a3bb383e133311f3c65f5711" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/711/073659e3a3bb383e133311f3c65f5711.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/612482,gletscherschlucht--pfingstegg--rundweg/" title="Gletscherschlucht - Pfingstegg - Rundweg">Gletscherschlucht - Pfingstegg - Rundweg</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  5.85<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>02:39</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  464<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,013 - 1,411<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="62dc4b5b6b306395b003cc5cf4f926c3" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/6c3/62dc4b5b6b306395b003cc5cf4f926c3.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="643dd48636b7968dc6c5f776c39e9fef" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/fef/643dd48636b7968dc6c5f776c39e9fef.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="83808f4b41288d9f642ab9db1baf9757" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/757/83808f4b41288d9f642ab9db1baf9757.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="e7b612776cde7ce9d6feecd60860595e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/95e/e7b612776cde7ce9d6feecd60860595e.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="408b010fbf191533e8c1512a276a52b4" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/2b4/408b010fbf191533e8c1512a276a52b4.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/133083,adelboden--cholerenschlucht--retour/" title="Adelboden - Cholerenschlucht - retour">Adelboden - Cholerenschlucht - retour</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-1">
#  easy
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  7.72<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>01:30</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  286<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,145 - 1,360<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="10a0b8d3d806b77b3ab1d1650f8c08d5" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/8d5/10a0b8d3d806b77b3ab1d1650f8c08d5.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/trailrunning/211604,helsana-trail-schoenried--bergmatte--grossi-vorschess--rellerli--ritmal--schoenried-gelb/" title="Helsana Trail: Schönried - Bergmatte - Grossi Vorschess - Rellerli - Ritmal - Schönried, gelb">Helsana Trail: Schönried - Bergmatte - Grossi Vorschess - Rellerli - Ritmal - Schönried, gelb</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Trailrunning
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  9.51<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>02:00</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  593<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,239 - 1,832<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="483634ddf61e249973438052340bf12d" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/12d/483634ddf61e249973438052340bf12d.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="e18f6ca61fdea01b09f715adc8b7b361" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/361/e18f6ca61fdea01b09f715adc8b7b361.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="7b1fc9d49442b1af706676f7ff8f3c91" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c91/7b1fc9d49442b1af706676f7ff8f3c91.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="9ea7a49bdc70a51c686a36824dd02773" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/773/9ea7a49bdc70a51c686a36824dd02773.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="70974247a29eef28b1cb9772991962c9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/2c9/70974247a29eef28b1cb9772991962c9.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/162712,hoehenweg-entlebuch-emmental--etappe-5-grosshorben--schangnau/" title="Höhenweg Entlebuch Emmental - Etappe 5: Grosshorben – Schangnau">Höhenweg Entlebuch Emmental - Etappe 5: Grosshorben – Schangnau</a>
#  <div>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  5.16<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>01:45</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  196<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  928 - 1,415<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="8f4bd3d5295c102f90390c8c724e5a94" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/a94/8f4bd3d5295c102f90390c8c724e5a94.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="d5244bdba6d0218379fa14056480ce00" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/e00/d5244bdba6d0218379fa14056480ce00.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="b96048cdf8ca06db6a06608a2c7c7ff9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ff9/b96048cdf8ca06db6a06608a2c7c7ff9.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-0"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/51213,auf-panoramawegen-durchs-bipperamt/" title="Auf Panoramawegen durchs Bipperamt">Auf Panoramawegen durchs Bipperamt</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  16.53<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>05:15</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  862<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  636 - 1,215<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="9cc876675b0de322e6a0e166b0095229" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/229/9cc876675b0de322e6a0e166b0095229.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/277646,kandersteg-to-allmenalp/" title="Kandersteg to Allmenalp">Kandersteg to Allmenalp</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  8.38<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>04:00</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  620<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,170 - 1,789<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="8cedfc2b0896ba7a9117e14e64faaef7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ef7/8cedfc2b0896ba7a9117e14e64faaef7.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="8952affe451df9f5a7d8c55819e2a773" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/773/8952affe451df9f5a7d8c55819e2a773.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="57c66493b25d5f5b2297549cbb6a75e2" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/5e2/57c66493b25d5f5b2297549cbb6a75e2.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="8fa4650e7a12dc596f379799b7f1d45a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/45a/8fa4650e7a12dc596f379799b7f1d45a.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="1cc3f633be8c819152906f4d2ba0242d" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/42d/1cc3f633be8c819152906f4d2ba0242d.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/744917,blausee/" title="Blausee">Blausee</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-1">
#  easy
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  11.53<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>03:20</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  315<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  888 - 1,186<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="f31b6da0b818cd9ee26b188c54b05dd7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/dd7/f31b6da0b818cd9ee26b188c54b05dd7.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/56959,huegelpanorama-oberhalb-trubschachen/" title="Hügelpanorama oberhalb Trubschachen">Hügelpanorama oberhalb Trubschachen</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  3.71<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>01:35</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  290<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  731 - 996<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="b2cd7c0629bf8d6c4c8c858befd75c64" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c64/b2cd7c0629bf8d6c4c8c858befd75c64.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="2227188921e2f47473030e02f7410c3b" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c3b/2227188921e2f47473030e02f7410c3b.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="861e6d84b05354acb211d673d9f8e8c5" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/8c5/861e6d84b05354acb211d673d9f8e8c5.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="2e29d166faf2daa914b9b1c7347ec005" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/005/2e29d166faf2daa914b9b1c7347ec005.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/radfahren/823060,e-bike-tour-entlang-der-diemtigtaler-hauswege/" title="E-Bike Tour entlang der Diemtigtaler Hauswege">E-Bike Tour entlang der Diemtigtaler Hauswege</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Cycling
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  43.09<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>03:00</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  1,103<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  669 - 1,270<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="073e0ba950351b7156129bd36a650f7a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f7a/073e0ba950351b7156129bd36a650f7a.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="99bb4272b8e5af0ad22be01a5482dc60" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c60/99bb4272b8e5af0ad22be01a5482dc60.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="3172cb3efa40eb6223096cc1411245d2" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/5d2/3172cb3efa40eb6223096cc1411245d2.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="125648fc671a19bd65755dec2d2c1842" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/842/125648fc671a19bd65755dec2d2c1842.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/595654,schoenried-ermitage-rellerli-panoramawanderung/" title="Schönried Ermitage Rellerli Panoramawanderung">Schönried Ermitage Rellerli Panoramawanderung</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  11.33<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>04:00</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  645<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,222 - 1,861<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="a0c49c7c67fcc7deeec2fa7a1021d41c" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/41c/a0c49c7c67fcc7deeec2fa7a1021d41c.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="fc1ecf55a983e1035ce26215b73baeb8" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/eb8/fc1ecf55a983e1035ce26215b73baeb8.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/klettersteig/114228,simmeflueh-klettersteig--wimmis/" title="Simmeflueh Klettersteig - Wimmis">Simmeflueh Klettersteig - Wimmis</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-1">
#  easy
#  </span>
#  <span class="tour-type">
#  Via ferrata
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  2.09<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>03:00</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  767<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  626 - 1,393<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="2cb8f0394a82fd5adde9d591cbca399b" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/99b/2cb8f0394a82fd5adde9d591cbca399b.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="6fad0fe68990c14640fdf13ab2406e99" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/e99/6fad0fe68990c14640fdf13ab2406e99.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="ab6f7db0af46f770ac72fa7e6ad12f22" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f22/ab6f7db0af46f770ac72fa7e6ad12f22.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="13547b8c5d8be3310b7f763fdce137e0" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7e0/13547b8c5d8be3310b7f763fdce137e0.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="a017eeb7c065bfc72b6066635a08f571" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/571/a017eeb7c065bfc72b6066635a08f571.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-0"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/themenweg/289903,schwingerweg-springenboden/" title="Schwingerweg Springenboden">Schwingerweg Springenboden</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-1">
#  easy
#  </span>
#  <span class="tour-type">
#  Thematic route
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  2.49<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>01:30</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  120<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,285 - 1,392<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="c3fbe3bb0e4f77761738b087a70991f0" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/1f0/c3fbe3bb0e4f77761738b087a70991f0.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="c5bbd4deb350dd72cc63e55470f7ef44" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f44/c5bbd4deb350dd72cc63e55470f7ef44.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="dfaa9d4063f9739b06c4ca5daee53387" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/387/dfaa9d4063f9739b06c4ca5daee53387.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="1284ca7e22de9a17266cb222b3bd9c2e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c2e/1284ca7e22de9a17266cb222b3bd9c2e.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="53e6b0b6cad7334c7e1072a544193c0e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c0e/53e6b0b6cad7334c7e1072a544193c0e.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  </div>
#  </div>]

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</title>
# <meta content="Swiss plateau,Switzerland,Tours," name="keywords"/>
# <meta content="Swiss plateau Switzerland: " name="description"/>
# <meta content="app-id=912776148" name="apple-itunes-app">
# <script src="https://cdn.stroeerdigitalgroup.de/metatag/live/SDG_ConsentOnly/metaTag.min.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="en" name="language"/>
# <meta content="width=device-width, viewport-fit=cover" name="viewport"/>
# <script type="application/ld+json">
# {
# "@context": "https://schema.org",
# "@type": "Organization",
# "url": "https://www.bergfex.com",
# "logo": "https://www.bergfex.com/images/logo.png"
# }
# </script>
# <meta content="BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking" property="og:title"/>
# <meta content="https://vcdn.bergfex.at/images/resized/d8/a65a94fd11f0d3d8_ad3f21a01c2764d0.jpg" property="og:image"/>
# <meta content="image/jpg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="627" property="og:image:height"/>
# <link href="//www.bergfex.ch/sommer/bern-region/touren/" hreflang="de" rel="alternate"/>
# <link href="//www.bergfex.com/sommer/bern-region/touren/" hreflang="en" rel="alternate"/>
# <link href="//www.bergfex.fr/sommer/bern-region/touren/" hreflang="fr" rel="alternate"/>
# <link href="//it.bergfex.com/sommer/bern-region/touren/" hreflang="it" rel="alternate"/>
# <link href="//www.bergfex.es/sommer/bern-region/touren/" hreflang="es" rel="alternate"/>
# <link href="//nl.bergfex.com/sommer/bern-region/touren/" hreflang="nl" rel="alternate"/>
# <link href="//se.bergfex.com/sommer/bern-region/touren/" hreflang="sv" rel="alternate"/>
# <link href="//no.bergfex.com/sommer/bern-region/touren/" hreflang="no" rel="alternate"/>
# <link href="//dk.bergfex.com/sommer/bern-region/touren/" hreflang="da" rel="alternate"/>
# <link href="//fi.bergfex.com/sommer/bern-region/touren/" hreflang="fi" rel="alternate"/>
# <link href="//hu.bergfex.com/sommer/bern-region/touren/" hreflang="hu" rel="alternate"/>
# <link href="//www.bergfex.cz/sommer/bern-region/touren/" hreflang="cs" rel="alternate"/>
# <link href="//sk.bergfex.com/sommer/bern-region/touren/" hreflang="sk" rel="alternate"/>
# <link href="//www.bergfex.pl/sommer/bern-region/touren/" hreflang="pl" rel="alternate"/>
# <link href="//hr.bergfex.com/sommer/bern-region/touren/" hreflang="hr" rel="alternate"/>
# <link href="//www.bergfex.si/sommer/bern-region/touren/" hreflang="sl" rel="alternate"/>
# <link href="//ru.bergfex.com/sommer/bern-region/touren/" hreflang="ru" rel="alternate"/>
# <link href="//ro.bergfex.com/sommer/bern-region/touren/" hreflang="ro" rel="alternate"/>
# <link href="https://plus.google.com/105981749558386334210" rel="publisher"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link color="#1599ff" href="//vcdn.bergfex.at/images/mask-icon.svg" rel="mask-icon"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/bergfex-1615903180.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/sommer-1608217936.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/print-1608217936.css" media="print" rel="stylesheet"/><script>
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.autoCompleteActive = false;
# bergfex.autoCompleteSuggestionStartChar = 1;
# </script><script>
# // bergfex namespace
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.staticHost = '//vcdn.bergfex.at';
# bergfex.staticHosts = ['//vcdn.bergfex.at'];
# bergfex.InfobannerCookiesOptions = {
# timesToShow: 3,
# textTitle: "Informationen zu Cookies",
# textInfo:
# "Diese Seite verwendet Cookies. " +
# "Für eine uneingeschränkte Nutzung der Website werden Cookies benötigt. " +
# "Sie stimmen der Verwendung von Cookies durch Anklicken von \"OK\" zu. " +
# "Nähere Informationen finden Sie in unseren ",
# textPolicy: "Datenschutzbedingungen",
# urlPolicy: "/datenschutz/",
# textButton: "OK",
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.1-1608217937.jsmin.js" type="text/javascript"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.2-1610094216.jsmin.js" type="text/javascript"></script><script src="//vcdn.bergfex.at/include/js/jquery/plugins/ui/1.10.3/i18n/jquery.ui.datepicker-en.js" type="text/javascript"></script><script>
# var gMapKey = "AIzaSyDhkXDPfuKgSZgCcKfDLRHNZFrsdbfQkiQ";
# var mapEnabled = true;
# var mapHeight = 360;
# bergfex.libs = { };
# bergfex.libs.srcElevLibs = "//vcdn.bergfex.at/include/jsmin/elevationprofile-libs-1608217937.jsmin.js";
# bergfex.libs.srcMapLibs  = "//vcdn.bergfex.at/include/jsmin/map-libs-1608217937.jsmin.js";
# bergfex.season = "sommer";
# </script><script>
# var jBlockTruncateSettings = {
# 'moreText': "show more",
# 'lessText': "less"
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/bergfex-libs-1616068547.jsmin.js" type="text/javascript"></script><meta content="0" name="geonomap"/>
# <meta content="keep" name="geomap"/>
# <meta content="Bundesland_16" name="geocontext"/>
# <meta content="46.939012,8.107910,10,o" name="geoposition"/>
# <meta content="1" name="geotarget"/>
# <meta content="touren" name="geolayer"/>
# <meta content="sommer" name="season"/></meta></meta></head>
# <body class="site">
# <div id="page-top">
# <!--page-top-->
# <div style="position: absolute;">
# <script src="//script.ioam.de/iam.js" type="text/javascript"></script>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         $(document).ready(function() {
#             var iam_data = {
#                 "st": "bergfex",
#                 "cp": "sommer-nonde",
#                 "sv": "in",  // keine Befragungseinladung
#                 "co": ""  // comment
#             }
#             try {
#                 iom.c(iam_data, 1);
#             } catch(e) {
#             }
#         });
#     </script>
# <!-- /SZM -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-15684980-1"></script>
# <script>
# // https://support.google.com/analytics/answer/10022331?hl=de
# // window['gtag_enable_tcf_support'] = true;
# bergfex.Analytics = {
# send_to: 'UA-15684980-1',
# admask: 'schweiz.bern-region',
# language: 'en',
# page_location: '/sommer/bern-region/touren/?isAjax=1&page=1',
# };
# window.dataLayer = window.dataLayer || [];
# bergfex.gtag = function() {
# dataLayer.push(arguments);
# }
# bergfex.gtag('js', new Date());
# bergfex.gtag('config', 'UA-15684980-1', {
# send_page_view: false,
# custom_map: {
# dimension1: 'admask',
# dimension2: 'language',
# },
# });
# bergfex.gtag('event', 'init');
# window.addEventListener('metaTagSystemCmpChoiceUiShown', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceUiShown');
# });
# window.addEventListener('metaTagSystemCmpChoiceSelected', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceSelected');
# });
# // log map views.
# </script></div>
# <nav class="nav-default" id="nav-main">
# <div class="nav-main-trigger-side"></div>
# <a class="logo-bergfex" href="/" title="bergfex Homepage"></a>
# <div class="nav-main-search responsive-only" id="nav-main-search">
# </div>
# <div class="nav-main-user responsive-only">
# <a href="/mybergfex/">
# <div class="avatar">
# </div></a>
# </div>
# <div class="nav-main-trigger"></div>
# <div class="nav-main-close"></div>
# <div class="nav-main-container page-left-margin">
# <div class="nav-search">
# <form action="/sommer/suchen/" autocomplete="off" method="get" name="sitesearch">
# <div class="search-icon"></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" id="search-input-field" maxlength="256" name="q" placeholder="Search" spellcheck="false" type="text"/>
# </form>
# </div>
# <!-- on dropdown, inject logo from mainlogo position via js -->
# <ul class="nav-list">
# <li class="has-children collapsed">
# <a>Winter</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li>
# <a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li>
# <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/italien/">Italy</a>
# </li>
# <li>
# <a href="/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/frankreich/">France</a>
# </li>
# <li>
# <a href="/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/polska/">Poland</a>
# </li>
# <li>
# <a href="/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/spanien/">Spain</a>
# </li>
# <li>
# <a href="/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/wallis/">Valais</a>
# </li>
# <li>
# <a href="/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed selected-init">
# <a>Summer</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/sommer/schweiz/">Regions</a></li>
# <li class="selected">
# <a href="/sommer/schweiz/touren/">Tours</a></li>
# <li>
# <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
# <li>
# <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
# <li>
# <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/sommer/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/sommer/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/sommer/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/sommer/italien/">Italy</a>
# </li>
# <li>
# <a href="/sommer/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/sommer/frankreich/">France</a>
# </li>
# <li>
# <a href="/sommer/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/sommer/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/sommer/polska/">Poland</a>
# </li>
# <li>
# <a href="/sommer/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/sommer/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/sommer/spanien/">Spain</a>
# </li>
# <li>
# <a href="/sommer/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/sommer/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/sommer/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/sommer/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/sommer/wallis/">Valais</a>
# </li>
# <li>
# <a href="/sommer/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/sommer/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/sommer/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/sommer/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/sommer/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/sommer/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/sommer/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/sommer/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/sommer/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="/sommer/schweiz/wetter/prognose/">Weather</a>
# </li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# <li><a href="/sommer/angebote/">Offers</a></li>
# <li><a href="/forum/">Forum</a></li>
# <li>
# <a class="has-avatar" href="/mybergfex/">
# <div class="avatar">
# </div><span class="nav-main-username">MyBergfex</span>
# </a>
# </li>
# <div id="mybergfex"></div>
# </ul>
# </div>
# <div id="dropdown">
# <!-- optional logo in dropdown -->
# <img alt="" border="0" class="dropdown-logo" height="77" src="https://vcdn.bergfex.at/images/resized/5e/5aa28b0e4d23a15e_6c75f271197432f5@2x.png" width="77"/>
# <div class="dropdown-container page-left-margin">
# <div class="dropdown-content"></div>
# <div class="dropdown-close"></div>
# </div>
# </div>
# </nav><!--/page-top-->
# </div>
# <div id="mapactions">
# <div class="map_enable" id="mapaction_enable_big"></div>
# <div class="mapactions-separator"></div>
# <div class="mapactions-buttons">
# <div class="map_enable" id="mapaction_enable"></div>
# <div id="mapaction_help"></div>
# <div id="mapaction_link"></div>
# <div id="mapaction_up"></div>
# <div id="mapaction_down"></div>
# <div id="mapaction_full"></div>
# <div id="mapaction_close"></div>
# </div>
# </div>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/leaflet-1608217936.css" rel="stylesheet"/><div class="leaflet-map" id="siteMap" style="height: 180px; position: absolute; visibility: hidden; z-index: -1;">
# <div id="siteMapCanvas" style="height: 100%; width: 100%;"></div>
# </div>
# <script>
# var leafletMapOptions = {
# idCanvas: 'siteMapCanvas',
# idContainer: 'siteMap',
# minHeight: 350,
# maxHeight: Math.round($(window).height() * 0.66),
# zoom: 10,
# markerLayers: {
# skigebiete: {
# name: 'Ski resorts'
# },
# langlaufen: {
# name: 'Cross-country skiing'
# },
# unterkuenfte: {
# name: 'Accommodation'
# },
# sommerinfos: {
# name: 'Summer'
# },
# wandertouren: {
# name: 'Hiking tours'
# },
# alpintouren: {
# name: 'Alpine tours'
# },
# wintertouren: {
# name: 'Winter tours'
# },
# biketouren: {
# name: 'Bike tours'
# },
# lauftouren: {
# name: 'Running tours'
# },
# badeseen: {
# name: 'Bathing lakes'
# }
# },
# mapTypes: {
# oek: {
# name: 'bergfex OEK',
# title: 'bergfex Österreichische Karte 1:50.000'
# },
# osm: {
# name: 'bergfex OSM',
# title: 'bergfex OpenStreetMap'
# },
# basemap: {
# name: 'Basemap',
# title: 'Basemap Österreich'
# },
# basemapOrtho: {
# name: 'Basemap Orthofoto',
# title: 'Basemap Orthofotos Österreich'
# },
# satellite: {
# name: 'Satellite',
# title: 'Satellite'
# },
# roadmap: {
# name: 'Map',
# title: 'Map'
# }
# },
# overlays: {
# slopes: {
# name: 'Slope gradient'
# }
# },
# controls: {
# mapZoomControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# }
# },
# mapTypeControl: {
# showAsDropDown: function()
# {
# return bergfex.isMobile;
# }
# },
# mapSearchControl: {
# placeholder: 'Search in the map'
# },
# fullScreenControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# },
# title: {
# 'false': 'Vollbild',
# 'true': 'Vollbild verlassen'
# }
# },
# fullscreenContentControl: {
# i18n: {
# 'showContent': 'Inhalt einblenden',
# 'hideContent': 'Inhalt ausblenden'
# }
# },
# elevationControl: {
# i18n: {
# uphill: 'Uphill',
# downhill: 'Downhill',
# length: 'Length',
# height: 'Height'
# }
# },
# osmLegendControl: {
# language: 'en',
# i18n: {
# title: 'Legend'
# }
# },
# oekLegendControl: {
# i18n: {
# title: 'Legend'
# }
# }
# },
# layersDropDownContainer: {
# title: '<strong>Topics</strong> show <div class="layers-icon"></div>'
# }
# };
# $(document).ready(function()
# {
# var isChromium = !!window.chrome;
# if(isChromium) {
# leafletMapOptions.mapTypes.osm.class = bergfex.Leaflet.MapTypes.Osm_Mapboxgl
# }
# bergfex.MapHandler.init(leafletMapOptions);
# });
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/es6-promise.min-1608217937.jsmin.js" type="text/javascript"></script><script>ES6Promise.polyfill();</script>
# <script src="/include/js/leaflet/plugins/mapbox-gl-1.5.0/mapbox-gl.js"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/leaflet-map-1616403709.jsmin.js" type="text/javascript"></script><h1 id="document-title" style="display: none;">BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</h1>
# <!--page-bottom-->
# <div id="page-container">
# <nav class="breadcrumb mobile-hidden">
# <a href="/sommer/schweiz/" title="Summer Switzerland">Summer Switzerland</a> /
# <a class="important" href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </nav>
# <main class="page-left-margin">
# <aside id="nav-side">
# <div class="nav-side-close"></div>
# <div class="logo">
# <img alt="" border="0" height="37.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_ca92b0a06176d736@2x.png" width="133"/>
# </div>
# <div class="location">
# <a class="country" href="/sommer/schweiz/">Switzerland</a> /
# <a class="region" href="/sommer/bern-region/">Swiss plateau</a>
# </div>
# <div class="location-map">
# <div class="locationmap">
# <img alt="" border="0" height="83" src="https://vcdn.bergfex.at/images/resized/47/bb3e2117b44f9a47_30bc1b8b1f3fcfa4@2x.png" width="129.5"/>
# <a href="/sommer/schweiz/">
# <img alt="" border="0" class="layer" height="83" src="https://vcdn.bergfex.at/images/resized/6d/0767a6107b78396d_57e7f5a1ae33f073@2x.png" width="129.5"/>
# </a>
# </div>
# </div>
# <ul class="tree">
# <li class="level0">
# <a href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/" title="Regions">Regions</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/wetter/prognose/" title="Weather">Weather</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/webcams/" title="Webcams">Webcams</a>
# </li><li class="level1 selected">
# <a href="/sommer/bern-region/touren/" title="Tours">Tours</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/highlights/" title="Highlights">Highlights</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/seen/" title="Bathing lakes">Bathing lakes</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/unterkuenfte/" title="Accommodation">Accommodation</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/pauschalangebote/" title="Offers and All-inclusive prices">Offers and All-inclusive prices</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/sportanbieter/" title="Sports and leisure provider">Sports and leisure provider</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/veranstaltungen/" title="Events">Events</a>
# </li><li class="level0 winter">
# <a href="/bern-region/" title="Ski resorts">Ski resorts</a>
# </li><li class="level0 winter">
# <a href="/bern-region/langlaufen/" title="Cross-country skiing">Cross-country skiing</a>
# </li><li class="level0 winter">
# <a href="/bern-region/snow-parks/" title="Snow parks">Snow parks</a>
# </li></ul>
# <script>
# $(document).ready(function() {
# $("#quiz-container .quiz-teaser")
# .delay(2000)
# .animate( {
# left: 0
# }, 1000);
# $("#quiz-container .quiz-gewinn")
# .delay(5000)
# .animate( {
# height: $("#quiz-container .quiz-gewinn-text").height() + 14,
# }, 800);
# });
# </script>
# <div class="quiz-container-full clickable" id="quiz-container">
# <div style="position: absolute">
# <img alt="" border="0" height="160" src="https://vcdn.bergfex.at/images/resized/3d/46c4f2ac4d70223d_20ca31835d844cba@2x.jpg" width="160"/>
# </div>
# <!--  animate: -->
# <div class="quiz-gewinn">
# <div class="quiz-gewinn-text">
# 2 ÜN in einer Pension für 2 Personen zu gewinnen
# </div>
# <div class="inner-shadow-top"></div>
# <div class="inner-shadow-bottom"></div>
# </div>
# <!--  animate: -->
# <div class="quiz-teaser">
# <div class="quiz-label"><a href="/redirect/e9b472/212/547/https%3A%2F%2Fwww.bergfex.com%2Fsommer%2Fquiz%2F%3Fid%3D547%26utm_source%3Dbergfex%26utm_medium%3Dbanner%26utm_campaign%3Dgewinnspiel" rel="nofollow">Competition</a></div>
# <div class="quiz-title" style="font-size: 11px; line-height: 13px;"><span>Ferienregion Fügen – Kaltenbach im Zillertal</span></div>
# </div>
# </div>
# <ul class="tree info jblocktruncate" style="max-height: 200px;">
# <li class="level1 label">
# Favourite regions
# </li>
# <li class="level1"><a href="/sommer/bern-stadt/">Bern - Stadt</a></li>
# <li class="level1"><a href="/sommer/emmental/">Emmental</a></li>
# <li class="level1"><a href="/sommer/naturpark-gantrisch/">Naturpark Gantrisch</a></li>
# <li class="level1"><a href="/sommer/oberaargau/">Oberaargau</a></li>
# <li class="level1"><a href="/sommer/burgdorf/">Burgdorf</a></li>
# <li class="level1"><a href="/sommer/muensingen/">Münsingen</a></li>
# <li class="level1"><a href="/sommer/muri-bei-bern/">Muri bei Bern</a></li>
# <li class="level1"><a href="/sommer/laupen/">Laupen</a></li>
# <li class="level1"><a href="/sommer/lyss/">Lyss</a></li>
# <li class="level1"><a href="/sommer/langenthal/">Langenthal</a></li>
# <li class="level1"><a href="/sommer/zollikofen/">Zollikofen</a></li>
# <li class="level1"><a href="/sommer/steffisburg/">Steffisburg</a></li>
# <li class="level1"><a href="/sommer/worb/">Worb</a></li>
# <li class="level1"><a href="/sommer/belp/">Belp</a></li>
# <li class="level1"><a href="/sommer/koeniz/">Köniz</a></li>
# <li class="level1"><a href="/sommer/ostermundigen/">Ostermundigen</a></li>
# <li class="level1"><a href="/sommer/ittigen/">Ittigen</a></li>
# </ul>
# <div style="text-align: center">
# <a class="app-badge googleplay-badge" href="/redirect/f258b4/1231/0/1/https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdeveloper%3Fid%3Dbergfex%2BGmbH" target="_blank" title="Android Apps">
# </a>
# <a class="app-badge appstore-badge" href="/redirect/e29ab4/1230/0/1/https%3A%2F%2Fapps.apple.com%2Fat%2Fdeveloper%2Fbergfex-gmbh%2Fid355025018" target="_blank" title="iPhone Apps"></a>
# </div>
# <script>
# $(document).ready(function() {
# if($.browser){
# if ($.browser.isIOS) {
# $(".googleplay-badge").hide();
# $(".appstore-badge").addClass("big-badge");
# } else if ($.browser.isAndroid) {
# $(".appstore-badge").hide();
# $(".googleplay-badge").addClass("big-badge");
# }
# }
# });
# </script></aside>
# <div class="content" id="detail"><div class="section-left">
# <header>
# <a class="mobile-back mobile-only" href="/sommer/bern-region/">Swiss plateau</a>
# <!--    <div class="nav-side-trigger mobile-only"></div>  -->
# <div class="logo mobile-only">
# <img alt="" border="0" height="25.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_f1f23b72380280e9@2x.png" width="90"/>
# </div>
# <h1>Tours <span class="less-important">Swiss plateau</span>
# </h1><div class="buttons">
# <div class="desktop-only button-small button-small-icon button-small-icon-down" id="btn-map-show">
# Map
# </div>
# <div class="desktop-only button-small button-dark-grey button-small-icon button-small-icon-up" id="btn-map-hide">
# Hide map
# </div>
# </div>
# <div class="clearer"></div>
# </header><hr class="desktop-only"/>
# <form action="/sommer/bern-region/touren/" class="form-horizontal" id="touren_searchform" method="get">
# <div class="box-container mobile-collapsed">
# <div class="box-header mobile-only">
# Touren filtern
# </div>
# <div class="box-content">
# <div class="control-group">
# <label>Region</label>
# <div class="controls">
# <script>
# function locationSelected(data) {
# $("#touren_searchform").attr("action", "/" + data[7] + "/touren/");
# }
# </script>
# <input class="input-100 input-important" id="text_location" name="text_location" placeholder="" style="font-weight: bold;" type="text" value=""/><script>$(document).ready(function() { addAutocompleter('location', '/ajax/jquery/autocompleter/regionen/', 3, 200, 400 , locationSelected); });</script><input id="location" name="location" type="hidden" value=""/>
# </div>
# </div>
# <div class="control-group">
# <label>Tour type</label>
# <div class="controls">
# <select class="input-100" name="type">
# <option value="0">(All)</option>
# <option value="14">Hiking (271)</option>
# <option value="17">Thematic route (44)</option>
# <option value="10">Mountainbike (43)</option>
# <option value="11">Cycling (37)</option>
# <option value="24">Trailrunning (17)</option>
# <option value="12">Racing (11)</option>
# <option value="16">Pilgrimage (11)</option>
# <option value="8">Via ferrata (4)</option>
# <option value="7">High tour (3)</option>
# <option value="13">Long distance cycling (3)</option>
# <option value="30">E-MTB (3)</option>
# <option value="23">Running (3)</option>
# <option value="42">E-Bike (2)</option>
# <option value="3">Ski tour (2)</option>
# <option value="22">Nordic Walking (2)</option>
# <option value="15">long-distance walking trail (1)</option>
# <option value="18">Kayak / Canoe (1)</option>
# <option value="4">Snowshoe (1)</option>
# </select>
# </div>
# </div>
# <div class="control-group">
# <label>Full-text search</label>
# <div class="controls">
# <input class="input-100" name="q" type="text">
# </input></div>
# </div>
# <div class="control-group">
# <label>Fitness</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_kondition">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_kondition">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Technique</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_fahrtechnik">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_fahrtechnik">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Length (km)</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_laenge" placeholder="min." size="2" type="text">
# </input></div>
# <div class="col">
# <input name="max_laenge" placeholder="max." size="2" type="text"/>
# </div>
# </div>
# </div>
# <div class="control-group">
# <label>Altitude metres</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_hm" placeholder="min." size="4" type="text"/>
# </div>
# <div class="col">
# <input name="max_hm" placeholder="max." size="4" type="text"/>
# </div>
# </div>
# </div>
# <input name="search" type="hidden" value="1"/>
# <div class="form-actions nobackground">
# <button class="button button-blue" type="submit">Search</button>
# <a class="button button-grey" href="http://www.bergfex.com/sommer/bern-region/touren/"><span>Reset</span></a>
# </div>
# </div>
# </div>
# </form>
# <div style="float: left; line-height: 24px; font-weight: bold;">
# Seite 2 <span class="less-important">von 459 Tours.</span>
# </div>
# <div class="sort-selector" data-order-selected="DESC" data-sort-selected="Relevanz" style="float: right;">
# <div class="sort-option-active">sortiert nach <span class="sort-name">Relevanz</span></div>
# <div class="sort-options">
# <div class="sort-option" data-order="DESC" data-sort="Relevanz" title="nach Relevanz sortieren">Relevanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Laenge" title="nach längste Distanz sortieren">längste Distanz</div>
# <div class="sort-option" data-order="ASC" data-sort="Laenge" title="nach kürzeste Distanz sortieren">kürzeste Distanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Zeit" title="nach längste Dauer sortieren">längste Dauer</div>
# <div class="sort-option" data-order="ASC" data-sort="Zeit" title="nach kürzeste Dauer sortieren">kürzeste Dauer</div>
# <div class="sort-option" data-order="DESC" data-sort="Hoehenmeter" title="nach meiste Höhenmeter sortieren">meiste Höhenmeter</div>
# <div class="sort-option" data-order="ASC" data-sort="Hoehenmeter" title="nach wenigste Höhenmeter sortieren">wenigste Höhenmeter</div>
# <div class="sort-option" data-order="DESC" data-sort="Kondition" title="nach hohe Kondition sortieren">hohe Kondition</div>
# <div class="sort-option" data-order="ASC" data-sort="Kondition" title="nach niedrige Kondition sortieren">niedrige Kondition</div>
# <div class="sort-option" data-order="DESC" data-sort="Technik" title="nach hohem Technikanspruch sortieren">hohe Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="Technik" title="nach niedrigem Technikanspruch sortieren">niedrige Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="Titel" title="nach Name A-Z sortieren">Name A-Z</div>
# <div class="sort-option" data-order="DESC" data-sort="Titel" title="nach Name Z-A sortieren">Name Z-A</div>
# </div>
# </div>
# <div class="clearer"></div>
# <div class="section">
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/114256,zur-hohwacht-im-emmental/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="114256" src="https://vcdn.bergfex.at/images/resized/fc/ff13da84556852fc_461dc0843de0fcce@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114256,zur-hohwacht-im-emmental/" title="Zur Hohwacht im Emmental">Zur Hohwacht im Emmental</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 11.37<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:20</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 423<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 669 - 1,074<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="84f7246e881e3d9ede82b2cecedc5d8a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/d8a/84f7246e881e3d9ede82b2cecedc5d8a.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="e2b4028dc84ce0f7ec1835237deb0be4" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/be4/e2b4028dc84ce0f7ec1835237deb0be4.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="a70d31a153c428e5d5e79f037f0165bf" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/5bf/a70d31a153c428e5d5e79f037f0165bf.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="86c2624025961ef1b67172a72d848107" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/107/86c2624025961ef1b67172a72d848107.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/radfahren/700226,st-stephan--ruewlispass--gstaad--saanenmoeser--st-stephan/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="700226" src="https://vcdn.bergfex.at/images/resized/4f/0e6f93c17d867e4f_c1bc6b9f247deb17@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/radfahren/700226,st-stephan--ruewlispass--gstaad--saanenmoeser--st-stephan/" title="St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan">St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Cycling
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 38.14<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:50</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 1,055<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 934 - 1,724<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="919452c86a22554672db285b53f98ed2" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ed2/919452c86a22554672db285b53f98ed2.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="8549a8f400887bb87c0a88646176c9c9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/9c9/8549a8f400887bb87c0a88646176c9c9.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="0561cc12a0e6bad5f10cf10b1fd75c00" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c00/0561cc12a0e6bad5f10cf10b1fd75c00.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="4b7084b7d21181e129f7a9c753fcc7b9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7b9/4b7084b7d21181e129f7a9c753fcc7b9.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/themenweg/108674,holz-skulpturenweg--frutigen/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="108674" src="https://vcdn.bergfex.at/images/resized/59/f4f831bcf5ce6959_fa2551107925693f@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/themenweg/108674,holz-skulpturenweg--frutigen/" title="Holz-Skulpturenweg - Frutigen">Holz-Skulpturenweg - Frutigen</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 9.56<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>02:45</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 134<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 779 - 913<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="189e5cfd81f6947c350ad868ffa1dc82" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c82/189e5cfd81f6947c350ad868ffa1dc82.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="99c5d31d8e7d9eeda477d6cf062c5ef3" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ef3/99c5d31d8e7d9eeda477d6cf062c5ef3.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="cb8cf20183df84cdaee3df8a5f3efbe7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/be7/cb8cf20183df84cdaee3df8a5f3efbe7.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="3c8af39949e1117898d99d4473308ad9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ad9/3c8af39949e1117898d99d4473308ad9.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/themenweg/295433,diemtigtaler-hausweg-mittleres-tal/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="295433" src="https://vcdn.bergfex.at/images/resized/85/40ead7011d722e85_5a82d86240c324ce@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/themenweg/295433,diemtigtaler-hausweg-mittleres-tal/" title="Diemtigtaler Hausweg «Mittleres Tal»">Diemtigtaler Hausweg «Mittleres Tal»</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 10.2<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:15</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 434<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 814 - 1,128<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="7ddcf296ce9de48e981ddcafd78c8238" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/238/7ddcf296ce9de48e981ddcafd78c8238.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="95fd65948c1651fc8acfe27477cd2c7d" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c7d/95fd65948c1651fc8acfe27477cd2c7d.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="f48283d2e801d036df90e06e990aaae5" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ae5/f48283d2e801d036df90e06e990aaae5.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="49d996e736eac6736015ed7116034f4a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f4a/49d996e736eac6736015ed7116034f4a.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/radfahren/172139,moraenensee-route/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="172139" src="https://vcdn.bergfex.at/images/resized/b7/d72b02757c14b2b7_cd0a3ce1146ae894@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/radfahren/172139,moraenensee-route/" title="Moränensee Route">Moränensee Route</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Cycling
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 25.49<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>01:40</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 197<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 553 - 750<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="9ea606c8c82bbd9f28c9ee6ffac2366e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/66e/9ea606c8c82bbd9f28c9ee6ffac2366e.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="689c2e8bdc609f7f83d981c043c14f65" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f65/689c2e8bdc609f7f83d981c043c14f65.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="7bba0d70a0824d2a80eb6f7e434c5152" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/152/7bba0d70a0824d2a80eb6f7e434c5152.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/99639,probsteberg--einsames-grenzgebiet-bern-solothurn/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="99639" src="https://vcdn.bergfex.at/images/resized/e8/f5aa1c00dcb748e8_00900eddd5bcbc18@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/99639,probsteberg--einsames-grenzgebiet-bern-solothurn/" title="Probsteberg - einsames Grenzgebiet Bern/Solothurn">Probsteberg - einsames Grenzgebiet Bern/Solothurn</a>
# <div>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 16.44<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>04:45</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 581<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 640 - 1,149<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="54600219282c1badb675b774fa3418c8" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/8c8/54600219282c1badb675b774fa3418c8.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="3f2f03ffc4b1c201f2c0cd87cadac7a7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7a7/3f2f03ffc4b1c201f2c0cd87cadac7a7.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-0"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/509375,meraengge-cher-im-kemmribodenbad/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="509375" src="https://vcdn.bergfex.at/images/resized/9c/d81af72f0175ff9c_b45bbe258a52a58a@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/509375,meraengge-cher-im-kemmribodenbad/" title="Merängge-Cher im Kemmribodenbad">Merängge-Cher im Kemmribodenbad</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 6.97<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>02:10</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 330<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 975 - 1,184<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="7e83b7446943e940e9b6769b2ec64302" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/302/7e83b7446943e940e9b6769b2ec64302.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/348126,lauenen--lauenensee--lauenen/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="348126" src="https://vcdn.bergfex.at/images/resized/03/4bf20abb357fab03_7884e5b24c857254@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/348126,lauenen--lauenensee--lauenen/" title="Lauenen – Lauenensee - Lauenen">Lauenen – Lauenensee - Lauenen</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 8.99<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# ...
# <img alt="" border="0" class="tour-photo" height="57" id="c5bbd4deb350dd72cc63e55470f7ef44" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f44/c5bbd4deb350dd72cc63e55470f7ef44.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="dfaa9d4063f9739b06c4ca5daee53387" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/387/dfaa9d4063f9739b06c4ca5daee53387.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="1284ca7e22de9a17266cb222b3bd9c2e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c2e/1284ca7e22de9a17266cb222b3bd9c2e.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="53e6b0b6cad7334c7e1072a544193c0e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c0e/53e6b0b6cad7334c7e1072a544193c0e.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section">
# <link href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" rel="first"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" rel="prev"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=23" rel="last"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" rel="next"/>
# <div class="pager">
# <div class="label">Pages:</div><a class="navigation pager-previous" href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" title="">previous<span class="pagerCaret"></span></a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" title="">1</a>
# <div class="page-selected">2</div>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" title="">3</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=4" title="">4</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=5" title="">5</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=6" title="">6</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=7" title="">7</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=8" title="">8</a>
# <a class="navigation pager-next" href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" title="">
# next<span class="pagerCaret"></span>
# </a>
# </div>
# </div>
# </div>
# <div class="section-right">
# <div class="listbox box-container mobile-collapsed">
# <div class="box-header">Tours by type</div>
# <div class="box-content grid cols2">
# <div class="col">
# <ul>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/wandern/">Hiking</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/bike/">Bike</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/laufen/">Running</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/alpin/">Alpine</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/winter/">Winter</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/wasser/">Water</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="contentbox box-container">
# <div class="box-header">
# <span class="less-important">bergfex</span> Bergungskosten-Versicherung
# </div>
# <div class="box-content">
# <p>Noch schnell für den anstehenden Ausflug versichern? Inkl. Rettungshubschrauber <span class="important nowrap">ab 3,98 €</span>
# </p><a class="link-important button-green" href="/redirect/69bce4/131/0/https%3A%2F%2Fergo-versicherung.at%2Fbergfex-bergung%2F%3Futm_source%3Dbergfex%26utm_medium%3DLink%26utm_campaign%3Dbergfex-bergung%26aid%3DD146" target="_blank">
# Jetzt Informieren
# </a>
# </div>
# </div>
# <div class="listbox box-container mobile-collapsed">
# <div class="box-header">
# Countries
# </div>
# <div class="box-content grid cols2">
# <div class="col">
# <ul>
# <li><a href="/sommer/oesterreich/touren/">Austria</a></li>
# <li class="selected"><a href="/sommer/schweiz/touren/">Switzerland</a></li>
# <li><a href="/sommer/deutschland/touren/">Germany</a></li>
# <li><a href="/sommer/italien/touren/">Italy</a></li>
# <li><a href="/sommer/slovenia/touren/">Slovenia</a></li>
# <li><a href="/sommer/frankreich/touren/">France</a></li>
# <li><a href="/sommer/nederland/touren/">Netherlands</a></li>
# <li><a href="/sommer/belgie/touren/">Belgium</a></li>
# <li><a href="/sommer/czechia/touren/">Czechia</a></li>
# <li><a href="/sommer/slovakia/touren/">Slovakia</a></li>
# <li><a href="/sommer/spanien/touren/">Spain</a></li>
# <li><a href="/sommer/kroatien/touren/">Croatia</a></li>
# <li><a href="/sommer/luxemburg/touren/">Luxembourg</a></li>
# <li><a href="/sommer/liechtenstein/touren/">Liechtenstein</a></li>
# </ul>
# </div>
# <div class="col">
# <ul>
# <li><a href="/sommer/graubuenden/touren/">Graubünden</a></li>
# <li><a href="/sommer/wallis/touren/">Valais</a></li>
# <li><a href="/sommer/berneroberland/touren/">Bernese Oberland</a></li>
# <li><a href="/sommer/luzern-vierwaldstaettersee/touren/">Central Switzerland</a></li>
# <li><a href="/sommer/ostschweiz/touren/">Eastern Switzerland</a></li>
# <li><a href="/sommer/zuerich/touren/">Zurich region</a></li>
# <li><a href="/sommer/aargau/touren/">Aargau</a></li>
# <li><a href="/sommer/jura-drei-seen-land/touren/">Jura</a></li>
# <li><a href="/sommer/tessin/touren/">Ticino</a></li>
# <li><a href="/sommer/freiburg-region/touren/">Fribourg</a></li>
# <li><a href="/sommer/genferseegebiet-waadtland/touren/">Vaud / Lake Geneva Region</a></li>
# <li class="selected"><a href="/sommer/bern-region/touren/">Swiss plateau</a></li>
# <li><a href="/sommer/basel-region/touren/">Aargau-Basle</a></li>
# <li><a href="/sommer/genf-region/touren/">Geneva</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="section">
# <h3>Popular tours in the area</h3>
# <script>
#                 var oaTrackingDetail = null;
#                 var oaTrackingTeaser = [];
#
#                 if(typeof trackOutdooractiveActivities === "undefined") {
#                     function trackOutdooractiveActivities() {
#                         if (oaTrackingDetail !== null) {
#                             $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackDetail(oaTrackingDetail);
#                         }
#                         if (oaTrackingTeaser.length > 0) {
#                             _.forEach(oaTrackingTeaser, function(teaserId) {
#                                 $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackTeaser(teaserId);
#                             });
#                         }
#                     }
#                 }
#
#                 if(typeof outdooractiveTrackingIframeLoaded === "undefined") {
#                     function outdooractiveTrackingIframeLoaded() {
#                         trackOutdooractiveActivities();
#                     }
#                 }
#
#                 $(document).ready(function() {
#                     var $iframe = $("#outdooractive_tracking_iframe");
#
#                     if($iframe.length === 0) {
#                         $("body").append("<iframe id='outdooractive_tracking_iframe' src='//www.bergfex.com/ajax/outdooractive/tracking.php'></iframe>");
#                     } else {
#                         trackOutdooractiveActivities();
#                     }
#                 });
#             </script>
# <script>oaTrackingTeaser.push('15655063');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1216109" height="200" src="https://vcdn.bergfex.at/images/resized/fb/88ab53a017f741fb_e5f641d58b13d34e@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86144,waldhaeusern--beliebtes-ausflugsziel-im-emmental/" title="„Signau…in allen Jahreszeiten schön“. Mit diesem Motto werden die Besucher der Gemeinde-Homepage...">
# Waldhäusern - ...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>9.63</strong>km | <strong>373</strong>hm | <strong>03:00</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86144" src="https://vcdn.bergfex.at/images/resized/c0/763597cd262eb0c0_8638de0c909f0598@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('17346892');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1149454" height="200" src="https://vcdn.bergfex.at/images/resized/dd/2378e3c744ce8fdd_0b7155a0cb1d6e86@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/themenweg/78168,baenkli-rundweg-aeschi-bei-spiez/" title="&lt;p&gt;Sie laden zum Ausruhen ein. Oft empfangen sie Wandererinnen und Spaziergänger, manchmal nur...">
# Bänkli-Rundweg...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="smaller">
# <strong>7.38</strong>km | <strong>255</strong>hm | <strong>02:13</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="78168" src="https://vcdn.bergfex.at/images/resized/f9/9dc49d1e748a4bf9_876815c39274c206@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('15655869');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1215216" height="200" src="https://vcdn.bergfex.at/images/resized/c9/5c1c0d0fdafa3ac9_cff36ffac8048b95@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86037,auf-dem-beatenberg-der-sonnenterrasse-des-berner-oberlandes/" title="Auf dieser Wanderung erlebt und geniesst man die Schönheit des Dreigestirnes Eiger Mönch und...">
# Auf dem Beatenb...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.74</strong>km | <strong>752</strong>hm | <strong>04:10</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86037" src="https://vcdn.bergfex.at/images/resized/ff/d89b53e14797e2ff_4f7456e6cd041215@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('8483704');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="752976" height="200" src="https://vcdn.bergfex.at/images/resized/2a/6a97642fd5aebb2a_df99cc7fae3f8d32@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/51212,zu-eiszeitlichen-riesen-und-zur-wohnstaette-steinzeitlicher-menschen/" title="Abwechslungsreiche Wanderung durch Wälder, weite Matten und über aussichtsreiche Höhen zum...">
# Zu eiszeitliche...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.5</strong>km | <strong>254</strong>hm | <strong>02:40</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="51212" src="https://vcdn.bergfex.at/images/resized/6c/5d461db57398d66c_f4c1dd3fc9c64149@2x.jpg" width="240"/>
# </div>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </main>
# <div id="sidebar">
# <div class="adzone_skyscraper partner" data-geo="sommer.schweiz.bern-region" data-tags="" data-zoneid="2" id="adzone_skyscraper"></div>
# </div>
# <!--/page-bottom-->
# </div>
# <div class="clearer"></div>
# <div id="mapsearch-template-h2noresult">
# <h2>Keine Einträge gefunden.</h2>
# </div>
# <div id="mapsearch-template-h2overflow">
# <h2>Es wurden %count% Einträge gefunden. Bitte Suche verfeinern.</h2>
# </div>
# <div id="mapsearch-template-h2local">
# <h2>Lokale Suchergebnisse <span class="less-important">(Distance &lt;= 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2nonlocal">
# <h2>More results <span class="less-important">(Distance &gt; 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2all">
# <h2>All %count% Search results</h2>
# </div>
# <div id="mapsearch-template-line">
# <div class="mapsearch-line">
# <div><a class="name" href="">%name%</a> <span class="region">%region%</span></div>
# <div><span class="type">%type%</span> <span class="elevation">%elevation%</span></div>
# </div>
# </div><footer id="footer">
# <div class="footer-container page-left-margin">
# <div class="footer-location">
# / <a href="/sommer/schweiz/">Summer Switzerland</a> /
# <a href="/sommer/bern-region/">Swiss plateau</a> /
# <strong>Tours</strong>
# </div>
# <ul class="nav-list">
# <li class="has-children collapsed language-select">
# <h2 class="no-select" style="overflow: visible"><span class="mobile-only">Language</span> <span class="flag en"></span> english</h2>
# <ul>
# <li><a href="//www.bergfex.ch/sommer/bern-region/touren/" rel='"nofollow"'>
# <span class="flag de"></span> Deutsch</a></li>
# <li><a href="//www.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag en"></span> English</a></li>
# <li><a href="//www.bergfex.fr/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fr"></span> Français</a></li>
# <li><a href="//it.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag it"></span> Italiano</a></li>
# <li><a href="//www.bergfex.es/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag es"></span> Español</a></li>
# <li><a href="//nl.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag nl"></span> Nederlands</a></li>
# <li><a href="//se.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag se"></span> Svenska</a></li>
# <li><a href="//no.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag no"></span> Norsk</a></li>
# <li><a href="//dk.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag dk"></span> Dansk</a></li>
# <li><a href="//fi.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fi"></span> Suomi</a></li>
# <li><a href="//hu.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hu"></span> Magyar</a></li>
# <li><a href="//www.bergfex.cz/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag cz"></span> český</a></li>
# <li><a href="//www.bergfex.sk/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag sk"></span> Slovensky</a></li>
# <li><a href="//www.bergfex.pl/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag pl"></span> Polski</a></li>
# <li><a href="//hr.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hr"></span> Hrvatski</a></li>
# <li><a href="//www.bergfex.si/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag si"></span> Slovenščina</a></li>
# <li><a href="//ru.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ru"></span> русский</a></li>
# <li><a href="//ro.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ro"></span> Român</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>Themen</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li><a href="/sommer/schweiz/">Summer regions</a></li>
# <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>General</h2>
# <ul>
# <li><a href="/newsletter/">Newsletter</a></li>
# <li><a href="/produkte/">Products</a></li>
# <li><a href="/shop/">Shop</a></li>
# <li><a href="/login/">Login</a></li>
# </ul>
# </li>
# </ul>
# <div id="language-select-overlay"></div>
# <div class="copyright-container">
# <!-- background image -->
# <div class="copyright">Copyright © 1999, 2021 bergfex GmbH. All rights reserved.</div>
# <div class="copyright-links">
# <a href="/datenschutz/">Privacy policy</a> |
# <a href="/impressum/">About us</a> |
# <a href="" id="privacy-manager">Privacy Manager</a>
# </div>
# </div>
# </div>
# </footer></body>
# </html>

# %%
print("number of tours collected:", len(title))
# Out:
# number of tours collected: 40

# %% [markdown]
# ## 1.2 Extracting embedded HTML tags: <a href=""
# Each trail name and ID was used in Bergfex's URL. Using the trail ID in the dataframe will provide a unique ID to use later in the analysis. However, those two data points are embedded deeper in the html code. The below codes shows how to extract the datapoints into a dataframe.

# %%
# Extracting the ID via the URL
links_title = []

for i in total_title:
    i = str(i)
    i = i.strip('[]')
    links_title.append(i)

# %% [markdown]
# In order to make the trail ID usable it needs to be cleaned up and converted into a string

# %%
# Extracting ID
id_df3 = pd.DataFrame(links_title)
id_df2 = id_df3[0].str.split(' ',expand = True)
id_df1 = id_df2[2].str.split(',',expand = True)
id_df = id_df1[0].str.split('/',expand = True)

# %%
# from this format:
pd.options.display.max_colwidth = 100
id_df3.head()
# Out:
#                                                                                                      0
# 0  <a class="h2" href="/sommer/bern-region/touren/fernradweg/177067,biel-bienne--ins/" title="Biel/...
# 1  <a class="h2" href="/sommer/bern-region/touren/mountainbike/698710,gehrihorn-frutigen-biketour/"...
# 2  <a class="h2" href="/sommer/bern-region/touren/wanderung/51815,nervenkitzel-und-viel-abwechslung...
# 3  <a class="h2" href="/sommer/bern-region/touren/wanderung/133081,adelboden--hahnenmoos/" title="A...
# 4  <a class="h2" href="/sommer/bern-region/touren/themenweg/296938,der-ringweg-am-kleinen-rugen/" t...

# %%
# to this format:
id_df.head()
# Out:
#         0       1            2       3             4       5
# 0  href="  sommer  bern-region  touren    fernradweg  177067
# 1  href="  sommer  bern-region  touren  mountainbike  698710
# 2  href="  sommer  bern-region  touren     wanderung   51815
# 3  href="  sommer  bern-region  touren     wanderung  133081
# 4  href="  sommer  bern-region  touren     themenweg  296938

# %% [markdown]
# ## 1.3 Extracting embedded HTML tags: <Div class=""
# The HTML tags for the fitness and technique ratings were embedded within Div class tags; they are extracted using a for-loop and then stripped of unecessary characeters.
# - Convert the tour rating tag into a string
# - Strip away unecessary characters
# - Split into lists which look like rating_list [Technique, Fitness]
# - Finally, convert into seperate lists for Technique and Fitness

# %%
rating[0] # View the emmbedded DIV tag
# Out:
# [<div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>,
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
#  </div>]

# %%
# Replace unwanted information
tour_rating_str = str(rating)
rating_all_short = tour_rating_str.replace(
'<div class="tour-rating">\n<div class="tour-rating-label">Technique</div>\n<div class="rating-circles rating-max6"><div class="',''
).replace(
    '<div class="tour-rating">\n<div class="tour-rating-label">Fitness</div>\n<div class="rating-circles rating-max6"><div class="','').replace('"></div></div>\n</div>',"")
rating_even_shorter = rating_all_short.replace('[','').replace(']','')
rating_list = rating_even_shorter.split(", ")

for i in range(0,(len(rating_list))):
    if i == 0:
        technique.append(rating_list[i]) # add first item in technique
    elif i % 2 == 0:
        technique.append(rating_list[i]) # then every second item as well
    else:
        fitness.append(rating_list[i]) # the other appended to fitness list

# %%
## Let's look at the result

#rating_all_short
#rating_even_shorter
rating_list
# Out:
# ['rating-1',
#  'rating-1',
#  'rating-',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-1',
#  'rating-2',
#  'rating-5',
#  'rating-5',
#  'rating-2',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-3',
#  'rating-2',
#  'rating-1',
#  'rating-2',
#  'rating-1',
#  'rating-1',
#  'rating-',
#  'rating-0',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-4',
#  'rating-1',
#  'rating-2',
#  'rating-4',
#  'rating-4',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-4',
#  'rating-1',
#  'rating-3',
#  'rating-1',
#  'rating-1',
#  'rating-2',
#  'rating-3',
#  'rating-',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-2']

# %% [markdown]
# ## 1.4  Create dataframe for extracted elements
#
# This dataframe is not in the final stage yet as there are still extra brackets, the minimum and maximum elevation are still in one column, and units must be stripped away

# %%
activities_df_unclean = pd.DataFrame(
    {'title': title,
     'difficulty': difficulty,
     'sport': sport,
     'length': length,
     'time': time_list,
     'climb': climb,
     'minmax': minmax,
     'technique': technique,
     'fitness': fitness
    })
activities_df_unclean['ID']= id_df.iloc[:,5].copy() # add the ID columns from an earlier DF
activities_df_unclean.head()
# Out:
#                                                   title difficulty  \
# 0                                   [Biel/Bienne - Ins]     [easy]
# 1                       [Gehrihorn (Frutigen) Biketour]   [medium]
# 2  [Nervenkitzel und viel Abwechslung für Jung und Alt]     [easy]
# 3                              [Adelboden - Hahnenmoos]   [medium]
# 4                        [Der Ringweg am kleinen Rugen]     [easy]
#
#                      sport   length    time    climb          minmax  \
# 0  [Long distance cycling]  31.43km  02:09h     29hm      430 - 460m
# 1           [Mountainbike]  36.46km  04:00h  1,056hm    762 - 1,429m
# 2                 [Hiking]   3.63km  01:10h    170hm      772 - 889m
# 3                 [Hiking]   8.16km  02:30h    670hm  1,295 - 1,950m
# 4         [Thematic route]   3.35km  00:58h     84hm      572 - 655m
#
#   technique   fitness      ID
# 0  rating-1  rating-1  177067
# 1   rating-  rating-4  698710
# 2  rating-2  rating-2   51815
# 3  rating-2  rating-3  133081
# 4  rating-1  rating-2  296938

# %% [markdown]
# ## 1.5 Write CSV file of scrapped and uncleaned DF

# %%
activities_df_unclean.to_csv("../data/unclean_activities.csv", index=False)
activities_df_unclean.head()
# Out:
#                                                   title difficulty  \
# 0                                   [Biel/Bienne - Ins]     [easy]
# 1                       [Gehrihorn (Frutigen) Biketour]   [medium]
# 2  [Nervenkitzel und viel Abwechslung für Jung und Alt]     [easy]
# 3                              [Adelboden - Hahnenmoos]   [medium]
# 4                        [Der Ringweg am kleinen Rugen]     [easy]
#
#                      sport   length    time    climb          minmax  \
# 0  [Long distance cycling]  31.43km  02:09h     29hm      430 - 460m
# 1           [Mountainbike]  36.46km  04:00h  1,056hm    762 - 1,429m
# 2                 [Hiking]   3.63km  01:10h    170hm      772 - 889m
# 3                 [Hiking]   8.16km  02:30h    670hm  1,295 - 1,950m
# 4         [Thematic route]   3.35km  00:58h     84hm      572 - 655m
#
#   technique   fitness      ID
# 0  rating-1  rating-1  177067
# 1   rating-  rating-4  698710
# 2  rating-2  rating-2   51815
# 3  rating-2  rating-3  133081
# 4  rating-1  rating-2  296938

# %% [markdown]
# ## Scrape Regions (to be deleted)

# %%
regions = []
base_link_region = 'https://www.bergfex.com/sommer/berneroberland/'
page_region = requests.get(base_link_region, timeout=5)
soup_region = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
region = soup.findAll('div', {'class': 'box-content greid cols2'})  # checks for the separate tours on the page
region2 = soup.findAll('a', {'href': '*/sommer/*'})
region3 = soup.findAll('li', {'class': 'has-children collapsed'})

# %%
soup_region
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</title>
# <meta content="Swiss plateau,Switzerland,Tours," name="keywords"/>
# <meta content="Swiss plateau Switzerland: " name="description"/>
# <meta content="app-id=912776148" name="apple-itunes-app">
# <script src="https://cdn.stroeerdigitalgroup.de/metatag/live/SDG_ConsentOnly/metaTag.min.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="en" name="language"/>
# <meta content="width=device-width, viewport-fit=cover" name="viewport"/>
# <script type="application/ld+json">
# {
# "@context": "https://schema.org",
# "@type": "Organization",
# "url": "https://www.bergfex.com",
# "logo": "https://www.bergfex.com/images/logo.png"
# }
# </script>
# <meta content="BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking" property="og:title"/>
# <meta content="https://vcdn.bergfex.at/images/resized/d8/a65a94fd11f0d3d8_ad3f21a01c2764d0.jpg" property="og:image"/>
# <meta content="image/jpg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="627" property="og:image:height"/>
# <link href="//www.bergfex.ch/sommer/bern-region/touren/" hreflang="de" rel="alternate"/>
# <link href="//www.bergfex.com/sommer/bern-region/touren/" hreflang="en" rel="alternate"/>
# <link href="//www.bergfex.fr/sommer/bern-region/touren/" hreflang="fr" rel="alternate"/>
# <link href="//it.bergfex.com/sommer/bern-region/touren/" hreflang="it" rel="alternate"/>
# <link href="//www.bergfex.es/sommer/bern-region/touren/" hreflang="es" rel="alternate"/>
# <link href="//nl.bergfex.com/sommer/bern-region/touren/" hreflang="nl" rel="alternate"/>
# <link href="//se.bergfex.com/sommer/bern-region/touren/" hreflang="sv" rel="alternate"/>
# <link href="//no.bergfex.com/sommer/bern-region/touren/" hreflang="no" rel="alternate"/>
# <link href="//dk.bergfex.com/sommer/bern-region/touren/" hreflang="da" rel="alternate"/>
# <link href="//fi.bergfex.com/sommer/bern-region/touren/" hreflang="fi" rel="alternate"/>
# <link href="//hu.bergfex.com/sommer/bern-region/touren/" hreflang="hu" rel="alternate"/>
# <link href="//www.bergfex.cz/sommer/bern-region/touren/" hreflang="cs" rel="alternate"/>
# <link href="//sk.bergfex.com/sommer/bern-region/touren/" hreflang="sk" rel="alternate"/>
# <link href="//www.bergfex.pl/sommer/bern-region/touren/" hreflang="pl" rel="alternate"/>
# <link href="//hr.bergfex.com/sommer/bern-region/touren/" hreflang="hr" rel="alternate"/>
# <link href="//www.bergfex.si/sommer/bern-region/touren/" hreflang="sl" rel="alternate"/>
# <link href="//ru.bergfex.com/sommer/bern-region/touren/" hreflang="ru" rel="alternate"/>
# <link href="//ro.bergfex.com/sommer/bern-region/touren/" hreflang="ro" rel="alternate"/>
# <link href="https://plus.google.com/105981749558386334210" rel="publisher"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link color="#1599ff" href="//vcdn.bergfex.at/images/mask-icon.svg" rel="mask-icon"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/bergfex-1615903180.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/sommer-1608217936.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/print-1608217936.css" media="print" rel="stylesheet"/><script>
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.autoCompleteActive = false;
# bergfex.autoCompleteSuggestionStartChar = 1;
# </script><script>
# // bergfex namespace
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.staticHost = '//vcdn.bergfex.at';
# bergfex.staticHosts = ['//vcdn.bergfex.at'];
# bergfex.InfobannerCookiesOptions = {
# timesToShow: 3,
# textTitle: "Informationen zu Cookies",
# textInfo:
# "Diese Seite verwendet Cookies. " +
# "Für eine uneingeschränkte Nutzung der Website werden Cookies benötigt. " +
# "Sie stimmen der Verwendung von Cookies durch Anklicken von \"OK\" zu. " +
# "Nähere Informationen finden Sie in unseren ",
# textPolicy: "Datenschutzbedingungen",
# urlPolicy: "/datenschutz/",
# textButton: "OK",
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.1-1608217937.jsmin.js" type="text/javascript"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.2-1610094216.jsmin.js" type="text/javascript"></script><script src="//vcdn.bergfex.at/include/js/jquery/plugins/ui/1.10.3/i18n/jquery.ui.datepicker-en.js" type="text/javascript"></script><script>
# var gMapKey = "AIzaSyDhkXDPfuKgSZgCcKfDLRHNZFrsdbfQkiQ";
# var mapEnabled = true;
# var mapHeight = 360;
# bergfex.libs = { };
# bergfex.libs.srcElevLibs = "//vcdn.bergfex.at/include/jsmin/elevationprofile-libs-1608217937.jsmin.js";
# bergfex.libs.srcMapLibs  = "//vcdn.bergfex.at/include/jsmin/map-libs-1608217937.jsmin.js";
# bergfex.season = "sommer";
# </script><script>
# var jBlockTruncateSettings = {
# 'moreText': "show more",
# 'lessText': "less"
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/bergfex-libs-1616068547.jsmin.js" type="text/javascript"></script><meta content="0" name="geonomap"/>
# <meta content="keep" name="geomap"/>
# <meta content="Bundesland_16" name="geocontext"/>
# <meta content="46.939012,8.107910,10,o" name="geoposition"/>
# <meta content="1" name="geotarget"/>
# <meta content="touren" name="geolayer"/>
# <meta content="sommer" name="season"/></meta></meta></head>
# <body class="site">
# <div id="page-top">
# <!--page-top-->
# <div style="position: absolute;">
# <script src="//script.ioam.de/iam.js" type="text/javascript"></script>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         $(document).ready(function() {
#             var iam_data = {
#                 "st": "bergfex",
#                 "cp": "sommer-nonde",
#                 "sv": "in",  // keine Befragungseinladung
#                 "co": ""  // comment
#             }
#             try {
#                 iom.c(iam_data, 1);
#             } catch(e) {
#             }
#         });
#     </script>
# <!-- /SZM -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-15684980-1"></script>
# <script>
# // https://support.google.com/analytics/answer/10022331?hl=de
# // window['gtag_enable_tcf_support'] = true;
# bergfex.Analytics = {
# send_to: 'UA-15684980-1',
# admask: 'schweiz.bern-region',
# language: 'en',
# page_location: '/sommer/bern-region/touren/?isAjax=1&page=1',
# };
# window.dataLayer = window.dataLayer || [];
# bergfex.gtag = function() {
# dataLayer.push(arguments);
# }
# bergfex.gtag('js', new Date());
# bergfex.gtag('config', 'UA-15684980-1', {
# send_page_view: false,
# custom_map: {
# dimension1: 'admask',
# dimension2: 'language',
# },
# });
# bergfex.gtag('event', 'init');
# window.addEventListener('metaTagSystemCmpChoiceUiShown', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceUiShown');
# });
# window.addEventListener('metaTagSystemCmpChoiceSelected', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceSelected');
# });
# // log map views.
# </script></div>
# <nav class="nav-default" id="nav-main">
# <div class="nav-main-trigger-side"></div>
# <a class="logo-bergfex" href="/" title="bergfex Homepage"></a>
# <div class="nav-main-search responsive-only" id="nav-main-search">
# </div>
# <div class="nav-main-user responsive-only">
# <a href="/mybergfex/">
# <div class="avatar">
# </div></a>
# </div>
# <div class="nav-main-trigger"></div>
# <div class="nav-main-close"></div>
# <div class="nav-main-container page-left-margin">
# <div class="nav-search">
# <form action="/sommer/suchen/" autocomplete="off" method="get" name="sitesearch">
# <div class="search-icon"></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" id="search-input-field" maxlength="256" name="q" placeholder="Search" spellcheck="false" type="text"/>
# </form>
# </div>
# <!-- on dropdown, inject logo from mainlogo position via js -->
# <ul class="nav-list">
# <li class="has-children collapsed">
# <a>Winter</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li>
# <a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li>
# <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/italien/">Italy</a>
# </li>
# <li>
# <a href="/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/frankreich/">France</a>
# </li>
# <li>
# <a href="/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/polska/">Poland</a>
# </li>
# <li>
# <a href="/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/spanien/">Spain</a>
# </li>
# <li>
# <a href="/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/wallis/">Valais</a>
# </li>
# <li>
# <a href="/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed selected-init">
# <a>Summer</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/sommer/schweiz/">Regions</a></li>
# <li class="selected">
# <a href="/sommer/schweiz/touren/">Tours</a></li>
# <li>
# <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
# <li>
# <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
# <li>
# <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/sommer/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/sommer/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/sommer/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/sommer/italien/">Italy</a>
# </li>
# <li>
# <a href="/sommer/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/sommer/frankreich/">France</a>
# </li>
# <li>
# <a href="/sommer/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/sommer/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/sommer/polska/">Poland</a>
# </li>
# <li>
# <a href="/sommer/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/sommer/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/sommer/spanien/">Spain</a>
# </li>
# <li>
# <a href="/sommer/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/sommer/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/sommer/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/sommer/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/sommer/wallis/">Valais</a>
# </li>
# <li>
# <a href="/sommer/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/sommer/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/sommer/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/sommer/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/sommer/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/sommer/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/sommer/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/sommer/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/sommer/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="/sommer/schweiz/wetter/prognose/">Weather</a>
# </li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# <li><a href="/sommer/angebote/">Offers</a></li>
# <li><a href="/forum/">Forum</a></li>
# <li>
# <a class="has-avatar" href="/mybergfex/">
# <div class="avatar">
# </div><span class="nav-main-username">MyBergfex</span>
# </a>
# </li>
# <div id="mybergfex"></div>
# </ul>
# </div>
# <div id="dropdown">
# <!-- optional logo in dropdown -->
# <img alt="" border="0" class="dropdown-logo" height="77" src="https://vcdn.bergfex.at/images/resized/5e/5aa28b0e4d23a15e_6c75f271197432f5@2x.png" width="77"/>
# <div class="dropdown-container page-left-margin">
# <div class="dropdown-content"></div>
# <div class="dropdown-close"></div>
# </div>
# </div>
# </nav><!--/page-top-->
# </div>
# <div id="mapactions">
# <div class="map_enable" id="mapaction_enable_big"></div>
# <div class="mapactions-separator"></div>
# <div class="mapactions-buttons">
# <div class="map_enable" id="mapaction_enable"></div>
# <div id="mapaction_help"></div>
# <div id="mapaction_link"></div>
# <div id="mapaction_up"></div>
# <div id="mapaction_down"></div>
# <div id="mapaction_full"></div>
# <div id="mapaction_close"></div>
# </div>
# </div>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/leaflet-1608217936.css" rel="stylesheet"/><div class="leaflet-map" id="siteMap" style="height: 180px; position: absolute; visibility: hidden; z-index: -1;">
# <div id="siteMapCanvas" style="height: 100%; width: 100%;"></div>
# </div>
# <script>
# var leafletMapOptions = {
# idCanvas: 'siteMapCanvas',
# idContainer: 'siteMap',
# minHeight: 350,
# maxHeight: Math.round($(window).height() * 0.66),
# zoom: 10,
# markerLayers: {
# skigebiete: {
# name: 'Ski resorts'
# },
# langlaufen: {
# name: 'Cross-country skiing'
# },
# unterkuenfte: {
# name: 'Accommodation'
# },
# sommerinfos: {
# name: 'Summer'
# },
# wandertouren: {
# name: 'Hiking tours'
# },
# alpintouren: {
# name: 'Alpine tours'
# },
# wintertouren: {
# name: 'Winter tours'
# },
# biketouren: {
# name: 'Bike tours'
# },
# lauftouren: {
# name: 'Running tours'
# },
# badeseen: {
# name: 'Bathing lakes'
# }
# },
# mapTypes: {
# oek: {
# name: 'bergfex OEK',
# title: 'bergfex Österreichische Karte 1:50.000'
# },
# osm: {
# name: 'bergfex OSM',
# title: 'bergfex OpenStreetMap'
# },
# basemap: {
# name: 'Basemap',
# title: 'Basemap Österreich'
# },
# basemapOrtho: {
# name: 'Basemap Orthofoto',
# title: 'Basemap Orthofotos Österreich'
# },
# satellite: {
# name: 'Satellite',
# title: 'Satellite'
# },
# roadmap: {
# name: 'Map',
# title: 'Map'
# }
# },
# overlays: {
# slopes: {
# name: 'Slope gradient'
# }
# },
# controls: {
# mapZoomControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# }
# },
# mapTypeControl: {
# showAsDropDown: function()
# {
# return bergfex.isMobile;
# }
# },
# mapSearchControl: {
# placeholder: 'Search in the map'
# },
# fullScreenControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# },
# title: {
# 'false': 'Vollbild',
# 'true': 'Vollbild verlassen'
# }
# },
# fullscreenContentControl: {
# i18n: {
# 'showContent': 'Inhalt einblenden',
# 'hideContent': 'Inhalt ausblenden'
# }
# },
# elevationControl: {
# i18n: {
# uphill: 'Uphill',
# downhill: 'Downhill',
# length: 'Length',
# height: 'Height'
# }
# },
# osmLegendControl: {
# language: 'en',
# i18n: {
# title: 'Legend'
# }
# },
# oekLegendControl: {
# i18n: {
# title: 'Legend'
# }
# }
# },
# layersDropDownContainer: {
# title: '<strong>Topics</strong> show <div class="layers-icon"></div>'
# }
# };
# $(document).ready(function()
# {
# var isChromium = !!window.chrome;
# if(isChromium) {
# leafletMapOptions.mapTypes.osm.class = bergfex.Leaflet.MapTypes.Osm_Mapboxgl
# }
# bergfex.MapHandler.init(leafletMapOptions);
# });
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/es6-promise.min-1608217937.jsmin.js" type="text/javascript"></script><script>ES6Promise.polyfill();</script>
# <script src="/include/js/leaflet/plugins/mapbox-gl-1.5.0/mapbox-gl.js"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/leaflet-map-1616403709.jsmin.js" type="text/javascript"></script><h1 id="document-title" style="display: none;">BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</h1>
# <!--page-bottom-->
# <div id="page-container">
# <nav class="breadcrumb mobile-hidden">
# <a href="/sommer/schweiz/" title="Summer Switzerland">Summer Switzerland</a> /
# <a class="important" href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </nav>
# <main class="page-left-margin">
# <aside id="nav-side">
# <div class="nav-side-close"></div>
# <div class="logo">
# <img alt="" border="0" height="37.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_ca92b0a06176d736@2x.png" width="133"/>
# </div>
# <div class="location">
# <a class="country" href="/sommer/schweiz/">Switzerland</a> /
# <a class="region" href="/sommer/bern-region/">Swiss plateau</a>
# </div>
# <div class="location-map">
# <div class="locationmap">
# <img alt="" border="0" height="83" src="https://vcdn.bergfex.at/images/resized/47/bb3e2117b44f9a47_30bc1b8b1f3fcfa4@2x.png" width="129.5"/>
# <a href="/sommer/schweiz/">
# <img alt="" border="0" class="layer" height="83" src="https://vcdn.bergfex.at/images/resized/6d/0767a6107b78396d_57e7f5a1ae33f073@2x.png" width="129.5"/>
# </a>
# </div>
# </div>
# <ul class="tree">
# <li class="level0">
# <a href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/" title="Regions">Regions</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/wetter/prognose/" title="Weather">Weather</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/webcams/" title="Webcams">Webcams</a>
# </li><li class="level1 selected">
# <a href="/sommer/bern-region/touren/" title="Tours">Tours</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/highlights/" title="Highlights">Highlights</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/seen/" title="Bathing lakes">Bathing lakes</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/unterkuenfte/" title="Accommodation">Accommodation</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/pauschalangebote/" title="Offers and All-inclusive prices">Offers and All-inclusive prices</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/sportanbieter/" title="Sports and leisure provider">Sports and leisure provider</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/veranstaltungen/" title="Events">Events</a>
# </li><li class="level0 winter">
# <a href="/bern-region/" title="Ski resorts">Ski resorts</a>
# </li><li class="level0 winter">
# <a href="/bern-region/langlaufen/" title="Cross-country skiing">Cross-country skiing</a>
# </li><li class="level0 winter">
# <a href="/bern-region/snow-parks/" title="Snow parks">Snow parks</a>
# </li></ul>
# <script>
# $(document).ready(function() {
# $("#quiz-container .quiz-teaser")
# .delay(2000)
# .animate( {
# left: 0
# }, 1000);
# $("#quiz-container .quiz-gewinn")
# .delay(5000)
# .animate( {
# height: $("#quiz-container .quiz-gewinn-text").height() + 14,
# }, 800);
# });
# </script>
# <div class="quiz-container-full clickable" id="quiz-container">
# <div style="position: absolute">
# <img alt="" border="0" height="160" src="https://vcdn.bergfex.at/images/resized/3d/46c4f2ac4d70223d_20ca31835d844cba@2x.jpg" width="160"/>
# </div>
# <!--  animate: -->
# <div class="quiz-gewinn">
# <div class="quiz-gewinn-text">
# 2 ÜN in einer Pension für 2 Personen zu gewinnen
# </div>
# <div class="inner-shadow-top"></div>
# <div class="inner-shadow-bottom"></div>
# </div>
# <!--  animate: -->
# <div class="quiz-teaser">
# <div class="quiz-label"><a href="/redirect/e9b472/212/547/https%3A%2F%2Fwww.bergfex.com%2Fsommer%2Fquiz%2F%3Fid%3D547%26utm_source%3Dbergfex%26utm_medium%3Dbanner%26utm_campaign%3Dgewinnspiel" rel="nofollow">Competition</a></div>
# <div class="quiz-title" style="font-size: 11px; line-height: 13px;"><span>Ferienregion Fügen – Kaltenbach im Zillertal</span></div>
# </div>
# </div>
# <ul class="tree info jblocktruncate" style="max-height: 200px;">
# <li class="level1 label">
# Favourite regions
# </li>
# <li class="level1"><a href="/sommer/bern-stadt/">Bern - Stadt</a></li>
# <li class="level1"><a href="/sommer/emmental/">Emmental</a></li>
# <li class="level1"><a href="/sommer/naturpark-gantrisch/">Naturpark Gantrisch</a></li>
# <li class="level1"><a href="/sommer/oberaargau/">Oberaargau</a></li>
# <li class="level1"><a href="/sommer/burgdorf/">Burgdorf</a></li>
# <li class="level1"><a href="/sommer/muensingen/">Münsingen</a></li>
# <li class="level1"><a href="/sommer/muri-bei-bern/">Muri bei Bern</a></li>
# <li class="level1"><a href="/sommer/laupen/">Laupen</a></li>
# <li class="level1"><a href="/sommer/lyss/">Lyss</a></li>
# <li class="level1"><a href="/sommer/langenthal/">Langenthal</a></li>
# <li class="level1"><a href="/sommer/zollikofen/">Zollikofen</a></li>
# <li class="level1"><a href="/sommer/steffisburg/">Steffisburg</a></li>
# <li class="level1"><a href="/sommer/worb/">Worb</a></li>
# <li class="level1"><a href="/sommer/belp/">Belp</a></li>
# <li class="level1"><a href="/sommer/koeniz/">Köniz</a></li>
# <li class="level1"><a href="/sommer/ostermundigen/">Ostermundigen</a></li>
# <li class="level1"><a href="/sommer/ittigen/">Ittigen</a></li>
# </ul>
# <div style="text-align: center">
# <a class="app-badge googleplay-badge" href="/redirect/f258b4/1231/0/1/https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdeveloper%3Fid%3Dbergfex%2BGmbH" target="_blank" title="Android Apps">
# </a>
# <a class="app-badge appstore-badge" href="/redirect/e29ab4/1230/0/1/https%3A%2F%2Fapps.apple.com%2Fat%2Fdeveloper%2Fbergfex-gmbh%2Fid355025018" target="_blank" title="iPhone Apps"></a>
# </div>
# <script>
# $(document).ready(function() {
# if($.browser){
# if ($.browser.isIOS) {
# $(".googleplay-badge").hide();
# $(".appstore-badge").addClass("big-badge");
# } else if ($.browser.isAndroid) {
# $(".appstore-badge").hide();
# $(".googleplay-badge").addClass("big-badge");
# }
# }
# });
# </script></aside>
# <div class="content" id="detail"><div class="section-left">
# <header>
# <a class="mobile-back mobile-only" href="/sommer/bern-region/">Swiss plateau</a>
# <!--    <div class="nav-side-trigger mobile-only"></div>  -->
# <div class="logo mobile-only">
# <img alt="" border="0" height="25.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_f1f23b72380280e9@2x.png" width="90"/>
# </div>
# <h1>Tours <span class="less-important">Swiss plateau</span>
# </h1><div class="buttons">
# <div class="desktop-only button-small button-small-icon button-small-icon-down" id="btn-map-show">
# Map
# </div>
# <div class="desktop-only button-small button-dark-grey button-small-icon button-small-icon-up" id="btn-map-hide">
# Hide map
# </div>
# </div>
# <div class="clearer"></div>
# </header><hr class="desktop-only"/>
# <form action="/sommer/bern-region/touren/" class="form-horizontal" id="touren_searchform" method="get">
# <div class="box-container mobile-collapsed">
# <div class="box-header mobile-only">
# Touren filtern
# </div>
# <div class="box-content">
# <div class="control-group">
# <label>Region</label>
# <div class="controls">
# <script>
# function locationSelected(data) {
# $("#touren_searchform").attr("action", "/" + data[7] + "/touren/");
# }
# </script>
# <input class="input-100 input-important" id="text_location" name="text_location" placeholder="" style="font-weight: bold;" type="text" value=""/><script>$(document).ready(function() { addAutocompleter('location', '/ajax/jquery/autocompleter/regionen/', 3, 200, 400 , locationSelected); });</script><input id="location" name="location" type="hidden" value=""/>
# </div>
# </div>
# <div class="control-group">
# <label>Tour type</label>
# <div class="controls">
# <select class="input-100" name="type">
# <option value="0">(All)</option>
# <option value="14">Hiking (271)</option>
# <option value="17">Thematic route (44)</option>
# <option value="10">Mountainbike (43)</option>
# <option value="11">Cycling (37)</option>
# <option value="24">Trailrunning (17)</option>
# <option value="12">Racing (11)</option>
# <option value="16">Pilgrimage (11)</option>
# <option value="8">Via ferrata (4)</option>
# <option value="7">High tour (3)</option>
# <option value="13">Long distance cycling (3)</option>
# <option value="30">E-MTB (3)</option>
# <option value="23">Running (3)</option>
# <option value="42">E-Bike (2)</option>
# <option value="3">Ski tour (2)</option>
# <option value="22">Nordic Walking (2)</option>
# <option value="15">long-distance walking trail (1)</option>
# <option value="18">Kayak / Canoe (1)</option>
# <option value="4">Snowshoe (1)</option>
# </select>
# </div>
# </div>
# <div class="control-group">
# <label>Full-text search</label>
# <div class="controls">
# <input class="input-100" name="q" type="text">
# </input></div>
# </div>
# <div class="control-group">
# <label>Fitness</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_kondition">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_kondition">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Technique</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_fahrtechnik">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_fahrtechnik">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Length (km)</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_laenge" placeholder="min." size="2" type="text">
# </input></div>
# <div class="col">
# <input name="max_laenge" placeholder="max." size="2" type="text"/>
# </div>
# </div>
# </div>
# <div class="control-group">
# <label>Altitude metres</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_hm" placeholder="min." size="4" type="text"/>
# </div>
# <div class="col">
# <input name="max_hm" placeholder="max." size="4" type="text"/>
# </div>
# </div>
# </div>
# <input name="search" type="hidden" value="1"/>
# <div class="form-actions nobackground">
# <button class="button button-blue" type="submit">Search</button>
# <a class="button button-grey" href="http://www.bergfex.com/sommer/bern-region/touren/"><span>Reset</span></a>
# </div>
# </div>
# </div>
# </form>
# <div style="float: left; line-height: 24px; font-weight: bold;">
# Seite 2 <span class="less-important">von 459 Tours.</span>
# </div>
# <div class="sort-selector" data-order-selected="DESC" data-sort-selected="Relevanz" style="float: right;">
# <div class="sort-option-active">sortiert nach <span class="sort-name">Relevanz</span></div>
# <div class="sort-options">
# <div class="sort-option" data-order="DESC" data-sort="Relevanz" title="nach Relevanz sortieren">Relevanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Laenge" title="nach längste Distanz sortieren">längste Distanz</div>
# <div class="sort-option" data-order="ASC" data-sort="Laenge" title="nach kürzeste Distanz sortieren">kürzeste Distanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Zeit" title="nach längste Dauer sortieren">längste Dauer</div>
# <div class="sort-option" data-order="ASC" data-sort="Zeit" title="nach kürzeste Dauer sortieren">kürzeste Dauer</div>
# <div class="sort-option" data-order="DESC" data-sort="Hoehenmeter" title="nach meiste Höhenmeter sortieren">meiste Höhenmeter</div>
# <div class="sort-option" data-order="ASC" data-sort="Hoehenmeter" title="nach wenigste Höhenmeter sortieren">wenigste Höhenmeter</div>
# <div class="sort-option" data-order="DESC" data-sort="Kondition" title="nach hohe Kondition sortieren">hohe Kondition</div>
# <div class="sort-option" data-order="ASC" data-sort="Kondition" title="nach niedrige Kondition sortieren">niedrige Kondition</div>
# <div class="sort-option" data-order="DESC" data-sort="Technik" title="nach hohem Technikanspruch sortieren">hohe Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="Technik" title="nach niedrigem Technikanspruch sortieren">niedrige Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="Titel" title="nach Name A-Z sortieren">Name A-Z</div>
# <div class="sort-option" data-order="DESC" data-sort="Titel" title="nach Name Z-A sortieren">Name Z-A</div>
# </div>
# </div>
# <div class="clearer"></div>
# <div class="section">
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/114256,zur-hohwacht-im-emmental/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="114256" src="https://vcdn.bergfex.at/images/resized/fc/ff13da84556852fc_461dc0843de0fcce@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114256,zur-hohwacht-im-emmental/" title="Zur Hohwacht im Emmental">Zur Hohwacht im Emmental</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 11.37<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:20</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 423<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 669 - 1,074<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="84f7246e881e3d9ede82b2cecedc5d8a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/d8a/84f7246e881e3d9ede82b2cecedc5d8a.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="e2b4028dc84ce0f7ec1835237deb0be4" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/be4/e2b4028dc84ce0f7ec1835237deb0be4.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="a70d31a153c428e5d5e79f037f0165bf" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/5bf/a70d31a153c428e5d5e79f037f0165bf.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="86c2624025961ef1b67172a72d848107" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/107/86c2624025961ef1b67172a72d848107.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/radfahren/700226,st-stephan--ruewlispass--gstaad--saanenmoeser--st-stephan/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="700226" src="https://vcdn.bergfex.at/images/resized/4f/0e6f93c17d867e4f_c1bc6b9f247deb17@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/radfahren/700226,st-stephan--ruewlispass--gstaad--saanenmoeser--st-stephan/" title="St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan">St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Cycling
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 38.14<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:50</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 1,055<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 934 - 1,724<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="919452c86a22554672db285b53f98ed2" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ed2/919452c86a22554672db285b53f98ed2.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="8549a8f400887bb87c0a88646176c9c9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/9c9/8549a8f400887bb87c0a88646176c9c9.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="0561cc12a0e6bad5f10cf10b1fd75c00" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c00/0561cc12a0e6bad5f10cf10b1fd75c00.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="4b7084b7d21181e129f7a9c753fcc7b9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7b9/4b7084b7d21181e129f7a9c753fcc7b9.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/themenweg/108674,holz-skulpturenweg--frutigen/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="108674" src="https://vcdn.bergfex.at/images/resized/59/f4f831bcf5ce6959_fa2551107925693f@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/themenweg/108674,holz-skulpturenweg--frutigen/" title="Holz-Skulpturenweg - Frutigen">Holz-Skulpturenweg - Frutigen</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 9.56<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>02:45</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 134<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 779 - 913<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="189e5cfd81f6947c350ad868ffa1dc82" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c82/189e5cfd81f6947c350ad868ffa1dc82.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="99c5d31d8e7d9eeda477d6cf062c5ef3" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ef3/99c5d31d8e7d9eeda477d6cf062c5ef3.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="cb8cf20183df84cdaee3df8a5f3efbe7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/be7/cb8cf20183df84cdaee3df8a5f3efbe7.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="3c8af39949e1117898d99d4473308ad9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ad9/3c8af39949e1117898d99d4473308ad9.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/themenweg/295433,diemtigtaler-hausweg-mittleres-tal/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="295433" src="https://vcdn.bergfex.at/images/resized/85/40ead7011d722e85_5a82d86240c324ce@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/themenweg/295433,diemtigtaler-hausweg-mittleres-tal/" title="Diemtigtaler Hausweg «Mittleres Tal»">Diemtigtaler Hausweg «Mittleres Tal»</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 10.2<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:15</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 434<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 814 - 1,128<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="7ddcf296ce9de48e981ddcafd78c8238" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/238/7ddcf296ce9de48e981ddcafd78c8238.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="95fd65948c1651fc8acfe27477cd2c7d" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c7d/95fd65948c1651fc8acfe27477cd2c7d.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="f48283d2e801d036df90e06e990aaae5" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ae5/f48283d2e801d036df90e06e990aaae5.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="49d996e736eac6736015ed7116034f4a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f4a/49d996e736eac6736015ed7116034f4a.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/radfahren/172139,moraenensee-route/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="172139" src="https://vcdn.bergfex.at/images/resized/b7/d72b02757c14b2b7_cd0a3ce1146ae894@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/radfahren/172139,moraenensee-route/" title="Moränensee Route">Moränensee Route</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Cycling
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 25.49<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>01:40</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 197<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 553 - 750<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="9ea606c8c82bbd9f28c9ee6ffac2366e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/66e/9ea606c8c82bbd9f28c9ee6ffac2366e.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="689c2e8bdc609f7f83d981c043c14f65" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f65/689c2e8bdc609f7f83d981c043c14f65.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="7bba0d70a0824d2a80eb6f7e434c5152" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/152/7bba0d70a0824d2a80eb6f7e434c5152.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/99639,probsteberg--einsames-grenzgebiet-bern-solothurn/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="99639" src="https://vcdn.bergfex.at/images/resized/e8/f5aa1c00dcb748e8_00900eddd5bcbc18@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/99639,probsteberg--einsames-grenzgebiet-bern-solothurn/" title="Probsteberg - einsames Grenzgebiet Bern/Solothurn">Probsteberg - einsames Grenzgebiet Bern/Solothurn</a>
# <div>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 16.44<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>04:45</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 581<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 640 - 1,149<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="54600219282c1badb675b774fa3418c8" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/8c8/54600219282c1badb675b774fa3418c8.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="3f2f03ffc4b1c201f2c0cd87cadac7a7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7a7/3f2f03ffc4b1c201f2c0cd87cadac7a7.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-0"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/509375,meraengge-cher-im-kemmribodenbad/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="509375" src="https://vcdn.bergfex.at/images/resized/9c/d81af72f0175ff9c_b45bbe258a52a58a@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/509375,meraengge-cher-im-kemmribodenbad/" title="Merängge-Cher im Kemmribodenbad">Merängge-Cher im Kemmribodenbad</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 6.97<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>02:10</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 330<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 975 - 1,184<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="7e83b7446943e940e9b6769b2ec64302" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/302/7e83b7446943e940e9b6769b2ec64302.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/348126,lauenen--lauenensee--lauenen/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="348126" src="https://vcdn.bergfex.at/images/resized/03/4bf20abb357fab03_7884e5b24c857254@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/348126,lauenen--lauenensee--lauenen/" title="Lauenen – Lauenensee - Lauenen">Lauenen – Lauenensee - Lauenen</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 8.99<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# ...
# <img alt="" border="0" class="tour-photo" height="57" id="c5bbd4deb350dd72cc63e55470f7ef44" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f44/c5bbd4deb350dd72cc63e55470f7ef44.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="dfaa9d4063f9739b06c4ca5daee53387" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/387/dfaa9d4063f9739b06c4ca5daee53387.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="1284ca7e22de9a17266cb222b3bd9c2e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c2e/1284ca7e22de9a17266cb222b3bd9c2e.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="53e6b0b6cad7334c7e1072a544193c0e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c0e/53e6b0b6cad7334c7e1072a544193c0e.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section">
# <link href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" rel="first"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" rel="prev"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=23" rel="last"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" rel="next"/>
# <div class="pager">
# <div class="label">Pages:</div><a class="navigation pager-previous" href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" title="">previous<span class="pagerCaret"></span></a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" title="">1</a>
# <div class="page-selected">2</div>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" title="">3</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=4" title="">4</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=5" title="">5</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=6" title="">6</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=7" title="">7</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=8" title="">8</a>
# <a class="navigation pager-next" href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" title="">
# next<span class="pagerCaret"></span>
# </a>
# </div>
# </div>
# </div>
# <div class="section-right">
# <div class="listbox box-container mobile-collapsed">
# <div class="box-header">Tours by type</div>
# <div class="box-content grid cols2">
# <div class="col">
# <ul>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/wandern/">Hiking</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/bike/">Bike</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/laufen/">Running</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/alpin/">Alpine</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/winter/">Winter</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/wasser/">Water</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="contentbox box-container">
# <div class="box-header">
# <span class="less-important">bergfex</span> Bergungskosten-Versicherung
# </div>
# <div class="box-content">
# <p>Noch schnell für den anstehenden Ausflug versichern? Inkl. Rettungshubschrauber <span class="important nowrap">ab 3,98 €</span>
# </p><a class="link-important button-green" href="/redirect/69bce4/131/0/https%3A%2F%2Fergo-versicherung.at%2Fbergfex-bergung%2F%3Futm_source%3Dbergfex%26utm_medium%3DLink%26utm_campaign%3Dbergfex-bergung%26aid%3DD146" target="_blank">
# Jetzt Informieren
# </a>
# </div>
# </div>
# <div class="listbox box-container mobile-collapsed">
# <div class="box-header">
# Countries
# </div>
# <div class="box-content grid cols2">
# <div class="col">
# <ul>
# <li><a href="/sommer/oesterreich/touren/">Austria</a></li>
# <li class="selected"><a href="/sommer/schweiz/touren/">Switzerland</a></li>
# <li><a href="/sommer/deutschland/touren/">Germany</a></li>
# <li><a href="/sommer/italien/touren/">Italy</a></li>
# <li><a href="/sommer/slovenia/touren/">Slovenia</a></li>
# <li><a href="/sommer/frankreich/touren/">France</a></li>
# <li><a href="/sommer/nederland/touren/">Netherlands</a></li>
# <li><a href="/sommer/belgie/touren/">Belgium</a></li>
# <li><a href="/sommer/czechia/touren/">Czechia</a></li>
# <li><a href="/sommer/slovakia/touren/">Slovakia</a></li>
# <li><a href="/sommer/spanien/touren/">Spain</a></li>
# <li><a href="/sommer/kroatien/touren/">Croatia</a></li>
# <li><a href="/sommer/luxemburg/touren/">Luxembourg</a></li>
# <li><a href="/sommer/liechtenstein/touren/">Liechtenstein</a></li>
# </ul>
# </div>
# <div class="col">
# <ul>
# <li><a href="/sommer/graubuenden/touren/">Graubünden</a></li>
# <li><a href="/sommer/wallis/touren/">Valais</a></li>
# <li><a href="/sommer/berneroberland/touren/">Bernese Oberland</a></li>
# <li><a href="/sommer/luzern-vierwaldstaettersee/touren/">Central Switzerland</a></li>
# <li><a href="/sommer/ostschweiz/touren/">Eastern Switzerland</a></li>
# <li><a href="/sommer/zuerich/touren/">Zurich region</a></li>
# <li><a href="/sommer/aargau/touren/">Aargau</a></li>
# <li><a href="/sommer/jura-drei-seen-land/touren/">Jura</a></li>
# <li><a href="/sommer/tessin/touren/">Ticino</a></li>
# <li><a href="/sommer/freiburg-region/touren/">Fribourg</a></li>
# <li><a href="/sommer/genferseegebiet-waadtland/touren/">Vaud / Lake Geneva Region</a></li>
# <li class="selected"><a href="/sommer/bern-region/touren/">Swiss plateau</a></li>
# <li><a href="/sommer/basel-region/touren/">Aargau-Basle</a></li>
# <li><a href="/sommer/genf-region/touren/">Geneva</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="section">
# <h3>Popular tours in the area</h3>
# <script>
#                 var oaTrackingDetail = null;
#                 var oaTrackingTeaser = [];
#
#                 if(typeof trackOutdooractiveActivities === "undefined") {
#                     function trackOutdooractiveActivities() {
#                         if (oaTrackingDetail !== null) {
#                             $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackDetail(oaTrackingDetail);
#                         }
#                         if (oaTrackingTeaser.length > 0) {
#                             _.forEach(oaTrackingTeaser, function(teaserId) {
#                                 $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackTeaser(teaserId);
#                             });
#                         }
#                     }
#                 }
#
#                 if(typeof outdooractiveTrackingIframeLoaded === "undefined") {
#                     function outdooractiveTrackingIframeLoaded() {
#                         trackOutdooractiveActivities();
#                     }
#                 }
#
#                 $(document).ready(function() {
#                     var $iframe = $("#outdooractive_tracking_iframe");
#
#                     if($iframe.length === 0) {
#                         $("body").append("<iframe id='outdooractive_tracking_iframe' src='//www.bergfex.com/ajax/outdooractive/tracking.php'></iframe>");
#                     } else {
#                         trackOutdooractiveActivities();
#                     }
#                 });
#             </script>
# <script>oaTrackingTeaser.push('15655063');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1216109" height="200" src="https://vcdn.bergfex.at/images/resized/fb/88ab53a017f741fb_e5f641d58b13d34e@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86144,waldhaeusern--beliebtes-ausflugsziel-im-emmental/" title="„Signau…in allen Jahreszeiten schön“. Mit diesem Motto werden die Besucher der Gemeinde-Homepage...">
# Waldhäusern - ...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>9.63</strong>km | <strong>373</strong>hm | <strong>03:00</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86144" src="https://vcdn.bergfex.at/images/resized/c0/763597cd262eb0c0_8638de0c909f0598@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('17346892');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1149454" height="200" src="https://vcdn.bergfex.at/images/resized/dd/2378e3c744ce8fdd_0b7155a0cb1d6e86@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/themenweg/78168,baenkli-rundweg-aeschi-bei-spiez/" title="&lt;p&gt;Sie laden zum Ausruhen ein. Oft empfangen sie Wandererinnen und Spaziergänger, manchmal nur...">
# Bänkli-Rundweg...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="smaller">
# <strong>7.38</strong>km | <strong>255</strong>hm | <strong>02:13</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="78168" src="https://vcdn.bergfex.at/images/resized/f9/9dc49d1e748a4bf9_876815c39274c206@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('15655869');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1215216" height="200" src="https://vcdn.bergfex.at/images/resized/c9/5c1c0d0fdafa3ac9_cff36ffac8048b95@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86037,auf-dem-beatenberg-der-sonnenterrasse-des-berner-oberlandes/" title="Auf dieser Wanderung erlebt und geniesst man die Schönheit des Dreigestirnes Eiger Mönch und...">
# Auf dem Beatenb...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.74</strong>km | <strong>752</strong>hm | <strong>04:10</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86037" src="https://vcdn.bergfex.at/images/resized/ff/d89b53e14797e2ff_4f7456e6cd041215@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('8483704');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="752976" height="200" src="https://vcdn.bergfex.at/images/resized/2a/6a97642fd5aebb2a_df99cc7fae3f8d32@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/51212,zu-eiszeitlichen-riesen-und-zur-wohnstaette-steinzeitlicher-menschen/" title="Abwechslungsreiche Wanderung durch Wälder, weite Matten und über aussichtsreiche Höhen zum...">
# Zu eiszeitliche...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.5</strong>km | <strong>254</strong>hm | <strong>02:40</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="51212" src="https://vcdn.bergfex.at/images/resized/6c/5d461db57398d66c_f4c1dd3fc9c64149@2x.jpg" width="240"/>
# </div>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </main>
# <div id="sidebar">
# <div class="adzone_skyscraper partner" data-geo="sommer.schweiz.bern-region" data-tags="" data-zoneid="2" id="adzone_skyscraper"></div>
# </div>
# <!--/page-bottom-->
# </div>
# <div class="clearer"></div>
# <div id="mapsearch-template-h2noresult">
# <h2>Keine Einträge gefunden.</h2>
# </div>
# <div id="mapsearch-template-h2overflow">
# <h2>Es wurden %count% Einträge gefunden. Bitte Suche verfeinern.</h2>
# </div>
# <div id="mapsearch-template-h2local">
# <h2>Lokale Suchergebnisse <span class="less-important">(Distance &lt;= 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2nonlocal">
# <h2>More results <span class="less-important">(Distance &gt; 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2all">
# <h2>All %count% Search results</h2>
# </div>
# <div id="mapsearch-template-line">
# <div class="mapsearch-line">
# <div><a class="name" href="">%name%</a> <span class="region">%region%</span></div>
# <div><span class="type">%type%</span> <span class="elevation">%elevation%</span></div>
# </div>
# </div><footer id="footer">
# <div class="footer-container page-left-margin">
# <div class="footer-location">
# / <a href="/sommer/schweiz/">Summer Switzerland</a> /
# <a href="/sommer/bern-region/">Swiss plateau</a> /
# <strong>Tours</strong>
# </div>
# <ul class="nav-list">
# <li class="has-children collapsed language-select">
# <h2 class="no-select" style="overflow: visible"><span class="mobile-only">Language</span> <span class="flag en"></span> english</h2>
# <ul>
# <li><a href="//www.bergfex.ch/sommer/bern-region/touren/" rel='"nofollow"'>
# <span class="flag de"></span> Deutsch</a></li>
# <li><a href="//www.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag en"></span> English</a></li>
# <li><a href="//www.bergfex.fr/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fr"></span> Français</a></li>
# <li><a href="//it.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag it"></span> Italiano</a></li>
# <li><a href="//www.bergfex.es/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag es"></span> Español</a></li>
# <li><a href="//nl.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag nl"></span> Nederlands</a></li>
# <li><a href="//se.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag se"></span> Svenska</a></li>
# <li><a href="//no.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag no"></span> Norsk</a></li>
# <li><a href="//dk.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag dk"></span> Dansk</a></li>
# <li><a href="//fi.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fi"></span> Suomi</a></li>
# <li><a href="//hu.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hu"></span> Magyar</a></li>
# <li><a href="//www.bergfex.cz/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag cz"></span> český</a></li>
# <li><a href="//www.bergfex.sk/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag sk"></span> Slovensky</a></li>
# <li><a href="//www.bergfex.pl/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag pl"></span> Polski</a></li>
# <li><a href="//hr.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hr"></span> Hrvatski</a></li>
# <li><a href="//www.bergfex.si/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag si"></span> Slovenščina</a></li>
# <li><a href="//ru.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ru"></span> русский</a></li>
# <li><a href="//ro.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ro"></span> Român</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>Themen</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li><a href="/sommer/schweiz/">Summer regions</a></li>
# <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>General</h2>
# <ul>
# <li><a href="/newsletter/">Newsletter</a></li>
# <li><a href="/produkte/">Products</a></li>
# <li><a href="/shop/">Shop</a></li>
# <li><a href="/login/">Login</a></li>
# </ul>
# </li>
# </ul>
# <div id="language-select-overlay"></div>
# <div class="copyright-container">
# <!-- background image -->
# <div class="copyright">Copyright © 1999, 2021 bergfex GmbH. All rights reserved.</div>
# <div class="copyright-links">
# <a href="/datenschutz/">Privacy policy</a> |
# <a href="/impressum/">About us</a> |
# <a href="" id="privacy-manager">Privacy Manager</a>
# </div>
# </div>
# </div>
# </footer></body>
# </html>

# %%
region3
# Out:
# [<li class="has-children collapsed">
#  <a>Winter</a>
#  <ul>
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li>
#  <a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li>
#  <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li>
#  <a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li>
#  <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/sommer/schweiz/">Regions</a></li>
#  <li class="selected">
#  <a href="/sommer/schweiz/touren/">Tours</a></li>
#  <li>
#  <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
#  <li>
#  <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
#  <li>
#  <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/sommer/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/sommer/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/sommer/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/sommer/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/sommer/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/sommer/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/sommer/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/sommer/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/sommer/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/sommer/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/sommer/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/sommer/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/sommer/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/sommer/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/sommer/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/sommer/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/sommer/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/sommer/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/sommer/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/sommer/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/sommer/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/sommer/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/sommer/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/sommer/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Themen</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li><a href="/sommer/schweiz/">Summer regions</a></li>
#  <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/sommer/schweiz/touren/">Tours</a></li>
#  <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>General</h2>
#  <ul>
#  <li><a href="/newsletter/">Newsletter</a></li>
#  <li><a href="/produkte/">Products</a></li>
#  <li><a href="/shop/">Shop</a></li>
#  <li><a href="/login/">Login</a></li>
#  </ul>
#  </li>]

# %%
region_copy = region3.copy()

# %%
region_copy
# Out:
# [<li class="has-children collapsed">
#  <a>Winter</a>
#  <ul>
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li>
#  <a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li>
#  <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li>
#  <a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li>
#  <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/sommer/schweiz/">Regions</a></li>
#  <li class="selected">
#  <a href="/sommer/schweiz/touren/">Tours</a></li>
#  <li>
#  <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
#  <li>
#  <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
#  <li>
#  <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/sommer/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/sommer/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/sommer/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/sommer/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/sommer/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/sommer/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/sommer/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/sommer/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/sommer/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/sommer/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/sommer/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/sommer/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/sommer/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/sommer/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/sommer/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/sommer/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/sommer/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/sommer/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/sommer/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/sommer/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/sommer/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/sommer/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/sommer/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/sommer/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Themen</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li><a href="/sommer/schweiz/">Summer regions</a></li>
#  <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/sommer/schweiz/touren/">Tours</a></li>
#  <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>General</h2>
#  <ul>
#  <li><a href="/newsletter/">Newsletter</a></li>
#  <li><a href="/produkte/">Products</a></li>
#  <li><a href="/shop/">Shop</a></li>
#  <li><a href="/login/">Login</a></li>
#  </ul>
#  </li>]

# %%
soup_region
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</title>
# <meta content="Swiss plateau,Switzerland,Tours," name="keywords"/>
# <meta content="Swiss plateau Switzerland: " name="description"/>
# <meta content="app-id=912776148" name="apple-itunes-app">
# <script src="https://cdn.stroeerdigitalgroup.de/metatag/live/SDG_ConsentOnly/metaTag.min.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="en" name="language"/>
# <meta content="width=device-width, viewport-fit=cover" name="viewport"/>
# <script type="application/ld+json">
# {
# "@context": "https://schema.org",
# "@type": "Organization",
# "url": "https://www.bergfex.com",
# "logo": "https://www.bergfex.com/images/logo.png"
# }
# </script>
# <meta content="BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking" property="og:title"/>
# <meta content="https://vcdn.bergfex.at/images/resized/d8/a65a94fd11f0d3d8_ad3f21a01c2764d0.jpg" property="og:image"/>
# <meta content="image/jpg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="627" property="og:image:height"/>
# <link href="//www.bergfex.ch/sommer/bern-region/touren/" hreflang="de" rel="alternate"/>
# <link href="//www.bergfex.com/sommer/bern-region/touren/" hreflang="en" rel="alternate"/>
# <link href="//www.bergfex.fr/sommer/bern-region/touren/" hreflang="fr" rel="alternate"/>
# <link href="//it.bergfex.com/sommer/bern-region/touren/" hreflang="it" rel="alternate"/>
# <link href="//www.bergfex.es/sommer/bern-region/touren/" hreflang="es" rel="alternate"/>
# <link href="//nl.bergfex.com/sommer/bern-region/touren/" hreflang="nl" rel="alternate"/>
# <link href="//se.bergfex.com/sommer/bern-region/touren/" hreflang="sv" rel="alternate"/>
# <link href="//no.bergfex.com/sommer/bern-region/touren/" hreflang="no" rel="alternate"/>
# <link href="//dk.bergfex.com/sommer/bern-region/touren/" hreflang="da" rel="alternate"/>
# <link href="//fi.bergfex.com/sommer/bern-region/touren/" hreflang="fi" rel="alternate"/>
# <link href="//hu.bergfex.com/sommer/bern-region/touren/" hreflang="hu" rel="alternate"/>
# <link href="//www.bergfex.cz/sommer/bern-region/touren/" hreflang="cs" rel="alternate"/>
# <link href="//sk.bergfex.com/sommer/bern-region/touren/" hreflang="sk" rel="alternate"/>
# <link href="//www.bergfex.pl/sommer/bern-region/touren/" hreflang="pl" rel="alternate"/>
# <link href="//hr.bergfex.com/sommer/bern-region/touren/" hreflang="hr" rel="alternate"/>
# <link href="//www.bergfex.si/sommer/bern-region/touren/" hreflang="sl" rel="alternate"/>
# <link href="//ru.bergfex.com/sommer/bern-region/touren/" hreflang="ru" rel="alternate"/>
# <link href="//ro.bergfex.com/sommer/bern-region/touren/" hreflang="ro" rel="alternate"/>
# <link href="https://plus.google.com/105981749558386334210" rel="publisher"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link color="#1599ff" href="//vcdn.bergfex.at/images/mask-icon.svg" rel="mask-icon"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/bergfex-1615903180.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/sommer-1608217936.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/print-1608217936.css" media="print" rel="stylesheet"/><script>
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.autoCompleteActive = false;
# bergfex.autoCompleteSuggestionStartChar = 1;
# </script><script>
# // bergfex namespace
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.staticHost = '//vcdn.bergfex.at';
# bergfex.staticHosts = ['//vcdn.bergfex.at'];
# bergfex.InfobannerCookiesOptions = {
# timesToShow: 3,
# textTitle: "Informationen zu Cookies",
# textInfo:
# "Diese Seite verwendet Cookies. " +
# "Für eine uneingeschränkte Nutzung der Website werden Cookies benötigt. " +
# "Sie stimmen der Verwendung von Cookies durch Anklicken von \"OK\" zu. " +
# "Nähere Informationen finden Sie in unseren ",
# textPolicy: "Datenschutzbedingungen",
# urlPolicy: "/datenschutz/",
# textButton: "OK",
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.1-1608217937.jsmin.js" type="text/javascript"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.2-1610094216.jsmin.js" type="text/javascript"></script><script src="//vcdn.bergfex.at/include/js/jquery/plugins/ui/1.10.3/i18n/jquery.ui.datepicker-en.js" type="text/javascript"></script><script>
# var gMapKey = "AIzaSyDhkXDPfuKgSZgCcKfDLRHNZFrsdbfQkiQ";
# var mapEnabled = true;
# var mapHeight = 360;
# bergfex.libs = { };
# bergfex.libs.srcElevLibs = "//vcdn.bergfex.at/include/jsmin/elevationprofile-libs-1608217937.jsmin.js";
# bergfex.libs.srcMapLibs  = "//vcdn.bergfex.at/include/jsmin/map-libs-1608217937.jsmin.js";
# bergfex.season = "sommer";
# </script><script>
# var jBlockTruncateSettings = {
# 'moreText': "show more",
# 'lessText': "less"
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/bergfex-libs-1616068547.jsmin.js" type="text/javascript"></script><meta content="0" name="geonomap"/>
# <meta content="keep" name="geomap"/>
# <meta content="Bundesland_16" name="geocontext"/>
# <meta content="46.939012,8.107910,10,o" name="geoposition"/>
# <meta content="1" name="geotarget"/>
# <meta content="touren" name="geolayer"/>
# <meta content="sommer" name="season"/></meta></meta></head>
# <body class="site">
# <div id="page-top">
# <!--page-top-->
# <div style="position: absolute;">
# <script src="//script.ioam.de/iam.js" type="text/javascript"></script>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         $(document).ready(function() {
#             var iam_data = {
#                 "st": "bergfex",
#                 "cp": "sommer-nonde",
#                 "sv": "in",  // keine Befragungseinladung
#                 "co": ""  // comment
#             }
#             try {
#                 iom.c(iam_data, 1);
#             } catch(e) {
#             }
#         });
#     </script>
# <!-- /SZM -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-15684980-1"></script>
# <script>
# // https://support.google.com/analytics/answer/10022331?hl=de
# // window['gtag_enable_tcf_support'] = true;
# bergfex.Analytics = {
# send_to: 'UA-15684980-1',
# admask: 'schweiz.bern-region',
# language: 'en',
# page_location: '/sommer/bern-region/touren/?isAjax=1&page=1',
# };
# window.dataLayer = window.dataLayer || [];
# bergfex.gtag = function() {
# dataLayer.push(arguments);
# }
# bergfex.gtag('js', new Date());
# bergfex.gtag('config', 'UA-15684980-1', {
# send_page_view: false,
# custom_map: {
# dimension1: 'admask',
# dimension2: 'language',
# },
# });
# bergfex.gtag('event', 'init');
# window.addEventListener('metaTagSystemCmpChoiceUiShown', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceUiShown');
# });
# window.addEventListener('metaTagSystemCmpChoiceSelected', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceSelected');
# });
# // log map views.
# </script></div>
# <nav class="nav-default" id="nav-main">
# <div class="nav-main-trigger-side"></div>
# <a class="logo-bergfex" href="/" title="bergfex Homepage"></a>
# <div class="nav-main-search responsive-only" id="nav-main-search">
# </div>
# <div class="nav-main-user responsive-only">
# <a href="/mybergfex/">
# <div class="avatar">
# </div></a>
# </div>
# <div class="nav-main-trigger"></div>
# <div class="nav-main-close"></div>
# <div class="nav-main-container page-left-margin">
# <div class="nav-search">
# <form action="/sommer/suchen/" autocomplete="off" method="get" name="sitesearch">
# <div class="search-icon"></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" id="search-input-field" maxlength="256" name="q" placeholder="Search" spellcheck="false" type="text"/>
# </form>
# </div>
# <!-- on dropdown, inject logo from mainlogo position via js -->
# <ul class="nav-list">
# <li class="has-children collapsed">
# <a>Winter</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li>
# <a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li>
# <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/italien/">Italy</a>
# </li>
# <li>
# <a href="/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/frankreich/">France</a>
# </li>
# <li>
# <a href="/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/polska/">Poland</a>
# </li>
# <li>
# <a href="/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/spanien/">Spain</a>
# </li>
# <li>
# <a href="/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/wallis/">Valais</a>
# </li>
# <li>
# <a href="/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed selected-init">
# <a>Summer</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/sommer/schweiz/">Regions</a></li>
# <li class="selected">
# <a href="/sommer/schweiz/touren/">Tours</a></li>
# <li>
# <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
# <li>
# <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
# <li>
# <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/sommer/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/sommer/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/sommer/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/sommer/italien/">Italy</a>
# </li>
# <li>
# <a href="/sommer/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/sommer/frankreich/">France</a>
# </li>
# <li>
# <a href="/sommer/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/sommer/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/sommer/polska/">Poland</a>
# </li>
# <li>
# <a href="/sommer/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/sommer/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/sommer/spanien/">Spain</a>
# </li>
# <li>
# <a href="/sommer/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/sommer/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/sommer/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/sommer/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/sommer/wallis/">Valais</a>
# </li>
# <li>
# <a href="/sommer/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/sommer/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/sommer/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/sommer/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/sommer/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/sommer/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/sommer/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/sommer/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/sommer/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="/sommer/schweiz/wetter/prognose/">Weather</a>
# </li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# <li><a href="/sommer/angebote/">Offers</a></li>
# <li><a href="/forum/">Forum</a></li>
# <li>
# <a class="has-avatar" href="/mybergfex/">
# <div class="avatar">
# </div><span class="nav-main-username">MyBergfex</span>
# </a>
# </li>
# <div id="mybergfex"></div>
# </ul>
# </div>
# <div id="dropdown">
# <!-- optional logo in dropdown -->
# <img alt="" border="0" class="dropdown-logo" height="77" src="https://vcdn.bergfex.at/images/resized/5e/5aa28b0e4d23a15e_6c75f271197432f5@2x.png" width="77"/>
# <div class="dropdown-container page-left-margin">
# <div class="dropdown-content"></div>
# <div class="dropdown-close"></div>
# </div>
# </div>
# </nav><!--/page-top-->
# </div>
# <div id="mapactions">
# <div class="map_enable" id="mapaction_enable_big"></div>
# <div class="mapactions-separator"></div>
# <div class="mapactions-buttons">
# <div class="map_enable" id="mapaction_enable"></div>
# <div id="mapaction_help"></div>
# <div id="mapaction_link"></div>
# <div id="mapaction_up"></div>
# <div id="mapaction_down"></div>
# <div id="mapaction_full"></div>
# <div id="mapaction_close"></div>
# </div>
# </div>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/leaflet-1608217936.css" rel="stylesheet"/><div class="leaflet-map" id="siteMap" style="height: 180px; position: absolute; visibility: hidden; z-index: -1;">
# <div id="siteMapCanvas" style="height: 100%; width: 100%;"></div>
# </div>
# <script>
# var leafletMapOptions = {
# idCanvas: 'siteMapCanvas',
# idContainer: 'siteMap',
# minHeight: 350,
# maxHeight: Math.round($(window).height() * 0.66),
# zoom: 10,
# markerLayers: {
# skigebiete: {
# name: 'Ski resorts'
# },
# langlaufen: {
# name: 'Cross-country skiing'
# },
# unterkuenfte: {
# name: 'Accommodation'
# },
# sommerinfos: {
# name: 'Summer'
# },
# wandertouren: {
# name: 'Hiking tours'
# },
# alpintouren: {
# name: 'Alpine tours'
# },
# wintertouren: {
# name: 'Winter tours'
# },
# biketouren: {
# name: 'Bike tours'
# },
# lauftouren: {
# name: 'Running tours'
# },
# badeseen: {
# name: 'Bathing lakes'
# }
# },
# mapTypes: {
# oek: {
# name: 'bergfex OEK',
# title: 'bergfex Österreichische Karte 1:50.000'
# },
# osm: {
# name: 'bergfex OSM',
# title: 'bergfex OpenStreetMap'
# },
# basemap: {
# name: 'Basemap',
# title: 'Basemap Österreich'
# },
# basemapOrtho: {
# name: 'Basemap Orthofoto',
# title: 'Basemap Orthofotos Österreich'
# },
# satellite: {
# name: 'Satellite',
# title: 'Satellite'
# },
# roadmap: {
# name: 'Map',
# title: 'Map'
# }
# },
# overlays: {
# slopes: {
# name: 'Slope gradient'
# }
# },
# controls: {
# mapZoomControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# }
# },
# mapTypeControl: {
# showAsDropDown: function()
# {
# return bergfex.isMobile;
# }
# },
# mapSearchControl: {
# placeholder: 'Search in the map'
# },
# fullScreenControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# },
# title: {
# 'false': 'Vollbild',
# 'true': 'Vollbild verlassen'
# }
# },
# fullscreenContentControl: {
# i18n: {
# 'showContent': 'Inhalt einblenden',
# 'hideContent': 'Inhalt ausblenden'
# }
# },
# elevationControl: {
# i18n: {
# uphill: 'Uphill',
# downhill: 'Downhill',
# length: 'Length',
# height: 'Height'
# }
# },
# osmLegendControl: {
# language: 'en',
# i18n: {
# title: 'Legend'
# }
# },
# oekLegendControl: {
# i18n: {
# title: 'Legend'
# }
# }
# },
# layersDropDownContainer: {
# title: '<strong>Topics</strong> show <div class="layers-icon"></div>'
# }
# };
# $(document).ready(function()
# {
# var isChromium = !!window.chrome;
# if(isChromium) {
# leafletMapOptions.mapTypes.osm.class = bergfex.Leaflet.MapTypes.Osm_Mapboxgl
# }
# bergfex.MapHandler.init(leafletMapOptions);
# });
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/es6-promise.min-1608217937.jsmin.js" type="text/javascript"></script><script>ES6Promise.polyfill();</script>
# <script src="/include/js/leaflet/plugins/mapbox-gl-1.5.0/mapbox-gl.js"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/leaflet-map-1616403709.jsmin.js" type="text/javascript"></script><h1 id="document-title" style="display: none;">BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</h1>
# <!--page-bottom-->
# <div id="page-container">
# <nav class="breadcrumb mobile-hidden">
# <a href="/sommer/schweiz/" title="Summer Switzerland">Summer Switzerland</a> /
# <a class="important" href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </nav>
# <main class="page-left-margin">
# <aside id="nav-side">
# <div class="nav-side-close"></div>
# <div class="logo">
# <img alt="" border="0" height="37.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_ca92b0a06176d736@2x.png" width="133"/>
# </div>
# <div class="location">
# <a class="country" href="/sommer/schweiz/">Switzerland</a> /
# <a class="region" href="/sommer/bern-region/">Swiss plateau</a>
# </div>
# <div class="location-map">
# <div class="locationmap">
# <img alt="" border="0" height="83" src="https://vcdn.bergfex.at/images/resized/47/bb3e2117b44f9a47_30bc1b8b1f3fcfa4@2x.png" width="129.5"/>
# <a href="/sommer/schweiz/">
# <img alt="" border="0" class="layer" height="83" src="https://vcdn.bergfex.at/images/resized/6d/0767a6107b78396d_57e7f5a1ae33f073@2x.png" width="129.5"/>
# </a>
# </div>
# </div>
# <ul class="tree">
# <li class="level0">
# <a href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/" title="Regions">Regions</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/wetter/prognose/" title="Weather">Weather</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/webcams/" title="Webcams">Webcams</a>
# </li><li class="level1 selected">
# <a href="/sommer/bern-region/touren/" title="Tours">Tours</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/highlights/" title="Highlights">Highlights</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/seen/" title="Bathing lakes">Bathing lakes</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/unterkuenfte/" title="Accommodation">Accommodation</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/pauschalangebote/" title="Offers and All-inclusive prices">Offers and All-inclusive prices</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/sportanbieter/" title="Sports and leisure provider">Sports and leisure provider</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/veranstaltungen/" title="Events">Events</a>
# </li><li class="level0 winter">
# <a href="/bern-region/" title="Ski resorts">Ski resorts</a>
# </li><li class="level0 winter">
# <a href="/bern-region/langlaufen/" title="Cross-country skiing">Cross-country skiing</a>
# </li><li class="level0 winter">
# <a href="/bern-region/snow-parks/" title="Snow parks">Snow parks</a>
# </li></ul>
# <script>
# $(document).ready(function() {
# $("#quiz-container .quiz-teaser")
# .delay(2000)
# .animate( {
# left: 0
# }, 1000);
# $("#quiz-container .quiz-gewinn")
# .delay(5000)
# .animate( {
# height: $("#quiz-container .quiz-gewinn-text").height() + 14,
# }, 800);
# });
# </script>
# <div class="quiz-container-full clickable" id="quiz-container">
# <div style="position: absolute">
# <img alt="" border="0" height="160" src="https://vcdn.bergfex.at/images/resized/3d/46c4f2ac4d70223d_20ca31835d844cba@2x.jpg" width="160"/>
# </div>
# <!--  animate: -->
# <div class="quiz-gewinn">
# <div class="quiz-gewinn-text">
# 2 ÜN in einer Pension für 2 Personen zu gewinnen
# </div>
# <div class="inner-shadow-top"></div>
# <div class="inner-shadow-bottom"></div>
# </div>
# <!--  animate: -->
# <div class="quiz-teaser">
# <div class="quiz-label"><a href="/redirect/e9b472/212/547/https%3A%2F%2Fwww.bergfex.com%2Fsommer%2Fquiz%2F%3Fid%3D547%26utm_source%3Dbergfex%26utm_medium%3Dbanner%26utm_campaign%3Dgewinnspiel" rel="nofollow">Competition</a></div>
# <div class="quiz-title" style="font-size: 11px; line-height: 13px;"><span>Ferienregion Fügen – Kaltenbach im Zillertal</span></div>
# </div>
# </div>
# <ul class="tree info jblocktruncate" style="max-height: 200px;">
# <li class="level1 label">
# Favourite regions
# </li>
# <li class="level1"><a href="/sommer/bern-stadt/">Bern - Stadt</a></li>
# <li class="level1"><a href="/sommer/emmental/">Emmental</a></li>
# <li class="level1"><a href="/sommer/naturpark-gantrisch/">Naturpark Gantrisch</a></li>
# <li class="level1"><a href="/sommer/oberaargau/">Oberaargau</a></li>
# <li class="level1"><a href="/sommer/burgdorf/">Burgdorf</a></li>
# <li class="level1"><a href="/sommer/muensingen/">Münsingen</a></li>
# <li class="level1"><a href="/sommer/muri-bei-bern/">Muri bei Bern</a></li>
# <li class="level1"><a href="/sommer/laupen/">Laupen</a></li>
# <li class="level1"><a href="/sommer/lyss/">Lyss</a></li>
# <li class="level1"><a href="/sommer/langenthal/">Langenthal</a></li>
# <li class="level1"><a href="/sommer/zollikofen/">Zollikofen</a></li>
# <li class="level1"><a href="/sommer/steffisburg/">Steffisburg</a></li>
# <li class="level1"><a href="/sommer/worb/">Worb</a></li>
# <li class="level1"><a href="/sommer/belp/">Belp</a></li>
# <li class="level1"><a href="/sommer/koeniz/">Köniz</a></li>
# <li class="level1"><a href="/sommer/ostermundigen/">Ostermundigen</a></li>
# <li class="level1"><a href="/sommer/ittigen/">Ittigen</a></li>
# </ul>
# <div style="text-align: center">
# <a class="app-badge googleplay-badge" href="/redirect/f258b4/1231/0/1/https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdeveloper%3Fid%3Dbergfex%2BGmbH" target="_blank" title="Android Apps">
# </a>
# <a class="app-badge appstore-badge" href="/redirect/e29ab4/1230/0/1/https%3A%2F%2Fapps.apple.com%2Fat%2Fdeveloper%2Fbergfex-gmbh%2Fid355025018" target="_blank" title="iPhone Apps"></a>
# </div>
# <script>
# $(document).ready(function() {
# if($.browser){
# if ($.browser.isIOS) {
# $(".googleplay-badge").hide();
# $(".appstore-badge").addClass("big-badge");
# } else if ($.browser.isAndroid) {
# $(".appstore-badge").hide();
# $(".googleplay-badge").addClass("big-badge");
# }
# }
# });
# </script></aside>
# <div class="content" id="detail"><div class="section-left">
# <header>
# <a class="mobile-back mobile-only" href="/sommer/bern-region/">Swiss plateau</a>
# <!--    <div class="nav-side-trigger mobile-only"></div>  -->
# <div class="logo mobile-only">
# <img alt="" border="0" height="25.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_f1f23b72380280e9@2x.png" width="90"/>
# </div>
# <h1>Tours <span class="less-important">Swiss plateau</span>
# </h1><div class="buttons">
# <div class="desktop-only button-small button-small-icon button-small-icon-down" id="btn-map-show">
# Map
# </div>
# <div class="desktop-only button-small button-dark-grey button-small-icon button-small-icon-up" id="btn-map-hide">
# Hide map
# </div>
# </div>
# <div class="clearer"></div>
# </header><hr class="desktop-only"/>
# <form action="/sommer/bern-region/touren/" class="form-horizontal" id="touren_searchform" method="get">
# <div class="box-container mobile-collapsed">
# <div class="box-header mobile-only">
# Touren filtern
# </div>
# <div class="box-content">
# <div class="control-group">
# <label>Region</label>
# <div class="controls">
# <script>
# function locationSelected(data) {
# $("#touren_searchform").attr("action", "/" + data[7] + "/touren/");
# }
# </script>
# <input class="input-100 input-important" id="text_location" name="text_location" placeholder="" style="font-weight: bold;" type="text" value=""/><script>$(document).ready(function() { addAutocompleter('location', '/ajax/jquery/autocompleter/regionen/', 3, 200, 400 , locationSelected); });</script><input id="location" name="location" type="hidden" value=""/>
# </div>
# </div>
# <div class="control-group">
# <label>Tour type</label>
# <div class="controls">
# <select class="input-100" name="type">
# <option value="0">(All)</option>
# <option value="14">Hiking (271)</option>
# <option value="17">Thematic route (44)</option>
# <option value="10">Mountainbike (43)</option>
# <option value="11">Cycling (37)</option>
# <option value="24">Trailrunning (17)</option>
# <option value="12">Racing (11)</option>
# <option value="16">Pilgrimage (11)</option>
# <option value="8">Via ferrata (4)</option>
# <option value="7">High tour (3)</option>
# <option value="13">Long distance cycling (3)</option>
# <option value="30">E-MTB (3)</option>
# <option value="23">Running (3)</option>
# <option value="42">E-Bike (2)</option>
# <option value="3">Ski tour (2)</option>
# <option value="22">Nordic Walking (2)</option>
# <option value="15">long-distance walking trail (1)</option>
# <option value="18">Kayak / Canoe (1)</option>
# <option value="4">Snowshoe (1)</option>
# </select>
# </div>
# </div>
# <div class="control-group">
# <label>Full-text search</label>
# <div class="controls">
# <input class="input-100" name="q" type="text">
# </input></div>
# </div>
# <div class="control-group">
# <label>Fitness</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_kondition">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_kondition">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Technique</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_fahrtechnik">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_fahrtechnik">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Length (km)</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_laenge" placeholder="min." size="2" type="text">
# </input></div>
# <div class="col">
# <input name="max_laenge" placeholder="max." size="2" type="text"/>
# </div>
# </div>
# </div>
# <div class="control-group">
# <label>Altitude metres</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_hm" placeholder="min." size="4" type="text"/>
# </div>
# <div class="col">
# <input name="max_hm" placeholder="max." size="4" type="text"/>
# </div>
# </div>
# </div>
# <input name="search" type="hidden" value="1"/>
# <div class="form-actions nobackground">
# <button class="button button-blue" type="submit">Search</button>
# <a class="button button-grey" href="http://www.bergfex.com/sommer/bern-region/touren/"><span>Reset</span></a>
# </div>
# </div>
# </div>
# </form>
# <div style="float: left; line-height: 24px; font-weight: bold;">
# Seite 2 <span class="less-important">von 459 Tours.</span>
# </div>
# <div class="sort-selector" data-order-selected="DESC" data-sort-selected="Relevanz" style="float: right;">
# <div class="sort-option-active">sortiert nach <span class="sort-name">Relevanz</span></div>
# <div class="sort-options">
# <div class="sort-option" data-order="DESC" data-sort="Relevanz" title="nach Relevanz sortieren">Relevanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Laenge" title="nach längste Distanz sortieren">längste Distanz</div>
# <div class="sort-option" data-order="ASC" data-sort="Laenge" title="nach kürzeste Distanz sortieren">kürzeste Distanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Zeit" title="nach längste Dauer sortieren">längste Dauer</div>
# <div class="sort-option" data-order="ASC" data-sort="Zeit" title="nach kürzeste Dauer sortieren">kürzeste Dauer</div>
# <div class="sort-option" data-order="DESC" data-sort="Hoehenmeter" title="nach meiste Höhenmeter sortieren">meiste Höhenmeter</div>
# <div class="sort-option" data-order="ASC" data-sort="Hoehenmeter" title="nach wenigste Höhenmeter sortieren">wenigste Höhenmeter</div>
# <div class="sort-option" data-order="DESC" data-sort="Kondition" title="nach hohe Kondition sortieren">hohe Kondition</div>
# <div class="sort-option" data-order="ASC" data-sort="Kondition" title="nach niedrige Kondition sortieren">niedrige Kondition</div>
# <div class="sort-option" data-order="DESC" data-sort="Technik" title="nach hohem Technikanspruch sortieren">hohe Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="Technik" title="nach niedrigem Technikanspruch sortieren">niedrige Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="Titel" title="nach Name A-Z sortieren">Name A-Z</div>
# <div class="sort-option" data-order="DESC" data-sort="Titel" title="nach Name Z-A sortieren">Name Z-A</div>
# </div>
# </div>
# <div class="clearer"></div>
# <div class="section">
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/114256,zur-hohwacht-im-emmental/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="114256" src="https://vcdn.bergfex.at/images/resized/fc/ff13da84556852fc_461dc0843de0fcce@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/114256,zur-hohwacht-im-emmental/" title="Zur Hohwacht im Emmental">Zur Hohwacht im Emmental</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 11.37<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:20</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 423<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 669 - 1,074<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="84f7246e881e3d9ede82b2cecedc5d8a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/d8a/84f7246e881e3d9ede82b2cecedc5d8a.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="e2b4028dc84ce0f7ec1835237deb0be4" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/be4/e2b4028dc84ce0f7ec1835237deb0be4.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="a70d31a153c428e5d5e79f037f0165bf" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/5bf/a70d31a153c428e5d5e79f037f0165bf.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="86c2624025961ef1b67172a72d848107" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/107/86c2624025961ef1b67172a72d848107.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/radfahren/700226,st-stephan--ruewlispass--gstaad--saanenmoeser--st-stephan/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="700226" src="https://vcdn.bergfex.at/images/resized/4f/0e6f93c17d867e4f_c1bc6b9f247deb17@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/radfahren/700226,st-stephan--ruewlispass--gstaad--saanenmoeser--st-stephan/" title="St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan">St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Cycling
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 38.14<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:50</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 1,055<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 934 - 1,724<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="919452c86a22554672db285b53f98ed2" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ed2/919452c86a22554672db285b53f98ed2.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="8549a8f400887bb87c0a88646176c9c9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/9c9/8549a8f400887bb87c0a88646176c9c9.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="0561cc12a0e6bad5f10cf10b1fd75c00" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c00/0561cc12a0e6bad5f10cf10b1fd75c00.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="4b7084b7d21181e129f7a9c753fcc7b9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7b9/4b7084b7d21181e129f7a9c753fcc7b9.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/themenweg/108674,holz-skulpturenweg--frutigen/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="108674" src="https://vcdn.bergfex.at/images/resized/59/f4f831bcf5ce6959_fa2551107925693f@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/themenweg/108674,holz-skulpturenweg--frutigen/" title="Holz-Skulpturenweg - Frutigen">Holz-Skulpturenweg - Frutigen</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 9.56<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>02:45</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 134<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 779 - 913<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="189e5cfd81f6947c350ad868ffa1dc82" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c82/189e5cfd81f6947c350ad868ffa1dc82.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="99c5d31d8e7d9eeda477d6cf062c5ef3" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ef3/99c5d31d8e7d9eeda477d6cf062c5ef3.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="cb8cf20183df84cdaee3df8a5f3efbe7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/be7/cb8cf20183df84cdaee3df8a5f3efbe7.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="3c8af39949e1117898d99d4473308ad9" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ad9/3c8af39949e1117898d99d4473308ad9.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/themenweg/295433,diemtigtaler-hausweg-mittleres-tal/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="295433" src="https://vcdn.bergfex.at/images/resized/85/40ead7011d722e85_5a82d86240c324ce@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/themenweg/295433,diemtigtaler-hausweg-mittleres-tal/" title="Diemtigtaler Hausweg «Mittleres Tal»">Diemtigtaler Hausweg «Mittleres Tal»</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 10.2<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>03:15</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 434<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 814 - 1,128<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="7ddcf296ce9de48e981ddcafd78c8238" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/238/7ddcf296ce9de48e981ddcafd78c8238.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="95fd65948c1651fc8acfe27477cd2c7d" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c7d/95fd65948c1651fc8acfe27477cd2c7d.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="f48283d2e801d036df90e06e990aaae5" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/ae5/f48283d2e801d036df90e06e990aaae5.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="49d996e736eac6736015ed7116034f4a" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f4a/49d996e736eac6736015ed7116034f4a.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/radfahren/172139,moraenensee-route/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="172139" src="https://vcdn.bergfex.at/images/resized/b7/d72b02757c14b2b7_cd0a3ce1146ae894@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/radfahren/172139,moraenensee-route/" title="Moränensee Route">Moränensee Route</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Cycling
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 25.49<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>01:40</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 197<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 553 - 750<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="9ea606c8c82bbd9f28c9ee6ffac2366e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/66e/9ea606c8c82bbd9f28c9ee6ffac2366e.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="689c2e8bdc609f7f83d981c043c14f65" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f65/689c2e8bdc609f7f83d981c043c14f65.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="7bba0d70a0824d2a80eb6f7e434c5152" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/152/7bba0d70a0824d2a80eb6f7e434c5152.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/99639,probsteberg--einsames-grenzgebiet-bern-solothurn/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="99639" src="https://vcdn.bergfex.at/images/resized/e8/f5aa1c00dcb748e8_00900eddd5bcbc18@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/99639,probsteberg--einsames-grenzgebiet-bern-solothurn/" title="Probsteberg - einsames Grenzgebiet Bern/Solothurn">Probsteberg - einsames Grenzgebiet Bern/Solothurn</a>
# <div>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 16.44<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>04:45</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 581<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 640 - 1,149<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="54600219282c1badb675b774fa3418c8" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/8c8/54600219282c1badb675b774fa3418c8.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="3f2f03ffc4b1c201f2c0cd87cadac7a7" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7a7/3f2f03ffc4b1c201f2c0cd87cadac7a7.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-0"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/509375,meraengge-cher-im-kemmribodenbad/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="509375" src="https://vcdn.bergfex.at/images/resized/9c/d81af72f0175ff9c_b45bbe258a52a58a@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/509375,meraengge-cher-im-kemmribodenbad/" title="Merängge-Cher im Kemmribodenbad">Merängge-Cher im Kemmribodenbad</a>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 6.97<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-time"></div>
# <strong>02:10</strong><span class="tour-stats-unit">h</span>
# </div>
# </div>
# <div class="tour-stats-right">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-up"></div>
# 330<span class="tour-stats-unit">hm</span>
# </div>
# <div class="tour-stats">
# <div class="tour-stats-icon tour-stats-icon-updown"></div>
# 975 - 1,184<span class="tour-stats-unit">m</span>
# </div>
# </div>
# </div>
# <div class="tour-photos">
# <img alt="" border="0" class="tour-photo" height="57" id="7e83b7446943e940e9b6769b2ec64302" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/302/7e83b7446943e940e9b6769b2ec64302.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/wanderung/348126,lauenen--lauenensee--lauenen/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="348126" src="https://vcdn.bergfex.at/images/resized/03/4bf20abb357fab03_7884e5b24c857254@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/wanderung/348126,lauenen--lauenensee--lauenen/" title="Lauenen – Lauenensee - Lauenen">Lauenen – Lauenensee - Lauenen</a>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="tour-stats-photos-container">
# <div class="tour-stats-container">
# <div class="tour-stats-left">
# <div class="tour-stats tour-stats-big">
# <div class="tour-stats-icon tour-stats-icon-length"></div>
# 8.99<span class="tour-stats-unit">km</span>
# </div>
# <div class="tour-stats">
# ...
# <img alt="" border="0" class="tour-photo" height="57" id="c5bbd4deb350dd72cc63e55470f7ef44" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/f44/c5bbd4deb350dd72cc63e55470f7ef44.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="dfaa9d4063f9739b06c4ca5daee53387" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/387/dfaa9d4063f9739b06c4ca5daee53387.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="1284ca7e22de9a17266cb222b3bd9c2e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c2e/1284ca7e22de9a17266cb222b3bd9c2e.jpg" width="57"/>
# <img alt="" border="0" class="tour-photo" height="57" id="53e6b0b6cad7334c7e1072a544193c0e" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/c0e/53e6b0b6cad7334c7e1072a544193c0e.jpg" width="57"/>
# </div>
# </div>
# <div class="tour-ratings">
# <div class="tour-rating">
# <div class="tour-rating-label">Technique</div>
# <div class="rating-circles rating-max6"><div class="rating-1"></div></div>
# </div>
# <div class="tour-rating">
# <div class="tour-rating-label">Fitness</div>
# <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section">
# <link href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" rel="first"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" rel="prev"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=23" rel="last"/><link href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" rel="next"/>
# <div class="pager">
# <div class="label">Pages:</div><a class="navigation pager-previous" href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" title="">previous<span class="pagerCaret"></span></a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=1" title="">1</a>
# <div class="page-selected">2</div>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" title="">3</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=4" title="">4</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=5" title="">5</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=6" title="">6</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=7" title="">7</a>
# <a class="page" href="/sommer/bern-region/touren/?isAjax=1&amp;page=8" title="">8</a>
# <a class="navigation pager-next" href="/sommer/bern-region/touren/?isAjax=1&amp;page=3" title="">
# next<span class="pagerCaret"></span>
# </a>
# </div>
# </div>
# </div>
# <div class="section-right">
# <div class="listbox box-container mobile-collapsed">
# <div class="box-header">Tours by type</div>
# <div class="box-content grid cols2">
# <div class="col">
# <ul>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/wandern/">Hiking</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/bike/">Bike</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/laufen/">Running</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/alpin/">Alpine</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/winter/">Winter</a>
# </li>
# <li class="hastotals">
# <a href="/sommer/bern-region/touren/wasser/">Water</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="contentbox box-container">
# <div class="box-header">
# <span class="less-important">bergfex</span> Bergungskosten-Versicherung
# </div>
# <div class="box-content">
# <p>Noch schnell für den anstehenden Ausflug versichern? Inkl. Rettungshubschrauber <span class="important nowrap">ab 3,98 €</span>
# </p><a class="link-important button-green" href="/redirect/69bce4/131/0/https%3A%2F%2Fergo-versicherung.at%2Fbergfex-bergung%2F%3Futm_source%3Dbergfex%26utm_medium%3DLink%26utm_campaign%3Dbergfex-bergung%26aid%3DD146" target="_blank">
# Jetzt Informieren
# </a>
# </div>
# </div>
# <div class="listbox box-container mobile-collapsed">
# <div class="box-header">
# Countries
# </div>
# <div class="box-content grid cols2">
# <div class="col">
# <ul>
# <li><a href="/sommer/oesterreich/touren/">Austria</a></li>
# <li class="selected"><a href="/sommer/schweiz/touren/">Switzerland</a></li>
# <li><a href="/sommer/deutschland/touren/">Germany</a></li>
# <li><a href="/sommer/italien/touren/">Italy</a></li>
# <li><a href="/sommer/slovenia/touren/">Slovenia</a></li>
# <li><a href="/sommer/frankreich/touren/">France</a></li>
# <li><a href="/sommer/nederland/touren/">Netherlands</a></li>
# <li><a href="/sommer/belgie/touren/">Belgium</a></li>
# <li><a href="/sommer/czechia/touren/">Czechia</a></li>
# <li><a href="/sommer/slovakia/touren/">Slovakia</a></li>
# <li><a href="/sommer/spanien/touren/">Spain</a></li>
# <li><a href="/sommer/kroatien/touren/">Croatia</a></li>
# <li><a href="/sommer/luxemburg/touren/">Luxembourg</a></li>
# <li><a href="/sommer/liechtenstein/touren/">Liechtenstein</a></li>
# </ul>
# </div>
# <div class="col">
# <ul>
# <li><a href="/sommer/graubuenden/touren/">Graubünden</a></li>
# <li><a href="/sommer/wallis/touren/">Valais</a></li>
# <li><a href="/sommer/berneroberland/touren/">Bernese Oberland</a></li>
# <li><a href="/sommer/luzern-vierwaldstaettersee/touren/">Central Switzerland</a></li>
# <li><a href="/sommer/ostschweiz/touren/">Eastern Switzerland</a></li>
# <li><a href="/sommer/zuerich/touren/">Zurich region</a></li>
# <li><a href="/sommer/aargau/touren/">Aargau</a></li>
# <li><a href="/sommer/jura-drei-seen-land/touren/">Jura</a></li>
# <li><a href="/sommer/tessin/touren/">Ticino</a></li>
# <li><a href="/sommer/freiburg-region/touren/">Fribourg</a></li>
# <li><a href="/sommer/genferseegebiet-waadtland/touren/">Vaud / Lake Geneva Region</a></li>
# <li class="selected"><a href="/sommer/bern-region/touren/">Swiss plateau</a></li>
# <li><a href="/sommer/basel-region/touren/">Aargau-Basle</a></li>
# <li><a href="/sommer/genf-region/touren/">Geneva</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="section">
# <h3>Popular tours in the area</h3>
# <script>
#                 var oaTrackingDetail = null;
#                 var oaTrackingTeaser = [];
#
#                 if(typeof trackOutdooractiveActivities === "undefined") {
#                     function trackOutdooractiveActivities() {
#                         if (oaTrackingDetail !== null) {
#                             $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackDetail(oaTrackingDetail);
#                         }
#                         if (oaTrackingTeaser.length > 0) {
#                             _.forEach(oaTrackingTeaser, function(teaserId) {
#                                 $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackTeaser(teaserId);
#                             });
#                         }
#                     }
#                 }
#
#                 if(typeof outdooractiveTrackingIframeLoaded === "undefined") {
#                     function outdooractiveTrackingIframeLoaded() {
#                         trackOutdooractiveActivities();
#                     }
#                 }
#
#                 $(document).ready(function() {
#                     var $iframe = $("#outdooractive_tracking_iframe");
#
#                     if($iframe.length === 0) {
#                         $("body").append("<iframe id='outdooractive_tracking_iframe' src='//www.bergfex.com/ajax/outdooractive/tracking.php'></iframe>");
#                     } else {
#                         trackOutdooractiveActivities();
#                     }
#                 });
#             </script>
# <script>oaTrackingTeaser.push('15655063');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1216109" height="200" src="https://vcdn.bergfex.at/images/resized/fb/88ab53a017f741fb_e5f641d58b13d34e@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86144,waldhaeusern--beliebtes-ausflugsziel-im-emmental/" title="„Signau…in allen Jahreszeiten schön“. Mit diesem Motto werden die Besucher der Gemeinde-Homepage...">
# Waldhäusern - ...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>9.63</strong>km | <strong>373</strong>hm | <strong>03:00</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86144" src="https://vcdn.bergfex.at/images/resized/c0/763597cd262eb0c0_8638de0c909f0598@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('17346892');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1149454" height="200" src="https://vcdn.bergfex.at/images/resized/dd/2378e3c744ce8fdd_0b7155a0cb1d6e86@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/themenweg/78168,baenkli-rundweg-aeschi-bei-spiez/" title="&lt;p&gt;Sie laden zum Ausruhen ein. Oft empfangen sie Wandererinnen und Spaziergänger, manchmal nur...">
# Bänkli-Rundweg...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Thematic route
# </span>
# </div>
# <div class="smaller">
# <strong>7.38</strong>km | <strong>255</strong>hm | <strong>02:13</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="78168" src="https://vcdn.bergfex.at/images/resized/f9/9dc49d1e748a4bf9_876815c39274c206@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('15655869');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1215216" height="200" src="https://vcdn.bergfex.at/images/resized/c9/5c1c0d0fdafa3ac9_cff36ffac8048b95@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86037,auf-dem-beatenberg-der-sonnenterrasse-des-berner-oberlandes/" title="Auf dieser Wanderung erlebt und geniesst man die Schönheit des Dreigestirnes Eiger Mönch und...">
# Auf dem Beatenb...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.74</strong>km | <strong>752</strong>hm | <strong>04:10</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86037" src="https://vcdn.bergfex.at/images/resized/ff/d89b53e14797e2ff_4f7456e6cd041215@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('8483704');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="752976" height="200" src="https://vcdn.bergfex.at/images/resized/2a/6a97642fd5aebb2a_df99cc7fae3f8d32@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/51212,zu-eiszeitlichen-riesen-und-zur-wohnstaette-steinzeitlicher-menschen/" title="Abwechslungsreiche Wanderung durch Wälder, weite Matten und über aussichtsreiche Höhen zum...">
# Zu eiszeitliche...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.5</strong>km | <strong>254</strong>hm | <strong>02:40</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="51212" src="https://vcdn.bergfex.at/images/resized/6c/5d461db57398d66c_f4c1dd3fc9c64149@2x.jpg" width="240"/>
# </div>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </main>
# <div id="sidebar">
# <div class="adzone_skyscraper partner" data-geo="sommer.schweiz.bern-region" data-tags="" data-zoneid="2" id="adzone_skyscraper"></div>
# </div>
# <!--/page-bottom-->
# </div>
# <div class="clearer"></div>
# <div id="mapsearch-template-h2noresult">
# <h2>Keine Einträge gefunden.</h2>
# </div>
# <div id="mapsearch-template-h2overflow">
# <h2>Es wurden %count% Einträge gefunden. Bitte Suche verfeinern.</h2>
# </div>
# <div id="mapsearch-template-h2local">
# <h2>Lokale Suchergebnisse <span class="less-important">(Distance &lt;= 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2nonlocal">
# <h2>More results <span class="less-important">(Distance &gt; 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2all">
# <h2>All %count% Search results</h2>
# </div>
# <div id="mapsearch-template-line">
# <div class="mapsearch-line">
# <div><a class="name" href="">%name%</a> <span class="region">%region%</span></div>
# <div><span class="type">%type%</span> <span class="elevation">%elevation%</span></div>
# </div>
# </div><footer id="footer">
# <div class="footer-container page-left-margin">
# <div class="footer-location">
# / <a href="/sommer/schweiz/">Summer Switzerland</a> /
# <a href="/sommer/bern-region/">Swiss plateau</a> /
# <strong>Tours</strong>
# </div>
# <ul class="nav-list">
# <li class="has-children collapsed language-select">
# <h2 class="no-select" style="overflow: visible"><span class="mobile-only">Language</span> <span class="flag en"></span> english</h2>
# <ul>
# <li><a href="//www.bergfex.ch/sommer/bern-region/touren/" rel='"nofollow"'>
# <span class="flag de"></span> Deutsch</a></li>
# <li><a href="//www.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag en"></span> English</a></li>
# <li><a href="//www.bergfex.fr/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fr"></span> Français</a></li>
# <li><a href="//it.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag it"></span> Italiano</a></li>
# <li><a href="//www.bergfex.es/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag es"></span> Español</a></li>
# <li><a href="//nl.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag nl"></span> Nederlands</a></li>
# <li><a href="//se.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag se"></span> Svenska</a></li>
# <li><a href="//no.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag no"></span> Norsk</a></li>
# <li><a href="//dk.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag dk"></span> Dansk</a></li>
# <li><a href="//fi.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fi"></span> Suomi</a></li>
# <li><a href="//hu.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hu"></span> Magyar</a></li>
# <li><a href="//www.bergfex.cz/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag cz"></span> český</a></li>
# <li><a href="//www.bergfex.sk/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag sk"></span> Slovensky</a></li>
# <li><a href="//www.bergfex.pl/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag pl"></span> Polski</a></li>
# <li><a href="//hr.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hr"></span> Hrvatski</a></li>
# <li><a href="//www.bergfex.si/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag si"></span> Slovenščina</a></li>
# <li><a href="//ru.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ru"></span> русский</a></li>
# <li><a href="//ro.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ro"></span> Român</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>Themen</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li><a href="/sommer/schweiz/">Summer regions</a></li>
# <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>General</h2>
# <ul>
# <li><a href="/newsletter/">Newsletter</a></li>
# <li><a href="/produkte/">Products</a></li>
# <li><a href="/shop/">Shop</a></li>
# <li><a href="/login/">Login</a></li>
# </ul>
# </li>
# </ul>
# <div id="language-select-overlay"></div>
# <div class="copyright-container">
# <!-- background image -->
# <div class="copyright">Copyright © 1999, 2021 bergfex GmbH. All rights reserved.</div>
# <div class="copyright-links">
# <a href="/datenschutz/">Privacy policy</a> |
# <a href="/impressum/">About us</a> |
# <a href="" id="privacy-manager">Privacy Manager</a>
# </div>
# </div>
# </div>
# </footer></body>
# </html>

# %% [markdown]
# ##  1.6 Combine all in scraping function

# %% [markdown]
# To be able to repeat the same steps for a different region (for example "Wallis"), we put the scraping code into a function. Here we can choose the region, how many pages we want to scrape and whether we want to save the file as CSV.

# %%
def scraping_region(region, n_pages):
    title = []  # Title of the tour
    difficulty = []  # difficulty (easy, medium, hard)
    sport = []  # Sport type (hiking, sledging, snowshoe...)
    length = []  # length in km
    time_list = []  # tour time in hours:minutes
    climb = []  # positive elevation climb in m
    minmax = []  # minimum and maximum altitude of the tour in m
    total_title = [] # will help extracting the ID of the tour
    # all ratings are stored together so we will need this along the way:
    rating = []  # list to store technique and fitness rating info
    
    # looping over the x first pages of Bergfex
    # each separate tour on the page is framed by a div tag with 'touren-details'
    page_number = n_pages  # number of pages we want to scap through

    for p in range(1, (page_number+1)):
        base_link = f'https://www.bergfex.com/sommer/{region}/touren/?isAjax=1&page='
        link = base_link+str(p)  # going over p pages with numbers appended to the base link
        page = requests.get(link, timeout=5)
        print("scraped page", p)
        soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
        tours = soup.findAll('div', {'class': 'touren-detail'})  # checks for the separate tours on the page

    # For each page, we loop over each tour and fill our lists with info     
        for i in range(0,len(tours)):
            tour_1 = tours[i] # tour iterating over the 20 tours of the page

            tour_title = tour_1.findAll('a' ) # this gets the title out
            title.append([info.get_text().strip() for info in tour_title])
            total_title.append(tour_title) 
            # this gets the full tour-title information including the ID, processed further later on

            tour_diff = tour_1.findAll('span', {'class': 'tour-difficulty'}) #tour level difficulty
            difficulty.append([info.get_text().strip() for info in tour_diff])

            tour_type = tour_1.findAll('span', {'class': 'tour-type'}) # putting type into sports
            sport.append([info.get_text().strip() for info in tour_type])

            tour_stats = tour_1.findAll('div', {'class': 'tour-stats'}) # stats has 4 info binned together
            stat_text = [info.get_text().strip() for info in tour_stats]
            length.append(stat_text[0])
            time_list.append(stat_text[1])
            climb.append(stat_text[2])
            minmax.append(stat_text[3])

            tour_rating = tour_1.find_all("div", {'class': 'tour-rating'}) # getting the rating data 
            rating.append([info for info in tour_rating])   # it's a class name so we can't get_text.
    print("number of tours collected:", len(title))
    return (title, difficulty, sport, length, time_list, climb, minmax, total_title, rating)

# %%
def extracting_id(total_title):
    links_title = []
    for i in total_title:
        i = str(i)
        i = i.strip('[]')
        links_title.append(i)
    # Extracting ID
    id_df3 = pd.DataFrame(links_title)
    id_df2 = id_df3[0].str.split(' ',expand = True)
    id_df1 = id_df2[2].str.split(',',expand = True)
    id_df = id_df1[0].str.split('/',expand = True)
    
    return id_df

# %%
def extracting_rating(rating):
    technique = []  # technique difficulty ratings (out of 6)
    fitness = []  # fitness difficulty ratings (out of 6)
    # Replace unwanted information
    tour_rating_str = str(rating)
    rating_all_short = tour_rating_str.replace(
    '<div class="tour-rating">\n<div class="tour-rating-label">Technique</div>\n<div class="rating-circles rating-max6"><div class="',''
    ).replace(
        '<div class="tour-rating">\n<div class="tour-rating-label">Fitness</div>\n<div class="rating-circles rating-max6"><div class="','').replace('"></div></div>\n</div>',"")
    rating_even_shorter = rating_all_short.replace('[','').replace(']','')
    rating_list = rating_even_shorter.split(", ")

    for i in range(0,(len(rating_list))):
        if i == 0:
            technique.append(rating_list[i]) # add first item in technique
        elif i % 2 == 0:
            technique.append(rating_list[i]) # then every second item as well
        else:
            fitness.append(rating_list[i]) # the other appended to fitness list
    return technique, fitness

# %%
def create_scraped_df(region, n_pages, save_as_csv = True):
    title, difficulty, sport, length, time_list, climb, minmax, total_title, rating = scraping_region(
        region, n_pages)
    id_df = extracting_id(total_title)
    technique, fitness = extracting_rating(rating)
    activities_df_unclean = pd.DataFrame(
    {'title': title,
     'difficulty': difficulty,
     'sport': sport,
     'length': length,
     'time': time_list,
     'climb': climb,
     'minmax': minmax,
     'technique': technique,
     'fitness': fitness
    })
    activities_df_unclean['ID']= id_df.iloc[:,5].copy() # add the ID columns from an earlier DF
    
    if save_as_csv == True:
        activities_df_unclean.to_csv(f"../data/unclean_activities_{region}.csv", index=False)
        
    return activities_df_unclean

# %% [markdown]
# Let's test it with different regions

# %%
region2 = "wallis"
n_pages2 = 20
#create_scraped_df(region2, n_pages2, save_as_csv = True)
#create_scraped_df('bern-region', n_pages2, save_as_csv = True)

# %% [markdown]
# # 2  Data Cleaning
#
# As mentioned above, the dataframe still needs to be cleaned up.

# %% [markdown]
# ## 2.0 Read in the "uncleaned" DF

# %%
activities_df_raw = pd.read_csv(f"../data/unclean_activities.csv")
activities_df = activities_df_raw.copy()
activities_df.head()
# Out:
#                                                     title  difficulty  \
# 0                                   ['Biel/Bienne - Ins']    ['easy']
# 1                       ['Gehrihorn (Frutigen) Biketour']  ['medium']
# 2  ['Nervenkitzel und viel Abwechslung für Jung und Alt']    ['easy']
# 3                              ['Adelboden - Hahnenmoos']  ['medium']
# 4                        ['Der Ringweg am kleinen Rugen']    ['easy']
#
#                        sport   length    time    climb          minmax  \
# 0  ['Long distance cycling']  31.43km  02:09h     29hm      430 - 460m
# 1           ['Mountainbike']  36.46km  04:00h  1,056hm    762 - 1,429m
# 2                 ['Hiking']   3.63km  01:10h    170hm      772 - 889m
# 3                 ['Hiking']   8.16km  02:30h    670hm  1,295 - 1,950m
# 4         ['Thematic route']   3.35km  00:58h     84hm      572 - 655m
#
#   technique   fitness      ID
# 0  rating-1  rating-1  177067
# 1   rating-  rating-4  698710
# 2  rating-2  rating-2   51815
# 3  rating-2  rating-3  133081
# 4  rating-1  rating-2  296938

# %% [markdown]
# ## 2.1 Check for duplicates and remove them

# %%
# check if there are duplicates
dups = activities_df.duplicated(subset=['ID'])
dups
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
# Which trails are duplicates?
pd.concat(g for _, g in activities_df.groupby('ID') if len(g) > 1)
# Out:
#                                                                   title  \
# 12  ['Höhenweg Entlebuch Emmental - Etappe 5: Grosshorben – Schangnau']
# 31  ['Höhenweg Entlebuch Emmental - Etappe 5: Grosshorben – Schangnau']
# 13                                          ['Kandersteg to Allmenalp']
# 33                                          ['Kandersteg to Allmenalp']
# 17                             ['Diemtigtaler Hausweg «Mittleres Tal»']
# 23                             ['Diemtigtaler Hausweg «Mittleres Tal»']
#
#     difficulty               sport  length    time  climb          minmax  \
# 12          []          ['Hiking']  5.16km  01:45h  196hm    928 - 1,415m
# 31          []          ['Hiking']  5.16km  01:45h  196hm    928 - 1,415m
# 13  ['medium']          ['Hiking']  8.38km  04:00h  620hm  1,170 - 1,789m
# 33  ['medium']          ['Hiking']  8.38km  04:00h  620hm  1,170 - 1,789m
# 17    ['easy']  ['Thematic route']  10.2km  03:15h  434hm    814 - 1,128m
# 23    ['easy']  ['Thematic route']  10.2km  03:15h  434hm    814 - 1,128m
#
#    technique   fitness      ID
# 12   rating-  rating-0  162712
# 31   rating-  rating-0  162712
# 13  rating-1  rating-3  277646
# 33  rating-1  rating-3  277646
# 17  rating-1  rating-2  295433
# 23  rating-1  rating-2  295433

# %%
# Remove duplicates
activities_df.drop_duplicates(subset ="ID", inplace = True)
activities_df
# Out:
#                                                                                                 title  \
# 0                                                                               ['Biel/Bienne - Ins']
# 1                                                                   ['Gehrihorn (Frutigen) Biketour']
# 2                                              ['Nervenkitzel und viel Abwechslung für Jung und Alt']
# 3                                                                          ['Adelboden - Hahnenmoos']
# 4                                                                    ['Der Ringweg am kleinen Rugen']
# 5                                                                                   ['Golitschenalp']
# 6       ['Tour de Gastlosen: Saanen - Mittelbergpass - Abländschen - Jaunpass - Zweisimmen - Saanen']
# 7                                               ['Im Innereriz, abseits der grossen Touristenströme']
# 8                                                                         ['Panoramatrail Faltschen']
# 9                                                                                ['Rund um Rüschegg']
# 10                                                                            ['Rund um den Moossee']
# 11                                                                          ['Albert Schweitzer Weg']
# 12                                ['Höhenweg Entlebuch Emmental - Etappe 5: Grosshorben – Schangnau']
# 13                                                                        ['Kandersteg to Allmenalp']
# 14                                                                          ['E-Bike Elsigen-Metsch']
# 15                                                              ['Rund ums Naturschutzgebiet Häftli']
# 16                                       ['Helsana Trail: Schönried - Saanenmöser - Schönried, grün']
# 17                                                           ['Diemtigtaler Hausweg «Mittleres Tal»']
# 18                                                      ['Zum Seebergsee: 100% Natur – 0% Hartbelag']
# 19    ['Von Alpiglen via Eigertrail, Klettersteig Rotstock und Eigergletscher nach Kleine Scheidegg']
# 20                                                                       ['Zur Hohwacht im Emmental']
# 21                                  ['St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan']
# 22                                                                  ['Holz-Skulpturenweg - Frutigen']
# 24                                                                               ['Moränensee Route']
# 25                                              ['Probsteberg - einsames Grenzgebiet Bern/Solothurn']
# 26                                                                ['Merängge-Cher im Kemmribodenbad']
# 27                                                                 ['Lauenen – Lauenensee - Lauenen']
# 28                                                       ['Gletscherschlucht - Pfingstegg - Rundweg']
# 29                                                          ['Adelboden - Cholerenschlucht - retour']
# 30  ['Helsana Trail: Schönried - Bergmatte - Grossi Vorschess - Rellerli - Ritmal - Schönried, gelb']
# 32                                                             ['Auf Panoramawegen durchs Bipperamt']
# 34                                                                                        ['Blausee']
# 35                                                            ['Hügelpanorama oberhalb Trubschachen']
# 36                                                  ['E-Bike Tour entlang der Diemtigtaler Hauswege']
# 37                                                  ['Schönried Ermitage Rellerli Panoramawanderung']
# 38                                                               ['Simmeflueh Klettersteig - Wimmis']
# 39                                                                     ['Schwingerweg Springenboden']
#
#        difficulty                      sport   length    time    climb  \
# 0        ['easy']  ['Long distance cycling']  31.43km  02:09h     29hm
# 1      ['medium']           ['Mountainbike']  36.46km  04:00h  1,056hm
# 2        ['easy']                 ['Hiking']   3.63km  01:10h    170hm
# 3      ['medium']                 ['Hiking']   8.16km  02:30h    670hm
# 4        ['easy']         ['Thematic route']   3.35km  00:58h     84hm
# 5   ['difficult']                 ['Hiking']   7.81km  05:37h    681hm
# 6   ['difficult']                 ['Racing']  62.14km  04:00h  1,658hm
# 7      ['medium']                 ['Hiking']    9.8km  03:30h    611hm
# 8      ['medium']           ['Mountainbike']  29.01km  02:30h    846hm
# 9      ['medium']                 ['Hiking']  13.32km  03:45h    490hm
# 10       ['easy']                 ['Hiking']   6.47km  01:40h     90hm
# 11       ['easy']         ['Thematic route']   4.81km  01:45h    121hm
# 12             []                 ['Hiking']   5.16km  01:45h    196hm
# 13     ['medium']                 ['Hiking']   8.38km  04:00h    620hm
# 14     ['medium']                ['Cycling']  24.82km  03:20h  1,000hm
# 15     ['medium']                 ['Hiking']  13.88km  03:30h    106hm
# 16     ['medium']           ['Trailrunning']   6.33km  01:15h    119hm
# 17       ['easy']         ['Thematic route']   10.2km  03:15h    434hm
# 18     ['medium']                 ['Hiking']  10.33km  03:20h    415hm
# 19     ['medium']            ['Via ferrata']   10.3km  05:00h  1,115hm
# 20     ['medium']                 ['Hiking']  11.37km  03:20h    423hm
# 21     ['medium']                ['Cycling']  38.14km  03:50h  1,055hm
# 22     ['medium']         ['Thematic route']   9.56km  02:45h    134hm
# 24       ['easy']                ['Cycling']  25.49km  01:40h    197hm
# 25             []                 ['Hiking']  16.44km  04:45h    581hm
# 26       ['easy']                 ['Hiking']   6.97km  02:10h    330hm
# 27     ['medium']                 ['Hiking']   8.99km  02:30h    178hm
# 28     ['medium']                 ['Hiking']   5.85km  02:39h    464hm
# 29       ['easy']                 ['Hiking']   7.72km  01:30h    286hm
# 30     ['medium']           ['Trailrunning']   9.51km  02:00h    593hm
# 32     ['medium']                 ['Hiking']  16.53km  05:15h    862hm
# 34       ['easy']                 ['Hiking']  11.53km  03:20h    315hm
# 35     ['medium']                 ['Hiking']   3.71km  01:35h    290hm
# 36     ['medium']                ['Cycling']  43.09km  03:00h  1,103hm
# 37     ['medium']                 ['Hiking']  11.33km  04:00h    645hm
# 38       ['easy']            ['Via ferrata']   2.09km  03:00h    767hm
# 39       ['easy']         ['Thematic route']   2.49km  01:30h    120hm
#
#             minmax technique   fitness      ID
# 0       430 - 460m  rating-1  rating-1  177067
# 1     762 - 1,429m   rating-  rating-4  698710
# 2       772 - 889m  rating-2  rating-2   51815
# 3   1,295 - 1,950m  rating-2  rating-3  133081
# 4       572 - 655m  rating-1  rating-2  296938
# 5   1,170 - 1,834m  rating-5  rating-5  709665
# 6     824 - 1,634m  rating-2  rating-5  131669
# 7   1,042 - 1,574m  rating-3  rating-3  100448
# 8     692 - 1,223m  rating-2  rating-3  172154
# 9       715 - 941m  rating-2  rating-3   65384
# 10      521 - 571m  rating-2  rating-2  276223
# 11  1,163 - 1,284m  rating-1  rating-2  292891
# 12    928 - 1,415m   rating-  rating-0  162712
# 13  1,170 - 1,789m  rating-1  rating-3  277646
# 14  1,196 - 1,814m  rating-4  rating-3  836971
# 15      426 - 445m  rating-2  rating-3   51188
# 16  1,229 - 1,348m  rating-2  rating-3  211600
# 17    814 - 1,128m  rating-1  rating-2  295433
# 18  1,760 - 1,980m  rating-3  rating-3  100447
# 19  1,615 - 2,662m  rating-3  rating-2  752896
# 20    669 - 1,074m  rating-2  rating-3  114256
# 21    934 - 1,724m  rating-2  rating-4  700226
# 22      779 - 913m  rating-3  rating-2  108674
# 24      553 - 750m  rating-1  rating-1  172139
# 25    640 - 1,149m   rating-  rating-0   99639
# 26    975 - 1,184m  rating-2  rating-2  509375
# 27  1,236 - 1,409m  rating-3  rating-3  348126
# 28  1,013 - 1,411m  rating-3  rating-4  612482
# 29  1,145 - 1,360m  rating-1  rating-2  133083
# 30  1,239 - 1,832m  rating-4  rating-4  211604
# 32    636 - 1,215m  rating-3  rating-4   51213
# 34    888 - 1,186m  rating-1  rating-1  744917
# 35      731 - 996m  rating-2  rating-3   56959
# 36    669 - 1,270m   rating-  rating-3  823060
# 37  1,222 - 1,861m  rating-2  rating-4  595654
# 38    626 - 1,393m   rating-  rating-0  114228
# 39  1,285 - 1,392m  rating-1  rating-2  289903

# %% [markdown]
# ## 2.2 Clean Categorical Data
# - Convert columns to strings
# - Remove brackets that are in the first 3 columnns
# - Remove extra whitespace

# %%
# Converting the text columns to strings for easier handling later
activities_df[['title', 'difficulty', 'sport']] = activities_df[['title', 'difficulty', 'sport']].astype('str')

# Removing the brackets
activities_df['title'] = activities_df['title'].str.strip('[]')
activities_df['difficulty'] = activities_df['difficulty'].str.strip('[]')
activities_df['sport'] = activities_df['sport'].str.strip('[]')

# Remove extra whitespace
activities_df['title'] = pd.Series(activities_df['title']).str.replace("'", '')
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("'", '')
activities_df['sport'] = pd.Series(activities_df['sport']).str.replace("'", '')

# Remove units (km, m, h, hm, m)
activities_df['length'] = pd.Series(activities_df['length']).str.replace("km", '')
activities_df['time'] = pd.Series(activities_df['time']).str.replace("h", '')
activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("hm", '')
activities_df['minmax'] = pd.Series(activities_df['minmax']).str.replace("m", '')

# Seperate the minmax altitude into a min column and a max column
activities_df[['min','max']] = activities_df['minmax'].str.split("-",expand=True)
activities_df = activities_df.drop(columns=['minmax'])

# Organize the dataframe columns
activities_df = activities_df[['ID','title', 'difficulty', 'sport', 'length', 
                               'time', 'climb', 'min', 'max', 'technique', 'fitness']]

# Remove remaining commas to avoid issues with reading CSV file in Tableau
activities_df['title'] = pd.Series(activities_df['title']).str.replace(",", '-')

# Add ordering of the difficulty
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("easy", '1 - easy')
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("medium", '2 - medium')
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("difficult", '3 - difficult')
activities_df['difficulty'].replace(r'^\s*$', '0 - no rating', regex=True, inplace=True)

# %%
activities_df.head(5)
# Out:
#        ID                                               title  difficulty  \
# 0  177067                                   Biel/Bienne - Ins    1 - easy
# 1  698710                       Gehrihorn (Frutigen) Biketour  2 - medium
# 2   51815  Nervenkitzel und viel Abwechslung für Jung und Alt    1 - easy
# 3  133081                              Adelboden - Hahnenmoos  2 - medium
# 4  296938                        Der Ringweg am kleinen Rugen    1 - easy
#
#                    sport length   time  climb     min     max technique  \
# 0  Long distance cycling  31.43  02:09     29    430      460  rating-1
# 1           Mountainbike  36.46  04:00  1,056    762    1,429   rating-
# 2                 Hiking   3.63  01:10    170    772      889  rating-2
# 3                 Hiking   8.16  02:30    670  1,295    1,950  rating-2
# 4         Thematic route   3.35  00:58     84    572      655  rating-1
#
#     fitness
# 0  rating-1
# 1  rating-4
# 2  rating-2
# 3  rating-3
# 4  rating-2

# %% [markdown]
# ## 2.3 Clean Numerical Data
#
# In order to normalize numerical data for analysis, we must preform the following steps:
#
# -  Replace missing numerical data with 0
# -  Remove commas
# -  Remove "-"
# -  Remove unnecessary words ("rating-")

# %%
activities_df['length'] = pd.Series(activities_df['length']).str.replace("-",'0')
activities_df['length'] = (activities_df['length']).astype(float)

activities_df['climb'] = pd.Series(activities_df['climb']).str.replace(",", '') 
activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("-", '0') 
activities_df['climb'] = (activities_df['climb']).astype(int)

activities_df['min'] = pd.Series(activities_df['min']).str.replace(",", '')
activities_df['min'].replace('',np.nan, inplace = True)
activities_df['min'] = activities_df['min'].fillna(0)
activities_df['min'] = (activities_df['min']).astype(int)
activities_df['max'].replace('',np.nan, inplace = True)
activities_df['max'] = activities_df['max'].fillna(0)
activities_df['max'] = pd.Series(activities_df['max']).str.replace(",", '') 

activities_df['max'] = (activities_df['max']).astype(int)

activities_df['technique'] = pd.Series(activities_df['technique']).str.replace("rating-", '')
activities_df['technique'] = pd.to_numeric(activities_df['technique'], errors='coerce')
activities_df['technique'] = pd.Series(activities_df['technique']).replace(np.nan, 0, regex = True)
activities_df['technique'] = pd.Series(activities_df['technique']).astype('int')

activities_df['fitness'] = pd.Series(activities_df['fitness']).str.replace("rating-", '')
activities_df['fitness'] = pd.to_numeric(activities_df['fitness'], errors='coerce')
activities_df['fitness'] = pd.Series(activities_df['fitness']).replace(np.nan, 0, regex = True)
activities_df['fitness'] = activities_df['fitness'].astype('int')

# %% [markdown]
# ## 2.4 Final check of DataFrame
# Double check for null values. It looks pretty good!  Now it's time to start analysis.

# %%
activities_df
# Out:
#         ID  \
# 0   177067
# 1   698710
# 2    51815
# 3   133081
# 4   296938
# 5   709665
# 6   131669
# 7   100448
# 8   172154
# 9    65384
# 10  276223
# 11  292891
# 12  162712
# 13  277646
# 14  836971
# 15   51188
# 16  211600
# 17  295433
# 18  100447
# 19  752896
# 20  114256
# 21  700226
# 22  108674
# 24  172139
# 25   99639
# 26  509375
# 27  348126
# 28  612482
# 29  133083
# 30  211604
# 32   51213
# 34  744917
# 35   56959
# 36  823060
# 37  595654
# 38  114228
# 39  289903
#
#                                                                                             title  \
# 0                                                                               Biel/Bienne - Ins
# 1                                                                   Gehrihorn (Frutigen) Biketour
# 2                                              Nervenkitzel und viel Abwechslung für Jung und Alt
# 3                                                                          Adelboden - Hahnenmoos
# 4                                                                    Der Ringweg am kleinen Rugen
# 5                                                                                   Golitschenalp
# 6       Tour de Gastlosen: Saanen - Mittelbergpass - Abländschen - Jaunpass - Zweisimmen - Saanen
# 7                                               Im Innereriz- abseits der grossen Touristenströme
# 8                                                                         Panoramatrail Faltschen
# 9                                                                                Rund um Rüschegg
# 10                                                                            Rund um den Moossee
# 11                                                                          Albert Schweitzer Weg
# 12                                Höhenweg Entlebuch Emmental - Etappe 5: Grosshorben – Schangnau
# 13                                                                        Kandersteg to Allmenalp
# 14                                                                          E-Bike Elsigen-Metsch
# 15                                                              Rund ums Naturschutzgebiet Häftli
# 16                                       Helsana Trail: Schönried - Saanenmöser - Schönried- grün
# 17                                                           Diemtigtaler Hausweg «Mittleres Tal»
# 18                                                      Zum Seebergsee: 100% Natur – 0% Hartbelag
# 19    Von Alpiglen via Eigertrail- Klettersteig Rotstock und Eigergletscher nach Kleine Scheidegg
# 20                                                                       Zur Hohwacht im Emmental
# 21                                  St. Stephan - Rüwlispass - Gstaad - Saanenmöser - St. Stephan
# 22                                                                  Holz-Skulpturenweg - Frutigen
# 24                                                                               Moränensee Route
# 25                                              Probsteberg - einsames Grenzgebiet Bern/Solothurn
# 26                                                                Merängge-Cher im Kemmribodenbad
# 27                                                                 Lauenen – Lauenensee - Lauenen
# 28                                                       Gletscherschlucht - Pfingstegg - Rundweg
# 29                                                          Adelboden - Cholerenschlucht - retour
# 30  Helsana Trail: Schönried - Bergmatte - Grossi Vorschess - Rellerli - Ritmal - Schönried- gelb
# 32                                                             Auf Panoramawegen durchs Bipperamt
# 34                                                                                        Blausee
# 35                                                            Hügelpanorama oberhalb Trubschachen
# 36                                                  E-Bike Tour entlang der Diemtigtaler Hauswege
# 37                                                  Schönried Ermitage Rellerli Panoramawanderung
# 38                                                               Simmeflueh Klettersteig - Wimmis
# 39                                                                     Schwingerweg Springenboden
#
#        difficulty                  sport  length   time  climb   min   max  \
# 0        1 - easy  Long distance cycling   31.43  02:09     29   430   460
# 1      2 - medium           Mountainbike   36.46  04:00   1056   762  1429
# 2        1 - easy                 Hiking    3.63  01:10    170   772   889
# 3      2 - medium                 Hiking    8.16  02:30    670  1295  1950
# 4        1 - easy         Thematic route    3.35  00:58     84   572   655
# 5   3 - difficult                 Hiking    7.81  05:37    681  1170  1834
# 6   3 - difficult                 Racing   62.14  04:00   1658   824  1634
# 7      2 - medium                 Hiking    9.80  03:30    611  1042  1574
# 8      2 - medium           Mountainbike   29.01  02:30    846   692  1223
# 9      2 - medium                 Hiking   13.32  03:45    490   715   941
# 10       1 - easy                 Hiking    6.47  01:40     90   521   571
# 11       1 - easy         Thematic route    4.81  01:45    121  1163  1284
# 12  0 - no rating                 Hiking    5.16  01:45    196   928  1415
# 13     2 - medium                 Hiking    8.38  04:00    620  1170  1789
# 14     2 - medium                Cycling   24.82  03:20   1000  1196  1814
# 15     2 - medium                 Hiking   13.88  03:30    106   426   445
# 16     2 - medium           Trailrunning    6.33  01:15    119  1229  1348
# 17       1 - easy         Thematic route   10.20  03:15    434   814  1128
# 18     2 - medium                 Hiking   10.33  03:20    415  1760  1980
# 19     2 - medium            Via ferrata   10.30  05:00   1115  1615  2662
# 20     2 - medium                 Hiking   11.37  03:20    423   669  1074
# 21     2 - medium                Cycling   38.14  03:50   1055   934  1724
# 22     2 - medium         Thematic route    9.56  02:45    134   779   913
# 24       1 - easy                Cycling   25.49  01:40    197   553   750
# 25  0 - no rating                 Hiking   16.44  04:45    581   640  1149
# 26       1 - easy                 Hiking    6.97  02:10    330   975  1184
# 27     2 - medium                 Hiking    8.99  02:30    178  1236  1409
# 28     2 - medium                 Hiking    5.85  02:39    464  1013  1411
# 29       1 - easy                 Hiking    7.72  01:30    286  1145  1360
# 30     2 - medium           Trailrunning    9.51  02:00    593  1239  1832
# 32     2 - medium                 Hiking   16.53  05:15    862   636  1215
# 34       1 - easy                 Hiking   11.53  03:20    315   888  1186
# 35     2 - medium                 Hiking    3.71  01:35    290   731   996
# 36     2 - medium                Cycling   43.09  03:00   1103   669  1270
# 37     2 - medium                 Hiking   11.33  04:00    645  1222  1861
# 38       1 - easy            Via ferrata    2.09  03:00    767   626  1393
# 39       1 - easy         Thematic route    2.49  01:30    120  1285  1392
#
#     technique  fitness
# 0           1        1
# 1           0        4
# 2           2        2
# 3           2        3
# 4           1        2
# 5           5        5
# 6           2        5
# 7           3        3
# 8           2        3
# 9           2        3
# 10          2        2
# 11          1        2
# 12          0        0
# 13          1        3
# 14          4        3
# 15          2        3
# 16          2        3
# 17          1        2
# 18          3        3
# 19          3        2
# 20          2        3
# 21          2        4
# 22          3        2
# 24          1        1
# 25          0        0
# 26          2        2
# 27          3        3
# 28          3        4
# 29          1        2
# 30          4        4
# 32          3        4
# 34          1        1
# 35          2        3
# 36          0        3
# 37          2        4
# 38          0        0
# 39          1        2

# %%
activities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 0 to 39
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          37 non-null     int64
#  1   title       37 non-null     object
#  2   difficulty  37 non-null     object
#  3   sport       37 non-null     object
#  4   length      37 non-null     float64
#  5   time        37 non-null     object
#  6   climb       37 non-null     int64
#  7   min         37 non-null     int64
#  8   max         37 non-null     int64
#  9   technique   37 non-null     int64
#  10  fitness     37 non-null     int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 3.5+ KB

# %% [markdown]
# ## 2.5 Write CSV
#
# Now that the data has been cleaned properly, let's save the dataframe to a CSV for future use.

# %%
activities_df.to_csv("../data/activities.csv", index=False)

# %% [markdown]
# ## 2.6 Functions for Data Cleaning

# %% [markdown]
# Let's again save these codes as functions to be able to run the script easily for other regions.

# %%
def clean_cat(activities_df):
    # Converting the text columns to strings for easier handling later
    activities_df[['title', 'difficulty', 'sport']] = activities_df[['title', 'difficulty', 'sport']].astype('str')

    # Removing the brackets
    activities_df['title'] = activities_df['title'].str.strip('[]')
    activities_df['difficulty'] = activities_df['difficulty'].str.strip('[]')
    activities_df['sport'] = activities_df['sport'].str.strip('[]')

    # Remove extra whitespace
    activities_df['title'] = pd.Series(activities_df['title']).str.replace("'", '')
    activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("'", '')
    activities_df['sport'] = pd.Series(activities_df['sport']).str.replace("'", '')

    # Remove units (km, m, h, hm, m)
    activities_df['length'] = pd.Series(activities_df['length']).str.replace("km", '')
    activities_df['time'] = pd.Series(activities_df['time']).str.replace("h", '')
    activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("hm", '')
    activities_df['minmax'] = pd.Series(activities_df['minmax']).str.replace("m", '')

    # Seperate the minmax altitude into a min column and a max column
    activities_df[['min','max']] = activities_df['minmax'].str.split("-",expand=True)
    activities_df = activities_df.drop(columns=['minmax'])

    # Organize the dataframe columns
    activities_df = activities_df[['ID','title', 'difficulty', 'sport', 'length', 
                                   'time', 'climb', 'min', 'max', 'technique', 'fitness']]

    # Add ordering of the difficulty
    activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("easy", '1 - easy')
    activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("medium", '2 - medium')
    activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("difficult",'3 - difficult')
    activities_df['difficulty'].replace(r'^\s*$', '0 - no rating', regex=True, inplace=True)
    return activities_df

# %%
def clean_num(activities_df):
    activities_df['length'] = pd.Series(activities_df['length']).str.replace("-",'0')
    activities_df['length'] = (activities_df['length']).astype(float)

    activities_df['climb'] = pd.Series(activities_df['climb']).str.replace(",", '') 
    activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("-", '0') 
    activities_df['climb'] = (activities_df['climb']).astype(int)
    
    activities_df['min'] = pd.Series(activities_df['min']).str.replace(",", '')
    activities_df['min'].replace('',np.nan, inplace = True)
    activities_df['min'] = activities_df['min'].fillna(0)
    activities_df['min'] = (activities_df['min']).astype(int)
    activities_df['max'].replace('',np.nan, inplace = True)
    activities_df['max'] = activities_df['max'].fillna(0)
    activities_df['max'] = pd.Series(activities_df['max']).str.replace(",", '') 

    activities_df['technique'] = pd.Series(activities_df['technique']).str.replace("rating-", '')
    activities_df['technique'] = pd.to_numeric(activities_df['technique'], errors='coerce')
    activities_df['technique'] = pd.Series(activities_df['technique']).replace(np.nan, 0, regex = True)
    activities_df['technique'] = pd.Series(activities_df['technique']).astype('int')

    activities_df['fitness'] = pd.Series(activities_df['fitness']).str.replace("rating-", '')
    activities_df['fitness'] = pd.to_numeric(activities_df['fitness'], errors='coerce')
    activities_df['fitness'] = pd.Series(activities_df['fitness']).replace(np.nan, 0, regex = True)
    activities_df['fitness'] = activities_df['fitness'].astype('int')
    return activities_df

# %%
def clean_time(activities_df):
    try:
        activities_df['time'] = activities_df['time'].dt.strftime('%H:%M')
    except ValueError:
        pass
    return activities_df

# %%
def clean_df(region, save_as_csv = True):
    activities_df_unclean = pd.read_csv(f"../data/unclean_activities_{region}.csv")
    activities_df_unclean.drop_duplicates(subset ="ID", inplace = True)
    activities_df = clean_cat(activities_df_unclean)
    activities_df = clean_num(activities_df)
    #clean_time(activities_df)
    
    if save_as_csv == True:
        activities_df.to_csv(f"../data/activities_{region}.csv", index=False)
        
    return activities_df

# %%
def preprocess(region, n_pages, save_as_csv = True):
    if save_as_csv == True:
        save = True
    else:
        save = False
    activities_df_unclean = create_scraped_df(region, n_pages, save_as_csv = save)
    activities_df = clean_df(region, save_as_csv = save)
        
    return activities_df, activities_df_unclean

# %% [markdown]
# Let's run the code for a new region or for all regions through a for-loop.
# Afterwards, we hash out the code. Otherwise if you rerun the Kernel too often, there is a risk of being blocked by the website.

# %%
region_test1 = 'bern-region'
n_pages_test = 35
#result_test1 = preprocess(region_test1, n_pages_test, save_as_csv = True)

regions = ['aargau', 'basel-region', 'bern-region', 'berneroberland', 'freiburg-region', 
           'genferseegebiet-waadtland', 'graubuenden', 'jura-drei-seen-land', 'luzern-vierwaldstaettersee',
          'ostschweiz', 'tessin', 'wallis', 'zuerich']

#for reg in regions:
 #   result_test_reg = preprocess(reg, n_pages_test, save_as_csv = True)

# %% [markdown]
# Let's combine all the CSV region files into one DF & CSV file:

# %%
all_act_df = pd.DataFrame()
for reg in regions:
    activities_df_reg = pd.read_csv(f"../data/activities_{reg}.csv")
    activities_df_reg['region'] = reg
    all_act_df = pd.concat([all_act_df, activities_df_reg], axis = 0)
    
all_act_df.to_csv(f"../data/activities_all.csv", index=False)

# %%
all_act_df['title'] = pd.Series(all_act_df['title']).str.replace(',', '-')
all_act_df.to_csv(f"../data/activities_all.csv", index=False)

# %% [markdown]
# # 3  Initial Data Analysis
#
# Before moving onto combining weather data with hiking trails, lets do some preliminary data analysis to see what we are working with. For that, we use the complete "bern-region" data we just scraped.

# %%
plt.style.use('seaborn-dark-palette')
rcParams['figure.figsize'] = 10, 8
activities_df_raw_br = pd.read_csv(f"../data/activities_bern-region.csv")
activities_df_br = activities_df_raw_br.copy()
activities_df_br.head()
# Out:
#        ID  \
# 0   48850
# 1   51212
# 2  870922
# 3  733527
# 4  133945
#
#                                                                  title  \
# 0                   Zum Hinterburgseeli, dem Naturwunder auf der Axalp
# 1  Zu eiszeitlichen Riesen und zur Wohnstätte steinzeitlicher Menschen
# 2                                                            Gehrihorn
# 3                                     Einzigartig: der neue Gäggersteg
# 4                                                Schwander - Lebensweg
#
#    difficulty           sport  length   time  climb   min   max  technique  \
# 0  2 - medium          Hiking   10.69  03:45    624  1521  1878          3
# 1    1 - easy          Hiking   10.50  02:40    254   459   564          2
# 2    1 - easy          Hiking    6.65  03:20   1357   771  2129          1
# 3    1 - easy          Hiking   13.36  04:00    510  1531  1720          2
# 4    1 - easy  Thematic route    3.55  01:30     86   647   735          1
#
#    fitness
# 0        3
# 1        2
# 2        0
# 3        2
# 4        2

# %% [markdown]
# ## 3.1 Data Exploration
#
# We will begin the data analysis by data exploration. By creating different data frames and removing activities with little data to improve visualizations we can get a better idea of what types of trails we are working with.
#
# Here we can see that cycling, racing, and long-distance walking are much longer than the other types of trails. Another helpful tool this DataFrame provides is that we can now view the least used trail types in the dataset. These are going to be removed for the next few analysis steps so it's easier to look at the interesting trail statistics.

# %%
# Creating a df for "Number of entries by sport type" + average tour length
sporttype = activities_df_br.groupby('sport') \
       .agg({'sport':'count', 'length':'mean'}) \
       .rename(columns={'sport':'count','length':'average_length'}) \
       .reset_index() \
       .sort_values(by=['average_length'])
sporttype
# Out:
#                           sport  count  average_length
# 13               Thematic route     30        5.363333
# 8                Nordic Walking      2        5.905000
# 12                     Snowshoe      1        8.120000
# 3                     High tour      2        8.695000
# 4                        Hiking    188        9.913830
# 11                      Running      3       10.443333
# 15                  Via ferrata      2       13.650000
# 14                 Trailrunning     12       19.826667
# 9                    Pilgrimage      4       20.372500
# 7                  Mountainbike     30       22.565333
# 5                 Kayak / Canoe      1       27.620000
# 6         Long distance cycling      3       30.960000
# 2                         E-MTB      2       33.580000
# 0                       Cycling     26       35.581923
# 1                        E-Bike      2       35.850000
# 10                       Racing      8       78.663750
# 16  long-distance walking trail      2      280.480000

# %% [markdown]
# ## 3.2 Focus on the most relevant activities
# Remove the activities, which have less than 5 entries.

# %%
analysis = activities_df_br.groupby("sport").filter(lambda x: len(x) > 10)
analysis.groupby(['sport']).size()
# Out:
# sport
# Cycling            26
# Hiking            188
# Mountainbike       30
# Thematic route     30
# Trailrunning       12
# dtype: int64

# %% [markdown]
# ## 3.3 Bar Chart Visualization
# Now that the activities with little entries are removed, a barchart of the sport types is much more readable. We can see that the most popular activity on our list of trails is hiking with more than 200 entries.

# %%
ax = analysis['sport'].value_counts().plot(kind='bar')
plt.title('Frequency of Activity types')
plt.xlabel('Type of Activity')
plt.ylabel('Count of Activity');

# %% [markdown]
# How does the picture look like by level of difficulty?

# %%
analysis['difficulty'].value_counts().plot(kind='bar')
plt.title('Number of Activities by Difficulty')
plt.xlabel('Difficulty')
plt.ylabel('Count of Activity');

# %% [markdown]
# ## 3.4 Scatter Plot Visualization
#
# The scatter plot paints an interesting picture of the trail data. First, the cycling trails are both the longest and the ones with most height difference out of the bunch. And second, it looks like all of the hiking trails fall between 2 and 20km (except for one). Perhaps this is because long distance hiking trails are considered to be "Pilgrimages"?

# %%
sns.scatterplot(    
    data=analysis,
    x="length", y="climb", hue='sport', 
    marker = "D", s=200, # set marker type and size
).set_title('Length and Distance By Sport Type')
plt.legend(loc='lower right'); # change default position of legend

# %%
# mean length for difficulty:
activities_df_br.groupby('difficulty').mean()
# Out:
#                           ID     length        climb          min  \
# difficulty
# 0 - no rating  452267.000000  12.640333   408.033333   841.966667
# 1 - easy       397930.828829   9.560450   251.378378   985.477477
# 2 - medium     432732.914286  15.402071   620.192857  1062.850000
# 3 - difficult  427644.054054  51.218108  2187.243243   835.324324
#
#                        max  technique   fitness
# difficulty
# 0 - no rating  1237.500000   0.000000  0.000000
# 1 - easy       1219.729730   1.369369  1.756757
# 2 - medium     1624.357143   2.464286  3.292857
# 3 - difficult  1879.864865   3.783784  5.351351

# %% [markdown]
# Now let's explore the data using only hiking trail data.

# %% [markdown]
# # 4 Analysis: Hiking Trails
#
# The primary interest of this analysis is hiking trail data. The following analysis will compare only hiking trails and drop the rest of the sport types.

# %%
hiking = activities_df_br[activities_df_br.sport == "Hiking"]
hiking.shape
# Out:
# (188, 11)

# %% [markdown]
# ## 4.1 Scatter plot: Length and Distance of each Activity By Difficulty

# %%
markers1 = {"1 - easy": ".", "2 - medium": "p",
           "3 - difficult":"s", "0 - no rating":"X"} #set the markers individually
sns.scatterplot(    
    data=hiking,
    x="length", y="climb", 
    hue='difficulty', # color by difficulty
    hue_order = ["1 - easy", "2 - medium", "3 - difficult", "0 - no rating"], # rearrange order of the legend
    style='difficulty', markers = markers1, # set markers
    s = 400 # size of markers
).set_title('Length and Distance By Difficulty');

# %% [markdown]
# Seems we have one "outlier" which is more than 200km long. Let's remove it to get a better view on the majority of the trails.

# %%
sns.scatterplot(    
    data=hiking[hiking.length < 200],
    x="length", y="climb", 
    hue='difficulty', # color by difficulty
    hue_order = ["1 - easy", "2 - medium", "3 - difficult", "0 - no rating"], # rearrange order of the legend
    style='difficulty', markers = markers1, # set markers
    s = 400, # size of markers
).set_title('Length and Distance By Difficulty');

# %% [markdown]
# The easier trails seem to be shorter in length and with lower elevation gain. Let's see if there is a correlation.

# %% [markdown]
# ## 4.2 Line Plot: Comparison of average Trail Length vs. Fitness Score

# %% [markdown]
# The following dataframe uses the fitness scores and compares them to the length of each trail. How correlated is the trail length to the fitness score? A new columns is added for average length.

# %%
# calculating the count by Fitness level and the average length 
fitness_length_check = hiking.groupby('fitness') \
       .agg({'fitness':'count', 'length':'mean'}) \
       .rename(columns={'fitness':'count','length':'average_length'}) \
       .reset_index()
fitness_length_check
# Out:
#    fitness  count  average_length
# 0        0     28       11.155357
# 1        1     24        5.527083
# 2        2     41        8.039024
# 3        3     51       10.359412
# 4        4     30       12.293333
# 5        5     11       12.962727
# 6        6      3       16.493333

# %% [markdown]
# The routes with no fitness rating seems quite long. Probably related to the outlier previously identified.
# For further analysis let's remove the trails without any difficulty rating and check if there is a visual clue.

# %%
fitness_length = fitness_length_check[fitness_length_check['fitness'] != 0]
plt.plot(fitness_length["fitness"], fitness_length["average_length"])
plt.ylabel('average_length')
plt.xlabel("rating_fitness")
plt.title('Hiking: Average Length by Fitness Level Rating')
#sns.linewidth = 6
#check linestyle
plt.show()

# %% [markdown]
# There seems to be a relationship indeed between fitness score and length of the hike but let's have a closer look.

# %% [markdown]
# ## 4.3 Boxplots: Difficulty vs. Elevation Gain and Length
#
# The following boxplots show how the trail data is distributed by difficulty catagory compared to both elevation gain and length. It's pretty clear that the relationship between elevation gain and difficulty is more meaningful than the relationship between distance and difficulty. My legs agree!

# %%
my_pal = {"1 - easy": "forestgreen", "2 - medium": "darkblue", "3 - difficult":"darkred", 
          "0 - no rating":"blanchedalmond"}
ax = sns.boxplot(x="difficulty", y="climb", data=hiking, 
                 order=["1 - easy", "2 - medium", "3 - difficult", "0 - no rating"],
                palette = my_pal) \
.set_title('Relationship between Trail Difficulty Rating and Elevation Gain')\

# https://matplotlib.org/2.0.2/examples/color/named_colors.html

# %%
ax = sns.boxplot(x="difficulty", y="length",showfliers = False, data=hiking, 
                 order=["1 - easy", "2 - medium", "3 - difficult", "0 - no rating"],
                palette = my_pal) \
.set_title('Relationship between Trail Difficulty Rating and Distance')

# %% [markdown]
# ## 3.6 Correlation Matrix
# Let's see what the mathematical correlations are between the four parameters: climb, length, fitness score, technique score. For that, trails without any rating will be excluded.

# %%
# remove numerical columns that are not needed and remove rows with no rating 
corr_matrix_df = hiking.drop(columns = ['min','max']).copy()
corr_matrix_df = corr_matrix_df[corr_matrix_df['difficulty'] != '0 - no rating']
# create a correlation matrix
corr_matrix = corr_matrix_df.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corr_matrix, annot = True, cmap = 'Blues');

# %%
corr_matrix_df.head()
# Out:
#        ID  \
# 0   48850
# 1   51212
# 2  870922
# 3  733527
# 5  509375
#
#                                                                  title  \
# 0                   Zum Hinterburgseeli, dem Naturwunder auf der Axalp
# 1  Zu eiszeitlichen Riesen und zur Wohnstätte steinzeitlicher Menschen
# 2                                                            Gehrihorn
# 3                                     Einzigartig: der neue Gäggersteg
# 5                                      Merängge-Cher im Kemmribodenbad
#
#    difficulty   sport  length   time  climb  technique  fitness
# 0  2 - medium  Hiking   10.69  03:45    624          3        3
# 1    1 - easy  Hiking   10.50  02:40    254          2        2
# 2    1 - easy  Hiking    6.65  03:20   1357          1        0
# 3    1 - easy  Hiking   13.36  04:00    510          2        2
# 5    1 - easy  Hiking    6.97  02:10    330          2        2

# %% [markdown]
# 'Fitness' and 'Technique' have the highest correlation among all measures.
# What about the correlation with the 'Difficulty Level'?
# We therefore convert the 'easy', 'medium', 'difficult' in numeric values and build a correlation matrix.

# %%
# add numerical column indicating the difficulty level
corr_matrix_df['difficulty_level'] = corr_matrix_df['difficulty']
corr_matrix_df.loc[corr_matrix_df['difficulty'] == '1 - easy', ['difficulty_level']] = 1
corr_matrix_df.loc[corr_matrix_df['difficulty'] == '2 - medium', ['difficulty_level']] = 2
corr_matrix_df.loc[corr_matrix_df['difficulty'] == '3 - difficult', ['difficulty_level']] = 3

# the column 'difficulty_level' will return object type which we need to convert to integers.
corr_matrix_df['difficulty_level']= corr_matrix_df['difficulty_level'].astype(str).astype(int)
#or corr_matrix_df2 = pd.to_numeric(corr_matrix_df['difficulty_level']).astype(int)
corr_matrix_df2 = corr_matrix_df.copy()
corr_matrix_df2
# Out:
#          ID  \
# 0     48850
# 1     51212
# 2    870922
# 3    733527
# 5    509375
# ..      ...
# 306  799947
# 307   62404
# 308  456685
# 311  190774
# 313  456688
#
#                                                                    title  \
# 0                     Zum Hinterburgseeli, dem Naturwunder auf der Axalp
# 1    Zu eiszeitlichen Riesen und zur Wohnstätte steinzeitlicher Menschen
# 2                                                              Gehrihorn
# 3                                       Einzigartig: der neue Gäggersteg
# 5                                        Merängge-Cher im Kemmribodenbad
# ..                                                                   ...
# 306                                            Anspruchsvolle Gipfeltour
# 307                                                       Five star walk
# 308                                                     Rundweg Hüslimad
# 311                                                   dw Schynige Platte
# 313                                                    Rundweg Fuchseren
#
#         difficulty   sport  length   time  climb  technique  fitness  \
# 0       2 - medium  Hiking   10.69  03:45    624          3        3
# 1         1 - easy  Hiking   10.50  02:40    254          2        2
# 2         1 - easy  Hiking    6.65  03:20   1357          1        0
# 3         1 - easy  Hiking   13.36  04:00    510          2        2
# 5         1 - easy  Hiking    6.97  02:10    330          2        2
# ..             ...     ...     ...    ...    ...        ...      ...
# 306  3 - difficult  Hiking   18.61  05:30   2032          6        6
# 307     2 - medium  Hiking   15.77  08:00      0          2        4
# 308     2 - medium  Hiking    3.18  01:09    189          2        3
# 311     2 - medium  Hiking    5.95  02:07    305          3        1
# 313     2 - medium  Hiking    2.95  01:06    194          2        3
#
#      difficulty_level
# 0                   2
# 1                   1
# 2                   1
# 3                   1
# 5                   1
# ..                ...
# 306                 3
# 307                 2
# 308                 2
# 311                 2
# 313                 2
#
# [162 rows x 10 columns]

# %%
corr_matrix_level = corr_matrix_df2.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corr_matrix_level, annot = True, cmap = 'Blues');

# %% [markdown]
# As we can see, the highest correlation is between the fitness level and the difficulty level, followed by the technique and the difficulty level. This was not visible in the box plot graphs above.

# %% [markdown]
# # 5 Download Trail GPS Data
#
# The next part of this notebook deals with parsing HTML tags again, however this time around we will be gathering the GPS data needed to create the snowfall alert in Milestone 3. The GPS data for each trail is actually a list of GPS points that comprise the length of the trail, from start to summit. However, we will only be using the first GPS point in our algorithm, which is the trail-head.
#
# The Bergfex website embeds their GPS data into downloadable files, which are meant to be uploaded to a GPS device for navigation purposes. As such, the following code will automatically download each GPS file into a folder. Importantly, a sleep timer is added to replicate how a human may download these files, if the sleep timer is not added, the website will become suspicious and prevent us from downloading more files.
#
# The type of GPS file that is being downloaded is a "GPX" or "GPS Exchange Format" file, which is a special type of XML file that can be used to describe waypoints.
#
# Finally, we crosscheck with Google Earth Web App, that our downloaded GPS data is exactly what we want.

# %% [markdown]
# ## 5.1 Download Batches of GPX Files
#
# This loop uses the activity id's to navigate to each of the activity's pages. It then downloads the GPS file to the folder "gpx_files" and saves it as a filename "Unique_id.gpx". To prevent being blocked from the page, we download the data in small batches (70) for all activities.

# %%
test_id = corr_matrix_df.iloc[:10,0]
test_id
# Out:
# 0      48850
# 1      51212
# 2     870922
# 3     733527
# 5     509375
# 6      86143
# 7      99640
# 8     744919
# 9     316229
# 10    658326
# Name: ID, dtype: int64

# %%
# create a small subset of data for testing
"""test_id = corr_matrix_df.iloc[:5,0]
for hike_id in test_id: 
    url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={str(hike_id)};fileType=kml"
    print(url_id)
    r = requests.get(url_id, allow_redirects=True)          # Send the request
    time.sleep(5)                                           # Include a timer to prevent blocking
    write_link = ('../gpx_files/'+ str(hike_id) + ".gpx")   # Create gpx file
    with open(write_link, 'wb') as f:
        f.write(r.content)                                  # Write data for each ID in each file"""
# Out:
# 'test_id = corr_matrix_df.iloc[20:22,0]\nfor hike_id in test_id: \n    url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={str(hike_id)};fileType=kml"\n    print(url_id)\n    r = requests.get(url_id, allow_redirects=True)          # Send the request\n    time.sleep(5)                                           # Include a timer to prevent blocking\n    write_link = (\'../gpx_files/\'+ str(hike_id) + ".gpx")   # Create gpx file\n    with open(write_link, \'wb\') as f:\n        f.write(r.content)                                  # Write data for each ID in each file'

# %% [markdown]
# Let's look at the content of one download. There are lots of data points of which the key data needs to be filtered out.

# %%
"""r.content"""
# Out:
# 'r.content'

# %% [markdown]
# ##  5.2 Extract Coordinates from GPX files
#
# Now that the GPX files have been downloaded to a local file, we can loop through them and extract the important information, which is the latitude and the longitude of the trail start.

# %%
"""list_of_trails_list = []
list_of_files = glob.glob('*gpx')                     # Create a list for each trail_id
for hike_id in test_id: 
    trail_gps_list = []
    gpx = gpxpy.parse(open('../gpx_files/'+str(hike_id)+'.gpx', 'r')) # Read content for each trail_id
    trail_gps_list.append(hike_id)
    for track in gpx.tracks: 
        trail_name = track.name                 # Track name
        trail_gps_list.append(trail_name)
        for segment in track.segments: 
            for point in segment.points: 
              lat = point.latitude              # Latitude
              trail_gps_list.append(lat)
              lon = point.longitude             # Longitude
              trail_gps_list.append(lon) 
              break
        list_of_trails_list.append(trail_gps_list)

print(list_of_trails_list)"""
# Out:
# "list_of_trails_list = []\nlist_of_files = glob.glob('*gpx')                     # Create a list for each trail_id\nfor hike_id in test_id: \n    trail_gps_list = []\n    gpx = gpxpy.parse(open('../gpx_files/'+str(hike_id)+'.gpx', 'r')) # Read content for each trail_id\n    trail_gps_list.append(hike_id)\n    for track in gpx.tracks: \n        trail_name = track.name                 # Track name\n        trail_gps_list.append(trail_name)\n        for segment in track.segments: \n            for point in segment.points: \n              lat = point.latitude              # Latitude\n              trail_gps_list.append(lat)\n              lon = point.longitude             # Longitude\n              trail_gps_list.append(lon) \n              break\n        list_of_trails_list.append(trail_gps_list)\n\nprint(list_of_trails_list)"

# %% [markdown]
# ## 5.3  Create a Dataframe and save as CSV
#
# Let's take a look at our data now that it has been extracted. It looks like everything is working as intended. Each trail has a unique ID and latitude and longitude. This data can now be saved to a CSV file which will be used for the snow alert in the next notebook.

# %%
"""trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF
trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns
trail_coords_df.to_csv('../data/trail_coords_df.csv', index=False) # save to CSV
coords_df = pd.read_csv('../data/trail_coords_df.csv')
coords_df"""
# Out:
# "trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF\ntrail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns\ntrail_coords_df.to_csv('../data/trail_coords_df.csv', index=False) # save to CSV\ncoords_df = pd.read_csv('../data/trail_coords_df.csv')\ncoords_df"

# %% [markdown]
# ## 5.4 Check GPS example

# %% [markdown]
# Let's test one ID (48850) with its coordinates (lat = 46.718933, lon = 8.037732) in Google Earth web app. It correctly displays the location.
#
# Bergfex GPS data:
# - https://www.bergfex.com/downloads/gps/?type=&id=48850&fileType=kml
#
# Google Earth web app:
# - https://earth.google.com/web/search/46%2e718933+8%2e037732/@46.72096543,8.03751163,1503.22852736a,741.78182338d,35y,-80.11801825h,45.00028446t,0r/data=ClYaLBImGfGBHf8FXEdAIX0G1JtREyBAKhI0Ni43MTg5MzMgOC4wMzc3MzIYAiABIiYKJAkoo5mexUVHQBGyfRYeu0FHQBkErEmOIJsdQCGM9eFheUIdQA

# %%
#to delete:
# https://www.bergfex.com/downloads/gps/?type=&id=131699&fileType=kml
# https://www.bergfex.com/downloads/gps/?type=&id=48850&fileType=kml
#Let's test one ID (131699) with its coordinates (lat = 46.508190, lon = 7.358150)
#Let's test one ID (48850) with its coordinates (lat = 46.718933, lon = 8.037732)
#48850
#46.718933
#8.037732
#https://earth.google.com/web/search/46%2e508190+7%2e358150/@46.50819,7.35815,2006.43177272a,699.98943356d,35y,0h,45t,0r/data=ClYaLBImGb4Ts14MQUdAIeU_pN--bh1AKhI0Ni41MDgxOTAgNy4zNTgxNTAYAiABIiYKJAlWqScNN6A1QBFWqScNN6A1wBkg4Hxc5e7VPyFlaK6dDdtZwA
#https://earth.google.com/web/search/46%2e718933+8%2e037732/@46.72096543,8.03751163,1503.22852736a,741.78182338d,35y,-80.11801825h,45.00028446t,0r/data=ClYaLBImGfGBHf8FXEdAIX0G1JtREyBAKhI0Ni43MTg5MzMgOC4wMzc3MzIYAiABIiYKJAkoo5mexUVHQBGyfRYeu0FHQBkErEmOIJsdQCGM9eFheUIdQA

# %%
"""example = coords_df[coords_df['trail_id'] == 48850]
example"""
# Out:
# "example = coords_df[coords_df['trail_id'] == 131699]\nexample"

# %%
# needed to increase the display size of the png
# %matplotlib notebook 
img = mpimg.imread('../GoogleEarth.jpeg')
plt.rcParams['figure.dpi'] = 140
imgplot = plt.imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="896">

# %% [markdown]
# ## 5.5 Functions for GPS data

# %% [markdown]
# Now that we confirmed the GPS data, let's combine the code in functions. By adding tranches and a timer for their download, we make sure we will not be blocked by the website.

# %% [markdown]
# ### Function to download the GPX data by regions and in tranches
# We recommend a maximum tranch of 62 ID's with a timer of 2000 seconds in between. Executing this for all ID's can take quite some time, so we recommend to execute it by region.

# %%
def get_gpx_data_short(region, tranch_len, timer, save_as_csv = True):
    
    start_time = time.time()
    
    for_gpx_df = pd.read_csv(f"../data/activities_{region}.csv") # import csv file for resp. region
    n_tranches = math.ceil(len(for_gpx_df.iloc[:,0])/ tranch_len) # calculate # of tranches
    
    tranch_df = pd.DataFrame()
    list_of_trails_list = []
    start_t = 0
    end_t = tranch_len
    
    for i in range(n_tranches): # subset all IDs into different tranches 
        tranch_df = for_gpx_df.iloc[start_t:end_t,0]
        start_t = start_t + tranch_len                # set new subset start
        end_t = start_t + tranch_len                  # set new subset end
        tranch_df = tranch_df.fillna(0).astype(int)   # format df
        ids_df = tranch_df.loc[(tranch_df != 0)]      # filter out non-valid IDs
        
        # download file for each ID of the subset
        for ids in ids_df: 
            url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={str(ids)};fileType=kml"
            r = requests.get(url_id, allow_redirects=True)    # Send the request
            write_link = ('../gpx_files/'+ str(ids) + ".gpx") # Create gpx file
            with open(write_link, 'wb') as f:
                f.write(r.content)                            # Write data for each ID in each file
            # extract the trail_id, name of the hike, lat, lon from GPX files
            trail_gps_list = []
            gpx = gpxpy.parse(open('../gpx_files/'+str(ids)+'.gpx', 'r')) # Read content for each trail_id
            trail_gps_list.append(ids)                  # ID
            for track in gpx.tracks: 
                trail_name = track.name                 # Track name
                trail_gps_list.append(trail_name)
                for segment in track.segments: 
                    for point in segment.points: 
                      lat = point.latitude              # Latitude
                      trail_gps_list.append(lat)
                      lon = point.longitude             # Longitude
                      trail_gps_list.append(lon) 
                      break
                list_of_trails_list.append(trail_gps_list)
        time.sleep(timer) # timer to prevent being blocked
    
    trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF
    trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns
    if save_as_csv == True:                                    # Option to save to csv
        trail_coords_df.to_csv(f'../data/trail_coords_df_{region}_SD.csv', index=False)
    print("-- {0} seconds -- for {1} tranches".format(time.time() - start_time, n_tranches)) # time needed
    
    return trail_coords_df

# %% [markdown]
# ### Function to add GPS data from downloaded GPX files to activity DF
# Once we have all the GPX files for one region, we can add them to the activity df by merging the tables on the ID and removing duplicate columns.

# %%
def merge_activities_gpx(region):
    act_df = pd.read_csv(f"../data/activities_{region}.csv")
    gpx_df = pd.read_csv(f"../data/trail_coords_df_{region}.csv")
    act_gpx = act_df.merge(gpx_df, how="left", left_on = 'ID', right_on = "trail_id")
    act_gpx = act_gpx.drop(columns=['name', 'traid_id'])
    act_gpx.to_csv(f"../data/activities_{region}_gpx.csv", index=False)

# %% [markdown]
# # CONTINUE IN NOTEBOOK II

# %% [markdown]
# to delete

# %%
test_reg_special = 'special2'
tranch_len = 2
timer = 2

test_id_2 = activities_df_br.iloc[25:30,:]
test_id_2.to_csv(f'../data/activities_{test_reg_special}.csv', index=False)

result_spec = get_gpx_data_short(test_reg_special, tranch_len, timer, save_as_csv = True)
result_spec

# %%
result_spec2 = merge_activities_gpx(test_reg_special)
result_spec2
