# %% [markdown]
# ### Installations

# %%
#!pip install lxml
#!pip install wget
#!pip install gpxpy

# %% [markdown]
# ### Imports

# %%
# import requests
import re
from bs4 import BeautifulSoup 
import pandas as pd
import lxml

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math

import requests
#import wget
import glob
import datetime as dt
import time

import seaborn as sns
from matplotlib import rcParams
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import gpxpy 
import gpxpy.gpx 
import glob

# %% [markdown]
# # Still to do:
# - Add key words: Webscraping from a static page, Data Cleaning, plots, GPX coordinates, KML coordinates (add both? describe the differences?), spatial data, tableau, visualization, seaboarn, matplotlib
#
# - DONE with functions: import csv file instead of rescrapping (hash out the rest)
#
# - DONE: change difficulty to '0 - No rating', '1 - Easy' etc
# - DONE for corr matrix: remove '0 - No rating' for some plots
# - DONE: easy = green etc
# - DONE: nicer look of plots?
#
# - DONE: create function for gpx part
# - DONE: simplify gpx code
# - WIP - blocked: run gpx code for all 257 codes (check if not blocked)
# - DONE Taken out as not needed: check why datetime code does not always work
#
# - DONE: Check comment with Google earth and "KML" file

# %% [markdown]
# # 1  Data scraping
#
# Prepare to scrape the Bergfex.com website in order to create Pandas dataframes that contain important information about each trail. This code uses BeautifulSoup to parse the html tags into json, which is easier to work with. A for-loop iterates over each html tag and adds the corresponding information into empty lists.

# %% [markdown]
# ### 1.1 Scrape all the information (basic and more complicated)

# %%
title = []  # Title of the tour
difficulty = []  # difficulty (easy, medium, hard)
sport = []  # Sport type (hiking, sledging, snowshoe...)
length = []  # length in km
time_list = []  # tour time in hours:minutes
climb = []  # positive elevation climb in m
minmax = []  # minimum and maximum altitude of the tour in m
technique = []  # technique difficulty ratings (out of 6)
fitness = []  # fitness difficulty ratings (out of 6)
total_title = [] # will help extracting the ID of the tour

# all ratings are stored together so we will need this along the way:
rating = []  # list to store technique and fitness rating info

# %%
# looping over the x first pages of Bergfex
# each separate tour on the page is framed by a div tag with 'touren-details'

page_number = 2  # number of pages we want to scrape through

for p in range(1, (page_number+1)):
    base_link = 'https://www.bergfex.com/sommer/bern-region/touren/?isAjax=1&page='
    link = base_link+str(p)  # going over p pages with numbers appended to the base link
    page = requests.get(link, timeout=5)
    print("scraped page", p)
    soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
    tours = soup.findAll('div', {'class': 'touren-detail'})  # checks for the separate tours on the page

# For each page, we loop over each tour and fill our lists with info     
    for i in range(0,len(tours)):
        tour_1 = tours[i] # tour iterating over the 20 tours of the page

        tour_title = tour_1.findAll('a' ) # this gets the title out
        title.append([info.get_text().strip() for info in tour_title])
        total_title.append(tour_title) 
        # this gets the full tour-title information including the ID, will need to be processed further later on
        
        tour_diff = tour_1.findAll('span', {'class': 'tour-difficulty'}) #tour level difficulty
        difficulty.append([info.get_text().strip() for info in tour_diff])

        tour_type = tour_1.findAll('span', {'class': 'tour-type'}) # putting type into sports
        sport.append([info.get_text().strip() for info in tour_type])

        tour_stats = tour_1.findAll('div', {'class': 'tour-stats'}) # stats has 4 info binned together
        stat_text = [info.get_text().strip() for info in tour_stats]
        length.append(stat_text[0])
        time_list.append(stat_text[1])
        climb.append(stat_text[2])
        minmax.append(stat_text[3])
        
        tour_rating = tour_1.find_all("div", {'class': 'tour-rating'}) # getting the rating data 
        rating.append([info for info in tour_rating])   # it's a class name so we can't get_text.
# Out:
# scraped page 1
# scraped page 2

# %%
tours
# Out:
# [<div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren
jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="70d40ae8a9ddfff63481b222faaf2de8" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/de8/70d40ae8a9ddfff63481b222faaf2de8.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="906551c832e7d3cf9939c0608001a6d1" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/6d1/906551c832e7d3cf9939c0608001a6d1.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/wanderung/508332,I-gloube-I-gange-no-meh-a-louenesee/" title="I gloube i gange no meh a Louenesee">I gloube i gange no meh a Louenesee</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-2">
#  medium
#  </span>
#  <span class="tour-type">
#  Hiking
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  9.99<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>02:50</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  340<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,236 - 1,433<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="46c5731d787fe44822415654e9db08e8" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/8e8/46c5731d787fe44822415654e9db08e8.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="b5d5a0011af7f663bd8d19ec2d0cce82" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/e82/b5d5a0011af7f663bd8d19ec2d0cce82.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="c93bd4840d1d4ee0f1d627b37e90245c" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/45c/c93bd4840d1d4ee0f1d627b37e90245c.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="50629f6880489d89ac581e5b75185357" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/357/50629f6880489d89ac581e5b75185357.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-3"></div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="touren-detail">
#  <a class="h2" href="/sommer/bern-region/touren/themenweg/131627,audioguide-saanen/" title="Audioguide Saanen">Audioguide Saanen</a>
#  <div>
#  <span class="tour-difficulty tour-difficulty-1">
#  easy
#  </span>
#  <span class="tour-type">
#  Thematic route
#  </span>
#  </div>
#  <div class="tour-stats-photos-container">
#  <div class="tour-stats-container">
#  <div class="tour-stats-left">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-length"></div>
#  1.78<span class="tour-stats-unit">km</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-time"></div>
#  <strong>00:30</strong><span class="tour-stats-unit">h</span>
#  </div>
#  </div>
#  <div class="tour-stats-right">
#  <div class="tour-stats tour-stats-big">
#  <div class="tour-stats-icon tour-stats-icon-up"></div>
#  23<span class="tour-stats-unit">hm</span>
#  </div>
#  <div class="tour-stats">
#  <div class="tour-stats-icon tour-stats-icon-updown"></div>
#  1,009 - 1,029<span class="tour-stats-unit">m</span>
#  </div>
#  </div>
#  </div>
#  <div class="tour-photos">
#  <img alt="" border="0" class="tour-photo" height="57" id="02fdeee9c4536c50d0be3e25a9d253b2" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/3b2/02fdeee9c4536c50d0be3e25a9d253b2.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="64a81c388b209a54aa4e5164edba57ad" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/7ad/64a81c388b209a54aa4e5164edba57ad.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="71c2c2c02967f778875d1a0e5def965b" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/65b/71c2c2c02967f778875d1a0e5def965b.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="917af114c5c57022132056193423d40f" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/40f/917af114c5c57022132056193423d40f.jpg" width="57"/>
#  <img alt="" border="0" class="tour-photo" height="57" id="62ecd1f21d09734210f75c6e5889bcde" src="https://vcdn.bergfex.at/images/resized/profiles/preview-cropped/cde/62ecd1f21d09734210f75c6e5889bcde.jpg" width="57"/>
#  </div>
#  </div>
#  <div class="tour-ratings">
#  <div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-2"></div></div>
#  </div>
#  </div>
#  </div>]

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</title>
# <script src="https://cdn.stroeerdigitalgroup.de/metatag/live/SDG_ConsentOnly/metaTag.min.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="en" name="language"/>
# <meta content="width=device-width, viewport-fit=cover" name="viewport"/>
# <script type="application/ld+json">
# {
# "@context": "https://schema.org",
# "@type": "Organization",
# "url": "https://www.bergfex.com",
# "logo": "https://www.bergfex.com/images/logo.png"
# }
# </script>
# <meta content="" property="og:title"/>
# <meta content="https://vcdn.bergfex.at/images/resized/d8/a65a94fd11f0d3d8_2931d3a04a0e346a.jpg" property="og:image"/>
# <meta content="image/jpg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="627" property="og:image:height"/>
# <link href="//www.bergfex.ch/sommer/bern-region/touren/" hreflang="de" rel="alternate"/>
# <link href="//www.bergfex.com/sommer/bern-region/touren/" hreflang="en" rel="alternate"/>
# <link href="//www.bergfex.fr/sommer/bern-region/touren/" hreflang="fr" rel="alternate"/>
# <link href="//it.bergfex.com/sommer/bern-region/touren/" hreflang="it" rel="alternate"/>
# <link href="//www.bergfex.es/sommer/bern-region/touren/" hreflang="es" rel="alternate"/>
# <link href="//nl.bergfex.com/sommer/bern-region/touren/" hreflang="nl" rel="alternate"/>
# <link href="//se.bergfex.com/sommer/bern-region/touren/" hreflang="sv" rel="alternate"/>
# <link href="//no.bergfex.com/sommer/bern-region/touren/" hreflang="no" rel="alternate"/>
# <link href="//dk.bergfex.com/sommer/bern-region/touren/" hreflang="da" rel="alternate"/>
# <link href="//fi.bergfex.com/sommer/bern-region/touren/" hreflang="fi" rel="alternate"/>
# <link href="//hu.bergfex.com/sommer/bern-region/touren/" hreflang="hu" rel="alternate"/>
# <link href="//www.bergfex.cz/sommer/bern-region/touren/" hreflang="cs" rel="alternate"/>
# <link href="//sk.bergfex.com/sommer/bern-region/touren/" hreflang="sk" rel="alternate"/>
# <link href="//www.bergfex.pl/sommer/bern-region/touren/" hreflang="pl" rel="alternate"/>
# <link href="//hr.bergfex.com/sommer/bern-region/touren/" hreflang="hr" rel="alternate"/>
# <link href="//www.bergfex.si/sommer/bern-region/touren/" hreflang="sl" rel="alternate"/>
# <link href="//ru.bergfex.com/sommer/bern-region/touren/" hreflang="ru" rel="alternate"/>
# <link href="//ro.bergfex.com/sommer/bern-region/touren/" hreflang="ro" rel="alternate"/>
# <link href="https://plus.google.com/105981749558386334210" rel="publisher"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link color="#1599ff" href="//vcdn.bergfex.at/images/mask-icon.svg" rel="mask-icon"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/bergfex-1615903179.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/sommer-1595402128.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/print-1606325961.css" media="print" rel="stylesheet"/><script>
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.autoCompleteActive = false;
# bergfex.autoCompleteSuggestionStartChar = 1;
# </script><script>
# // bergfex namespace
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.staticHost = '//vcdn.bergfex.at';
# bergfex.staticHosts = ['//vcdn.bergfex.at'];
# bergfex.InfobannerCookiesOptions = {
# timesToShow: 3,
# textTitle: "Informationen zu Cookies",
# textInfo:
# "Diese Seite verwendet Cookies. " +
# "Für eine uneingeschränkte Nutzung der Website werden Cookies benötigt. " +
# "Sie stimmen der Verwendung von Cookies durch Anklicken von \"OK\" zu. " +
# "Nähere Informationen finden Sie in unseren ",
# textPolicy: "Datenschutzbedingungen",
# urlPolicy: "/datenschutz/",
# textButton: "OK",
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.1-1595402130.jsmin.js" type="text/javascript"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.2-1610094216.jsmin.js" type="text/javascript"></script><script src="//vcdn.bergfex.at/include/js/jquery/plugins/ui/1.10.3/i18n/jquery.ui.datepicker-en.js" type="text/javascript"></script><script>
# var gMapKey = "AIzaSyDhkXDPfuKgSZgCcKfDLRHNZFrsdbfQkiQ";
# var mapEnabled = true;
# var mapHeight = 360;
# bergfex.libs = { };
# bergfex.libs.srcElevLibs = "//vcdn.bergfex.at/include/jsmin/elevationprofile-libs-1595402128.jsmin.js";
# bergfex.libs.srcMapLibs  = "//vcdn.bergfex.at/include/jsmin/map-libs-1601299449.jsmin.js";
# bergfex.season = "sommer";
# </script><script>
# var jBlockTruncateSettings = {
# 'moreText': "show more",
# 'lessText': "less"
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/bergfex-libs-1616068547.jsmin.js" type="text/javascript"></script><meta content="0" name="geonomap"/>
# <meta content="keep" name="geomap"/>
# <meta content="Bundesland_16" name="geocontext"/>
# <meta content="46.939012,8.107910,10,o" name="geoposition"/>
# <meta content="1" name="geotarget"/>
# <meta content="touren" name="geolayer"/>
# <meta content="sommer" name="season"/><meta content="Swiss plateau,Switzerland,Tours," name="keywords"/>
# <meta content="Swiss plateau Switzerland:  - Tours" name="description"/>
# <meta content="app-id=912776148" name="apple-itunes-app">
# </meta></head>
# <body class="site">
# <div id="page-top">
# <!--page-top-->
# <div style="position: absolute;">
# <script src="//script.ioam.de/iam.js" type="text/javascript"></script>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         $(document).ready(function() {
#             var iam_data = {
#                 "st": "bergfex",
#                 "cp": "sommer-nonde",
#                 "sv": "in",  // keine Befragungseinladung
#                 "co": ""  // comment
#             }
#             try {
#                 iom.c(iam_data, 1);
#             } catch(e) {
#             }
#         });
#     </script>
# <!-- /SZM -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-15684980-1"></script>
# <script>
# // https://support.google.com/analytics/answer/10022331?hl=de
# // window['gtag_enable_tcf_support'] = true;
# bergfex.Analytics = {
# send_to: 'UA-15684980-1',
# admask: 'schweiz.bern-region',
# language: 'en',
# page_location: '/sommer/bern-region/touren/?isAjax=1&page=1',
# };
# window.dataLayer = window.dataLayer || [];
# bergfex.gtag = function() {
# dataLayer.push(arguments);
# }
# bergfex.gtag('js', new Date());
# bergfex.gtag('config', 'UA-15684980-1', {
# send_page_view: false,
# custom_map: {
# dimension1: 'admask',
# dimension2: 'language',
# },
# });
# bergfex.gtag('event', 'init');
# window.addEventListener('metaTagSystemCmpChoiceUiShown', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceUiShown');
# });
# window.addEventListener('metaTagSystemCmpChoiceSelected', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceSelected');
# });
# // log map views.
# </script></div>
# <nav class="nav-default" id="nav-main">
# <div class="nav-main-trigger-side"></div>
# <a class="logo-bergfex" href="/" title="bergfex Homepage"></a>
# <div class="nav-main-search responsive-only" id="nav-main-search">
# </div>
# <div class="nav-main-user responsive-only">
# <a href="/mybergfex/">
# <div class="avatar">
# </div></a>
# </div>
# <div class="nav-main-trigger"></div>
# <div class="nav-main-close"></div>
# <div class="nav-main-container page-left-margin">
# <div class="nav-search">
# <form action="/sommer/suchen/" autocomplete="off" method="get" name="sitesearch">
# <div class="search-icon"></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" id="search-input-field" maxlength="256" name="q" placeholder="Search" spellcheck="false" type="text"/>
# </form>
# </div>
# <!-- on dropdown, inject logo from mainlogo position via js -->
# <ul class="nav-list">
# <li class="has-children collapsed">
# <a>Winter</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li>
# <a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li>
# <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/italien/">Italy</a>
# </li>
# <li>
# <a href="/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/frankreich/">France</a>
# </li>
# <li>
# <a href="/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/polska/">Poland</a>
# </li>
# <li>
# <a href="/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/spanien/">Spain</a>
# </li>
# <li>
# <a href="/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/wallis/">Valais</a>
# </li>
# <li>
# <a href="/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed selected-init">
# <a>Summer</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/sommer/schweiz/">Regions</a></li>
# <li class="selected">
# <a href="/sommer/schweiz/touren/">Tours</a></li>
# <li>
# <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
# <li>
# <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
# <li>
# <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/sommer/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/sommer/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/sommer/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/sommer/italien/">Italy</a>
# </li>
# <li>
# <a href="/sommer/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/sommer/frankreich/">France</a>
# </li>
# <li>
# <a href="/sommer/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/sommer/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/sommer/polska/">Poland</a>
# </li>
# <li>
# <a href="/sommer/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/sommer/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/sommer/spanien/">Spain</a>
# </li>
# <li>
# <a href="/sommer/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/sommer/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/sommer/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/sommer/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/sommer/wallis/">Valais</a>
# </li>
# <li>
# <a href="/sommer/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/sommer/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/sommer/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/sommer/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/sommer/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/sommer/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/sommer/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/sommer/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/sommer/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="/sommer/schweiz/wetter/prognose/">Weather</a>
# </li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# <li><a href="/sommer/angebote/">Offers</a></li>
# <li><a href="/forum/">Forum</a></li>
# <li>
# <a class="has-avatar" href="/mybergfex/">
# <div class="avatar">
# </div><span class="nav-main-username">MyBergfex</span>
# </a>
# </li>
# <div id="mybergfex"></div>
# </ul>
# </div>
# <div id="dropdown">
# <!-- optional logo in dropdown -->
# <img alt="" border="0" class="dropdown-logo" height="77" src="https://vcdn.bergfex.at/images/resized/5e/5aa28b0e4d23a15e_6c75f271197432f5@2x.png" width="77"/>
# <div class="dropdown-container page-left-margin">
# <div class="dropdown-content"></div>
# <div class="dropdown-close"></div>
# </div>
# </div>
# </nav><!--/page-top-->
# </div>
# <div id="mapactions">
# <div class="map_enable" id="mapaction_enable_big"></div>
# <div class="mapactions-separator"></div>
# <div class="mapactions-buttons">
# <div class="map_enable" id="mapaction_enable"></div>
# <div id="mapaction_help"></div>
# <div id="mapaction_link"></div>
# <div id="mapaction_up"></div>
# <div id="mapaction_down"></div>
# <div id="mapaction_full"></div>
# <div id="mapaction_close"></div>
# </div>
# </div>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/leaflet-1601550149.css" rel="stylesheet"/><div class="leaflet-map" id="siteMap" style="height: 180px; position: absolute; visibility: hidden; z-index: -1;">
# <div id="siteMapCanvas" style="height: 100%; width: 100%;"></div>
# </div>
# <script>
# var leafletMapOptions = {
# idCanvas: 'siteMapCanvas',
# idContainer: 'siteMap',
# minHeight: 350,
# maxHeight: Math.round($(window).height() * 0.66),
# zoom: 10,
# markerLayers: {
# skigebiete: {
# name: 'Ski resorts'
# },
# langlaufen: {
# name: 'Cross-country skiing'
# },
# unterkuenfte: {
# name: 'Accommodation'
# },
# sommerinfos: {
# name: 'Summer'
# },
# wandertouren: {
# name: 'Hiking tours'
# },
# alpintouren: {
# name: 'Alpine tours'
# },
# wintertouren: {
# name: 'Winter tours'
# },
# biketouren: {
# name: 'Bike tours'
# },
# lauftouren: {
# name: 'Running tours'
# },
# badeseen: {
# name: 'Bathing lakes'
# }
# },
# mapTypes: {
# oek: {
# name: 'bergfex OEK',
# title: 'bergfex Österreichische Karte 1:50.000'
# },
# osm: {
# name: 'bergfex OSM',
# title: 'bergfex OpenStreetMap'
# },
# basemap: {
# name: 'Basemap',
# title: 'Basemap Österreich'
# },
# basemapOrtho: {
# name: 'Basemap Orthofoto',
# title: 'Basemap Orthofotos Österreich'
# },
# satellite: {
# name: 'Satellite',
# title: 'Satellite'
# },
# roadmap: {
# name: 'Map',
# title: 'Map'
# }
# },
# overlays: {
# slopes: {
# name: 'Slope gradient'
# }
# },
# controls: {
# mapZoomControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# }
# },
# mapTypeControl: {
# showAsDropDown: function()
# {
# return bergfex.isMobile;
# }
# },
# mapSearchControl: {
# placeholder: 'Search in the map'
# },
# fullScreenControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# },
# title: {
# 'false': 'Vollbild',
# 'true': 'Vollbild verlassen'
# }
# },
# fullscreenContentControl: {
# i18n: {
# 'showContent': 'Inhalt einblenden',
# 'hideContent': 'Inhalt ausblenden'
# }
# },
# elevationControl: {
# i18n: {
# uphill: 'Uphill',
# downhill: 'Downhill',
# length: 'Length',
# height: 'Height'
# }
# },
# osmLegendControl: {
# language: 'en',
# i18n: {
# title: 'Legend'
# }
# },
# oekLegendControl: {
# i18n: {
# title: 'Legend'
# }
# }
# },
# layersDropDownContainer: {
# title: '<strong>Topics</strong> show <div class="layers-icon"></div>'
# }
# };
# $(document).ready(function()
# {
# var isChromium = !!window.chrome;
# if(isChromium) {
# leafletMapOptions.mapTypes.osm.class = bergfex.Leaflet.MapTypes.Osm_Mapboxgl
# }
# bergfex.MapHandler.init(leafletMapOptions);
# });
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/es6-promise.min-1595402129.jsmin.js" type="text/javascript"></script><script>ES6Promise.polyfill();</script>
# <script src="/include/js/leaflet/plugins/mapbox-gl-1.5.0/mapbox-gl.js"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/leaflet-map-1616403708.jsmin.js" type="text/javascript"></script><h1 id="document-title" style="display: none;">BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</h1>
# <!--page-bottom-->
# <div id="page-container">
# <nav class="breadcrumb mobile-hidden">
# <a href="/sommer/schweiz/" title="Summer Switzerland">Summer Switzerland</a> /
# <a class="important" href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </nav>
# <main class="page-left-margin">
# <aside id="nav-side">
# <div class="nav-side-close"></div>
# <div class="logo">
# <img alt="" border="0" height="37.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_ca92b0a06176d736@2x.png" width="133"/>
# </div>
# <div class="location">
# <a class="country" href="/sommer/schweiz/">Switzerland</a> /
# <a class="region" href="/sommer/bern-region/">Swiss plateau</a>
# </div>
# <div class="location-map">
# <div class="locationmap">
# <img alt="" border="0" height="83" src="https://vcdn.bergfex.at/images/resized/47/bb3e2117b44f9a47_a8e041be49be1fcf@2x.png" width="129.5"/>
# <a href="/sommer/schweiz/">
# <img alt="" border="0" class="layer" height="83" src="https://vcdn.bergfex.at/images/resized/6d/0767a6107b78396d_84ed19a8e14775b8@2x.png" width="129.5"/>
# </a>
# </div>
# </div>
# <ul class="tree">
# <li class="level0">
# <a href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/" title="Regions">Regions</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/wetter/prognose/" title="Weather">Weather</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/webcams/" title="Webcams">Webcams</a>
# </li><li class="level1 selected">
# <a href="/sommer/bern-region/touren/" title="Tours">Tours</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/highlights/" title="Highlights">Highlights</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/seen/" title="Bathing lakes">Bathing lakes</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/unterkuenfte/" title="Accommodation">Accommodation</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/pauschalangebote/" title="Offers and All-inclusive prices">Offers and All-inclusive prices</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/sportanbieter/" title="Sports and leisure provider">Sports and leisure provider</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/veranstaltungen/" title="Events">Events</a>
# </li><li class="level0 winter">
# <a href="/bern-region/" title="Ski resorts">Ski resorts</a>
# </li><li class="level0 winter">
# <a href="/bern-region/langlaufen/" title="Cross-country skiing">Cross-country skiing</a>
# </li><li class="level0 winter">
# <a href="/bern-region/snow-parks/" title="Snow parks">Snow parks</a>
# </li></ul>
# <ul class="tree info jblocktruncate" style="max-height: 200px;">
# <li class="level1 label">
# Favourite regions
# </li>
# <li class="level1"><a href="/sommer/bern-stadt/">Bern - Stadt</a></li>
# <li class="level1"><a href="/sommer/emmental/">Emmental</a></li>
# <li class="level1"><a href="/sommer/naturpark-gantrisch/">Naturpark Gantrisch</a></li>
# <li class="level1"><a href="/sommer/oberaargau/">Oberaargau</a></li>
# <li class="level1"><a href="/sommer/burgdorf/">Burgdorf</a></li>
# <li class="level1"><a href="/sommer/muensingen/">Münsingen</a></li>
# <li class="level1"><a href="/sommer/muri-bei-bern/">Muri bei Bern</a></li>
# <li class="level1"><a href="/sommer/laupen/">Laupen</a></li>
# <li class="level1"><a href="/sommer/langenthal/">Langenthal</a></li>
# <li class="level1"><a href="/sommer/lyss/">Lyss</a></li>
# <li class="level1"><a href="/sommer/zollikofen/">Zollikofen</a></li>
# <li class="level1"><a href="/sommer/worb/">Worb</a></li>
# <li class="level1"><a href="/sommer/steffisburg/">Steffisburg</a></li>
# <li class="level1"><a href="/sommer/belp/">Belp</a></li>
# <li class="level1"><a href="/sommer/koeniz/">Köniz</a></li>
# <li class="level1"><a href="/sommer/ostermundigen/">Ostermundigen</a></li>
# <li class="level1"><a href="/sommer/ittigen/">Ittigen</a></li>
# </ul>
# <div style="text-align: center">
# <a class="app-badge googleplay-badge" href="/redirect/f258b4/1231/0/1/https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdeveloper%3Fid%3Dbergfex%2BGmbH" target="_blank" title="Android Apps">
# </a>
# <a class="app-badge appstore-badge" href="/redirect/e29ab4/1230/0/1/https%3A%2F%2Fapps.apple.com%2Fat%2Fdeveloper%2Fbergfex-gmbh%2Fid355025018" target="_blank" title="iPhone Apps"></a>
# </div>
# <script>
# $(document).ready(function() {
# if($.browser){
# if ($.browser.isIOS) {
# $(".googleplay-badge").hide();
# $(".appstore-badge").addClass("big-badge");
# } else if ($.browser.isAndroid) {
# $(".appstore-badge").hide();
# $(".googleplay-badge").addClass("big-badge");
# }
# }
# });
# </script></aside>
# <div class="content" id="detail"><div class="section-left">
# <header>
# <a class="mobile-back mobile-only" href="/sommer/bern-region/">Swiss plateau</a>
# <!--    <div class="nav-side-trigger mobile-only"></div>  -->
# <div class="logo mobile-only">
# <img alt="" border="0" height="25.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_f1f23b72380280e9@2x.png" width="90"/>
# </div>
# <h1>Tours <span class="less-important">Swiss plateau</span>
# </h1><div class="buttons">
# <div class="desktop-only button-small button-small-icon button-small-icon-down" id="btn-map-show">
# Map
# </div>
# <div class="desktop-only button-small button-dark-grey button-small-icon button-small-icon-up" id="btn-map-hide">
# Hide map
# </div>
# </div>
# <div class="clearer"></div>
# </header><hr class="desktop-only"/>
# <form action="/sommer/bern-region/touren/" class="form-horizontal" id="touren_searchform" method="get">
# <div class="box-container mobile-collapsed">
# <div class="box-header mobile-only">
# Touren filtern
# </div>
# <div class="box-content">
# <div class="control-group">
# <label>Region</label>
# <div class="controls">
# <script>
# function locationSelected(data) {
# $("#touren_searchform").attr("action", "/" + data[7] + "/touren/");
# }
# </script>
# <input class="input-100 input-important" id="text_location" name="text_location" placeholder="" style="font-weight: bold;" type="text" value=""/><script>$(document).ready(function() { addAutocompleter('location', '/ajax/jquery/autocompleter/regionen/', 3, 200, 400 , locationSelected); });</script><input id="location" name="location" type="hidden" value=""/>
# </div>
# </div>
# <div class="control-group">
# <label>Tour type</label>
# <div class="controls">
# <select class="input-100" name="type">
# <option value="0">(All)</option>
# <option value="14">Hiking (281)</option>
# <option value="10">Mountainbike (44)</option>
# <option value="17">Thematic route (44)</option>
# <option value="11">Cycling (39)</option>
# <option value="24">Trailrunning (17)</option>
# <option value="12">Racing (11)</option>
# <option value="16">Pilgrimage (11)</option>
# <option value="8">Via ferrata (4)</option>
# <option value="7">High tour (3)</option>
# <option value="13">Long distance cycling (3)</option>
# <option value="30">E-MTB (3)</option>
# <option value="23">Running (3)</option>
# <option value="42">E-Bike (2)</option>
# <option value="3">Ski tour (2)</option>
# <option value="22">Nordic Walking (2)</option>
# <option value="15">long-distance walking trail (1)</option>
# <option value="18">Kayak / Canoe (1)</option>
# <option value="4">Snowshoe (1)</option>
# </select>
# </div>
# </div>
# <div class="control-group">
# <label>Full-text search</label>
# <div class="controls">
# <input class="input-100" name="q" type="text">
# </input></div>
# </div>
# <div class="control-group">
# <label>Fitness</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_kondition">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_kondition">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Technique</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_fahrtechnik">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_fahrtechnik">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Length (km)</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_laenge" placeholder="min." size="2" type="text">
# </input></div>
# <div class="col">
# <input name="max_laenge" placeholder="max." size="2" type="text"/>
# </div>
# </div>
# </div>
# <div class="control-group">
# <label>Altitude metres</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_hm" placeholder="min." size="4" type="text"/>
# </div>
# <div class="col">
# <input name="max_hm" placeholder="max." size="4" type="text"/>
# </div>
# </div>
# </div>
# <input name="search" type="hidden" value="1"/>
# <div class="form-actions nobackground">
# <button class="button button-blue" type="submit">Search</button>
# <a class="button button-grey" href="http://www.bergfex.com/sommer/bern-region/touren/"><span>Reset</span></a>
# </div>
# </div>
# </div>
# </form>
# <div style="float: left; line-height: 24px; font-weight: bold;">
# Seite 2 <span class="less-important">von 472 Tours.</span>
# </div>
# <div class="sort-selector" data-order-selected="DESC" data-sort-selected="Relevanz" style="float: right;">
# <div class="sort-option-active">sortiert nach <span class="sort-name">Relevanz</span></div>
# <div class="sort-options">
# <div class="sort-option" data-order="DESC" data-sort="Relevanz" title="nach Relevanz sortieren">Relevanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Laenge" title="nach längste Distanz sortieren">längste Distanz</div>
# <div class="sort-option" data-order="ASC" data-sort="Laenge" title="nach kürzeste Distanz sortieren">kürzeste Distanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Zeit" title="nach längste Dauer sortieren">längste Dauer</div>
# <div class="sort-option" data-order="ASC" data-sort="Zeit" title="nach kürzeste Dauer sortieren">kürzeste Dauer</div>
# <div class="sort-option" data-order="DESC" data-sort="Hoehenmeter" title="nach meiste Höhenmeter sortieren">meiste Höhenmeter</div>
# <div class="sort-option" data-order="ASC" data-sort="Hoehenmeter" title="nach wenigste Höhenmeter sortieren">wenigste Höhenmeter</div>
# <div class="sort-option" data-order="DESC" data-sort="Kondition" title="nach hohe Kondition sortieren">hohe Kondition</div>
# <div class="sort-option" data-order="ASC" data-sort="Kondition" title="nach niedrige Kondition sortieren">niedrige Kondition</div>
# <div class="sort-option" data-order="DESC" data-sort="Technik" title="nach hohem Technikanspruch sortieren">hohe Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="
("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackDetail(oaTrackingDetail);
#                         }
#                         if (oaTrackingTeaser.length > 0) {
#                             _.forEach(oaTrackingTeaser, function(teaserId) {
#                                 $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackTeaser(teaserId);
#                             });
#                         }
#                     }
#                 }
#
#                 if(typeof outdooractiveTrackingIframeLoaded === "undefined") {
#                     function outdooractiveTrackingIframeLoaded() {
#                         trackOutdooractiveActivities();
#                     }
#                 }
#
#                 $(document).ready(function() {
#                     var $iframe = $("#outdooractive_tracking_iframe");
#
#                     if($iframe.length === 0) {
#                         $("body").append("<iframe id='outdooractive_tracking_iframe' src='//www.bergfex.com/ajax/outdooractive/tracking.php'></iframe>");
#                     } else {
#                         trackOutdooractiveActivities();
#                     }
#                 });
#             </script>
# <script>oaTrackingTeaser.push('8483710');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="690414" height="200" src="https://vcdn.bergfex.at/images/resized/d1/cdfcaf00d8c185d1_e43cb7be9d398e31@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/48799,moosegg-inbegriff-von-aussicht-und-gastlichkeit/" title="Recht anspruchsvolle Rundwanderung über aussichtsreiche Eggen und durch schattenspendende Wälder...">
# Moosegg: Inbegr...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.07</strong>km | <strong>460</strong>hm | <strong>03:20</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="48799" src="https://vcdn.bergfex.at/images/resized/f6/c2775a4c95ab7cf6_5a602d99a86ea463@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('17956755');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1198462" height="200" src="https://vcdn.bergfex.at/images/resized/1c/204cf366eb8aaf1c_3d898e589e352cc7@2x.jpg" title="Axalp – Axalp" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/83713,wanderung-axalp--axalp/" title="Schnitzlerweg zum Hinterburgsee">
# Wanderung Axalp...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>5.22</strong>km | <strong>200</strong>hm | <strong>01:40</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="83713" src="https://vcdn.bergfex.at/images/resized/ee/614ebd00d76fabee_88c9229927ddf249@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('8483794');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="692953" height="200" src="https://vcdn.bergfex.at/images/resized/b7/05980b8ae3e2c7b7_caf419090c0c52c8@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/48925,aussichtsreiche-wege-in-der-adelbodner-bergwelt/" title="Man braucht nicht zwingend in grosse Höhen zu steigen, um malerische Ausblicke in die Bergwelt...">
# Aussichtsreiche...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>8.39</strong>km | <strong>420</strong>hm | <strong>02:30</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="48925" src="https://vcdn.bergfex.at/images/resized/9c/41f24729487ba09c_eca517843a054715@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('15655063');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1216109" height="200" src="https://vcdn.bergfex.at/images/resized/fb/88ab53a017f741fb_e5f641d58b13d34e@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86144,waldhaeusern--beliebtes-ausflugsziel-im-emmental/" title="„Signau…in allen Jahreszeiten schön“. Mit diesem Motto werden die Besucher der Gemeinde-Homepage...">
# Waldhäusern - ...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>9.63</strong>km | <strong>373</strong>hm | <strong>03:00</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86144" src="https://vcdn.bergfex.at/images/resized/c0/763597cd262eb0c0_8638de0c909f0598@2x.jpg" width="240"/>
# </div>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </main>
# <div id="sidebar">
# <div class="adzone_skyscraper partner" data-geo="sommer.schweiz.bern-region" data-tags="" data-zoneid="2" id="adzone_skyscraper"></div>
# </div>
# <!--/page-bottom-->
# </div>
# <div class="clearer"></div>
# <div id="mapsearch-template-h2noresult">
# <h2>Keine Einträge gefunden.</h2>
# </div>
# <div id="mapsearch-template-h2overflow">
# <h2>Es wurden %count% Einträge gefunden. Bitte Suche verfeinern.</h2>
# </div>
# <div id="mapsearch-template-h2local">
# <h2>Lokale Suchergebnisse <span class="less-important">(Distance &lt;= 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2nonlocal">
# <h2>More results <span class="less-important">(Distance &gt; 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2all">
# <h2>All %count% Search results</h2>
# </div>
# <div id="mapsearch-template-line">
# <div class="mapsearch-line">
# <div><a class="name" href="">%name%</a> <span class="region">%region%</span></div>
# <div><span class="type">%type%</span> <span class="elevation">%elevation%</span></div>
# </div>
# </div><footer id="footer">
# <div class="footer-container page-left-margin">
# <div class="footer-location">
# / <a href="/sommer/schweiz/">Summer Switzerland</a> /
# <a href="/sommer/bern-region/">Swiss plateau</a> /
# <strong>Tours</strong>
# </div>
# <ul class="nav-list">
# <li class="has-children collapsed language-select">
# <h2 class="no-select" style="overflow: visible"><span class="mobile-only">Language</span> <span class="flag en"></span> english</h2>
# <ul>
# <li><a href="//www.bergfex.ch/sommer/bern-region/touren/" rel='"nofollow"'>
# <span class="flag de"></span> Deutsch</a></li>
# <li><a href="//www.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag en"></span> English</a></li>
# <li><a href="//www.bergfex.fr/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fr"></span> Français</a></li>
# <li><a href="//it.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag it"></span> Italiano</a></li>
# <li><a href="//www.bergfex.es/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag es"></span> Español</a></li>
# <li><a href="//nl.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag nl"></span> Nederlands</a></li>
# <li><a href="//se.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag se"></span> Svenska</a></li>
# <li><a href="//no.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag no"></span> Norsk</a></li>
# <li><a href="//dk.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag dk"></span> Dansk</a></li>
# <li><a href="//fi.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fi"></span> Suomi</a></li>
# <li><a href="//hu.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hu"></span> Magyar</a></li>
# <li><a href="//www.bergfex.cz/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag cz"></span> český</a></li>
# <li><a href="//www.bergfex.sk/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag sk"></span> Slovensky</a></li>
# <li><a href="//www.bergfex.pl/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag pl"></span> Polski</a></li>
# <li><a href="//hr.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hr"></span> Hrvatski</a></li>
# <li><a href="//www.bergfex.si/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag si"></span> Slovenščina</a></li>
# <li><a href="//ru.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ru"></span> русский</a></li>
# <li><a href="//ro.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ro"></span> Român</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>Themen</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li><a href="/sommer/schweiz/">Summer regions</a></li>
# <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>General</h2>
# <ul>
# <li><a href="/newsletter/">Newsletter</a></li>
# <li><a href="/produkte/">Products</a></li>
# <li><a href="/shop/">Shop</a></li>
# <li><a href="/login/">Login</a></li>
# </ul>
# </li>
# </ul>
# <div id="language-select-overlay"></div>
# <div class="copyright-container">
# <!-- background image -->
# <div class="copyright">Copyright © 1999, 2021 bergfex GmbH. All rights reserved.</div>
# <div class="copyright-links">
# <a href="/datenschutz/">Privacy policy</a> |
# <a href="/impressum/">About us</a> |
# <a href="" id="privacy-manager">Privacy Manager</a>
# </div>
# </div>
# </div>
# </footer></body>
# </html>

# %%
print("number of tours collected:", len(title))
# Out:
# number of tours collected: 40

# %% [markdown]
# ### 1.2 Extracting embedded HTML tags: <a href=""
# Each trail name and ID was used in Bergfex's URL. Using the trail ID in the dataframe will provide a unique ID to use later in the analysis. However, those two data points are embedded deeper in the html code. The below codes shows how to extract the datapoints into a dataframe.

# %%
# Extracting the ID via the URL
links_title = []

for i in total_title:
    i = str(i)
    i = i.strip('[]')
    links_title.append(i)

# %% [markdown]
# In order to make the trail ID usable it needs to be cleaned up and converted into a string

# %%
# Extracting ID
id_df3 = pd.DataFrame(links_title)
id_df2 = id_df3[0].str.split(' ',expand = True)
id_df1 = id_df2[2].str.split(',',expand = True)
id_df = id_df1[0].str.split('/',expand = True)

# %%
# from this format:
pd.options.display.max_colwidth = 100
id_df3.head()
# Out:
#                                                                                                      0
# 0  <a class="h2" href="/sommer/bern-region/touren/mountainbike/698705,ueschenen-biketour/" title="Ü...
# 1  <a class="h2" href="/sommer/bern-region/touren/wanderung/509375,meraengge-cher-im-kemmribodenbad...
# 2  <a class="h2" href="/sommer/bern-region/touren/wanderung/92457,auf-den-gurten-den-berner-hausber...
# 3  <a class="h2" href="/sommer/bern-region/touren/wanderung/114222,grenzerfahrung-durch-die-comb-de...
# 4  <a class="h2" href="/sommer/bern-region/touren/laufen/891249,bluemlisalp-lauf--stecke/" title="B...

# %%
# to this format:
id_df.head()
# Out:
#         0       1            2       3             4       5
# 0  href="  sommer  bern-region  touren  mountainbike  698705
# 1  href="  sommer  bern-region  touren     wanderung  509375
# 2  href="  sommer  bern-region  touren     wanderung   92457
# 3  href="  sommer  bern-region  touren     wanderung  114222
# 4  href="  sommer  bern-region  touren        laufen  891249

# %% [markdown]
# ### 1.3 Extracting embedded HTML tags: <Div class=""
# The HTML tags for the fitness and technique ratings were embedded within Div class tags; they are extracted using a for-loop and then stripped of unecessary characeters.
# - Convert the tour rating tag into a string
# - Strip away unecessary characters
# - Split into lists which look like rating_list [Technique, Fitness]
# - Finally, convert into seperate lists for Technique and Fitness

# %%
rating[0] # View the emmbedded DIV tag
# Out:
# [<div class="tour-rating">
#  <div class="tour-rating-label">Technique</div>
#  <div class="rating-circles rating-max6"><div class="rating-"></div></div>
#  </div>,
#  <div class="tour-rating">
#  <div class="tour-rating-label">Fitness</div>
#  <div class="rating-circles rating-max6"><div class="rating-4"></div></div>
#  </div>]

# %%
# Replace unwanted information
tour_rating_str = str(rating)
rating_all_short = tour_rating_str.replace(
'<div class="tour-rating">\n<div class="tour-rating-label">Technique</div>\n<div class="rating-circles rating-max6"><div class="',''
).replace(
    '<div class="tour-rating">\n<div class="tour-rating-label">Fitness</div>\n<div class="rating-circles rating-max6"><div class="','').replace('"></div></div>\n</div>',"")
rating_even_shorter = rating_all_short.replace('[','').replace(']','')
rating_list = rating_even_shorter.split(", ")

for i in range(0,(len(rating_list))):
    if i == 0:
        technique.append(rating_list[i]) # add first item in technique
    elif i % 2 == 0:
        technique.append(rating_list[i]) # then every second item as well
    else:
        fitness.append(rating_list[i]) # the other appended to fitness list

# %%
## Let's look at the result

#rating_all_short
#rating_even_shorter
rating_list
# Out:
# ['rating-',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-',
#  'rating-0',
#  'rating-4',
#  'rating-0',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-4',
#  'rating-3',
#  'rating-4',
#  'rating-5',
#  'rating-5',
#  'rating-2',
#  'rating-3',
#  'rating-',
#  'rating-4',
#  'rating-',
#  'rating-4',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-5',
#  'rating-5',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-4',
#  'rating-6',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-3',
#  'rating-1',
#  'rating-2',
#  'rating-',
#  'rating-0',
#  'rating-',
#  'rating-0',
#  'rating-',
#  'rating-0',
#  'rating-',
#  'rating-0',
#  'rating-3',
#  'rating-4',
#  'rating-3',
#  'rating-2',
#  'rating-2',
#  'rating-2',
#  'rating-3',
#  'rating-4',
#  'rating-4',
#  'rating-6',
#  'rating-',
#  'rating-0',
#  'rating-1',
#  'rating-1',
#  'rating-4',
#  'rating-6',
#  'rating-1',
#  'rating-3',
#  'rating-3',
#  'rating-3',
#  'rating-2',
#  'rating-3',
#  'rating-2',
#  'rating-2']

# %% [markdown]
# ### 1.4  Create dataframe for extracted elements
#
# This dataframe is not in the final stage yet as there are still extra brackets, the minimum and maximum elevation are still in one column, and units must be stripped away

# %%
activities_df_unclean = pd.DataFrame(
    {'title': title,
     'difficulty': difficulty,
     'sport': sport,
     'length': length,
     'time': time_list,
     'climb': climb,
     'minmax': minmax,
     'technique': technique,
     'fitness': fitness
    })
activities_df_unclean['ID']= id_df.iloc[:,5].copy() # add the ID columns from an earlier DF
activities_df_unclean.head()
# Out:
#                                           title difficulty           sport  \
# 0                           [Üschenen Biketour]   [medium]  [Mountainbike]
# 1             [Merängge-Cher im Kemmribodenbad]     [easy]        [Hiking]
# 2         [Auf den Gurten, den Berner Hausberg]         []        [Hiking]
# 3  [Grenzerfahrung durch die Comb de Biaufonds]         []        [Hiking]
# 4                    [Blümlisalp-Lauf - Stecke]   [medium]       [Running]
#
#     length    time  climb          minmax technique   fitness      ID
# 0  23.88km  02:55h  835hm  1,171 - 1,975m   rating-  rating-4  698705
# 1   6.97km  02:10h  330hm    975 - 1,184m  rating-2  rating-2  509375
# 2   4.22km  01:10h  128hm      748 - 857m   rating-  rating-0   92457
# 3  13.62km  04:00h  475hm    618 - 1,035m   rating-  rating-0  114222
# 4  15.94km  05:05h  886hm    706 - 1,409m  rating-4  rating-0  891249

# %% [markdown]
# ### 1.5 Write CSV file of scrapped and uncleaned DF

# %%
activities_df_unclean.to_csv("../data/unclean_activities.csv", index=False)
activities_df_unclean.head()
# Out:
#                                           title difficulty           sport  \
# 0                           [Üschenen Biketour]   [medium]  [Mountainbike]
# 1             [Merängge-Cher im Kemmribodenbad]     [easy]        [Hiking]
# 2         [Auf den Gurten, den Berner Hausberg]         []        [Hiking]
# 3  [Grenzerfahrung durch die Comb de Biaufonds]         []        [Hiking]
# 4                    [Blümlisalp-Lauf - Stecke]   [medium]       [Running]
#
#     length    time  climb          minmax technique   fitness      ID
# 0  23.88km  02:55h  835hm  1,171 - 1,975m   rating-  rating-4  698705
# 1   6.97km  02:10h  330hm    975 - 1,184m  rating-2  rating-2  509375
# 2   4.22km  01:10h  128hm      748 - 857m   rating-  rating-0   92457
# 3  13.62km  04:00h  475hm    618 - 1,035m   rating-  rating-0  114222
# 4  15.94km  05:05h  886hm    706 - 1,409m  rating-4  rating-0  891249

# %% [markdown]
# ### Scrape Regions (to be deleted)

# %%
regions = []
base_link_region = 'https://www.bergfex.com/sommer/berneroberland/'
page_region = requests.get(base_link_region, timeout=5)
soup_region = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
region = soup.findAll('div', {'class': 'box-content greid cols2'})  # checks for the separate tours on the page
region2 = soup.findAll('a', {'href': '*/sommer/*'})
region3 = soup.findAll('li', {'class': 'has-children collapsed'})

# %%
soup_region
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</title>
# <script src="https://cdn.stroeerdigitalgroup.de/metatag/live/SDG_ConsentOnly/metaTag.min.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="en" name="language"/>
# <meta content="width=device-width, viewport-fit=cover" name="viewport"/>
# <script type="application/ld+json">
# {
# "@context": "https://schema.org",
# "@type": "Organization",
# "url": "https://www.bergfex.com",
# "logo": "https://www.bergfex.com/images/logo.png"
# }
# </script>
# <meta content="" property="og:title"/>
# <meta content="https://vcdn.bergfex.at/images/resized/d8/a65a94fd11f0d3d8_2931d3a04a0e346a.jpg" property="og:image"/>
# <meta content="image/jpg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="627" property="og:image:height"/>
# <link href="//www.bergfex.ch/sommer/bern-region/touren/" hreflang="de" rel="alternate"/>
# <link href="//www.bergfex.com/sommer/bern-region/touren/" hreflang="en" rel="alternate"/>
# <link href="//www.bergfex.fr/sommer/bern-region/touren/" hreflang="fr" rel="alternate"/>
# <link href="//it.bergfex.com/sommer/bern-region/touren/" hreflang="it" rel="alternate"/>
# <link href="//www.bergfex.es/sommer/bern-region/touren/" hreflang="es" rel="alternate"/>
# <link href="//nl.bergfex.com/sommer/bern-region/touren/" hreflang="nl" rel="alternate"/>
# <link href="//se.bergfex.com/sommer/bern-region/touren/" hreflang="sv" rel="alternate"/>
# <link href="//no.bergfex.com/sommer/bern-region/touren/" hreflang="no" rel="alternate"/>
# <link href="//dk.bergfex.com/sommer/bern-region/touren/" hreflang="da" rel="alternate"/>
# <link href="//fi.bergfex.com/sommer/bern-region/touren/" hreflang="fi" rel="alternate"/>
# <link href="//hu.bergfex.com/sommer/bern-region/touren/" hreflang="hu" rel="alternate"/>
# <link href="//www.bergfex.cz/sommer/bern-region/touren/" hreflang="cs" rel="alternate"/>
# <link href="//sk.bergfex.com/sommer/bern-region/touren/" hreflang="sk" rel="alternate"/>
# <link href="//www.bergfex.pl/sommer/bern-region/touren/" hreflang="pl" rel="alternate"/>
# <link href="//hr.bergfex.com/sommer/bern-region/touren/" hreflang="hr" rel="alternate"/>
# <link href="//www.bergfex.si/sommer/bern-region/touren/" hreflang="sl" rel="alternate"/>
# <link href="//ru.bergfex.com/sommer/bern-region/touren/" hreflang="ru" rel="alternate"/>
# <link href="//ro.bergfex.com/sommer/bern-region/touren/" hreflang="ro" rel="alternate"/>
# <link href="https://plus.google.com/105981749558386334210" rel="publisher"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link color="#1599ff" href="//vcdn.bergfex.at/images/mask-icon.svg" rel="mask-icon"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/bergfex-1615903179.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/sommer-1595402128.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/print-1606325961.css" media="print" rel="stylesheet"/><script>
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.autoCompleteActive = false;
# bergfex.autoCompleteSuggestionStartChar = 1;
# </script><script>
# // bergfex namespace
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.staticHost = '//vcdn.bergfex.at';
# bergfex.staticHosts = ['//vcdn.bergfex.at'];
# bergfex.InfobannerCookiesOptions = {
# timesToShow: 3,
# textTitle: "Informationen zu Cookies",
# textInfo:
# "Diese Seite verwendet Cookies. " +
# "Für eine uneingeschränkte Nutzung der Website werden Cookies benötigt. " +
# "Sie stimmen der Verwendung von Cookies durch Anklicken von \"OK\" zu. " +
# "Nähere Informationen finden Sie in unseren ",
# textPolicy: "Datenschutzbedingungen",
# urlPolicy: "/datenschutz/",
# textButton: "OK",
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.1-1595402130.jsmin.js" type="text/javascript"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.2-1610094216.jsmin.js" type="text/javascript"></script><script src="//vcdn.bergfex.at/include/js/jquery/plugins/ui/1.10.3/i18n/jquery.ui.datepicker-en.js" type="text/javascript"></script><script>
# var gMapKey = "AIzaSyDhkXDPfuKgSZgCcKfDLRHNZFrsdbfQkiQ";
# var mapEnabled = true;
# var mapHeight = 360;
# bergfex.libs = { };
# bergfex.libs.srcElevLibs = "//vcdn.bergfex.at/include/jsmin/elevationprofile-libs-1595402128.jsmin.js";
# bergfex.libs.srcMapLibs  = "//vcdn.bergfex.at/include/jsmin/map-libs-1601299449.jsmin.js";
# bergfex.season = "sommer";
# </script><script>
# var jBlockTruncateSettings = {
# 'moreText': "show more",
# 'lessText': "less"
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/bergfex-libs-1616068547.jsmin.js" type="text/javascript"></script><meta content="0" name="geonomap"/>
# <meta content="keep" name="geomap"/>
# <meta content="Bundesland_16" name="geocontext"/>
# <meta content="46.939012,8.107910,10,o" name="geoposition"/>
# <meta content="1" name="geotarget"/>
# <meta content="touren" name="geolayer"/>
# <meta content="sommer" name="season"/><meta content="Swiss plateau,Switzerland,Tours," name="keywords"/>
# <meta content="Swiss plateau Switzerland:  - Tours" name="description"/>
# <meta content="app-id=912776148" name="apple-itunes-app">
# </meta></head>
# <body class="site">
# <div id="page-top">
# <!--page-top-->
# <div style="position: absolute;">
# <script src="//script.ioam.de/iam.js" type="text/javascript"></script>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         $(document).ready(function() {
#             var iam_data = {
#                 "st": "bergfex",
#                 "cp": "sommer-nonde",
#                 "sv": "in",  // keine Befragungseinladung
#                 "co": ""  // comment
#             }
#             try {
#                 iom.c(iam_data, 1);
#             } catch(e) {
#             }
#         });
#     </script>
# <!-- /SZM -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-15684980-1"></script>
# <script>
# // https://support.google.com/analytics/answer/10022331?hl=de
# // window['gtag_enable_tcf_support'] = true;
# bergfex.Analytics = {
# send_to: 'UA-15684980-1',
# admask: 'schweiz.bern-region',
# language: 'en',
# page_location: '/sommer/bern-region/touren/?isAjax=1&page=1',
# };
# window.dataLayer = window.dataLayer || [];
# bergfex.gtag = function() {
# dataLayer.push(arguments);
# }
# bergfex.gtag('js', new Date());
# bergfex.gtag('config', 'UA-15684980-1', {
# send_page_view: false,
# custom_map: {
# dimension1: 'admask',
# dimension2: 'language',
# },
# });
# bergfex.gtag('event', 'init');
# window.addEventListener('metaTagSystemCmpChoiceUiShown', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceUiShown');
# });
# window.addEventListener('metaTagSystemCmpChoiceSelected', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceSelected');
# });
# // log map views.
# </script></div>
# <nav class="nav-default" id="nav-main">
# <div class="nav-main-trigger-side"></div>
# <a class="logo-bergfex" href="/" title="bergfex Homepage"></a>
# <div class="nav-main-search responsive-only" id="nav-main-search">
# </div>
# <div class="nav-main-user responsive-only">
# <a href="/mybergfex/">
# <div class="avatar">
# </div></a>
# </div>
# <div class="nav-main-trigger"></div>
# <div class="nav-main-close"></div>
# <div class="nav-main-container page-left-margin">
# <div class="nav-search">
# <form action="/sommer/suchen/" autocomplete="off" method="get" name="sitesearch">
# <div class="search-icon"></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" id="search-input-field" maxlength="256" name="q" placeholder="Search" spellcheck="false" type="text"/>
# </form>
# </div>
# <!-- on dropdown, inject logo from mainlogo position via js -->
# <ul class="nav-list">
# <li class="has-children collapsed">
# <a>Winter</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li>
# <a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li>
# <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/italien/">Italy</a>
# </li>
# <li>
# <a href="/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/frankreich/">France</a>
# </li>
# <li>
# <a href="/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/polska/">Poland</a>
# </li>
# <li>
# <a href="/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/spanien/">Spain</a>
# </li>
# <li>
# <a href="/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/wallis/">Valais</a>
# </li>
# <li>
# <a href="/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed selected-init">
# <a>Summer</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/sommer/schweiz/">Regions</a></li>
# <li class="selected">
# <a href="/sommer/schweiz/touren/">Tours</a></li>
# <li>
# <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
# <li>
# <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
# <li>
# <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/sommer/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/sommer/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/sommer/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/sommer/italien/">Italy</a>
# </li>
# <li>
# <a href="/sommer/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/sommer/frankreich/">France</a>
# </li>
# <li>
# <a href="/sommer/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/sommer/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/sommer/polska/">Poland</a>
# </li>
# <li>
# <a href="/sommer/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/sommer/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/sommer/spanien/">Spain</a>
# </li>
# <li>
# <a href="/sommer/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/sommer/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/sommer/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/sommer/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/sommer/wallis/">Valais</a>
# </li>
# <li>
# <a href="/sommer/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/sommer/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/sommer/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/sommer/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/sommer/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/sommer/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/sommer/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/sommer/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/sommer/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="/sommer/schweiz/wetter/prognose/">Weather</a>
# </li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# <li><a href="/sommer/angebote/">Offers</a></li>
# <li><a href="/forum/">Forum</a></li>
# <li>
# <a class="has-avatar" href="/mybergfex/">
# <div class="avatar">
# </div><span class="nav-main-username">MyBergfex</span>
# </a>
# </li>
# <div id="mybergfex"></div>
# </ul>
# </div>
# <div id="dropdown">
# <!-- optional logo in dropdown -->
# <img alt="" border="0" class="dropdown-logo" height="77" src="https://vcdn.bergfex.at/images/resized/5e/5aa28b0e4d23a15e_6c75f271197432f5@2x.png" width="77"/>
# <div class="dropdown-container page-left-margin">
# <div class="dropdown-content"></div>
# <div class="dropdown-close"></div>
# </div>
# </div>
# </nav><!--/page-top-->
# </div>
# <div id="mapactions">
# <div class="map_enable" id="mapaction_enable_big"></div>
# <div class="mapactions-separator"></div>
# <div class="mapactions-buttons">
# <div class="map_enable" id="mapaction_enable"></div>
# <div id="mapaction_help"></div>
# <div id="mapaction_link"></div>
# <div id="mapaction_up"></div>
# <div id="mapaction_down"></div>
# <div id="mapaction_full"></div>
# <div id="mapaction_close"></div>
# </div>
# </div>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/leaflet-1601550149.css" rel="stylesheet"/><div class="leaflet-map" id="siteMap" style="height: 180px; position: absolute; visibility: hidden; z-index: -1;">
# <div id="siteMapCanvas" style="height: 100%; width: 100%;"></div>
# </div>
# <script>
# var leafletMapOptions = {
# idCanvas: 'siteMapCanvas',
# idContainer: 'siteMap',
# minHeight: 350,
# maxHeight: Math.round($(window).height() * 0.66),
# zoom: 10,
# markerLayers: {
# skigebiete: {
# name: 'Ski resorts'
# },
# langlaufen: {
# name: 'Cross-country skiing'
# },
# unterkuenfte: {
# name: 'Accommodation'
# },
# sommerinfos: {
# name: 'Summer'
# },
# wandertouren: {
# name: 'Hiking tours'
# },
# alpintouren: {
# name: 'Alpine tours'
# },
# wintertouren: {
# name: 'Winter tours'
# },
# biketouren: {
# name: 'Bike tours'
# },
# lauftouren: {
# name: 'Running tours'
# },
# badeseen: {
# name: 'Bathing lakes'
# }
# },
# mapTypes: {
# oek: {
# name: 'bergfex OEK',
# title: 'bergfex Österreichische Karte 1:50.000'
# },
# osm: {
# name: 'bergfex OSM',
# title: 'bergfex OpenStreetMap'
# },
# basemap: {
# name: 'Basemap',
# title: 'Basemap Österreich'
# },
# basemapOrtho: {
# name: 'Basemap Orthofoto',
# title: 'Basemap Orthofotos Österreich'
# },
# satellite: {
# name: 'Satellite',
# title: 'Satellite'
# },
# roadmap: {
# name: 'Map',
# title: 'Map'
# }
# },
# overlays: {
# slopes: {
# name: 'Slope gradient'
# }
# },
# controls: {
# mapZoomControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# }
# },
# mapTypeControl: {
# showAsDropDown: function()
# {
# return bergfex.isMobile;
# }
# },
# mapSearchControl: {
# placeholder: 'Search in the map'
# },
# fullScreenControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# },
# title: {
# 'false': 'Vollbild',
# 'true': 'Vollbild verlassen'
# }
# },
# fullscreenContentControl: {
# i18n: {
# 'showContent': 'Inhalt einblenden',
# 'hideContent': 'Inhalt ausblenden'
# }
# },
# elevationControl: {
# i18n: {
# uphill: 'Uphill',
# downhill: 'Downhill',
# length: 'Length',
# height: 'Height'
# }
# },
# osmLegendControl: {
# language: 'en',
# i18n: {
# title: 'Legend'
# }
# },
# oekLegendControl: {
# i18n: {
# title: 'Legend'
# }
# }
# },
# layersDropDownContainer: {
# title: '<strong>Topics</strong> show <div class="layers-icon"></div>'
# }
# };
# $(document).ready(function()
# {
# var isChromium = !!window.chrome;
# if(isChromium) {
# leafletMapOptions.mapTypes.osm.class = bergfex.Leaflet.MapTypes.Osm_Mapboxgl
# }
# bergfex.MapHandler.init(leafletMapOptions);
# });
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/es6-promise.min-1595402129.jsmin.js" type="text/javascript"></script><script>ES6Promise.polyfill();</script>
# <script src="/include/js/leaflet/plugins/mapbox-gl-1.5.0/mapbox-gl.js"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/leaflet-map-1616403708.jsmin.js" type="text/javascript"></script><h1 id="document-title" style="display: none;">BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</h1>
# <!--page-bottom-->
# <div id="page-container">
# <nav class="breadcrumb mobile-hidden">
# <a href="/sommer/schweiz/" title="Summer Switzerland">Summer Switzerland</a> /
# <a class="important" href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </nav>
# <main class="page-left-margin">
# <aside id="nav-side">
# <div class="nav-side-close"></div>
# <div class="logo">
# <img alt="" border="0" height="37.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_ca92b0a06176d736@2x.png" width="133"/>
# </div>
# <div class="location">
# <a class="country" href="/sommer/schweiz/">Switzerland</a> /
# <a class="region" href="/sommer/bern-region/">Swiss plateau</a>
# </div>
# <div class="location-map">
# <div class="locationmap">
# <img alt="" border="0" height="83" src="https://vcdn.bergfex.at/images/resized/47/bb3e2117b44f9a47_a8e041be49be1fcf@2x.png" width="129.5"/>
# <a href="/sommer/schweiz/">
# <img alt="" border="0" class="layer" height="83" src="https://vcdn.bergfex.at/images/resized/6d/0767a6107b78396d_84ed19a8e14775b8@2x.png" width="129.5"/>
# </a>
# </div>
# </div>
# <ul class="tree">
# <li class="level0">
# <a href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/" title="Regions">Regions</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/wetter/prognose/" title="Weather">Weather</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/webcams/" title="Webcams">Webcams</a>
# </li><li class="level1 selected">
# <a href="/sommer/bern-region/touren/" title="Tours">Tours</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/highlights/" title="Highlights">Highlights</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/seen/" title="Bathing lakes">Bathing lakes</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/unterkuenfte/" title="Accommodation">Accommodation</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/pauschalangebote/" title="Offers and All-inclusive prices">Offers and All-inclusive prices</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/sportanbieter/" title="Sports and leisure provider">Sports and leisure provider</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/veranstaltungen/" title="Events">Events</a>
# </li><li class="level0 winter">
# <a href="/bern-region/" title="Ski resorts">Ski resorts</a>
# </li><li class="level0 winter">
# <a href="/bern-region/langlaufen/" title="Cross-country skiing">Cross-country skiing</a>
# </li><li class="level0 winter">
# <a href="/bern-region/snow-parks/" title="Snow parks">Snow parks</a>
# </li></ul>
# <ul class="tree info jblocktruncate" style="max-height: 200px;">
# <li class="level1 label">
# Favourite regions
# </li>
# <li class="level1"><a href="/sommer/bern-stadt/">Bern - Stadt</a></li>
# <li class="level1"><a href="/sommer/emmental/">Emmental</a></li>
# <li class="level1"><a href="/sommer/naturpark-gantrisch/">Naturpark Gantrisch</a></li>
# <li class="level1"><a href="/sommer/oberaargau/">Oberaargau</a></li>
# <li class="level1"><a href="/sommer/burgdorf/">Burgdorf</a></li>
# <li class="level1"><a href="/sommer/muensingen/">Münsingen</a></li>
# <li class="level1"><a href="/sommer/muri-bei-bern/">Muri bei Bern</a></li>
# <li class="level1"><a href="/sommer/laupen/">Laupen</a></li>
# <li class="level1"><a href="/sommer/langenthal/">Langenthal</a></li>
# <li class="level1"><a href="/sommer/lyss/">Lyss</a></li>
# <li class="level1"><a href="/sommer/zollikofen/">Zollikofen</a></li>
# <li class="level1"><a href="/sommer/worb/">Worb</a></li>
# <li class="level1"><a href="/sommer/steffisburg/">Steffisburg</a></li>
# <li class="level1"><a href="/sommer/belp/">Belp</a></li>
# <li class="level1"><a href="/sommer/koeniz/">Köniz</a></li>
# <li class="level1"><a href="/sommer/ostermundigen/">Ostermundigen</a></li>
# <li class="level1"><a href="/sommer/ittigen/">Ittigen</a></li>
# </ul>
# <div style="text-align: center">
# <a class="app-badge googleplay-badge" href="/redirect/f258b4/1231/0/1/https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdeveloper%3Fid%3Dbergfex%2BGmbH" target="_blank" title="Android Apps">
# </a>
# <a class="app-badge appstore-badge" href="/redirect/e29ab4/1230/0/1/https%3A%2F%2Fapps.apple.com%2Fat%2Fdeveloper%2Fbergfex-gmbh%2Fid355025018" target="_blank" title="iPhone Apps"></a>
# </div>
# <script>
# $(document).ready(function() {
# if($.browser){
# if ($.browser.isIOS) {
# $(".googleplay-badge").hide();
# $(".appstore-badge").addClass("big-badge");
# } else if ($.browser.isAndroid) {
# $(".appstore-badge").hide();
# $(".googleplay-badge").addClass("big-badge");
# }
# }
# });
# </script></aside>
# <div class="content" id="detail"><div class="section-left">
# <header>
# <a class="mobile-back mobile-only" href="/sommer/bern-region/">Swiss plateau</a>
# <!--    <div class="nav-side-trigger mobile-only"></div>  -->
# <div class="logo mobile-only">
# <img alt="" border="0" height="25.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_f1f23b72380280e9@2x.png" width="90"/>
# </div>
# <h1>Tours <span class="less-important">Swiss plateau</span>
# </h1><div class="buttons">
# <div class="desktop-only button-small button-small-icon button-small-icon-down" id="btn-map-show">
# Map
# </div>
# <div class="desktop-only button-small button-dark-grey button-small-icon button-small-icon-up" id="btn-map-hide">
# Hide map
# </div>
# </div>
# <div class="clearer"></div>
# </header><hr class="desktop-only"/>
# <form action="/sommer/bern-region/touren/" class="form-horizontal" id="touren_searchform" method="get">
# <div class="box-container mobile-collapsed">
# <div class="box-header mobile-only">
# Touren filtern
# </div>
# <div class="box-content">
# <div class="control-group">
# <label>Region</label>
# <div class="controls">
# <script>
# function locationSelected(data) {
# $("#touren_searchform").attr("action", "/" + data[7] + "/touren/");
# }
# </script>
# <input class="input-100 input-important" id="text_location" name="text_location" placeholder="" style="font-weight: bold;" type="text" value=""/><script>$(document).ready(function() { addAutocompleter('location', '/ajax/jquery/autocompleter/regionen/', 3, 200, 400 , locationSelected); });</script><input id="location" name="location" type="hidden" value=""/>
# </div>
# </div>
# <div class="control-group">
# <label>Tour type</label>
# <div class="controls">
# <select class="input-100" name="type">
# <option value="0">(All)</option>
# <option value="14">Hiking (281)</option>
# <option value="10">Mountainbike (44)</option>
# <option value="17">Thematic route (44)</option>
# <option value="11">Cycling (39)</option>
# <option value="24">Trailrunning (17)</option>
# <option value="12">Racing (11)</option>
# <option value="16">Pilgrimage (11)</option>
# <option value="8">Via ferrata (4)</option>
# <option value="7">High tour (3)</option>
# <option value="13">Long distance cycling (3)</option>
# <option value="30">E-MTB (3)</option>
# <option value="23">Running (3)</option>
# <option value="42">E-Bike (2)</option>
# <option value="3">Ski tour (2)</option>
# <option value="22">Nordic Walking (2)</option>
# <option value="15">long-distance walking trail (1)</option>
# <option value="18">Kayak / Canoe (1)</option>
# <option value="4">Snowshoe (1)</option>
# </select>
# </div>
# </div>
# <div class="control-group">
# <label>Full-text search</label>
# <div class="controls">
# <input class="input-100" name="q" type="text">
# </input></div>
# </div>
# <div class="control-group">
# <label>Fitness</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_kondition">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_kondition">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Technique</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_fahrtechnik">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_fahrtechnik">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Length (km)</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_laenge" placeholder="min." size="2" type="text">
# </input></div>
# <div class="col">
# <input name="max_laenge" placeholder="max." size="2" type="text"/>
# </div>
# </div>
# </div>
# <div class="control-group">
# <label>Altitude metres</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_hm" placeholder="min." size="4" type="text"/>
# </div>
# <div class="col">
# <input name="max_hm" placeholder="max." size="4" type="text"/>
# </div>
# </div>
# </div>
# <input name="search" type="hidden" value="1"/>
# <div class="form-actions nobackground">
# <button class="button button-blue" type="submit">Search</button>
# <a class="button button-grey" href="http://www.bergfex.com/sommer/bern-region/touren/"><span>Reset</span></a>
# </div>
# </div>
# </div>
# </form>
# <div style="float: left; line-height: 24px; font-weight: bold;">
# Seite 2 <span class="less-important">von 472 Tours.</span>
# </div>
# <div class="sort-selector" data-order-selected="DESC" data-sort-selected="Relevanz" style="float: right;">
# <div class="sort-option-active">sortiert nach <span class="sort-name">Relevanz</span></div>
# <div class="sort-options">
# <div class="sort-option" data-order="DESC" data-sort="Relevanz" title="nach Relevanz sortieren">Relevanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Laenge" title="nach längste Distanz sortieren">längste Distanz</div>
# <div class="sort-option" data-order="ASC" data-sort="Laenge" title="nach kürzeste Distanz sortieren">kürzeste Distanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Zeit" title="nach längste Dauer sortieren">längste Dauer</div>
# <div class="sort-option" data-order="ASC" data-sort="Zeit" title="nach kürzeste Dauer sortieren">kürzeste Dauer</div>
# <div class="sort-option" data-order="DESC" data-sort="Hoehenmeter" title="nach meiste Höhenmeter sortieren">meiste Höhenmeter</div>
# <div class="sort-option" data-order="ASC" data-sort="Hoehenmeter" title="nach wenigste Höhenmeter sortieren">wenigste Höhenmeter</div>
# <div class="sort-option" data-order="DESC" data-sort="Kondition" title="nach hohe Kondition sortieren">hohe Kondition</div>
# <div class="sort-option" data-order="ASC" data-sort="Kondition" title="nach niedrige Kondition sortieren">niedrige Kondition</div>
# <div class="sort-option" data-order="DESC" data-sort="Technik" title="nach hohem Technikanspruch sortieren">hohe Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="Technik" title="nach niedrigem Technikanspruch sortieren">niedrige Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="Titel" title="nach Name A-Z sortieren">Name A-Z</div>
# <div class="sort-option" data-order="DESC" data-sort="Titel" title="nach Name Z-A sortieren">Name Z-A</div>
# </div>
# </div>
# <div class="clearer"></div>
# <div class="section">
# <div class="touren-row clickable">
# <a class="tour-preview-gpx" href="/sommer/bern-region/touren/mountainbike/834956,berschel-tour/">
# <img alt="" border="0" class="tour-preview-gpx" height="240" id="834956" src="https://vcdn.bergfex.at/images/resized/00/c23993daaca0fc00_47cdab80a7360a4f@2x.jpg" width="240"/>
# </a>
# <div class="touren-detail">
# <a class="h2" href="/sommer/bern-region/touren/mountainbike
("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackTeaser(teaserId);
#                             });
#                         }
#                     }
#                 }
#
#                 if(typeof outdooractiveTrackingIframeLoaded === "undefined") {
#                     function outdooractiveTrackingIframeLoaded() {
#                         trackOutdooractiveActivities();
#                     }
#                 }
#
#                 $(document).ready(function() {
#                     var $iframe = $("#outdooractive_tracking_iframe");
#
#                     if($iframe.length === 0) {
#                         $("body").append("<iframe id='outdooractive_tracking_iframe' src='//www.bergfex.com/ajax/outdooractive/tracking.php'></iframe>");
#                     } else {
#                         trackOutdooractiveActivities();
#                     }
#                 });
#             </script>
# <script>oaTrackingTeaser.push('8483710');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="690414" height="200" src="https://vcdn.bergfex.at/images/resized/d1/cdfcaf00d8c185d1_e43cb7be9d398e31@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/48799,moosegg-inbegriff-von-aussicht-und-gastlichkeit/" title="Recht anspruchsvolle Rundwanderung über aussichtsreiche Eggen und durch schattenspendende Wälder...">
# Moosegg: Inbegr...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.07</strong>km | <strong>460</strong>hm | <strong>03:20</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="48799" src="https://vcdn.bergfex.at/images/resized/f6/c2775a4c95ab7cf6_5a602d99a86ea463@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('17956755');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1198462" height="200" src="https://vcdn.bergfex.at/images/resized/1c/204cf366eb8aaf1c_3d898e589e352cc7@2x.jpg" title="Axalp – Axalp" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/83713,wanderung-axalp--axalp/" title="Schnitzlerweg zum Hinterburgsee">
# Wanderung Axalp...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>5.22</strong>km | <strong>200</strong>hm | <strong>01:40</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="83713" src="https://vcdn.bergfex.at/images/resized/ee/614ebd00d76fabee_88c9229927ddf249@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('8483794');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="692953" height="200" src="https://vcdn.bergfex.at/images/resized/b7/05980b8ae3e2c7b7_caf419090c0c52c8@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/48925,aussichtsreiche-wege-in-der-adelbodner-bergwelt/" title="Man braucht nicht zwingend in grosse Höhen zu steigen, um malerische Ausblicke in die Bergwelt...">
# Aussichtsreiche...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>8.39</strong>km | <strong>420</strong>hm | <strong>02:30</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="48925" src="https://vcdn.bergfex.at/images/resized/9c/41f24729487ba09c_eca517843a054715@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('15655063');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1216109" height="200" src="https://vcdn.bergfex.at/images/resized/fb/88ab53a017f741fb_e5f641d58b13d34e@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86144,waldhaeusern--beliebtes-ausflugsziel-im-emmental/" title="„Signau…in allen Jahreszeiten schön“. Mit diesem Motto werden die Besucher der Gemeinde-Homepage...">
# Waldhäusern - ...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>9.63</strong>km | <strong>373</strong>hm | <strong>03:00</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86144" src="https://vcdn.bergfex.at/images/resized/c0/763597cd262eb0c0_8638de0c909f0598@2x.jpg" width="240"/>
# </div>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </main>
# <div id="sidebar">
# <div class="adzone_skyscraper partner" data-geo="sommer.schweiz.bern-region" data-tags="" data-zoneid="2" id="adzone_skyscraper"></div>
# </div>
# <!--/page-bottom-->
# </div>
# <div class="clearer"></div>
# <div id="mapsearch-template-h2noresult">
# <h2>Keine Einträge gefunden.</h2>
# </div>
# <div id="mapsearch-template-h2overflow">
# <h2>Es wurden %count% Einträge gefunden. Bitte Suche verfeinern.</h2>
# </div>
# <div id="mapsearch-template-h2local">
# <h2>Lokale Suchergebnisse <span class="less-important">(Distance &lt;= 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2nonlocal">
# <h2>More results <span class="less-important">(Distance &gt; 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2all">
# <h2>All %count% Search results</h2>
# </div>
# <div id="mapsearch-template-line">
# <div class="mapsearch-line">
# <div><a class="name" href="">%name%</a> <span class="region">%region%</span></div>
# <div><span class="type">%type%</span> <span class="elevation">%elevation%</span></div>
# </div>
# </div><footer id="footer">
# <div class="footer-container page-left-margin">
# <div class="footer-location">
# / <a href="/sommer/schweiz/">Summer Switzerland</a> /
# <a href="/sommer/bern-region/">Swiss plateau</a> /
# <strong>Tours</strong>
# </div>
# <ul class="nav-list">
# <li class="has-children collapsed language-select">
# <h2 class="no-select" style="overflow: visible"><span class="mobile-only">Language</span> <span class="flag en"></span> english</h2>
# <ul>
# <li><a href="//www.bergfex.ch/sommer/bern-region/touren/" rel='"nofollow"'>
# <span class="flag de"></span> Deutsch</a></li>
# <li><a href="//www.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag en"></span> English</a></li>
# <li><a href="//www.bergfex.fr/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fr"></span> Français</a></li>
# <li><a href="//it.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag it"></span> Italiano</a></li>
# <li><a href="//www.bergfex.es/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag es"></span> Español</a></li>
# <li><a href="//nl.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag nl"></span> Nederlands</a></li>
# <li><a href="//se.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag se"></span> Svenska</a></li>
# <li><a href="//no.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag no"></span> Norsk</a></li>
# <li><a href="//dk.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag dk"></span> Dansk</a></li>
# <li><a href="//fi.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fi"></span> Suomi</a></li>
# <li><a href="//hu.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hu"></span> Magyar</a></li>
# <li><a href="//www.bergfex.cz/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag cz"></span> český</a></li>
# <li><a href="//www.bergfex.sk/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag sk"></span> Slovensky</a></li>
# <li><a href="//www.bergfex.pl/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag pl"></span> Polski</a></li>
# <li><a href="//hr.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hr"></span> Hrvatski</a></li>
# <li><a href="//www.bergfex.si/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag si"></span> Slovenščina</a></li>
# <li><a href="//ru.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ru"></span> русский</a></li>
# <li><a href="//ro.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ro"></span> Român</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>Themen</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li><a href="/sommer/schweiz/">Summer regions</a></li>
# <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>General</h2>
# <ul>
# <li><a href="/newsletter/">Newsletter</a></li>
# <li><a href="/produkte/">Products</a></li>
# <li><a href="/shop/">Shop</a></li>
# <li><a href="/login/">Login</a></li>
# </ul>
# </li>
# </ul>
# <div id="language-select-overlay"></div>
# <div class="copyright-container">
# <!-- background image -->
# <div class="copyright">Copyright © 1999, 2021 bergfex GmbH. All rights reserved.</div>
# <div class="copyright-links">
# <a href="/datenschutz/">Privacy policy</a> |
# <a href="/impressum/">About us</a> |
# <a href="" id="privacy-manager">Privacy Manager</a>
# </div>
# </div>
# </div>
# </footer></body>
# </html>

# %%
region3
# Out:
# [<li class="has-children collapsed">
#  <a>Winter</a>
#  <ul>
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li>
#  <a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li>
#  <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li>
#  <a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li>
#  <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/sommer/schweiz/">Regions</a></li>
#  <li class="selected">
#  <a href="/sommer/schweiz/touren/">Tours</a></li>
#  <li>
#  <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
#  <li>
#  <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
#  <li>
#  <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/sommer/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/sommer/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/sommer/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/sommer/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/sommer/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/sommer/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/sommer/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/sommer/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/sommer/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/sommer/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/sommer/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/sommer/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/sommer/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/sommer/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/sommer/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/sommer/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/sommer/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/sommer/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/sommer/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/sommer/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/sommer/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/sommer/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/sommer/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/sommer/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Themen</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li><a href="/sommer/schweiz/">Summer regions</a></li>
#  <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/sommer/schweiz/touren/">Tours</a></li>
#  <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>General</h2>
#  <ul>
#  <li><a href="/newsletter/">Newsletter</a></li>
#  <li><a href="/produkte/">Products</a></li>
#  <li><a href="/shop/">Shop</a></li>
#  <li><a href="/login/">Login</a></li>
#  </ul>
#  </li>]

# %%
region_copy = region3.copy()

# %%
region_copy
# Out:
# [<li class="has-children collapsed">
#  <a>Winter</a>
#  <ul>
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li>
#  <a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li>
#  <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li>
#  <a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li>
#  <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Topics</h2>
#  <ul>
#  <li><a href="/sommer/schweiz/">Regions</a></li>
#  <li class="selected">
#  <a href="/sommer/schweiz/touren/">Tours</a></li>
#  <li>
#  <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
#  <li>
#  <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
#  <li>
#  <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Countries</h2>
#  <ul>
#  <li>
#  <a href="/sommer/oesterreich/">Austria</a>
#  </li>
#  <li class="selected">
#  <a href="/sommer/schweiz/">Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/deutschland/">Germany</a>
#  </li>
#  <li>
#  <a href="/sommer/italien/">Italy</a>
#  </li>
#  <li>
#  <a href="/sommer/slovenia/">Slovenia</a>
#  </li>
#  <li>
#  <a href="/sommer/frankreich/">France</a>
#  </li>
#  <li>
#  <a href="/sommer/nederland/">Netherlands</a>
#  </li>
#  <li>
#  <a href="/sommer/belgie/">Belgium</a>
#  </li>
#  <li>
#  <a href="/sommer/polska/">Poland</a>
#  </li>
#  <li>
#  <a href="/sommer/czechia/">Czechia</a>
#  </li>
#  <li>
#  <a href="/sommer/slovakia/">Slovakia</a>
#  </li>
#  <li>
#  <a href="/sommer/spanien/">Spain</a>
#  </li>
#  <li>
#  <a href="/sommer/kroatien/">Croatia</a>
#  </li>
#  <li>
#  <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
#  </li>
#  <li>
#  <a href="/sommer/luxemburg/">Luxembourg</a>
#  </li>
#  <li>
#  <a href="/sommer/liechtenstein/">Liechtenstein</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
#  <h2>Regions</h2>
#  <ul>
#  <li>
#  <a href="/sommer/graubuenden/">Graubünden</a>
#  </li>
#  <li>
#  <a href="/sommer/wallis/">Valais</a>
#  </li>
#  <li>
#  <a href="/sommer/berneroberland/">Bernese Oberland</a>
#  </li>
#  <li>
#  <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
#  </li>
#  <li>
#  <a href="/sommer/zuerich/">Zurich region</a>
#  </li>
#  <li>
#  <a href="/sommer/aargau/">Aargau</a>
#  </li>
#  <li>
#  <a href="/sommer/jura-drei-seen-land/">Jura</a>
#  </li>
#  <li>
#  <a href="/sommer/tessin/">Ticino</a>
#  </li>
#  <li>
#  <a href="/sommer/freiburg-region/">Fribourg</a>
#  </li>
#  <li>
#  <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
#  </li>
#  <li class="selected">
#  <a href="/sommer/bern-region/">Swiss plateau</a>
#  </li>
#  <li>
#  <a href="/sommer/basel-region/">Aargau-Basle</a>
#  </li>
#  <li>
#  <a href="/sommer/genf-region/">Geneva</a>
#  </li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>Themen</h2>
#  <ul>
#  <li><a href="/schweiz/">Ski resorts</a></li>
#  <li><a href="/sommer/schweiz/">Summer regions</a></li>
#  <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
#  <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
#  <li><a href="/sommer/schweiz/touren/">Tours</a></li>
#  <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
#  </ul>
#  </li>,
#  <li class="has-children collapsed">
#  <h2>General</h2>
#  <ul>
#  <li><a href="/newsletter/">Newsletter</a></li>
#  <li><a href="/produkte/">Products</a></li>
#  <li><a href="/shop/">Shop</a></li>
#  <li><a href="/login/">Login</a></li>
#  </ul>
#  </li>]

# %%
soup_region
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</title>
# <script src="https://cdn.stroeerdigitalgroup.de/metatag/live/SDG_ConsentOnly/metaTag.min.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en" http-equiv="Content-Language"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="en" name="language"/>
# <meta content="width=device-width, viewport-fit=cover" name="viewport"/>
# <script type="application/ld+json">
# {
# "@context": "https://schema.org",
# "@type": "Organization",
# "url": "https://www.bergfex.com",
# "logo": "https://www.bergfex.com/images/logo.png"
# }
# </script>
# <meta content="" property="og:title"/>
# <meta content="https://vcdn.bergfex.at/images/resized/d8/a65a94fd11f0d3d8_2931d3a04a0e346a.jpg" property="og:image"/>
# <meta content="image/jpg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="627" property="og:image:height"/>
# <link href="//www.bergfex.ch/sommer/bern-region/touren/" hreflang="de" rel="alternate"/>
# <link href="//www.bergfex.com/sommer/bern-region/touren/" hreflang="en" rel="alternate"/>
# <link href="//www.bergfex.fr/sommer/bern-region/touren/" hreflang="fr" rel="alternate"/>
# <link href="//it.bergfex.com/sommer/bern-region/touren/" hreflang="it" rel="alternate"/>
# <link href="//www.bergfex.es/sommer/bern-region/touren/" hreflang="es" rel="alternate"/>
# <link href="//nl.bergfex.com/sommer/bern-region/touren/" hreflang="nl" rel="alternate"/>
# <link href="//se.bergfex.com/sommer/bern-region/touren/" hreflang="sv" rel="alternate"/>
# <link href="//no.bergfex.com/sommer/bern-region/touren/" hreflang="no" rel="alternate"/>
# <link href="//dk.bergfex.com/sommer/bern-region/touren/" hreflang="da" rel="alternate"/>
# <link href="//fi.bergfex.com/sommer/bern-region/touren/" hreflang="fi" rel="alternate"/>
# <link href="//hu.bergfex.com/sommer/bern-region/touren/" hreflang="hu" rel="alternate"/>
# <link href="//www.bergfex.cz/sommer/bern-region/touren/" hreflang="cs" rel="alternate"/>
# <link href="//sk.bergfex.com/sommer/bern-region/touren/" hreflang="sk" rel="alternate"/>
# <link href="//www.bergfex.pl/sommer/bern-region/touren/" hreflang="pl" rel="alternate"/>
# <link href="//hr.bergfex.com/sommer/bern-region/touren/" hreflang="hr" rel="alternate"/>
# <link href="//www.bergfex.si/sommer/bern-region/touren/" hreflang="sl" rel="alternate"/>
# <link href="//ru.bergfex.com/sommer/bern-region/touren/" hreflang="ru" rel="alternate"/>
# <link href="//ro.bergfex.com/sommer/bern-region/touren/" hreflang="ro" rel="alternate"/>
# <link href="https://plus.google.com/105981749558386334210" rel="publisher"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="//vcdn.bergfex.at/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link color="#1599ff" href="//vcdn.bergfex.at/images/mask-icon.svg" rel="mask-icon"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/bergfex-1615903179.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/sommer-1595402128.css" rel="stylesheet"/>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/print-1606325961.css" media="print" rel="stylesheet"/><script>
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.autoCompleteActive = false;
# bergfex.autoCompleteSuggestionStartChar = 1;
# </script><script>
# // bergfex namespace
# if (typeof bergfex == "undefined") {
# var bergfex = new Object();
# }
# bergfex.staticHost = '//vcdn.bergfex.at';
# bergfex.staticHosts = ['//vcdn.bergfex.at'];
# bergfex.InfobannerCookiesOptions = {
# timesToShow: 3,
# textTitle: "Informationen zu Cookies",
# textInfo:
# "Diese Seite verwendet Cookies. " +
# "Für eine uneingeschränkte Nutzung der Website werden Cookies benötigt. " +
# "Sie stimmen der Verwendung von Cookies durch Anklicken von \"OK\" zu. " +
# "Nähere Informationen finden Sie in unseren ",
# textPolicy: "Datenschutzbedingungen",
# urlPolicy: "/datenschutz/",
# textButton: "OK",
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.1-1595402130.jsmin.js" type="text/javascript"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/js-libs.2-1610094216.jsmin.js" type="text/javascript"></script><script src="//vcdn.bergfex.at/include/js/jquery/plugins/ui/1.10.3/i18n/jquery.ui.datepicker-en.js" type="text/javascript"></script><script>
# var gMapKey = "AIzaSyDhkXDPfuKgSZgCcKfDLRHNZFrsdbfQkiQ";
# var mapEnabled = true;
# var mapHeight = 360;
# bergfex.libs = { };
# bergfex.libs.srcElevLibs = "//vcdn.bergfex.at/include/jsmin/elevationprofile-libs-1595402128.jsmin.js";
# bergfex.libs.srcMapLibs  = "//vcdn.bergfex.at/include/jsmin/map-libs-1601299449.jsmin.js";
# bergfex.season = "sommer";
# </script><script>
# var jBlockTruncateSettings = {
# 'moreText': "show more",
# 'lessText': "less"
# };
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/bergfex-libs-1616068547.jsmin.js" type="text/javascript"></script><meta content="0" name="geonomap"/>
# <meta content="keep" name="geomap"/>
# <meta content="Bundesland_16" name="geocontext"/>
# <meta content="46.939012,8.107910,10,o" name="geoposition"/>
# <meta content="1" name="geotarget"/>
# <meta content="touren" name="geolayer"/>
# <meta content="sommer" name="season"/><meta content="Swiss plateau,Switzerland,Tours," name="keywords"/>
# <meta content="Swiss plateau Switzerland:  - Tours" name="description"/>
# <meta content="app-id=912776148" name="apple-itunes-app">
# </meta></head>
# <body class="site">
# <div id="page-top">
# <!--page-top-->
# <div style="position: absolute;">
# <script src="//script.ioam.de/iam.js" type="text/javascript"></script>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         $(document).ready(function() {
#             var iam_data = {
#                 "st": "bergfex",
#                 "cp": "sommer-nonde",
#                 "sv": "in",  // keine Befragungseinladung
#                 "co": ""  // comment
#             }
#             try {
#                 iom.c(iam_data, 1);
#             } catch(e) {
#             }
#         });
#     </script>
# <!-- /SZM -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-15684980-1"></script>
# <script>
# // https://support.google.com/analytics/answer/10022331?hl=de
# // window['gtag_enable_tcf_support'] = true;
# bergfex.Analytics = {
# send_to: 'UA-15684980-1',
# admask: 'schweiz.bern-region',
# language: 'en',
# page_location: '/sommer/bern-region/touren/?isAjax=1&page=1',
# };
# window.dataLayer = window.dataLayer || [];
# bergfex.gtag = function() {
# dataLayer.push(arguments);
# }
# bergfex.gtag('js', new Date());
# bergfex.gtag('config', 'UA-15684980-1', {
# send_page_view: false,
# custom_map: {
# dimension1: 'admask',
# dimension2: 'language',
# },
# });
# bergfex.gtag('event', 'init');
# window.addEventListener('metaTagSystemCmpChoiceUiShown', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceUiShown');
# });
# window.addEventListener('metaTagSystemCmpChoiceSelected', function (eventObject) {
# bergfex.gtag('event', 'metaTagSystemCmpChoiceSelected');
# });
# // log map views.
# </script></div>
# <nav class="nav-default" id="nav-main">
# <div class="nav-main-trigger-side"></div>
# <a class="logo-bergfex" href="/" title="bergfex Homepage"></a>
# <div class="nav-main-search responsive-only" id="nav-main-search">
# </div>
# <div class="nav-main-user responsive-only">
# <a href="/mybergfex/">
# <div class="avatar">
# </div></a>
# </div>
# <div class="nav-main-trigger"></div>
# <div class="nav-main-close"></div>
# <div class="nav-main-container page-left-margin">
# <div class="nav-search">
# <form action="/sommer/suchen/" autocomplete="off" method="get" name="sitesearch">
# <div class="search-icon"></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" id="search-input-field" maxlength="256" name="q" placeholder="Search" spellcheck="false" type="text"/>
# </form>
# </div>
# <!-- on dropdown, inject logo from mainlogo position via js -->
# <ul class="nav-list">
# <li class="has-children collapsed">
# <a>Winter</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li>
# <a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li>
# <a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/italien/">Italy</a>
# </li>
# <li>
# <a href="/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/frankreich/">France</a>
# </li>
# <li>
# <a href="/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/polska/">Poland</a>
# </li>
# <li>
# <a href="/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/spanien/">Spain</a>
# </li>
# <li>
# <a href="/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/wallis/">Valais</a>
# </li>
# <li>
# <a href="/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed selected-init">
# <a>Summer</a>
# <ul>
# <li class="has-children collapsed">
# <h2>Topics</h2>
# <ul>
# <li><a href="/sommer/schweiz/">Regions</a></li>
# <li class="selected">
# <a href="/sommer/schweiz/touren/">Tours</a></li>
# <li>
# <a href="/sommer/schweiz/highlights/">Leisure tips</a></li>
# <li>
# <a href="/sommer/schweiz/seen/">Bathing lakes</a></li>
# <li>
# <a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Countries</h2>
# <ul>
# <li>
# <a href="/sommer/oesterreich/">Austria</a>
# </li>
# <li class="selected">
# <a href="/sommer/schweiz/">Switzerland</a>
# </li>
# <li>
# <a href="/sommer/deutschland/">Germany</a>
# </li>
# <li>
# <a href="/sommer/italien/">Italy</a>
# </li>
# <li>
# <a href="/sommer/slovenia/">Slovenia</a>
# </li>
# <li>
# <a href="/sommer/frankreich/">France</a>
# </li>
# <li>
# <a href="/sommer/nederland/">Netherlands</a>
# </li>
# <li>
# <a href="/sommer/belgie/">Belgium</a>
# </li>
# <li>
# <a href="/sommer/polska/">Poland</a>
# </li>
# <li>
# <a href="/sommer/czechia/">Czechia</a>
# </li>
# <li>
# <a href="/sommer/slovakia/">Slovakia</a>
# </li>
# <li>
# <a href="/sommer/spanien/">Spain</a>
# </li>
# <li>
# <a href="/sommer/kroatien/">Croatia</a>
# </li>
# <li>
# <a href="/sommer/bosnien-herzegowina/">Bosnia and Herzegovina</a>
# </li>
# <li>
# <a href="/sommer/luxemburg/">Luxembourg</a>
# </li>
# <li>
# <a href="/sommer/liechtenstein/">Liechtenstein</a>
# </li>
# </ul>
# </li>
# <li class="has-children collapsed"> <!-- define max height for section, overflow scroll -->
# <h2>Regions</h2>
# <ul>
# <li>
# <a href="/sommer/graubuenden/">Graubünden</a>
# </li>
# <li>
# <a href="/sommer/wallis/">Valais</a>
# </li>
# <li>
# <a href="/sommer/berneroberland/">Bernese Oberland</a>
# </li>
# <li>
# <a href="/sommer/luzern-vierwaldstaettersee/">Central Switzerland</a>
# </li>
# <li>
# <a href="/sommer/ostschweiz/">Eastern Switzerland</a>
# </li>
# <li>
# <a href="/sommer/zuerich/">Zurich region</a>
# </li>
# <li>
# <a href="/sommer/aargau/">Aargau</a>
# </li>
# <li>
# <a href="/sommer/jura-drei-seen-land/">Jura</a>
# </li>
# <li>
# <a href="/sommer/tessin/">Ticino</a>
# </li>
# <li>
# <a href="/sommer/freiburg-region/">Fribourg</a>
# </li>
# <li>
# <a href="/sommer/genferseegebiet-waadtland/">Vaud / Lake Geneva Region</a>
# </li>
# <li class="selected">
# <a href="/sommer/bern-region/">Swiss plateau</a>
# </li>
# <li>
# <a href="/sommer/basel-region/">Aargau-Basle</a>
# </li>
# <li>
# <a href="/sommer/genf-region/">Geneva</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="/sommer/schweiz/wetter/prognose/">Weather</a>
# </li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# <li><a href="/sommer/angebote/">Offers</a></li>
# <li><a href="/forum/">Forum</a></li>
# <li>
# <a class="has-avatar" href="/mybergfex/">
# <div class="avatar">
# </div><span class="nav-main-username">MyBergfex</span>
# </a>
# </li>
# <div id="mybergfex"></div>
# </ul>
# </div>
# <div id="dropdown">
# <!-- optional logo in dropdown -->
# <img alt="" border="0" class="dropdown-logo" height="77" src="https://vcdn.bergfex.at/images/resized/5e/5aa28b0e4d23a15e_6c75f271197432f5@2x.png" width="77"/>
# <div class="dropdown-container page-left-margin">
# <div class="dropdown-content"></div>
# <div class="dropdown-close"></div>
# </div>
# </div>
# </nav><!--/page-top-->
# </div>
# <div id="mapactions">
# <div class="map_enable" id="mapaction_enable_big"></div>
# <div class="mapactions-separator"></div>
# <div class="mapactions-buttons">
# <div class="map_enable" id="mapaction_enable"></div>
# <div id="mapaction_help"></div>
# <div id="mapaction_link"></div>
# <div id="mapaction_up"></div>
# <div id="mapaction_down"></div>
# <div id="mapaction_full"></div>
# <div id="mapaction_close"></div>
# </div>
# </div>
# <link charset="utf-8" href="//vcdn.bergfex.at/include/cssmin/leaflet-1601550149.css" rel="stylesheet"/><div class="leaflet-map" id="siteMap" style="height: 180px; position: absolute; visibility: hidden; z-index: -1;">
# <div id="siteMapCanvas" style="height: 100%; width: 100%;"></div>
# </div>
# <script>
# var leafletMapOptions = {
# idCanvas: 'siteMapCanvas',
# idContainer: 'siteMap',
# minHeight: 350,
# maxHeight: Math.round($(window).height() * 0.66),
# zoom: 10,
# markerLayers: {
# skigebiete: {
# name: 'Ski resorts'
# },
# langlaufen: {
# name: 'Cross-country skiing'
# },
# unterkuenfte: {
# name: 'Accommodation'
# },
# sommerinfos: {
# name: 'Summer'
# },
# wandertouren: {
# name: 'Hiking tours'
# },
# alpintouren: {
# name: 'Alpine tours'
# },
# wintertouren: {
# name: 'Winter tours'
# },
# biketouren: {
# name: 'Bike tours'
# },
# lauftouren: {
# name: 'Running tours'
# },
# badeseen: {
# name: 'Bathing lakes'
# }
# },
# mapTypes: {
# oek: {
# name: 'bergfex OEK',
# title: 'bergfex Österreichische Karte 1:50.000'
# },
# osm: {
# name: 'bergfex OSM',
# title: 'bergfex OpenStreetMap'
# },
# basemap: {
# name: 'Basemap',
# title: 'Basemap Österreich'
# },
# basemapOrtho: {
# name: 'Basemap Orthofoto',
# title: 'Basemap Orthofotos Österreich'
# },
# satellite: {
# name: 'Satellite',
# title: 'Satellite'
# },
# roadmap: {
# name: 'Map',
# title: 'Map'
# }
# },
# overlays: {
# slopes: {
# name: 'Slope gradient'
# }
# },
# controls: {
# mapZoomControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# }
# },
# mapTypeControl: {
# showAsDropDown: function()
# {
# return bergfex.isMobile;
# }
# },
# mapSearchControl: {
# placeholder: 'Search in the map'
# },
# fullScreenControl: {
# visible: function()
# {
# return !bergfex.isMobile;
# },
# title: {
# 'false': 'Vollbild',
# 'true': 'Vollbild verlassen'
# }
# },
# fullscreenContentControl: {
# i18n: {
# 'showContent': 'Inhalt einblenden',
# 'hideContent': 'Inhalt ausblenden'
# }
# },
# elevationControl: {
# i18n: {
# uphill: 'Uphill',
# downhill: 'Downhill',
# length: 'Length',
# height: 'Height'
# }
# },
# osmLegendControl: {
# language: 'en',
# i18n: {
# title: 'Legend'
# }
# },
# oekLegendControl: {
# i18n: {
# title: 'Legend'
# }
# }
# },
# layersDropDownContainer: {
# title: '<strong>Topics</strong> show <div class="layers-icon"></div>'
# }
# };
# $(document).ready(function()
# {
# var isChromium = !!window.chrome;
# if(isChromium) {
# leafletMapOptions.mapTypes.osm.class = bergfex.Leaflet.MapTypes.Osm_Mapboxgl
# }
# bergfex.MapHandler.init(leafletMapOptions);
# });
# </script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/es6-promise.min-1595402129.jsmin.js" type="text/javascript"></script><script>ES6Promise.polyfill();</script>
# <script src="/include/js/leaflet/plugins/mapbox-gl-1.5.0/mapbox-gl.js"></script>
# <script charset="utf-8" src="//vcdn.bergfex.at/include/jsmin/leaflet-map-1616403708.jsmin.js" type="text/javascript"></script><h1 id="document-title" style="display: none;">BERGFEX-  Swiss plateau - Hiking &amp; Mountain biking</h1>
# <!--page-bottom-->
# <div id="page-container">
# <nav class="breadcrumb mobile-hidden">
# <a href="/sommer/schweiz/" title="Summer Switzerland">Summer Switzerland</a> /
# <a class="important" href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </nav>
# <main class="page-left-margin">
# <aside id="nav-side">
# <div class="nav-side-close"></div>
# <div class="logo">
# <img alt="" border="0" height="37.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_ca92b0a06176d736@2x.png" width="133"/>
# </div>
# <div class="location">
# <a class="country" href="/sommer/schweiz/">Switzerland</a> /
# <a class="region" href="/sommer/bern-region/">Swiss plateau</a>
# </div>
# <div class="location-map">
# <div class="locationmap">
# <img alt="" border="0" height="83" src="https://vcdn.bergfex.at/images/resized/47/bb3e2117b44f9a47_a8e041be49be1fcf@2x.png" width="129.5"/>
# <a href="/sommer/schweiz/">
# <img alt="" border="0" class="layer" height="83" src="https://vcdn.bergfex.at/images/resized/6d/0767a6107b78396d_84ed19a8e14775b8@2x.png" width="129.5"/>
# </a>
# </div>
# </div>
# <ul class="tree">
# <li class="level0">
# <a href="/sommer/bern-region/" title="Swiss plateau">Swiss plateau</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/" title="Regions">Regions</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/wetter/prognose/" title="Weather">Weather</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/webcams/" title="Webcams">Webcams</a>
# </li><li class="level1 selected">
# <a href="/sommer/bern-region/touren/" title="Tours">Tours</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/highlights/" title="Highlights">Highlights</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/seen/" title="Bathing lakes">Bathing lakes</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/unterkuenfte/" title="Accommodation">Accommodation</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/pauschalangebote/" title="Offers and All-inclusive prices">Offers and All-inclusive prices</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/sportanbieter/" title="Sports and leisure provider">Sports and leisure provider</a>
# </li><li class="level1">
# <a href="/sommer/bern-region/veranstaltungen/" title="Events">Events</a>
# </li><li class="level0 winter">
# <a href="/bern-region/" title="Ski resorts">Ski resorts</a>
# </li><li class="level0 winter">
# <a href="/bern-region/langlaufen/" title="Cross-country skiing">Cross-country skiing</a>
# </li><li class="level0 winter">
# <a href="/bern-region/snow-parks/" title="Snow parks">Snow parks</a>
# </li></ul>
# <ul class="tree info jblocktruncate" style="max-height: 200px;">
# <li class="level1 label">
# Favourite regions
# </li>
# <li class="level1"><a href="/sommer/bern-stadt/">Bern - Stadt</a></li>
# <li class="level1"><a href="/sommer/emmental/">Emmental</a></li>
# <li class="level1"><a href="/sommer/naturpark-gantrisch/">Naturpark Gantrisch</a></li>
# <li class="level1"><a href="/sommer/oberaargau/">Oberaargau</a></li>
# <li class="level1"><a href="/sommer/burgdorf/">Burgdorf</a></li>
# <li class="level1"><a href="/sommer/muensingen/">Münsingen</a></li>
# <li class="level1"><a href="/sommer/muri-bei-bern/">Muri bei Bern</a></li>
# <li class="level1"><a href="/sommer/laupen/">Laupen</a></li>
# <li class="level1"><a href="/sommer/langenthal/">Langenthal</a></li>
# <li class="level1"><a href="/sommer/lyss/">Lyss</a></li>
# <li class="level1"><a href="/sommer/zollikofen/">Zollikofen</a></li>
# <li class="level1"><a href="/sommer/worb/">Worb</a></li>
# <li class="level1"><a href="/sommer/steffisburg/">Steffisburg</a></li>
# <li class="level1"><a href="/sommer/belp/">Belp</a></li>
# <li class="level1"><a href="/sommer/koeniz/">Köniz</a></li>
# <li class="level1"><a href="/sommer/ostermundigen/">Ostermundigen</a></li>
# <li class="level1"><a href="/sommer/ittigen/">Ittigen</a></li>
# </ul>
# <div style="text-align: center">
# <a class="app-badge googleplay-badge" href="/redirect/f258b4/1231/0/1/https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdeveloper%3Fid%3Dbergfex%2BGmbH" target="_blank" title="Android Apps">
# </a>
# <a class="app-badge appstore-badge" href="/redirect/e29ab4/1230/0/1/https%3A%2F%2Fapps.apple.com%2Fat%2Fdeveloper%2Fbergfex-gmbh%2Fid355025018" target="_blank" title="iPhone Apps"></a>
# </div>
# <script>
# $(document).ready(function() {
# if($.browser){
# if ($.browser.isIOS) {
# $(".googleplay-badge").hide();
# $(".appstore-badge").addClass("big-badge");
# } else if ($.browser.isAndroid) {
# $(".appstore-badge").hide();
# $(".googleplay-badge").addClass("big-badge");
# }
# }
# });
# </script></aside>
# <div class="content" id="detail"><div class="section-left">
# <header>
# <a class="mobile-back mobile-only" href="/sommer/bern-region/">Swiss plateau</a>
# <!--    <div class="nav-side-trigger mobile-only"></div>  -->
# <div class="logo mobile-only">
# <img alt="" border="0" height="25.5" src="https://vcdn.bergfex.at/images/resized/59/0e1e334abfcc0759_f1f23b72380280e9@2x.png" width="90"/>
# </div>
# <h1>Tours <span class="less-important">Swiss plateau</span>
# </h1><div class="buttons">
# <div class="desktop-only button-small button-small-icon button-small-icon-down" id="btn-map-show">
# Map
# </div>
# <div class="desktop-only button-small button-dark-grey button-small-icon button-small-icon-up" id="btn-map-hide">
# Hide map
# </div>
# </div>
# <div class="clearer"></div>
# </header><hr class="desktop-only"/>
# <form action="/sommer/bern-region/touren/" class="form-horizontal" id="touren_searchform" method="get">
# <div class="box-container mobile-collapsed">
# <div class="box-header mobile-only">
# Touren filtern
# </div>
# <div class="box-content">
# <div class="control-group">
# <label>Region</label>
# <div class="controls">
# <script>
# function locationSelected(data) {
# $("#touren_searchform").attr("action", "/" + data[7] + "/touren/");
# }
# </script>
# <input class="input-100 input-important" id="text_location" name="text_location" placeholder="" style="font-weight: bold;" type="text" value=""/><script>$(document).ready(function() { addAutocompleter('location', '/ajax/jquery/autocompleter/regionen/', 3, 200, 400 , locationSelected); });</script><input id="location" name="location" type="hidden" value=""/>
# </div>
# </div>
# <div class="control-group">
# <label>Tour type</label>
# <div class="controls">
# <select class="input-100" name="type">
# <option value="0">(All)</option>
# <option value="14">Hiking (281)</option>
# <option value="10">Mountainbike (44)</option>
# <option value="17">Thematic route (44)</option>
# <option value="11">Cycling (39)</option>
# <option value="24">Trailrunning (17)</option>
# <option value="12">Racing (11)</option>
# <option value="16">Pilgrimage (11)</option>
# <option value="8">Via ferrata (4)</option>
# <option value="7">High tour (3)</option>
# <option value="13">Long distance cycling (3)</option>
# <option value="30">E-MTB (3)</option>
# <option value="23">Running (3)</option>
# <option value="42">E-Bike (2)</option>
# <option value="3">Ski tour (2)</option>
# <option value="22">Nordic Walking (2)</option>
# <option value="15">long-distance walking trail (1)</option>
# <option value="18">Kayak / Canoe (1)</option>
# <option value="4">Snowshoe (1)</option>
# </select>
# </div>
# </div>
# <div class="control-group">
# <label>Full-text search</label>
# <div class="controls">
# <input class="input-100" name="q" type="text">
# </input></div>
# </div>
# <div class="control-group">
# <label>Fitness</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_kondition">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_kondition">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Technique</label>
# <div class="controls grid cols2">
# <div class="col">
# <select name="min_fahrtechnik">
# <option value="">min.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# <div class="col">
# <select name="max_fahrtechnik">
# <option value="">max.</option>
# <option value="1">1 easy</option>
# <option value="2">2 moderate</option>
# <option value="3">3 medium difficulty</option>
# <option value="4">4 difficult</option>
# <option value="5">5 very difficult</option>
# <option value="6">6 extremely</option>
# </select></div>
# </div>
# </div>
# <div class="control-group">
# <label>Length (km)</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_laenge" placeholder="min." size="2" type="text">
# </input></div>
# <div class="col">
# <input name="max_laenge" placeholder="max." size="2" type="text"/>
# </div>
# </div>
# </div>
# <div class="control-group">
# <label>Altitude metres</label>
# <div class="controls grid cols2">
# <div class="col">
# <input name="min_hm" placeholder="min." size="4" type="text"/>
# </div>
# <div class="col">
# <input name="max_hm" placeholder="max." size="4" type="text"/>
# </div>
# </div>
# </div>
# <input name="search" type="hidden" value="1"/>
# <div class="form-actions nobackground">
# <button class="button button-blue" type="submit">Search</button>
# <a class="button button-grey" href="http://www.bergfex.com/sommer/bern-region/touren/"><span>Reset</span></a>
# </div>
# </div>
# </div>
# </form>
# <div style="float: left; line-height: 24px; font-weight: bold;">
# Seite 2 <span class="less-important">von 472 Tours.</span>
# </div>
# <div class="sort-selector" data-order-selected="DESC" data-sort-selected="Relevanz" style="float: right;">
# <div class="sort-option-active">sortiert nach <span class="sort-name">Relevanz</span></div>
# <div class="sort-options">
# <div class="sort-option" data-order="DESC" data-sort="Relevanz" title="nach Relevanz sortieren">Relevanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Laenge" title="nach längste Distanz sortieren">längste Distanz</div>
# <div class="sort-option" data-order="ASC" data-sort="Laenge" title="nach kürzeste Distanz sortieren">kürzeste Distanz</div>
# <div class="sort-option" data-order="DESC" data-sort="Zeit" title="nach längste Dauer sortieren">längste Dauer</div>
# <div class="sort-option" data-order="ASC" data-sort="Zeit" title="nach kürzeste Dauer sortieren">kürzeste Dauer</div>
# <div class="sort-option" data-order="DESC" data-sort="Hoehenmeter" title="nach meiste Höhenmeter sortieren">meiste Höhenmeter</div>
# <div class="sort-option" data-order="ASC" data-sort="Hoehenmeter" title="nach wenigste Höhenmeter sortieren">wenigste Höhenmeter</div>
# <div class="sort-option" data-order="DESC" data-sort="Kondition" title="nach hohe Kondition sortieren">hohe Kondition</div>
# <div class="sort-option" data-order="ASC" data-sort="Kondition" title="nach niedrige Kondition sortieren">niedrige Kondition</div>
# <div class="sort-option" data-order="DESC" data-sort="Technik" title="nach hohem Technikanspruch sortieren">hohe Technik</div>
# <div class="sort-option" data-order="ASC" data-sort="
# <li><a href="/sommer/basel-region/touren/">Aargau-Basle</a></li>
# <li><a href="/sommer/genf-region/touren/">Geneva</a></li>
# </ul>
# </div>
# </div>
# </div><div class="adzone_content partner" data-geo="sommer.schweiz.bern-region" data-tags="" data-zoneid="46" id="adzone_content"></div>
# <div class="section">
# <h3>Popular tours in the area</h3>
# <script>
#                 var oaTrackingDetail = null;
#                 var oaTrackingTeaser = [];
#
#                 if(typeof trackOutdooractiveActivities === "undefined") {
#                     function trackOutdooractiveActivities() {
#                         if (oaTrackingDetail !== null) {
#                             $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackDetail(oaTrackingDetail);
#                         }
#                         if (oaTrackingTeaser.length > 0) {
#                             _.forEach(oaTrackingTeaser, function(teaserId) {
#                                 $("#outdooractive_tracking_iframe").get(0).contentWindow.oax.api.trackTeaser(teaserId);
#                             });
#                         }
#                     }
#                 }
#
#                 if(typeof outdooractiveTrackingIframeLoaded === "undefined") {
#                     function outdooractiveTrackingIframeLoaded() {
#                         trackOutdooractiveActivities();
#                     }
#                 }
#
#                 $(document).ready(function() {
#                     var $iframe = $("#outdooractive_tracking_iframe");
#
#                     if($iframe.length === 0) {
#                         $("body").append("<iframe id='outdooractive_tracking_iframe' src='//www.bergfex.com/ajax/outdooractive/tracking.php'></iframe>");
#                     } else {
#                         trackOutdooractiveActivities();
#                     }
#                 });
#             </script>
# <script>oaTrackingTeaser.push('8483710');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="690414" height="200" src="https://vcdn.bergfex.at/images/resized/d1/cdfcaf00d8c185d1_e43cb7be9d398e31@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/48799,moosegg-inbegriff-von-aussicht-und-gastlichkeit/" title="Recht anspruchsvolle Rundwanderung über aussichtsreiche Eggen und durch schattenspendende Wälder...">
# Moosegg: Inbegr...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>10.07</strong>km | <strong>460</strong>hm | <strong>03:20</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="48799" src="https://vcdn.bergfex.at/images/resized/f6/c2775a4c95ab7cf6_5a602d99a86ea463@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('17956755');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1198462" height="200" src="https://vcdn.bergfex.at/images/resized/1c/204cf366eb8aaf1c_3d898e589e352cc7@2x.jpg" title="Axalp – Axalp" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/83713,wanderung-axalp--axalp/" title="Schnitzlerweg zum Hinterburgsee">
# Wanderung Axalp...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>5.22</strong>km | <strong>200</strong>hm | <strong>01:40</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="83713" src="https://vcdn.bergfex.at/images/resized/ee/614ebd00d76fabee_88c9229927ddf249@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('8483794');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="692953" height="200" src="https://vcdn.bergfex.at/images/resized/b7/05980b8ae3e2c7b7_caf419090c0c52c8@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/48925,aussichtsreiche-wege-in-der-adelbodner-bergwelt/" title="Man braucht nicht zwingend in grosse Höhen zu steigen, um malerische Ausblicke in die Bergwelt...">
# Aussichtsreiche...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-1">
# easy
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>8.39</strong>km | <strong>420</strong>hm | <strong>02:30</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="48925" src="https://vcdn.bergfex.at/images/resized/9c/41f24729487ba09c_eca517843a054715@2x.jpg" width="240"/>
# </div>
# </div>
# <script>oaTrackingTeaser.push('15655063');</script>
# <div class="teaser-tour clickable">
# <img alt="" border="0" class="background" data-id="1216109" height="200" src="https://vcdn.bergfex.at/images/resized/fb/88ab53a017f741fb_e5f641d58b13d34e@2x.jpg" width="300"/>
# <div class="img-title-overlay">
# <h3>
# <a href="/sommer/bern-region/touren/wanderung/86144,waldhaeusern--beliebtes-ausflugsziel-im-emmental/" title="„Signau…in allen Jahreszeiten schön“. Mit diesem Motto werden die Besucher der Gemeinde-Homepage...">
# Waldhäusern - ...
# </a>
# </h3>
# <div>
# <span class="tour-difficulty tour-difficulty-2">
# medium
# </span>
# <span class="tour-type">
# Hiking
# </span>
# </div>
# <div class="smaller">
# <strong>9.63</strong>km | <strong>373</strong>hm | <strong>03:00</strong>h
# </div>
# <img alt="" border="0" class="gpx" height="240" id="86144" src="https://vcdn.bergfex.at/images/resized/c0/763597cd262eb0c0_8638de0c909f0598@2x.jpg" width="240"/>
# </div>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </main>
# <div id="sidebar">
# <div class="adzone_skyscraper partner" data-geo="sommer.schweiz.bern-region" data-tags="" data-zoneid="2" id="adzone_skyscraper"></div>
# </div>
# <!--/page-bottom-->
# </div>
# <div class="clearer"></div>
# <div id="mapsearch-template-h2noresult">
# <h2>Keine Einträge gefunden.</h2>
# </div>
# <div id="mapsearch-template-h2overflow">
# <h2>Es wurden %count% Einträge gefunden. Bitte Suche verfeinern.</h2>
# </div>
# <div id="mapsearch-template-h2local">
# <h2>Lokale Suchergebnisse <span class="less-important">(Distance &lt;= 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2nonlocal">
# <h2>More results <span class="less-important">(Distance &gt; 25km)</span></h2>
# </div>
# <div id="mapsearch-template-h2all">
# <h2>All %count% Search results</h2>
# </div>
# <div id="mapsearch-template-line">
# <div class="mapsearch-line">
# <div><a class="name" href="">%name%</a> <span class="region">%region%</span></div>
# <div><span class="type">%type%</span> <span class="elevation">%elevation%</span></div>
# </div>
# </div><footer id="footer">
# <div class="footer-container page-left-margin">
# <div class="footer-location">
# / <a href="/sommer/schweiz/">Summer Switzerland</a> /
# <a href="/sommer/bern-region/">Swiss plateau</a> /
# <strong>Tours</strong>
# </div>
# <ul class="nav-list">
# <li class="has-children collapsed language-select">
# <h2 class="no-select" style="overflow: visible"><span class="mobile-only">Language</span> <span class="flag en"></span> english</h2>
# <ul>
# <li><a href="//www.bergfex.ch/sommer/bern-region/touren/" rel='"nofollow"'>
# <span class="flag de"></span> Deutsch</a></li>
# <li><a href="//www.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag en"></span> English</a></li>
# <li><a href="//www.bergfex.fr/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fr"></span> Français</a></li>
# <li><a href="//it.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag it"></span> Italiano</a></li>
# <li><a href="//www.bergfex.es/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag es"></span> Español</a></li>
# <li><a href="//nl.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag nl"></span> Nederlands</a></li>
# <li><a href="//se.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag se"></span> Svenska</a></li>
# <li><a href="//no.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag no"></span> Norsk</a></li>
# <li><a href="//dk.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag dk"></span> Dansk</a></li>
# <li><a href="//fi.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag fi"></span> Suomi</a></li>
# <li><a href="//hu.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hu"></span> Magyar</a></li>
# <li><a href="//www.bergfex.cz/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag cz"></span> český</a></li>
# <li><a href="//www.bergfex.sk/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag sk"></span> Slovensky</a></li>
# <li><a href="//www.bergfex.pl/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag pl"></span> Polski</a></li>
# <li><a href="//hr.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag hr"></span> Hrvatski</a></li>
# <li><a href="//www.bergfex.si/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag si"></span> Slovenščina</a></li>
# <li><a href="//ru.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ru"></span> русский</a></li>
# <li><a href="//ro.bergfex.com/sommer/bern-region/touren/" rel='"nofollow"'><span class="flag ro"></span> Român</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>Themen</h2>
# <ul>
# <li><a href="/schweiz/">Ski resorts</a></li>
# <li><a href="/sommer/schweiz/">Summer regions</a></li>
# <li><a href="/schweiz/snow-parks/">Snow parks</a></li>
# <li><a href="/schweiz/langlaufen/">Cross-country skiing</a></li>
# <li><a href="/sommer/schweiz/touren/">Tours</a></li>
# <li><a href="/sommer/schweiz/unterkuenfte/">Accommodation</a></li>
# </ul>
# </li>
# <li class="has-children collapsed">
# <h2>General</h2>
# <ul>
# <li><a href="/newsletter/">Newsletter</a></li>
# <li><a href="/produkte/">Products</a></li>
# <li><a href="/shop/">Shop</a></li>
# <li><a href="/login/">Login</a></li>
# </ul>
# </li>
# </ul>
# <div id="language-select-overlay"></div>
# <div class="copyright-container">
# <!-- background image -->
# <div class="copyright">Copyright © 1999, 2021 bergfex GmbH. All rights reserved.</div>
# <div class="copyright-links">
# <a href="/datenschutz/">Privacy policy</a> |
# <a href="/impressum/">About us</a> |
# <a href="" id="privacy-manager">Privacy Manager</a>
# </div>
# </div>
# </div>
# </footer></body>
# </html>

# %% [markdown]
# ###  1.6 Combine all in scraping function

# %% [markdown]
# To be able to repeat the same steps for a different region (for example "Wallis"), we put the scraping code into a function. Here we can choose the region, how many pages we want to scrape and whether we want to save the file as CSV.

# %%
def scraping_region(region, n_pages):
    title = []  # Title of the tour
    difficulty = []  # difficulty (easy, medium, hard)
    sport = []  # Sport type (hiking, sledging, snowshoe...)
    length = []  # length in km
    time_list = []  # tour time in hours:minutes
    climb = []  # positive elevation climb in m
    minmax = []  # minimum and maximum altitude of the tour in m
    total_title = [] # will help extracting the ID of the tour
    # all ratings are stored together so we will need this along the way:
    rating = []  # list to store technique and fitness rating info
    
    # looping over the x first pages of Bergfex
    # each separate tour on the page is framed by a div tag with 'touren-details'
    page_number = n_pages  # number of pages we want to scap through

    for p in range(1, (page_number+1)):
        base_link = f'https://www.bergfex.com/sommer/{region}/touren/?isAjax=1&page='
        link = base_link+str(p)  # going over p pages with numbers appended to the base link
        page = requests.get(link, timeout=5)
        print("scraped page", p)
        soup = BeautifulSoup(page.content, "html.parser")  # bs4.BeautifulSoup object
        tours = soup.findAll('div', {'class': 'touren-detail'})  # checks for the separate tours on the page

    # For each page, we loop over each tour and fill our lists with info     
        for i in range(0,len(tours)):
            tour_1 = tours[i] # tour iterating over the 20 tours of the page

            tour_title = tour_1.findAll('a' ) # this gets the title out
            title.append([info.get_text().strip() for info in tour_title])
            total_title.append(tour_title) 
            # this gets the full tour-title information including the ID, processed further later on

            tour_diff = tour_1.findAll('span', {'class': 'tour-difficulty'}) #tour level difficulty
            difficulty.append([info.get_text().strip() for info in tour_diff])

            tour_type = tour_1.findAll('span', {'class': 'tour-type'}) # putting type into sports
            sport.append([info.get_text().strip() for info in tour_type])

            tour_stats = tour_1.findAll('div', {'class': 'tour-stats'}) # stats has 4 info binned together
            stat_text = [info.get_text().strip() for info in tour_stats]
            length.append(stat_text[0])
            time_list.append(stat_text[1])
            climb.append(stat_text[2])
            minmax.append(stat_text[3])

            tour_rating = tour_1.find_all("div", {'class': 'tour-rating'}) # getting the rating data 
            rating.append([info for info in tour_rating])   # it's a class name so we can't get_text.
    print("number of tours collected:", len(title))
    return (title, difficulty, sport, length, time_list, climb, minmax, total_title, rating)

# %%
def extracting_id(total_title):
    links_title = []
    for i in total_title:
        i = str(i)
        i = i.strip('[]')
        links_title.append(i)
    # Extracting ID
    id_df3 = pd.DataFrame(links_title)
    id_df2 = id_df3[0].str.split(' ',expand = True)
    id_df1 = id_df2[2].str.split(',',expand = True)
    id_df = id_df1[0].str.split('/',expand = True)
    
    return id_df

# %%
def extracting_rating(rating):
    technique = []  # technique difficulty ratings (out of 6)
    fitness = []  # fitness difficulty ratings (out of 6)
    # Replace unwanted information
    tour_rating_str = str(rating)
    rating_all_short = tour_rating_str.replace(
    '<div class="tour-rating">\n<div class="tour-rating-label">Technique</div>\n<div class="rating-circles rating-max6"><div class="',''
    ).replace(
        '<div class="tour-rating">\n<div class="tour-rating-label">Fitness</div>\n<div class="rating-circles rating-max6"><div class="','').replace('"></div></div>\n</div>',"")
    rating_even_shorter = rating_all_short.replace('[','').replace(']','')
    rating_list = rating_even_shorter.split(", ")

    for i in range(0,(len(rating_list))):
        if i == 0:
            technique.append(rating_list[i]) # add first item in technique
        elif i % 2 == 0:
            technique.append(rating_list[i]) # then every second item as well
        else:
            fitness.append(rating_list[i]) # the other appended to fitness list
    return technique, fitness

# %%
def create_scraped_df(region, n_pages, save_as_csv = True):
    title, difficulty, sport, length, time_list, climb, minmax, total_title, rating = scraping_region(
        region, n_pages)
    id_df = extracting_id(total_title)
    technique, fitness = extracting_rating(rating)
    activities_df_unclean = pd.DataFrame(
    {'title': title,
     'difficulty': difficulty,
     'sport': sport,
     'length': length,
     'time': time_list,
     'climb': climb,
     'minmax': minmax,
     'technique': technique,
     'fitness': fitness
    })
    activities_df_unclean['ID']= id_df.iloc[:,5].copy() # add the ID columns from an earlier DF
    
    if save_as_csv == True:
        activities_df_unclean.to_csv(f"../data/unclean_activities_{region}.csv", index=False)
        
    return activities_df_unclean

# %% [markdown]
# Let's test it with different regions

# %%
region2 = "wallis"
n_pages2 = 20
#create_scraped_df(region2, n_pages2, save_as_csv = True)
#create_scraped_df('bern-region', n_pages2, save_as_csv = True)

# %% [markdown]
# # 2  Data Cleaning
#
# As mentioned above, the dataframe still needs to be cleaned up.

# %% [markdown]
# ### 2.0 Read in the "uncleaned" DF

# %%
activities_df_raw = pd.read_csv(f"../data/unclean_activities.csv")
activities_df = activities_df_raw.copy()
activities_df.head()
# Out:
#                                             title  difficulty  \
# 0                           ['Üschenen Biketour']  ['medium']
# 1             ['Merängge-Cher im Kemmribodenbad']    ['easy']
# 2         ['Auf den Gurten, den Berner Hausberg']          []
# 3  ['Grenzerfahrung durch die Comb de Biaufonds']          []
# 4                    ['Blümlisalp-Lauf - Stecke']  ['medium']
#
#               sport   length    time  climb          minmax technique  \
# 0  ['Mountainbike']  23.88km  02:55h  835hm  1,171 - 1,975m   rating-
# 1        ['Hiking']   6.97km  02:10h  330hm    975 - 1,184m  rating-2
# 2        ['Hiking']   4.22km  01:10h  128hm      748 - 857m   rating-
# 3        ['Hiking']  13.62km  04:00h  475hm    618 - 1,035m   rating-
# 4       ['Running']  15.94km  05:05h  886hm    706 - 1,409m  rating-4
#
#     fitness      ID
# 0  rating-4  698705
# 1  rating-2  509375
# 2  rating-0   92457
# 3  rating-0  114222
# 4  rating-0  891249

# %% [markdown]
# ### 2.1 Check for duplicates and remove them

# %%
# check if there are duplicates
dups = activities_df.duplicated(subset=['ID'])
dups
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
# Which trails are duplicates?
pd.concat(g for _, g in activities_df.groupby('ID') if len(g) > 1)
# Out:
#                                              title difficulty       sport  \
# 2          ['Auf den Gurten, den Berner Hausberg']         []  ['Hiking']
# 24         ['Auf den Gurten, den Berner Hausberg']         []  ['Hiking']
# 3   ['Grenzerfahrung durch die Comb de Biaufonds']         []  ['Hiking']
# 26  ['Grenzerfahrung durch die Comb de Biaufonds']         []  ['Hiking']
#
#      length    time  climb        minmax technique   fitness      ID
# 2    4.22km  01:10h  128hm    748 - 857m   rating-  rating-0   92457
# 24   4.22km  01:10h  128hm    748 - 857m   rating-  rating-0   92457
# 3   13.62km  04:00h  475hm  618 - 1,035m   rating-  rating-0  114222
# 26  13.62km  04:00h  475hm  618 - 1,035m   rating-  rating-0  114222

# %%
# Remove duplicates
activities_df.drop_duplicates(subset ="ID", inplace = True)
activities_df
# Out:
#                                                               title  \
# 0                                             ['Üschenen Biketour']
# 1                               ['Merängge-Cher im Kemmribodenbad']
# 2                           ['Auf den Gurten, den Berner Hausberg']
# 3                    ['Grenzerfahrung durch die Comb de Biaufonds']
# 4                                      ['Blümlisalp-Lauf - Stecke']
# 5                                                           ['Höh']
# 6                       ['Kandersteg to Leukerbad (via Gemmipass)']
# 7                           ['Blumenweg Horneggli (Rundwanderung)']
# 8       ['Engstligenalp – Dossenseeli – Engstligenalp (Seeli-Weg)']
# 9                                                    ['Mont Sujet']
# 10                                   ['Durch die wilde Landschaft']
# 11                                             ['Rund um Rüschegg']
# 12                                           ['Allmenalp Biketour']
# 13                                             ["Walk to L'Etivaz"]
# 14                                          ['Schnitzlerweg Axalp']
# 15                                           ['Giro di Röstigrabe']
# 16                             ['Frei wie ein Vogel über der Lenk']
# 17                                ['Bergsee-Paradies am Stockhorn']
# 18                                        ['Wo der Frühling haust']
# 19                                            ['Moorweg Sparemoos']
# 20                                                ['Berschel Tour']
# 21            ['Probsteberg - einsames Grenzgebiet Bern/Solothurn']
# 22                               ['Trailrunning Rund um Adelboden']
# 23                               ['Breitlauenen - Schynige Platte']
# 25  ['Auf den Lisiberg - stadtnahe leichte Wanderung mit Aussicht']
# 27   ['Wandern dort, wo das -Vreneli ab em Guggisberg- gelebt hat']
# 28                 ['Durchs Jahr wandern - Edelweiss am Iffighorn']
# 29                               ['Wandern am Wasser - Lauenensee']
# 30                         ['Prachtswälder am Fusse des Gantrisch']
# 31                           ['Auf Panoramawegen durchs Bipperamt']
# 32                                        ['«Den Niesen geniesen»']
# 33                             ['Simmeflueh Klettersteig - Wimmis']
# 34         ['Schluchtrundweg Sigriswil - Aeschlen via Grabenmühle']
# 35                                               ['Grünenbergpass']
# 36                                       ['Durch Berns Kornkammer']
# 37                           ['Über die Greberegg zum Pochtenfall']
# 38                          ['I gloube i gange no meh a Louenesee']
# 39                                            ['Audioguide Saanen']
#
#        difficulty               sport   length    time    climb  \
# 0      ['medium']    ['Mountainbike']  23.88km  02:55h    835hm
# 1        ['easy']          ['Hiking']   6.97km  02:10h    330hm
# 2              []          ['Hiking']   4.22km  01:10h    128hm
# 3              []          ['Hiking']  13.62km  04:00h    475hm
# 4      ['medium']         ['Running']  15.94km  05:05h    886hm
# 5      ['medium']          ['Hiking']    5.3km  02:00h    141hm
# 6      ['medium']          ['Hiking']  14.64km  05:45h    545hm
# 7        ['easy']  ['Thematic route']    2.7km  01:00h    101hm
# 8      ['medium']          ['Hiking']   8.18km  02:50h    483hm
# 9      ['medium']    ['Mountainbike']  38.43km  05:49h  1,188hm
# 10  ['difficult']          ['Hiking']   9.38km  05:00h  1,631hm
# 11     ['medium']          ['Hiking']  13.32km  03:45h    490hm
# 12     ['medium']    ['Mountainbike']  21.14km  02:30h    677hm
# 13     ['medium']          ['Hiking']  18.87km  05:00h  1,251hm
# 14       ['easy']  ['Thematic route']   2.61km  01:00h    170hm
# 15     ['medium']          ['Racing']  40.77km  02:30h    864hm
# 16  ['difficult']          ['Hiking']  13.26km  05:40h  1,300hm
# 17     ['medium']          ['Hiking']   6.17km  02:20h    430hm
# 18       ['easy']          ['Hiking']   8.09km  02:24h    280hm
# 19       ['easy']  ['Thematic route']   3.39km  01:00h    130hm
# 20  ['difficult']    ['Mountainbike']  10.84km  01:40h    488hm
# 21             []          ['Hiking']  16.44km  04:45h    581hm
# 22     ['medium']    ['Trailrunning']  27.73km  05:45h  1,555hm
# 23       ['easy']          ['Hiking']   2.68km  01:30h    441hm
# 25             []          ['Hiking']   5.88km  01:30h    172hm
# 27             []          ['Hiking']   7.88km  02:15h    358hm
# 28     ['medium']          ['Hiking']  10.77km  04:20h    850hm
# 29     ['medium']          ['Hiking']   9.27km  02:40h    170hm
# 30       ['easy']          ['Hiking']   8.65km  02:40h    390hm
# 31     ['medium']          ['Hiking']  16.53km  05:15h    862hm
# 32  ['difficult']          ['Hiking']   9.27km  05:15h  1,712hm
# 33       ['easy']     ['Via ferrata']   2.09km  03:00h    767hm
# 34       ['easy']          ['Hiking']   3.84km  01:15h    124hm
# 35  ['difficult']    ['Mountainbike']   58.7km  05:30h  1,920hm
# 36     ['medium']          ['Hiking']  16.44km  04:00h    344hm
# 37     ['medium']          ['Hiking']  12.97km  04:50h    766hm
# 38     ['medium']          ['Hiking']   9.99km  02:50h    340hm
# 39       ['easy']  ['Thematic route']   1.78km  00:30h     23hm
#
#             minmax technique   fitness      ID
# 0   1,171 - 1,975m   rating-  rating-4  698705
# 1     975 - 1,184m  rating-2  rating-2  509375
# 2       748 - 857m   rating-  rating-0   92457
# 3     618 - 1,035m   rating-  rating-0  114222
# 4     706 - 1,409m  rating-4  rating-0  891249
# 5   1,170 - 1,310m  rating-3  rating-3  744918
# 6   1,383 - 2,320m  rating-2  rating-4  277605
# 7   1,767 - 1,868m  rating-2  rating-2  131614
# 8   1,937 - 2,343m  rating-4  rating-4  812684
# 9     434 - 1,383m  rating-3  rating-4   83742
# 10  1,330 - 2,940m  rating-5  rating-5   76670
# 11      715 - 941m  rating-2  rating-3   65384
# 12  1,170 - 1,789m   rating-  rating-4  698709
# 13  1,043 - 1,909m   rating-  rating-4  225655
# 14  1,521 - 1,639m  rating-2  rating-2   58522
# 15    955 - 1,408m  rating-2  rating-4  131758
# 16  1,014 - 2,079m  rating-5  rating-5   50926
# 17  1,596 - 1,798m  rating-3  rating-3   48808
# 18      527 - 806m  rating-2  rating-2  146292
# 19  1,570 - 1,679m  rating-2  rating-2   65411
# 20  1,154 - 1,601m  rating-4  rating-6  834956
# 21    640 - 1,149m   rating-  rating-0   99639
# 22  1,295 - 2,079m  rating-3  rating-3  837028
# 23  1,540 - 1,981m  rating-1  rating-2  131147
# 25      841 - 988m   rating-  rating-0  114214
# 27    805 - 1,118m   rating-  rating-0  101685
# 28  1,583 - 2,378m  rating-3  rating-4  658326
# 29  1,236 - 1,401m  rating-3  rating-2  174598
# 30    783 - 1,084m  rating-2  rating-2   48767
# 31    636 - 1,215m  rating-3  rating-4   51213
# 32    631 - 2,343m  rating-4  rating-6   50315
# 33    626 - 1,393m   rating-  rating-0  114228
# 34      765 - 885m  rating-1  rating-1  496021
# 35    561 - 1,555m  rating-4  rating-6  133924
# 36      495 - 609m  rating-1  rating-3   51169
# 37    979 - 1,650m  rating-3  rating-3   99641
# 38  1,236 - 1,433m  rating-2  rating-3  508332
# 39  1,009 - 1,029m  rating-2  rating-2  131627

# %% [markdown]
# ### 2.2 Clean Categorical Data
# - Convert columns to strings
# - Remove brackets that are in the first 3 columnns
# - Remove extra whitespace

# %%
# Converting the text columns to strings for easier handling later
activities_df[['title', 'difficulty', 'sport']] = activities_df[['title', 'difficulty', 'sport']].astype('str')

# Removing the brackets
activities_df['title'] = activities_df['title'].str.strip('[]')
activities_df['difficulty'] = activities_df['difficulty'].str.strip('[]')
activities_df['sport'] = activities_df['sport'].str.strip('[]')

# Remove extra whitespace
activities_df['title'] = pd.Series(activities_df['title']).str.replace("'", '')
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("'", '')
activities_df['sport'] = pd.Series(activities_df['sport']).str.replace("'", '')

# Remove units (km, m, h, hm, m)
activities_df['length'] = pd.Series(activities_df['length']).str.replace("km", '')
activities_df['time'] = pd.Series(activities_df['time']).str.replace("h", '')
activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("hm", '')
activities_df['minmax'] = pd.Series(activities_df['minmax']).str.replace("m", '')

# Seperate the minmax altitude into a min column and a max column
activities_df[['min','max']] = activities_df['minmax'].str.split("-",expand=True)
activities_df = activities_df.drop(columns=['minmax'])

# Organize the dataframe columns
activities_df = activities_df[['ID','title', 'difficulty', 'sport', 'length', 
                               'time', 'climb', 'min', 'max', 'technique', 'fitness']]

# Remove remaining commas to avoid issues with reading CSV file in Tableau
activities_df['title'] = pd.Series(activities_df['title']).str.replace(",", '-')

# Add ordering of the difficulty
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("easy", '1 - easy')
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("medium", '2 - medium')
activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("difficult", '3 - difficult')
activities_df['difficulty'].replace(r'^\s*$', '0 - no rating', regex=True, inplace=True)

# %%
activities_df.head(5)
# Out:
#        ID                                       title     difficulty  \
# 0  698705                           Üschenen Biketour     2 - medium
# 1  509375             Merängge-Cher im Kemmribodenbad       1 - easy
# 2   92457         Auf den Gurten- den Berner Hausberg  0 - no rating
# 3  114222  Grenzerfahrung durch die Comb de Biaufonds  0 - no rating
# 4  891249                    Blümlisalp-Lauf - Stecke     2 - medium
#
#           sport length   time climb     min     max technique   fitness
# 0  Mountainbike  23.88  02:55   835  1,171    1,975   rating-  rating-4
# 1        Hiking   6.97  02:10   330    975    1,184  rating-2  rating-2
# 2        Hiking   4.22  01:10   128    748      857   rating-  rating-0
# 3        Hiking  13.62  04:00   475    618    1,035   rating-  rating-0
# 4       Running  15.94  05:05   886    706    1,409  rating-4  rating-0

# %% [markdown]
# ### 2.3 Clean Numerical Data
#
# In order to normalize numerical data for analysis, we must preform the following steps:
#
# -  Replace missing numerical data with 0
# -  Remove commas
# -  Remove "-"
# -  Remove unnecessary words ("rating-")

# %%
activities_df['length'] = pd.Series(activities_df['length']).str.replace("-",'0')
activities_df['length'] = (activities_df['length']).astype(float)

activities_df['climb'] = pd.Series(activities_df['climb']).str.replace(",", '') 
activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("-", '0') 
activities_df['climb'] = (activities_df['climb']).astype(int)

activities_df['min'] = pd.Series(activities_df['min']).str.replace(",", '')
activities_df['min'].replace('',np.nan, inplace = True)
activities_df['min'] = activities_df['min'].fillna(0)
activities_df['min'] = (activities_df['min']).astype(int)
activities_df['max'].replace('',np.nan, inplace = True)
activities_df['max'] = activities_df['max'].fillna(0)
activities_df['max'] = pd.Series(activities_df['max']).str.replace(",", '') 

activities_df['max'] = (activities_df['max']).astype(int)

activities_df['technique'] = pd.Series(activities_df['technique']).str.replace("rating-", '')
activities_df['technique'] = pd.to_numeric(activities_df['technique'], errors='coerce')
activities_df['technique'] = pd.Series(activities_df['technique']).replace(np.nan, 0, regex = True)
activities_df['technique'] = pd.Series(activities_df['technique']).astype('int')

activities_df['fitness'] = pd.Series(activities_df['fitness']).str.replace("rating-", '')
activities_df['fitness'] = pd.to_numeric(activities_df['fitness'], errors='coerce')
activities_df['fitness'] = pd.Series(activities_df['fitness']).replace(np.nan, 0, regex = True)
activities_df['fitness'] = activities_df['fitness'].astype('int')

# %% [markdown]
# ### 2.4 Final check of DataFrame
# Double check for null values. It looks pretty good!  Now it's time to start analysis.

# %%
activities_df
# Out:
#         ID                                                        title  \
# 0   698705                                            Üschenen Biketour
# 1   509375                              Merängge-Cher im Kemmribodenbad
# 2    92457                          Auf den Gurten- den Berner Hausberg
# 3   114222                   Grenzerfahrung durch die Comb de Biaufonds
# 4   891249                                     Blümlisalp-Lauf - Stecke
# 5   744918                                                          Höh
# 6   277605                      Kandersteg to Leukerbad (via Gemmipass)
# 7   131614                          Blumenweg Horneggli (Rundwanderung)
# 8   812684      Engstligenalp – Dossenseeli – Engstligenalp (Seeli-Weg)
# 9    83742                                                   Mont Sujet
# 10   76670                                   Durch die wilde Landschaft
# 11   65384                                             Rund um Rüschegg
# 12  698709                                           Allmenalp Biketour
# 13  225655                                            "Walk to LEtivaz"
# 14   58522                                          Schnitzlerweg Axalp
# 15  131758                                           Giro di Röstigrabe
# 16   50926                             Frei wie ein Vogel über der Lenk
# 17   48808                                Bergsee-Paradies am Stockhorn
# 18  146292                                        Wo der Frühling haust
# 33       1 - easy     Via ferrata    2.09  03:00    767   626  1393
# 34       1 - easy          Hiking    3.84  01:15    124   765   885
# 35  3 - difficult    Mountainbike   58.70  05:30   1920   561  1555
# 36     2 - medium          Hiking   16.44  04:00    344   495   609
# 37     2 - medium          Hiking   12.97  04:50    766   979  1650
# 38     2 - medium          Hiking    9.99  02:50    340  1236  1433
# 39       1 - easy  Thematic route    1.78  00:30     23  1009  1029
#
#     technique  fitness
# 0           0        4
# 1           2        2
# 2           0        0
# 3           0        0
# 4           4        0
# 5           3        3
# 6           2        4
# 7           2        2
# 8           4        4
# 9           3        4
# 10          5        5
# 11          2        3
# 12          0        4
# 13          0        4
# 14          2        2
# 15          2        4
# 16          5        5
# 17          3        3
# 18          2        2
# 19          2        2
# 20          4        6
# 21          0        0
# 22          3        3
# 23          1        2
# 25          0        0
# 27          0        0
# 28          3        4
# 29          3        2
# 30          2        2
# 31          3        4
# 32          4        6
# 33          0        0
# 34          1        1
# 35          4        6
# 36          1        3
# 37          3        3
# 38          2        3
# 39          2        2

# %%
activities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 0 to 39
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          38 non-null     int64
#  1   title       38 non-null     object
#  2   difficulty  38 non-null     object
#  3   sport       38 non-null     object
#  4   length      38 non-null     float64
#  5   time        38 non-null     object
#  6   climb       38 non-null     int64
#  7   min         38 non-null     int64
#  8   max         38 non-null     int64
#  9   technique   38 non-null     int64
#  10  fitness     38 non-null     int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 3.6+ KB

# %% [markdown]
# ### 2.5 Write CSV
#
# Now that the data has been cleaned properly, let's save the dataframe to a CSV for future use.

# %%
activities_df.to_csv("../data/activities.csv", index=False)

# %% [markdown]
# ### 2.6 Functions for Data Cleaning

# %% [markdown]
# Let's again save these codes as functions to be able to run the script easily for other regions.

# %%
def clean_cat(activities_df):
    # Converting the text columns to strings for easier handling later
    activities_df[['title', 'difficulty', 'sport']] = activities_df[['title', 'difficulty', 'sport']].astype('str')

    # Removing the brackets
    activities_df['title'] = activities_df['title'].str.strip('[]')
    activities_df['difficulty'] = activities_df['difficulty'].str.strip('[]')
    activities_df['sport'] = activities_df['sport'].str.strip('[]')

    # Remove extra whitespace
    activities_df['title'] = pd.Series(activities_df['title']).str.replace("'", '')
    activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("'", '')
    activities_df['sport'] = pd.Series(activities_df['sport']).str.replace("'", '')

    # Remove units (km, m, h, hm, m)
    activities_df['length'] = pd.Series(activities_df['length']).str.replace("km", '')
    activities_df['time'] = pd.Series(activities_df['time']).str.replace("h", '')
    activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("hm", '')
    activities_df['minmax'] = pd.Series(activities_df['minmax']).str.replace("m", '')

    # Seperate the minmax altitude into a min column and a max column
    activities_df[['min','max']] = activities_df['minmax'].str.split("-",expand=True)
    activities_df = activities_df.drop(columns=['minmax'])

    # Organize the dataframe columns
    activities_df = activities_df[['ID','title', 'difficulty', 'sport', 'length', 
                                   'time', 'climb', 'min', 'max', 'technique', 'fitness']]

    # Add ordering of the difficulty
    activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("easy", '1 - easy')
    activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("medium", '2 - medium')
    activities_df['difficulty'] = pd.Series(activities_df['difficulty']).str.replace("difficult",'3 - difficult')
    activities_df['difficulty'].replace(r'^\s*$', '0 - no rating', regex=True, inplace=True)
    return activities_df

# %%
def clean_num(activities_df):
    activities_df['length'] = pd.Series(activities_df['length']).str.replace("-",'0')
    activities_df['length'] = (activities_df['length']).astype(float)

    activities_df['climb'] = pd.Series(activities_df['climb']).str.replace(",", '') 
    activities_df['climb'] = pd.Series(activities_df['climb']).str.replace("-", '0') 
    activities_df['climb'] = (activities_df['climb']).astype(int)
    
    activities_df['min'] = pd.Series(activities_df['min']).str.replace(",", '')
    activities_df['min'].replace('',np.nan, inplace = True)
    activities_df['min'] = activities_df['min'].fillna(0)
    activities_df['min'] = (activities_df['min']).astype(int)
    activities_df['max'].replace('',np.nan, inplace = True)
    activities_df['max'] = activities_df['max'].fillna(0)
    activities_df['max'] = pd.Series(activities_df['max']).str.replace(",", '') 

    activities_df['technique'] = pd.Series(activities_df['technique']).str.replace("rating-", '')
    activities_df['technique'] = pd.to_numeric(activities_df['technique'], errors='coerce')
    activities_df['technique'] = pd.Series(activities_df['technique']).replace(np.nan, 0, regex = True)
    activities_df['technique'] = pd.Series(activities_df['technique']).astype('int')

    activities_df['fitness'] = pd.Series(activities_df['fitness']).str.replace("rating-", '')
    activities_df['fitness'] = pd.to_numeric(activities_df['fitness'], errors='coerce')
    activities_df['fitness'] = pd.Series(activities_df['fitness']).replace(np.nan, 0, regex = True)
    activities_df['fitness'] = activities_df['fitness'].astype('int')
    return activities_df

# %%
def clean_time(activities_df):
    try:
        activities_df['time'] = activities_df['time'].dt.strftime('%H:%M')
    except ValueError:
        pass
    return activities_df

# %%
def clean_df(region, save_as_csv = True):
    activities_df_unclean = pd.read_csv(f"../data/unclean_activities_{region}.csv")
    activities_df_unclean.drop_duplicates(subset ="ID", inplace = True)
    activities_df = clean_cat(activities_df_unclean)
    activities_df = clean_num(activities_df)
    #clean_time(activities_df)
    
    if save_as_csv == True:
        activities_df.to_csv(f"../data/activities_{region}.csv", index=False)
        
    return activities_df

# %%
def preprocess(region, n_pages, save_as_csv = True):
    if save_as_csv == True:
        save = True
    else:
        save = False
    activities_df_unclean = create_scraped_df(region, n_pages, save_as_csv = save)
    activities_df = clean_df(region, save_as_csv = save)
        
    return activities_df, activities_df_unclean

# %% [markdown]
# Let's run the code for a new region.
# Afterwards, we hash out the code. Otherwise if you rerun the Kernel too often, there is a risk of being blocked by the website.

# %%
region_test1 = 'bern-region'
region_test2 = 'wallis'
region_test3 = 'genferseegebiet-waadtland'
region_test4 = "graubuenden"
region_test5 = 'berneroberland'
region_test6 = 'luzern-vierwaldstaettersee'
region_test7 = 'ostschweiz'
region_test8 = 'zuerich'
region_test9 = 'aargau'
region_test10 = 'jura-drei-seen-land'
region_test11 = 'tessin'
region_test12 = 'freiburg-region'
region_test13 = 'basel-region'

n_pages_test = 35
#result_test1 = preprocess(region_test1, n_pages_test,save_as_csv = True)
#result_test2 = preprocess(region_test2, n_pages_test,save_as_csv = True)
#result_test3 = preprocess(region_test3, n_pages_test,save_as_csv = True)
#result_test4 = preprocess(region_test4, n_pages_test,save_as_csv = True)
#result_test5 = preprocess(region_test5, n_pages_test,save_as_csv = True)
#result_test6 = preprocess(region_test6, n_pages_test,save_as_csv = True)
#result_test7 = preprocess(region_test7, n_pages_test,save_as_csv = True)
#result_test8 = preprocess(region_test8, n_pages_test,save_as_csv = True)
#result_test9 = preprocess(region_test9, n_pages_test,save_as_csv = True)
#result_test10 = preprocess(region_test10, n_pages_test,save_as_csv = True)
#result_test11 = preprocess(region_test11, n_pages_test,save_as_csv = True)
#result_test12 = preprocess(region_test12, n_pages_test,save_as_csv = True)
#result_test13 = preprocess(region_test13, n_pages_test,save_as_csv = True)
#result_test13[0]

# %% [markdown]
# Let's combine all the CSV region files into one DF & CSV file:

# %%
regions = ['aargau', 'basel-region', 'bern-region', 'berneroberland', 'freiburg-region', 
           'genferseegebiet-waadtland', 'graubuenden', 'jura-drei-seen-land', 'luzern-vierwaldstaettersee',
          'ostschweiz', 'tessin', 'wallis', 'zuerich']

all_act_df = pd.DataFrame()
for reg in regions:
    activities_df_reg = pd.read_csv(f"../data/activities_{reg}.csv")
    activities_df_reg['region'] = reg
    all_act_df = pd.concat([all_act_df, activities_df_reg], axis = 0)
    
all_act_df.to_csv(f"../data/activities_all.csv", index=False)

# %%
all_act_df['title'] = pd.Series(all_act_df['title']).str.replace(',', '-')
all_act_df.to_csv(f"../data/activities_all.csv", index=False)

# %% [markdown]
# # 3  Initial Data Analysis
#
# Before moving onto combining weather data with hiking trails, lets do some preliminary data analysis to see what we are working with. For that, we use the complete "bern-region" data we just scraped.

# %%
plt.style.use('seaborn-dark-palette')
rcParams['figure.figsize'] = 10, 8
activities_df_raw_br = pd.read_csv(f"../data/activities_bern-region.csv")
activities_df_br = activities_df_raw_br.copy()
activities_df_br.head()
# Out:
#        ID  \
# 0   48850
# 1   51212
# 2  870922
# 3  733527
# 4  133945
#
#                                                                  title  \
# 0                   Zum Hinterburgseeli, dem Naturwunder auf der Axalp
# 1  Zu eiszeitlichen Riesen und zur Wohnstätte steinzeitlicher Menschen
# 2                                                            Gehrihorn
# 3                                     Einzigartig: der neue Gäggersteg
# 4                                                Schwander - Lebensweg
#
#    difficulty           sport  length   time  climb   min   max  technique  \
# 0  2 - medium          Hiking   10.69  03:45    624  1521  1878          3
# 1    1 - easy          Hiking   10.50  02:40    254   459   564          2
# 2    1 - easy          Hiking    6.65  03:20   1357   771  2129          1
# 3    1 - easy          Hiking   13.36  04:00    510  1531  1720          2
# 4    1 - easy  Thematic route    3.55  01:30     86   647   735          1
#
#    fitness
# 0        3
# 1        2
# 2        0
# 3        2
# 4        2

# %% [markdown]
# ### 3.1 Data Exploration
#
# We will begin the data analysis by data exploration. By creating different data frames and removing activities with little data to improve visualizations we can get a better idea of what types of trails we are working with.
#
# Here we can see that cycling, racing, and long-distance walking are much longer than the other types of trails. Another helpful tool this DataFrame provides is that we can now view the least used trail types in the dataset. These are going to be removed for the next few analysis steps so it's easier to look at the interesting trail statistics.

# %%
# Creating a df for "Number of entries by sport type" + average tour length
sporttype = activities_df_br.groupby('sport') \
       .agg({'sport':'count', 'length':'mean'}) \
       .rename(columns={'sport':'count','length':'average_length'}) \
       .reset_index() \
       .sort_values(by=['average_length'])
sporttype
# Out:
#                           sport  count  average_length
# 13               Thematic route     30        5.363333
# 8                Nordic Walking      2        5.905000
# 12                     Snowshoe      1        8.120000
# 3                     High tour      2        8.695000
# 4                        Hiking    188        9.913830
# 11                      Running      3       10.443333
# 15                  Via ferrata      2       13.650000
# 14                 Trailrunning     12       19.826667
# 9                    Pilgrimage      4       20.372500
# 7                  Mountainbike     30       22.565333
# 5                 Kayak / Canoe      1       27.620000
# 6         Long distance cycling      3       30.960000
# 2                         E-MTB      2       33.580000
# 0                       Cycling     26       35.581923
# 1                        E-Bike      2       35.850000
# 10                       Racing      8       78.663750
# 16  long-distance walking trail      2      280.480000

# %% [markdown]
# ### 3.2 Focus on the most relevant activities
# Remove the activities, which have less than 5 entries.

# %%
analysis = activities_df_br.groupby("sport").filter(lambda x: len(x) > 10)
analysis.groupby(['sport']).size()
# Out:
# sport
# Cycling            26
# Hiking            188
# Mountainbike       30
# Thematic route     30
# Trailrunning       12
# dtype: int64

# %% [markdown]
# ### 3.3 Bar Chart Visualization
# Now that the activities with little entries are removed, a barchart of the sport types is much more readable. We can see that the most popular activity on our list of trails is hiking with more than 200 entries.

# %%
ax = analysis['sport'].value_counts().plot(kind='bar')
plt.title('Frequency of Activity types')
plt.xlabel('Type of Activity')
plt.ylabel('Count of Activity');

# %% [markdown]
# How does the picture look like by level of difficulty?

# %%
analysis['difficulty'].value_counts().plot(kind='bar')
plt.title('Number of Activities by Difficulty')
plt.xlabel('Difficulty')
plt.ylabel('Count of Activity');

# %% [markdown]
# ### 3.4 Scatter Plot Visualization
#
# The scatter plot paints an interesting picture of the trail data. First, the cycling trails are both the longest and the ones with most height difference out of the bunch. And second, it looks like all of the hiking trails fall between 2 and 20km (except for one). Perhaps this is because long distance hiking trails are considered to be "Pilgrimages"?

# %%
sns.scatterplot(    
    data=analysis,
    x="length", y="climb", hue='sport', 
    marker = "D", s=200, # set marker type and size
).set_title('Length and Distance By Sport Type')
plt.legend(loc='lower right'); # change default position of legend

# %%
# mean length for difficulty:
activities_df_br.groupby('difficulty').mean()
# Out:
#                           ID     length        climb          min  \
# difficulty
# 0 - no rating  452267.000000  12.640333   408.033333   841.966667
# 1 - easy       397930.828829   9.560450   251.378378   985.477477
# 2 - medium     432732.914286  15.402071   620.192857  1062.850000
# 3 - difficult  427644.054054  51.218108  2187.243243   835.324324
#
#                        max  technique   fitness
# difficulty
# 0 - no rating  1237.500000   0.000000  0.000000
# 1 - easy       1219.729730   1.369369  1.756757
# 2 - medium     1624.357143   2.464286  3.292857
# 3 - difficult  1879.864865   3.783784  5.351351

# %% [markdown]
# Now let's explore the data using only hiking trail data.

# %% [markdown]
# # 4 Analysis: Hiking Trails
#
# The primary interest of this analysis is hiking trail data. The following analysis will compare only hiking trails and drop the rest of the sport types.

# %%
hiking = activities_df_br[activities_df_br.sport == "Hiking"]
hiking.shape
# Out:
# (188, 11)

# %% [markdown]
# ### 4.1 Scatter plot: Length and Distance of each Activity By Difficulty

# %%
markers1 = {"1 - easy": ".", "2 - medium": "p",
           "3 - difficult":"s", "0 - no rating":"X"} #set the markers individually
sns.scatterplot(    
    data=hiking,
    x="length", y="climb", 
    hue='difficulty', # color by difficulty
    hue_order = ["1 - easy", "2 - medium", "3 - difficult", "0 - no rating"], # rearrange order of the legend
    style='difficulty', markers = markers1, # set markers
    s = 400 # size of markers
).set_title('Length and Distance By Difficulty');

# %% [markdown]
# Seems we have one "outlier" which is more than 200km long. Let's remove it to get a better view on the majority of the trails.

# %%
sns.scatterplot(    
    data=hiking[hiking.length < 200],
    x="length", y="climb", 
    hue='difficulty', # color by difficulty
    hue_order = ["1 - easy", "2 - medium", "3 - difficult", "0 - no rating"], # rearrange order of the legend
    style='difficulty', markers = markers1, # set markers
    s = 400, # size of markers
).set_title('Length and Distance By Difficulty');

# %% [markdown]
# The easier trails seem to be shorter in length and with lower elevation gain. Let's see if there is a correlation.

# %% [markdown]
# ### 4.2 Line Plot: Comparison of average Trail Length vs. Fitness Score

# %% [markdown]
# The following dataframe uses the fitness scores and compares them to the length of each trail. How correlated is the trail length to the fitness score? A new columns is added for average length.

# %%
# calculating the count by Fitness level and the average length 
fitness_length_check = hiking.groupby('fitness') \
       .agg({'fitness':'count', 'length':'mean'}) \
       .rename(columns={'fitness':'count','length':'average_length'}) \
       .reset_index()
fitness_length_check
# Out:
#    fitness  count  average_length
# 0        0     28       11.155357
# 1        1     24        5.527083
# 2        2     41        8.039024
# 3        3     51       10.359412
# 4        4     30       12.293333
# 5        5     11       12.962727
# 6        6      3       16.493333

# %% [markdown]
# The routes with no fitness rating seems quite long. Probably related to the outlier previously identified.
# For further analysis let's remove the trails without any difficulty rating and check if there is a visual clue.

# %%
fitness_length = fitness_length_check[fitness_length_check['fitness'] != 0]
plt.plot(fitness_length["fitness"], fitness_length["average_length"])
plt.ylabel('average_length')
plt.xlabel("rating_fitness")
plt.title('Hiking: Average Length by Fitness Level Rating')
#sns.linewidth = 6
#check linestyle
plt.show()

# %% [markdown]
# There seems to be a relationship indeed between fitness score and length of the hike but let's have a closer look.

# %% [markdown]
# ### 4.3 Boxplots: Difficulty vs. Elevation Gain and Length
#
# The following boxplots show how the trail data is distributed by difficulty catagory compared to both elevation gain and length. It's pretty clear that the relationship between elevation gain and difficulty is more meaningful than the relationship between distance and difficulty. My legs agree!

# %%
my_pal = {"1 - easy": "forestgreen", "2 - medium": "darkblue", "3 - difficult":"darkred", 
          "0 - no rating":"blanchedalmond"}
ax = sns.boxplot(x="difficulty", y="climb", data=hiking, 
                 order=["1 - easy", "2 - medium", "3 - difficult", "0 - no rating"],
                palette = my_pal) \
.set_title('Relationship between Trail Difficulty Rating and Elevation Gain')\

# https://matplotlib.org/2.0.2/examples/color/named_colors.html

# %%
ax = sns.boxplot(x="difficulty", y="length",showfliers = False, data=hiking, 
                 order=["1 - easy", "2 - medium", "3 - difficult", "0 - no rating"],
                palette = my_pal) \
.set_title('Relationship between Trail Difficulty Rating and Distance')

# %% [markdown]
# ### 3.6 Correlation Matrix
# Let's see what the mathematical correlations are between the four parameters: climb, length, fitness score, technique score. For that, trails without any rating will be excluded.

# %%
# remove numerical columns that are not needed and remove rows with no rating 
corr_matrix_df = hiking.drop(columns = ['min','max']).copy()
corr_matrix_df = corr_matrix_df[corr_matrix_df['difficulty'] != '0 - no rating']
# create a correlation matrix
corr_matrix = corr_matrix_df.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corr_matrix, annot = True, cmap = 'Blues');

# %%
corr_matrix_df.head()
# Out:
#        ID  \
# 0   48850
# 1   51212
# 2  870922
# 3  733527
# 5  509375
#
#                                                                  title  \
# 0                   Zum Hinterburgseeli, dem Naturwunder auf der Axalp
# 1  Zu eiszeitlichen Riesen und zur Wohnstätte steinzeitlicher Menschen
# 2                                                            Gehrihorn
# 3                                     Einzigartig: der neue Gäggersteg
# 5                                      Merängge-Cher im Kemmribodenbad
#
#    difficulty   sport  length   time  climb  technique  fitness
# 0  2 - medium  Hiking   10.69  03:45    624          3        3
# 1    1 - easy  Hiking   10.50  02:40    254          2        2
# 2    1 - easy  Hiking    6.65  03:20   1357          1        0
# 3    1 - easy  Hiking   13.36  04:00    510          2        2
# 5    1 - easy  Hiking    6.97  02:10    330          2        2

# %% [markdown]
# 'Fitness' and 'Technique' have the highest correlation among all measures.
# What about the correlation with the 'Difficulty Level'?
# We therefore convert the 'easy', 'medium', 'difficult' in numeric values and build a correlation matrix.

# %%
# add numerical column indicating the difficulty level
corr_matrix_df['difficulty_level'] = corr_matrix_df['difficulty']
corr_matrix_df.loc[corr_matrix_df['difficulty'] == '1 - easy', ['difficulty_level']] = 1
corr_matrix_df.loc[corr_matrix_df['difficulty'] == '2 - medium', ['difficulty_level']] = 2
corr_matrix_df.loc[corr_matrix_df['difficulty'] == '3 - difficult', ['difficulty_level']] = 3

# the column 'difficulty_level' will return object type which we need to convert to integers.
corr_matrix_df['difficulty_level']= corr_matrix_df['difficulty_level'].astype(str).astype(int)
#or corr_matrix_df2 = pd.to_numeric(corr_matrix_df['difficulty_level']).astype(int)
corr_matrix_df2 = corr_matrix_df.copy()
corr_matrix_df2
# Out:
#          ID  \
# 0     48850
# 1     51212
# 2    870922
# 3    733527
# 5    509375
# ..      ...
# 306  799947
# 307   62404
# 308  456685
# 311  190774
# 313  456688
#
#                                                                    title  \
# 0                     Zum Hinterburgseeli, dem Naturwunder auf der Axalp
# 1    Zu eiszeitlichen Riesen und zur Wohnstätte steinzeitlicher Menschen
# 2                                                              Gehrihorn
# 3                                       Einzigartig: der neue Gäggersteg
# 5                                        Merängge-Cher im Kemmribodenbad
# ..                                                                   ...
# 306                                            Anspruchsvolle Gipfeltour
# 307                                                       Five star walk
# 308                                                     Rundweg Hüslimad
# 311                                                   dw Schynige Platte
# 313                                                    Rundweg Fuchseren
#
#         difficulty   sport  length   time  climb  technique  fitness  \
# 0       2 - medium  Hiking   10.69  03:45    624          3        3
# 1         1 - easy  Hiking   10.50  02:40    254          2        2
# 2         1 - easy  Hiking    6.65  03:20   1357          1        0
# 3         1 - easy  Hiking   13.36  04:00    510          2        2
# 5         1 - easy  Hiking    6.97  02:10    330          2        2
# ..             ...     ...     ...    ...    ...        ...      ...
# 306  3 - difficult  Hiking   18.61  05:30   2032          6        6
# 307     2 - medium  Hiking   15.77  08:00      0          2        4
# 308     2 - medium  Hiking    3.18  01:09    189          2        3
# 311     2 - medium  Hiking    5.95  02:07    305          3        1
# 313     2 - medium  Hiking    2.95  01:06    194          2        3
#
#      difficulty_level
# 0                   2
# 1                   1
# 2                   1
# 3                   1
# 5                   1
# ..                ...
# 306                 3
# 307                 2
# 308                 2
# 311                 2
# 313                 2
#
# [162 rows x 10 columns]

# %%
corr_matrix_level = corr_matrix_df2.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corr_matrix_level, annot = True, cmap = 'Blues');

# %% [markdown]
# As we can see, the highest correlation is between the fitness level and the difficulty level, followed by the technique and the difficulty level. This was not visible in the box plot graphs above.

# %% [markdown]
# # 5 Download Trail GPS Data
#
# The next part of this notebook deals with parsing HTML tags again, however this time around we will be gathering the GPS data needed to create the snowfall alert. The GPS data for each trail is actually a list of GPS points that comprise the length of the trail, from start to summit. However, we will only be using the first GPS point in our algorithm, which is the trail-head.
#
# The Bergfex website embedds their GPS data into downloadable files, which are meant to be uploaded to a GPS device for navigation purposes. As such, the following code will automatically download each GPS file into a folder. Importantly, a sleep timer is added to replicate how a human may download these files, if the sleep timer is not added, the website will become suspicious and prevent us from downloading more files.
#
# The type of GPS file that is being downloaded is a "GPX" or "GPS Exchange Format" file, which is a special type of XML file that can be used to describe waypoints.
#
# Finally, we crosscheck with Google Earth Web App, that our downloaded GPS data is exactly what we want.

# %% [markdown]
# ### 5.1 Download Batches of GPX Files
#
# This loop uses the hike id's to navigate to each of the hike's pages. It then downloads the GPS file to the folder "gpx_files" and saves it as a filename "Unique hike id.gpx". To prevent being blocked from the page, we download the dat in small batches for all 400 activities.

# %%
# create a small subset of data for testing
"""test_id = corr_matrix_df.iloc[20:22,0]
for hike_id in test_id: 
    url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={str(hike_id)};fileType=kml"
    print(url_id)
    r = requests.get(url_id, allow_redirects=True)          # Send the request
    time.sleep(5)                                           # Include a timer to prevent blocking
    write_link = ('../gpx_files/'+ str(hike_id) + ".gpx")   # Create gpx file
    with open(write_link, 'wb') as f:
        f.write(r.content)                                  # Write data for each ID in each file"""
# Out:
# 'test_id = corr_matrix_df.iloc[20:22,0]\nfor hike_id in test_id: \n    url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={str(hike_id)};fileType=kml"\n    print(url_id)\n    r = requests.get(url_id, allow_redirects=True)          # Send the request\n    time.sleep(5)                                           # Include a timer to prevent blocking\n    write_link = (\'../gpx_files/\'+ str(hike_id) + ".gpx")   # Create gpx file\n    with open(write_link, \'wb\') as f:\n        f.write(r.content)                                  # Write data for each ID in each file'

# %% [markdown]
# Let's look at the content of one download. There are lots of data points of which the key data needs to be filtered out.

# %%
"""r.content"""
# Out:
# 'r.content'

# %% [markdown]
# ###  5.2 Extract Coordinates from GPX files
#
# Now that the GPX files have been downloaded to a local file, we can loop through them and extract the important information, which is the latitude and the longitude of the trail start.

# %%
"""list_of_trails_list = []
list_of_files = glob.glob('*gpx')                     # Create a list for each trail_id
for hike_id in test_id: 
    trail_gps_list = []
    gpx = gpxpy.parse(open('../gpx_files/'+str(hike_id)+'.gpx', 'r')) # Read content for each trail_id
    trail_gps_list.append(hike_id)
    for track in gpx.tracks: 
        trail_name = track.name                 # Track name
        trail_gps_list.append(trail_name)
        for segment in track.segments: 
            for point in segment.points: 
              lat = point.latitude              # Latitude
              trail_gps_list.append(lat)
              lon = point.longitude             # Longitude
              trail_gps_list.append(lon) 
              break
        list_of_trails_list.append(trail_gps_list)

print(list_of_trails_list)"""
# Out:
# "list_of_trails_list = []\nlist_of_files = glob.glob('*gpx')                     # Create a list for each trail_id\nfor hike_id in test_id: \n    trail_gps_list = []\n    gpx = gpxpy.parse(open('../gpx_files/'+str(hike_id)+'.gpx', 'r')) # Read content for each trail_id\n    trail_gps_list.append(hike_id)\n    for track in gpx.tracks: \n        trail_name = track.name                 # Track name\n        trail_gps_list.append(trail_name)\n        for segment in track.segments: \n            for point in segment.points: \n              lat = point.latitude              # Latitude\n              trail_gps_list.append(lat)\n              lon = point.longitude             # Longitude\n              trail_gps_list.append(lon) \n              break\n        list_of_trails_list.append(trail_gps_list)\n\nprint(list_of_trails_list)"

# %% [markdown]
# ### 5.3  Create a Dataframe and save as CSV
#
# Let's take a look at our data now that it has been extracted. It looks like everything is working as intended. Each trail has a unique ID and latitude and longitude. This data can now be saved to a CSV file which will be used for the snow alert in the next notebook.

# %%
"""trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF
trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns
trail_coords_df.to_csv('../data/trail_coords_df.csv', index=False) # save to CSV
coords_df = pd.read_csv('../data/trail_coords_df.csv')
coords_df"""
# Out:
# "trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF\ntrail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns\ntrail_coords_df.to_csv('../data/trail_coords_df.csv', index=False) # save to CSV\ncoords_df = pd.read_csv('../data/trail_coords_df.csv')\ncoords_df"

# %% [markdown]
# ### 5.4 Check GPS example

# %% [markdown]
# Let's test one ID (131699) with its coordinates (lat = 46.508190, lon = 7.358150) in Google Earth web app. It correctly displays the location.
#
# Bergfex GPS data:
# - https://www.bergfex.com/downloads/gps/?type=&id=131699&fileType=kml
#
# Google Earth web app:
# - https://earth.google.com/web/search/46%2e508190+7%2e358150/@46.50819,7.35815,2006.43177272a,699.98943356d,35y,0h,45t,0r/data=ClYaLBImGb4Ts14MQUdAIeU_pN--bh1AKhI0Ni41MDgxOTAgNy4zNTgxNTAYAiABIiYKJAlWqScNN6A1QBFWqScNN6A1wBkg4Hxc5e7VPyFlaK6dDdtZwA

# %%
"""example = coords_df[coords_df['trail_id'] == 131699]
example"""
# Out:
# "example = coords_df[coords_df['trail_id'] == 131699]\nexample"

# %%
# needed to increase the display size of the png
# %matplotlib notebook 
img = mpimg.imread('../GoogleEarth.png')
plt.rcParams['figure.dpi'] = 140
imgplot = plt.imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="896">

# %% [markdown]
# ### 5.5 Functions for GPS data

# %% [markdown]
# Now that we confirmed the GPS data, let's combine the code in functions. By adding tranches and a timer for their download, we make sure we will not be blocked by the website.

# %%
def build_tranches(region, tranch_len, save_as_csv = True):
    
    for_tranches_df = pd.read_csv(f"../data/activities_{region}.csv") # import csv file for corr. region
    
    n_tranches = math.ceil(len(for_tranches_df.iloc[:,0])/ tranch_len) # calculate # of tranches
    
    tranch_df = pd.DataFrame()
    start_t = 0
    end_t = tranch_len
    for i in range(n_tranches): # subset all IDs into different tranches and save in seperate columns of DF
        tranch_df[i] = for_tranches_df.iloc[start_t:end_t,0].reset_index(drop=True)
        start_t = start_t + tranch_len
        end_t = start_t + tranch_len
    tranch_df = tranch_df.fillna(0)
    tranch_df = tranch_df.astype(int).reset_index()
    
    if save_as_csv == True:                                    # Option to save to csv
        tranch_df.to_csv(f'../data/tranches_df_{region}.csv', index=False)
        
    return tranch_df

# %% [markdown]
# Build tranches for each region.

# %%
regions = ['aargau', 'basel-region', 'bern-region', 'berneroberland', 'freiburg-region', 
           'genferseegebiet-waadtland', 'graubuenden', 'jura-drei-seen-land', 'luzern-vierwaldstaettersee',
          'ostschweiz', 'tessin', 'wallis', 'zuerich']
for reg in regions:
    build_tranches(reg, 70, save_as_csv = True)

# %% [markdown]
# Create a function that gets the GPX data for each regions based on the predefined tranches.

# %%
def get_gpx_data_new(region, save_as_csv = True):
    
    start_time = time.time()
    
    for_gpx_df = pd.read_csv(f"../data/tranches_df_{region}.csv") # import csv file for corr. region
    cols = for_gpx_df.columns.tolist() # define column names that need to be looped through
    cols = cols[2:] # take out index column
    
    list_of_trails_list = []
    
    for col in cols:
        # download the gpx files for each trail_id
        ids_df = for_gpx_df[col]
        ids_df = ids_df.loc[(ids_df != 0)] # filter out non-valid IDs
        for ids in ids_df: 
            url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={str(ids)};fileType=kml"
            r = requests.get(url_id, allow_redirects=True)    # Send the request
            write_link = ('../gpx_files/'+ str(ids) + ".gpx") # Create gpx file
            with open(write_link, 'wb') as f:
                f.write(r.content)                            # Write data for each ID in each file

            # extract the trail_id, name of the hike, lat, lon from GPX files
            trail_gps_list = []
            gpx = gpxpy.parse(open('../gpx_files/'+str(ids)+'.gpx', 'r')) # Read content for each trail_id
            trail_gps_list.append(ids)
            for track in gpx.tracks: 
                trail_name = track.name                 # Track name
                trail_gps_list.append(trail_name)
                for segment in track.segments: 
                    for point in segment.points: 
                      lat = point.latitude              # Latitude
                      trail_gps_list.append(lat)
                      lon = point.longitude             # Longitude
                      trail_gps_list.append(lon) 
                      break
                list_of_trails_list.append(trail_gps_list)
        #col2 = str(col + 1)
        #print(f'Tranch #{col2} is done.')
        time.sleep(1500) 
    
    trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF
    trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns
    if save_as_csv == True:                                    # Option to save to csv
        trail_coords_df.to_csv(f'../data/trail_coords_df_{region}_complete.csv', index=False)
    print("-- {0} seconds -- for {1} tranches".format(time.time() - start_time, len(cols))) # Record time needed
    
    return trail_coords_df

# %%
def get_gpx_data_remaining(df_remaining, tranch_len, save_as_csv = True):
    
    start_time = time.time()
    
    n_tranches = math.ceil(len(df_remaining.iloc[:,0])/ tranch_len) # calculate # of tranches
    
    tranch_df = pd.DataFrame()
    start_t = 0
    end_t = tranch_len
    for i in range(n_tranches): # subset all IDs into different tranches and save in seperate columns of DF
        tranch_df[i] = df_remaining.iloc[start_t:end_t,1].reset_index(drop=True)
        start_t = start_t + tranch_len
        end_t = start_t + tranch_len
    tranch_df = tranch_df.fillna(0)
    tranch_df = tranch_df.astype(int).reset_index()
    
    if save_as_csv == True:                                    # Option to save to csv
        tranch_df.to_csv(f'../data/tranches_df_remaining.csv', index=False)
        
    for_gpx_df =  tranch_df # import csv file for corr. region
    cols = for_gpx_df.columns.tolist() # define column names that need to be looped through
    cols = cols[1:] # take out index column
    
    list_of_trails_list = []
    
    for col in cols:
        # download the gpx files for each trail_id
        ids_df = for_gpx_df[col]
        ids_df = ids_df.loc[(ids_df != 0)] # filter out non-valid IDs
        for ids in ids_df: 
            url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={str(ids)};fileType=kml"
            r = requests.get(url_id, allow_redirects=True)    # Send the request
            write_link = ('../gpx_files/'+ str(ids) + ".gpx") # Create gpx file
            with open(write_link, 'wb') as f:
                f.write(r.content)                            # Write data for each ID in each file

            # extract the trail_id, name of the hike, lat, lon from GPX files
            trail_gps_list = []
            gpx = gpxpy.parse(open('../gpx_files/'+str(ids)+'.gpx', 'r')) # Read content for each trail_id
            trail_gps_list.append(ids)
            for track in gpx.tracks: 
                trail_name = track.name                 # Track name
                trail_gps_list.append(trail_name)
                for segment in track.segments: 
                    for point in segment.points: 
                      lat = point.latitude              # Latitude
                      trail_gps_list.append(lat)
                      lon = point.longitude             # Longitude
                      trail_gps_list.append(lon) 
                      break
                list_of_trails_list.append(trail_gps_list)
        time.sleep(1300) 
    
    trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF
    trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns
    if save_as_csv == True:                                    # Option to save to csv
        trail_coords_df.to_csv(f'../data/trail_coords_df_remaining_complete.csv', index=False)
    print("-- {0} seconds -- for {1} tranches".format(time.time() - start_time, len(cols))) # Record time needed
    
    return trail_coords_df

# %%
#get_gpx_data_new('jura-drei-seen-land', save_as_csv = True)

# %%
def get_gpx_data(region, tranch_len):
    
    build_tranches(region, tranch_len, save_as_csv = True)
    trail_coords_df = get_gpx_data_new(region, save_as_csv = True)
 
    return trail_coords_df

# %% [markdown]
# Let's test it with our 'bern-region' download.
#
# NOTE:
# - with 2 / 5 seconds / 10 tranch size blocked after 18 files / 2 tranches
# - with 2 / 10 seconds / 8 tranch size blocked after 62 files / 6 tranches

# %%
def get_gpx_data_tranch(tranch_df, tranch_n, save_as_csv = True):
    
    start_time = time.time()
    
    list_of_trails_list = []
    
    # download the gpx files for each trail_id
    ids_df = tranch_df[tranch_n]
    ids_df = ids_df[ids_df[tranch_n] != 0]
    for ids in ids_df: 
        url_id = f"https://www.bergfex.com/downloads/gps/?type=&id={str(ids)};fileType=kml"
        #print(url_id)
        r = requests.get(url_id, allow_redirects=True)    # Send the request
        time.sleep(2)                                     # Include a timer to prevent blocking
        write_link = ('../gpx_files/'+ str(ids) + ".gpx") # Create gpx file
        with open(write_link, 'wb') as f:
            f.write(r.content)                            # Write data for each ID in each file

    # extract the trail_id, name of the hike, lat, lon from GPX files
    list_of_files = glob.glob('*gpx')                     # Create a list for each trail_id
    for ids in ids_df: 
        trail_gps_list = []
        gpx = gpxpy.parse(open('../gpx_files/'+str(ids)+'.gpx', 'r')) # Read content for each trail_id
        trail_gps_list.append(ids)
        for track in gpx.tracks: 
            trail_name = track.name                 # Track name
            trail_gps_list.append(trail_name)
            for segment in track.segments: 
                for point in segment.points: 
                  lat = point.latitude              # Latitude
                  trail_gps_list.append(lat)
                  lon = point.longitude             # Longitude
                  trail_gps_list.append(lon) 
                  break
            list_of_trails_list.append(trail_gps_list)

    trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF
    trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns
    if save_as_csv == True:                                    # Option to save to csv
        trail_coords_df.to_csv(f'../data/trail_coords_df_{tranch_n}_all.csv', index=False)
    print("-- {0} seconds -- for tranch #{1}".format(time.time() - start_time, tranch_n)) # Record time needed
    return trail_coords_df

# %%
def gather_in_df(ids_df, save_as_csv = True):
    start_time = time.time()
    list_of_trails_list = []
    for ids in ids_df: 
        trail_gps_list = []
        gpx = gpxpy.parse(open('../gpx_files/'+str(ids)+'.gpx', 'r')) # Read content for each trail_id
        trail_gps_list.append(ids)
        for track in gpx.tracks: 
            trail_name = track.name                 # Track name
            trail_gps_list.append(trail_name)
            for segment in track.segments: 
                for point in segment.points: 
                  lat = point.latitude              # Latitude
                  trail_gps_list.append(lat)
                  lon = point.longitude             # Longitude
                  trail_gps_list.append(lon) 
                  break
            list_of_trails_list.append(trail_gps_list)

    trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF
    trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns
    if save_as_csv == True:                                    # Option to save to csv
        trail_coords_df.to_csv(f'../data/trail_coords_df_all.csv', index=False)
    print("-- {0} seconds --".format(time.time() - start_time)) # Record time needed
    return trail_coords_df

# %%
def gather_in_act_df(activities_df, save_as_csv = True):
    start_time = time.time()
    list_of_trails_list = []
    for ids in activities_df['ID']: 
        try:
            gpx = gpxpy.parse(open('../gpx_files/'+str(ids)+'.gpx', 'r')) # Read content for each trail_id
            trail_gps_list = []
            trail_gps_list.append(ids)
            for track in gpx.tracks: 
                trail_name = track.name                 # Track name
                trail_gps_list.append(trail_name)
                for segment in track.segments: 
                    for point in segment.points: 
                      lat = point.latitude              # Latitude
                      trail_gps_list.append(lat)
                      lon = point.longitude             # Longitude
                      trail_gps_list.append(lon) 
                      break
                list_of_trails_list.append(trail_gps_list)
        except:
            trail_gps_list = [0,0,0,0]
            list_of_trails_list.append(trail_gps_list)
            
    trail_coords_df = pd.DataFrame(list_of_trails_list)        # save to DF
    trail_coords_df.columns=['trail_id', 'name', 'lat', 'lon'] # name the columns
    if save_as_csv == True:                                    # Option to save to csv
        trail_coords_df.to_csv(f'../data/trail_coords_df_all_test.csv', index=False)
    print("-- {0} seconds --".format(time.time() - start_time)) # Record time needed
    return trail_coords_df

# %%
all_act_df = pd.read_csv(f"../data/activities_all.csv")
gpx_all = gather_in_act_df(all_act_df, save_as_csv = True)
all_act_gpx = all_act_df.merge(gpx_all, how="left", left_on = 'ID', right_on = "trail_id", )
all_act_gpx.to_csv(f"../data/activities_all_gpx.csv", index=False)
filt_rem = all_act_gpx[all_act_gpx['trail_id'].isnull()]
filt_rem
# Out:
# -- 15.53521990776062 seconds --
#            ID                                                   title  \
# 737    301337                     Panorama-Bergwanderung Grimmiwasser
# 751    859945                 Lauenen – Walliser Wispile (1982 M.ü.M)
# 752   1040660  Von Basel zum Mont Blanc  Etappe 8: Sonceboz–Chasseral
# 753     48769            Durch Auenwälder zu einem imposanten Schloss
# 754    709668                                      Jegertosse-Fisialp
# ...       ...                                                     ...
# 3792   347324                                9 km round to eschenberg
# 3793   860559                                                  Trails
# 3794   886876      2001004 Andelfingen Schloss  1-1 km  + 41 m  -16 m
# 3795   569711               Schaffhausen - Rheinfall - Jestetten (DE)
# 3796   500644                                        Wetzikon- Zürich
#
#          difficulty           sport  length   time  climb   min     max  \
# 737      2 - medium  Thematic route   11.46  04:00    674  1222  1843.0
# 751      2 - medium        Ski tour    4.54  02:05    743  1239  1982.0
# 752   3 - difficult          Hiking   15.94  05:15   1020   652  1607.0
# 753        1 - easy          Hiking   10.43  02:30    110   482   694.0
# 754      2 - medium          Hiking   12.26  05:50    988  1170  2157.0
# ...             ...             ...     ...    ...    ...   ...     ...
# 3792  0 - no rating          Hiking    8.90  01:31    214   440   589.0
# 3793     2 - medium    Mountainbike   39.85  02:26    863   451   824.0
# 3794       1 - easy          Hiking    1.10      -      0   392   392.0
# 3795     2 - medium          Hiking   18.69  04:07    786   353   440.0
# 3796  0 - no rating          Hiking    2.30  00:50      8   588   596.0
#
#       technique  fitness          region  trail_id name  lat  lon
# 737           3        4  berneroberland       NaN  NaN  NaN  NaN
# 751           3        3  berneroberland       NaN  NaN  NaN  NaN
# 752           1        5  berneroberland       NaN  NaN  NaN  NaN
# 753           2        2  berneroberland       NaN  NaN  NaN  NaN
# 754           4        4  berneroberland       NaN  NaN  NaN  NaN
# ...         ...      ...             ...       ...  ...  ...  ...
# 3792          3        3         zuerich       NaN  NaN  NaN  NaN
# 3793          5        4         zuerich       NaN  NaN  NaN  NaN
# 3794          1        1         zuerich       NaN  NaN  NaN  NaN
# 3795          2        5         zuerich       NaN  NaN  NaN  NaN
# 3796          0        0         zuerich       NaN  NaN  NaN  NaN
#
# [2924 rows x 16 columns]

# %%
current_gpx = pd.read_csv(f"../data/activities_all_gpx.csv")
current_gpx.shape
# Out:
# (3797, 16)

# %%
filt_ids = filt_rem.iloc[:276,0].reset_index()
get_gpx_data_remaining(filt_ids, tranch_len = 69, save_as_csv = True)
# Out:
# ---------------------------------------------------------------------------
# XMLSyntaxError                            Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/gpxpy/parser.py in parse(self, version)
#     131                 self.xml = cast(str, self.xml.encode('utf-8'))
# --> 132                 root = mod_etree.XML(self.xml, mod_etree.XMLParser(remove_comments=True))
#     133             else:
#
# src/lxml/etree.pyx in lxml.etree.XML()
#
# src/lxml/parser.pxi in lxml.etree._parseMemoryDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDoc()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDoc()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/parser.pxi in lxml.etree._raiseParseError()
#
# XMLSyntaxError: Start tag expected, '<' not found, line 1, column 1 (<string>, line 1)
#
# The above exception was the direct cause of the following exception:
#
# GPXXMLSyntaxException                     Traceback (most recent call last)
# <ipython-input-87-f09a5d0ffd4f> in <module>
#       1 filt_ids = filt_rem.iloc[:280,0].reset_index()
# ----> 2 get_gpx_data_remaining(filt_ids, tranch_len = 70, save_as_csv = True)
#
# <ipython-input-86-c08011a01429> in get_gpx_data_remaining(df_remaining, tranch_len, save_as_csv)
#      37             # extract the trail_id, name of the hike, lat, lon from GPX files
#      38             trail_gps_list = []
# ---> 39             gpx = gpxpy.parse(open('../gpx_files/'+str(ids)+'.gpx', 'r')) # Read content for each trail_id
#      40             trail_gps_list.append(ids)
#      41             for track in gpx.tracks:
#
# /opt/anaconda3/lib/python3.8/site-packages/gpxpy/__init__.py in parse(xml_or_file, version)
#      37     parser = mod_parser.GPXParser(xml_or_file)
#      38
# ---> 39     return parser.parse(version)
#
# /opt/anaconda3/lib/python3.8/site-packages/gpxpy/parser.py in parse(self, version)
#     144             # But, if the user needs the original exception (lxml or ElementTree)
#     145             # it is available with GPXXMLSyntaxException.original_exception:
# --> 146             raise mod_gpx.GPXXMLSyntaxException('Error parsing XML: %s' % str(e), e)
#     147
#     148         if root is None:
#
# GPXXMLSyntaxException: Error parsing XML: Start tag expected, '<' not found, line 1, column 1 (<string>, line 1)

# %%
https://www.bergfex.com/downloads/gps/?type=&id=162906;fileType=kml

# %% [markdown]
# # CONTINUE IN NOTEBOOK II
